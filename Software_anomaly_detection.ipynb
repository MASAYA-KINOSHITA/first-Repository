# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host',]
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.005712	eval-error:0.005766
#
# [1]	train-error:0.002665	eval-error:0.002676
#
# [2]	train-error:0.005993	eval-error:0.006181
#
# [3]	train-error:0.00609	eval-error:0.006307
#
# [4]	train-error:0.005999	eval-error:0.006178
#
# [5]	train-error:0.005972	eval-error:0.006153
#
# [6]	train-error:0.005977	eval-error:0.006147
#
# [7]	train-error:0.005537	eval-error:0.005684
#
# [8]	train-error:0.004385	eval-error:0.004538
#
# [9]	train-error:0.003	eval-error:0.002995
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.6825310982727848e-06, 'max_depth': 4, 'min_child_weight': 0.4013012782472487, 'subsample': 0.8500000000000001}, logloss: 0.2057
# [0]	train-error:0.001374	eval-error:0.001466
#
# [1]	train-error:0.00115	eval-error:0.001239
#
# [2]	train-error:0.003144	eval-error:0.003312
#
# [3]	train-error:0.001809	eval-error:0.001917
#
# [4]	train-error:0.002133	eval-error:0.002313
#
# [5]	train-error:0.001412	eval-error:0.001554
#
# [6]	train-error:0.001557	eval-error:0.001695
#
# [7]	train-error:0.001332	eval-error:0.001445
#
# [8]	train-error:0.001273	eval-error:0.001377
#
# [9]	train-error:0.001121	eval-error:0.001228
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.957304354532163e-05, 'max_depth': 6, 'min_child_weight': 8.908899062372202, 'subsample': 0.9}, logloss: 0.2009
# [0]	train-error:0.001341	eval-error:0.001448
#
# [1]	train-error:0.001148	eval-error:0.001257
#
# [2]	train-error:0.003459	eval-error:0.003686
#
# [3]	train-error:0.001712	eval-error:0.00189
#
# [4]	train-error:0.001701	eval-error:0.00186
#
# [5]	train-error:0.001185	eval-error:0.001271
#
# [6]	train-error:0.001007	eval-error:0.001121
#
# [7]	train-error:0.001088	eval-error:0.001203
#
# [8]	train-error:0.001063	eval-error:0.001183
#
# [9]	train-error:0.001044	eval-error:0.001167
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.1032284112518052e-06, 'max_depth': 6, 'min_child_weight': 1.9009387448411696, 'subsample': 0.7000000000000001}, logloss: 0.2010
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.006241	eval-error:0.006414
#
# [2]	train-error:0.007748	eval-error:0.007973
#
# [3]	train-error:0.007819	eval-error:0.008036
#
# [4]	train-error:0.007995	eval-error:0.008238
#
# [5]	train-error:0.007963	eval-error:0.00819
#
# [6]	train-error:0.007965	eval-error:0.008192
#
# [7]	train-error:0.00732	eval-error:0.007542
#
# [8]	train-error:0.007161	eval-error:0.007341
#
# [9]	train-error:0.007103	eval-error:0.007304
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.06615195544040704, 'max_depth': 3, 'min_child_weight': 0.11891361509196213, 'subsample': 0.75}, logloss: 0.2093
# [0]	train-error:0.001922	eval-error:0.002179
#
# [1]	train-error:0.000717	eval-error:0.000809
#
# [2]	train-error:0.000547	eval-error:0.000614
#
# [3]	train-error:0.000498	eval-error:0.000562
#
# [4]	train-error:0.000498	eval-error:0.000594
#
# [5]	train-error:0.000477	eval-error:0.000551
#
# [6]	train-error:0.000463	eval-error:0.000541
#
# [7]	train-error:0.000384	eval-error:0.000471
#
# [8]	train-error:0.000357	eval-error:0.00043
#
# [9]	train-error:0.000378	eval-error:0.000446
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.0375273828921462e-08, 'max_depth': 9, 'min_child_weight': 0.1282718834582236, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000816	eval-error:0.000906
#
# [1]	train-error:0.000754	eval-error:0.000825
#
# [2]	train-error:0.001762	eval-error:0.00193
#
# [3]	train-error:0.00143	eval-error:0.001536
#
# [4]	train-error:0.000989	eval-error:0.001078
#
# [5]	train-error:0.000793	eval-error:0.000863
#
# [6]	train-error:0.000988	eval-error:0.001072
#
# [7]	train-error:0.000715	eval-error:0.000761
#
# [8]	train-error:0.000721	eval-error:0.000793
#
# [9]	train-error:0.000699	eval-error:0.000782
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.160224469294315e-05, 'max_depth': 7, 'min_child_weight': 0.3430557757301517, 'subsample': 0.65}, logloss: 0.2000
# [0]	train-error:0.001016	eval-error:0.001124
#
# [1]	train-error:0.001045	eval-error:0.001155
#
# [2]	train-error:0.001534	eval-error:0.001677
#
# [3]	train-error:0.000724	eval-error:0.000779
#
# [4]	train-error:0.000757	eval-error:0.000818
#
# [5]	train-error:0.000706	eval-error:0.000759
#
# [6]	train-error:0.000905	eval-error:0.001008
#
# [7]	train-error:0.000673	eval-error:0.000759
#
# [8]	train-error:0.000692	eval-error:0.000793
#
# [9]	train-error:0.000627	eval-error:0.000711
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 2.5972187845981515e-07, 'max_depth': 7, 'min_child_weight': 0.1555934971739857, 'subsample': 0.9500000000000001}, logloss: 0.1999
# [0]	train-error:0.002481	eval-error:0.002503
#
# [1]	train-error:0.002118	eval-error:0.002112
#
# [2]	train-error:0.004234	eval-error:0.004398
#
# [3]	train-error:0.00442	eval-error:0.004554
#
# [4]	train-error:0.003648	eval-error:0.00391
#
# [5]	train-error:0.003658	eval-error:0.003908
#
# [6]	train-error:0.002482	eval-error:0.002687
#
# [7]	train-error:0.002109	eval-error:0.002334
#
# [8]	train-error:0.001228	eval-error:0.001359
#
# [9]	train-error:0.001164	eval-error:0.001285
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.8368854067783904e-06, 'max_depth': 5, 'min_child_weight': 6.5034150743572665, 'subsample': 0.8500000000000001}, logloss: 0.2027
# [0]	train-error:0.002247	eval-error:0.002238
#
# [1]	train-error:0.002353	eval-error:0.00232
#
# [2]	train-error:0.004246	eval-error:0.004411
#
# [3]	train-error:0.003511	eval-error:0.003765
#
# [4]	train-error:0.001274	eval-error:0.001416
#
# [5]	train-error:0.001507	eval-error:0.001584
#
# [6]	train-error:0.001252	eval-error:0.001377
#
# [7]	train-error:0.001196	eval-error:0.001334
#
# [8]	train-error:0.001219	eval-error:0.001368
#
# [9]	train-error:0.001256	eval-error:0.001387
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.005321931392786493, 'max_depth': 5, 'min_child_weight': 1.2417388443263333, 'subsample': 0.6000000000000001}, logloss: 0.2024
# [0]	train-error:0.001025	eval-error:0.001133
#
# [1]	train-error:0.001014	eval-error:0.001155
#
# [2]	train-error:0.00153	eval-error:0.001661
#
# [3]	train-error:0.00073	eval-error:0.000788
#
# [4]	train-error:0.000771	eval-error:0.000834
#
# [5]	train-error:0.000727	eval-error:0.000791
#
# [6]	train-error:0.0009	eval-error:0.000983
#
# [7]	train-error:0.000682	eval-error:0.000754
#
# [8]	train-error:0.000721	eval-error:0.000827
#
# [9]	train-error:0.000629	eval-error:0.000711
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 3.009245844577013e-08, 'max_depth': 7, 'min_child_weight': 0.23890022299799168, 'subsample': 0.65}, logloss: 0.2000
# [0]	train-error:0.001337	eval-error:0.001441
#
# [1]	train-error:0.00114	eval-error:0.001235
#
# [2]	train-error:0.00312	eval-error:0.003296
#
# [3]	train-error:0.001795	eval-error:0.001894
#
# [4]	train-error:0.002115	eval-error:0.002261
#
# [5]	train-error:0.001371	eval-error:0.001459
#
# [6]	train-error:0.001557	eval-error:0.001654
#
# [7]	train-error:0.001328	eval-error:0.001427
#
# [8]	train-error:0.001307	eval-error:0.001402
#
# [9]	train-error:0.001183	eval-error:0.001269
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.4631018461766253e-06, 'max_depth': 6, 'min_child_weight': 0.23555900278433747, 'subsample': 0.8}, logloss: 0.2009
# [0]	train-error:0.005716	eval-error:0.00577
#
# [1]	train-error:0.002697	eval-error:0.002707
#
# [2]	train-error:0.005989	eval-error:0.006171
#
# [3]	train-error:0.006085	eval-error:0.006305
#
# [4]	train-error:0.005962	eval-error:0.006137
#
# [5]	train-error:0.005993	eval-error:0.006167
#
# [6]	train-error:0.005989	eval-error:0.006167
#
# [7]	train-error:0.005481	eval-error:0.005639
#
# [8]	train-error:0.004537	eval-error:0.00471
#
# [9]	train-error:0.003016	eval-error:0.003004
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0019488371385144648, 'max_depth': 4, 'min_child_weight': 2.410425188390432, 'subsample': 0.75}, logloss: 0.2057
# [0]	train-error:0.005715	eval-error:0.005766
#
# [1]	train-error:0.002668	eval-error:0.002673
#
# [2]	train-error:0.005991	eval-error:0.006176
#
# [3]	train-error:0.006088	eval-error:0.006312
#
# [4]	train-error:0.00596	eval-error:0.006106
#
# [5]	train-error:0.00554	eval-error:0.005705
#
# [6]	train-error:0.00564	eval-error:0.005809
#
# [7]	train-error:0.004391	eval-error:0.004506
#
# [8]	train-error:0.002769	eval-error:0.002746
#
# [9]	train-error:0.002747	eval-error:0.002735
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.1282031564241256, 'max_depth': 4, 'min_child_weight': 0.5142841213417049, 'subsample': 0.7000000000000001}, logloss: 0.2054
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006242	eval-error:0.006418
#
# [2]	train-error:0.007748	eval-error:0.007973
#
# [3]	train-error:0.007819	eval-error:0.008036
#
# [4]	train-error:0.007371	eval-error:0.007612
#
# [5]	train-error:0.007344	eval-error:0.00756
#
# [6]	train-error:0.00797	eval-error:0.008199
#
# [7]	train-error:0.007341	eval-error:0.007556
#
# [8]	train-error:0.007172	eval-error:0.00735
#
# [9]	train-error:0.00664	eval-error:0.006819
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.19131671966898872, 'max_depth': 3, 'min_child_weight': 0.5737267270185505, 'subsample': 0.8}, logloss: 0.2094
# [0]	train-error:0.005715	eval-error:0.005768
#
# [1]	train-error:0.002555	eval-error:0.002492
#
# [2]	train-error:0.005993	eval-error:0.006169
#
# [3]	train-error:0.006073	eval-error:0.006289
#
# [4]	train-error:0.005969	eval-error:0.006147
#
# [5]	train-error:0.005985	eval-error:0.00616
#
# [6]	train-error:0.005979	eval-error:0.006153
#
# [7]	train-error:0.005625	eval-error:0.005802
#
# [8]	train-error:0.004549	eval-error:0.004726
#
# [9]	train-error:0.002824	eval-error:0.002775
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0040516254197631675, 'max_depth': 4, 'min_child_weight': 3.1035259571618923, 'subsample': 0.8}, logloss: 0.2055
# [0]	train-error:0.005716	eval-error:0.00577
#
# [1]	train-error:0.002555	eval-error:0.002488
#
# [2]	train-error:0.005994	eval-error:0.006171
#
# [3]	train-error:0.006073	eval-error:0.006287
#
# [4]	train-error:0.00596	eval-error:0.006142
#
# [5]	train-error:0.005983	eval-error:0.006162
#
# [6]	train-error:0.005981	eval-error:0.006165
#
# [7]	train-error:0.005487	eval-error:0.005648
#
# [8]	train-error:0.004552	eval-error:0.004733
#
# [9]	train-error:0.002827	eval-error:0.002782
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0015705006720728011, 'max_depth': 4, 'min_child_weight': 3.604912898858796, 'subsample': 0.75}, logloss: 0.2055
# [0]	train-error:0.000807	eval-error:0.000868
#
# [1]	train-error:0.000691	eval-error:0.000768
#
# [2]	train-error:0.000862	eval-error:0.000958
#
# [3]	train-error:0.000933	eval-error:0.001015
#
# [4]	train-error:0.000825	eval-error:0.000918
#
# [5]	train-error:0.000906	eval-error:0.000988
#
# [6]	train-error:0.000862	eval-error:0.000956
#
# [7]	train-error:0.000653	eval-error:0.000743
#
# [8]	train-error:0.000655	eval-error:0.000741
#
# [9]	train-error:0.000474	eval-error:0.000521
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.009666335291332328, 'max_depth': 8, 'min_child_weight': 4.400487894438505, 'subsample': 0.65}, logloss: 0.1994
# [0]	train-error:0.00078	eval-error:0.000847
#
# [1]	train-error:0.000721	eval-error:0.000829
#
# [2]	train-error:0.000841	eval-error:0.000938
#
# [3]	train-error:0.000955	eval-error:0.001065
#
# [4]	train-error:0.000815	eval-error:0.000924
#
# [5]	train-error:0.000877	eval-error:0.000976
#
# [6]	train-error:0.00086	eval-error:0.000958
#
# [7]	train-error:0.000664	eval-error:0.000759
#
# [8]	train-error:0.000617	eval-error:0.000707
#
# [9]	train-error:0.000479	eval-error:0.000557
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0006070581111231721, 'max_depth': 8, 'min_child_weight': 1.456534304494728, 'subsample': 0.6000000000000001}, logloss: 0.1995
# [0]	train-error:0.00638	eval-error:0.006575
#
# [1]	train-error:0.006555	eval-error:0.006733
#
# [2]	train-error:0.006173	eval-error:0.006366
#
# [3]	train-error:0.00269	eval-error:0.002773
#
# [4]	train-error:0.002479	eval-error:0.002494
#
# [5]	train-error:0.002647	eval-error:0.002698
#
# [6]	train-error:0.004936	eval-error:0.00522
#
# [7]	train-error:0.002568	eval-error:0.002712
#
# [8]	train-error:0.001686	eval-error:0.001763
#
# [9]	train-error:0.002036	eval-error:0.002125
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.00023355408226839608, 'max_depth': 4, 'min_child_weight': 8.56772666071484, 'subsample': 0.75}, logloss: 0.2055
# [0]	train-error:0.000845	eval-error:0.000924
#
# [1]	train-error:0.000826	eval-error:0.000886
#
# [2]	train-error:0.001334	eval-error:0.001464
#
# [3]	train-error:0.000917	eval-error:0.001001
#
# [4]	train-error:0.001031	eval-error:0.001101
#
# [5]	train-error:0.000955	eval-error:0.001013
#
# [6]	train-error:0.000964	eval-error:0.001053
#
# [7]	train-error:0.000793	eval-error:0.000845
#
# [8]	train-error:0.000665	eval-error:0.00072
#
# [9]	train-error:0.000548	eval-error:0.0006
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0001577220674719471, 'max_depth': 8, 'min_child_weight': 0.6998785323248696, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.001991	eval-error:0.002247
#
# [1]	train-error:0.000701	eval-error:0.000816
#
# [2]	train-error:0.000591	eval-error:0.000675
#
# [3]	train-error:0.000533	eval-error:0.000643
#
# [4]	train-error:0.000549	eval-error:0.000632
#
# [5]	train-error:0.000461	eval-error:0.000548
#
# [6]	train-error:0.000455	eval-error:0.000526
#
# [7]	train-error:0.000421	eval-error:0.000485
#
# [8]	train-error:0.000407	eval-error:0.000467
#
# [9]	train-error:0.000401	eval-error:0.000469
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.01774720251865932, 'max_depth': 9, 'min_child_weight': 4.823356145924708, 'subsample': 0.8500000000000001}, logloss: 0.1991
# [0]	train-error:0.002007	eval-error:0.00227
#
# [1]	train-error:0.000711	eval-error:0.000827
#
# [2]	train-error:0.000552	eval-error:0.00065
#
# [3]	train-error:0.000501	eval-error:0.000619
#
# [4]	train-error:0.000544	eval-error:0.00063
#
# [5]	train-error:0.000479	eval-error:0.000562
#
# [6]	train-error:0.000464	eval-error:0.000535
#
# [7]	train-error:0.000436	eval-error:0.000526
#
# [8]	train-error:0.00042	eval-error:0.000489
#
# [9]	train-error:0.000414	eval-error:0.000474
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.6995659243615981, 'max_depth': 9, 'min_child_weight': 5.773191248864288, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.00193	eval-error:0.0022
#
# [1]	train-error:0.000639	eval-error:0.000716
#
# [2]	train-error:0.000551	eval-error:0.000625
#
# [3]	train-error:0.000497	eval-error:0.00058
#
# [4]	train-error:0.000502	eval-error:0.000589
#
# [5]	train-error:0.000442	eval-error:0.000507
#
# [6]	train-error:0.000449	eval-error:0.000489
#
# [7]	train-error:0.000404	eval-error:0.000462
#
# [8]	train-error:0.000409	eval-error:0.000487
#
# [9]	train-error:0.000384	eval-error:0.000446
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 6.105210491117312e-08, 'max_depth': 9, 'min_child_weight': 0.12200850525121404, 'subsample': 0.9500000000000001}, logloss: 0.1990
# [0]	train-error:0.001926	eval-error:0.002184
#
# [1]	train-error:0.000649	eval-error:0.000732
#
# [2]	train-error:0.000532	eval-error:0.000594
#
# [3]	train-error:0.000487	eval-error:0.000564
#
# [4]	train-error:0.000502	eval-error:0.000575
#
# [5]	train-error:0.000466	eval-error:0.000532
#
# [6]	train-error:0.000431	eval-error:0.000496
#
# [7]	train-error:0.000394	eval-error:0.000458
#
# [8]	train-error:0.000388	eval-error:0.000442
#
# [9]	train-error:0.000383	eval-error:0.000437
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.137486317859505e-08, 'max_depth': 9, 'min_child_weight': 0.12418944200496614, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.002719	eval-error:0.002882
#
# [1]	train-error:0.001094	eval-error:0.001196
#
# [2]	train-error:0.0007	eval-error:0.000816
#
# [3]	train-error:0.000643	eval-error:0.000752
#
# [4]	train-error:0.000744	eval-error:0.00085
#
# [5]	train-error:0.000714	eval-error:0.000831
#
# [6]	train-error:0.000662	eval-error:0.000779
#
# [7]	train-error:0.000529	eval-error:0.000616
#
# [8]	train-error:0.000548	eval-error:0.00063
#
# [9]	train-error:0.000604	eval-error:0.000684
#
# params: {'colsample_bytree': 0.65, 'gamma': 8.947368726721379e-08, 'max_depth': 8, 'min_child_weight': 0.19972193127544247, 'subsample': 0.9500000000000001}, logloss: 0.1997
# [0]	train-error:0.001936	eval-error:0.002213
#
# [1]	train-error:0.000646	eval-error:0.00073
#
# [2]	train-error:0.000547	eval-error:0.000621
#
# [3]	train-error:0.000499	eval-error:0.000587
#
# [4]	train-error:0.000512	eval-error:0.0006
#
# [5]	train-error:0.000437	eval-error:0.000503
#
# [6]	train-error:0.000427	eval-error:0.000464
#
# [7]	train-error:0.000393	eval-error:0.000435
#
# [8]	train-error:0.00038	eval-error:0.000433
#
# [9]	train-error:0.000387	eval-error:0.000446
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 1.2606358497718145e-08, 'max_depth': 9, 'min_child_weight': 0.10290243595033227, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.002716	eval-error:0.002877
#
# [1]	train-error:0.001135	eval-error:0.001271
#
# [2]	train-error:0.000697	eval-error:0.000818
#
# [3]	train-error:0.000643	eval-error:0.000752
#
# [4]	train-error:0.000751	eval-error:0.000859
#
# [5]	train-error:0.000715	eval-error:0.000834
#
# [6]	train-error:0.000664	eval-error:0.000779
#
# [7]	train-error:0.000526	eval-error:0.000614
#
# [8]	train-error:0.000551	eval-error:0.000634
#
# [9]	train-error:0.000611	eval-error:0.000689
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.705134651051988e-07, 'max_depth': 8, 'min_child_weight': 0.7998479499355234, 'subsample': 0.9500000000000001}, logloss: 0.1997
# [0]	train-error:0.001929	eval-error:0.002182
#
# [1]	train-error:0.00065	eval-error:0.000734
#
# [2]	train-error:0.000535	eval-error:0.000594
#
# [3]	train-error:0.000487	eval-error:0.000566
#
# [4]	train-error:0.000504	eval-error:0.000575
#
# [5]	train-error:0.000467	eval-error:0.000535
#
# [6]	train-error:0.000433	eval-error:0.000496
#
# [7]	train-error:0.000396	eval-error:0.00046
#
# [8]	train-error:0.00039	eval-error:0.00044
#
# [9]	train-error:0.000386	eval-error:0.000435
#
# params: {'colsample_bytree': 0.65, 'gamma': 9.608267461505209e-06, 'max_depth': 9, 'min_child_weight': 0.3291753148300825, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.002766	eval-error:0.002936
#
# [1]	train-error:0.002755	eval-error:0.002963
#
# [2]	train-error:0.000966	eval-error:0.001135
#
# [3]	train-error:0.000733	eval-error:0.000831
#
# [4]	train-error:0.00087	eval-error:0.000961
#
# [5]	train-error:0.000853	eval-error:0.000927
#
# [6]	train-error:0.000776	eval-error:0.000865
#
# [7]	train-error:0.000654	eval-error:0.000718
#
# [8]	train-error:0.00072	eval-error:0.000788
#
# [9]	train-error:0.000728	eval-error:0.000804
#
# params: {'colsample_bytree': 0.65, 'gamma': 2.032416259944982e-05, 'max_depth': 7, 'min_child_weight': 0.3676549893134453, 'subsample': 0.8500000000000001}, logloss: 0.2003
# [0]	train-error:0.000474	eval-error:0.000512
#
# [1]	train-error:0.000461	eval-error:0.000514
#
# [2]	train-error:0.000638	eval-error:0.000671
#
# [3]	train-error:0.000737	eval-error:0.000784
#
# [4]	train-error:0.000605	eval-error:0.000623
#
# [5]	train-error:0.000443	eval-error:0.000474
#
# [6]	train-error:0.000563	eval-error:0.000589
#
# [7]	train-error:0.000436	eval-error:0.000467
#
# [8]	train-error:0.000408	eval-error:0.000453
#
# [9]	train-error:0.000366	eval-error:0.000421
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.395076340533998e-06, 'max_depth': 9, 'min_child_weight': 0.1864220538154882, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.000768	eval-error:0.000861
#
# [1]	train-error:0.00072	eval-error:0.000795
#
# [2]	train-error:0.001303	eval-error:0.001411
#
# [3]	train-error:0.001016	eval-error:0.001108
#
# [4]	train-error:0.000885	eval-error:0.000958
#
# [5]	train-error:0.000662	eval-error:0.000714
#
# [6]	train-error:0.000709	eval-error:0.000766
#
# [7]	train-error:0.000625	eval-error:0.000677
#
# [8]	train-error:0.000618	eval-error:0.000677
#
# [9]	train-error:0.000613	eval-error:0.000689
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.878947961964613e-07, 'max_depth': 8, 'min_child_weight': 0.1741780097825947, 'subsample': 0.8500000000000001}, logloss: 0.1993
# [0]	train-error:0.00225	eval-error:0.002247
#
# [1]	train-error:0.00235	eval-error:0.002313
#
# [2]	train-error:0.004414	eval-error:0.004558
#
# [3]	train-error:0.004287	eval-error:0.004443
#
# [4]	train-error:0.001458	eval-error:0.001541
#
# [5]	train-error:0.001229	eval-error:0.00135
#
# [6]	train-error:0.001392	eval-error:0.001464
#
# [7]	train-error:0.001217	eval-error:0.001323
#
# [8]	train-error:0.001223	eval-error:0.001325
#
# [9]	train-error:0.001224	eval-error:0.00133
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.444532216039912e-06, 'max_depth': 5, 'min_child_weight': 0.2432871033828409, 'subsample': 0.9}, logloss: 0.2024
# [0]	train-error:0.000821	eval-error:0.000913
#
# [1]	train-error:0.000749	eval-error:0.000825
#
# [2]	train-error:0.001604	eval-error:0.001715
#
# [3]	train-error:0.000921	eval-error:0.00097
#
# [4]	train-error:0.000926	eval-error:0.000967
#
# [5]	train-error:0.000774	eval-error:0.00085
#
# [6]	train-error:0.000914	eval-error:0.000965
#
# [7]	train-error:0.000705	eval-error:0.000761
#
# [8]	train-error:0.000804	eval-error:0.00087
#
# [9]	train-error:0.000801	eval-error:0.000872
#
# params: {'colsample_bytree': 0.9, 'gamma': 5.6703926245697094e-05, 'max_depth': 7, 'min_child_weight': 0.10334421061014104, 'subsample': 0.9}, logloss: 0.1999
# [0]	train-error:0.000739	eval-error:0.000834
#
# [1]	train-error:0.0006	eval-error:0.000696
#
# [2]	train-error:0.000631	eval-error:0.000705
#
# [3]	train-error:0.000634	eval-error:0.00072
#
# [4]	train-error:0.000541	eval-error:0.000582
#
# [5]	train-error:0.000523	eval-error:0.000571
#
# [6]	train-error:0.00053	eval-error:0.000564
#
# [7]	train-error:0.000477	eval-error:0.000512
#
# [8]	train-error:0.000394	eval-error:0.00044
#
# [9]	train-error:0.000369	eval-error:0.000428
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.1015074138042382e-06, 'max_depth': 9, 'min_child_weight': 0.8796288941153918, 'subsample': 0.8500000000000001}, logloss: 0.1988
# [0]	train-error:0.00134	eval-error:0.001434
#
# [1]	train-error:0.001143	eval-error:0.001244
#
# [2]	train-error:0.003078	eval-error:0.003247
#
# [3]	train-error:0.00167	eval-error:0.001837
#
# [4]	train-error:0.001646	eval-error:0.001797
#
# [5]	train-error:0.002034	eval-error:0.002179
#
# [6]	train-error:0.001619	eval-error:0.00174
#
# [7]	train-error:0.001144	eval-error:0.00123
#
# [8]	train-error:0.001069	eval-error:0.001137
#
# [9]	train-error:0.001055	eval-error:0.001162
#
# params: {'colsample_bytree': 0.75, 'gamma': 8.470487832269476e-07, 'max_depth': 6, 'min_child_weight': 1.1775905333074137, 'subsample': 0.8500000000000001}, logloss: 0.2012
# [0]	train-error:0.00085	eval-error:0.000924
#
# [1]	train-error:0.000746	eval-error:0.000818
#
# [2]	train-error:0.001342	eval-error:0.001466
#
# [3]	train-error:0.000915	eval-error:0.000992
#
# [4]	train-error:0.001019	eval-error:0.001092
#
# [5]	train-error:0.000958	eval-error:0.001022
#
# [6]	train-error:0.000955	eval-error:0.00104
#
# [7]	train-error:0.000791	eval-error:0.000845
#
# [8]	train-error:0.000662	eval-error:0.000718
#
# [9]	train-error:0.000583	eval-error:0.000625
#
# params: {'colsample_bytree': 0.8, 'gamma': 3.716975863418569e-06, 'max_depth': 8, 'min_child_weight': 1.6589070622349344, 'subsample': 0.8500000000000001}, logloss: 0.1994
# [0]	train-error:0.001016	eval-error:0.001124
#
# [1]	train-error:0.000768	eval-error:0.000845
#
# [2]	train-error:0.001769	eval-error:0.001912
#
# [3]	train-error:0.000889	eval-error:0.000942
#
# [4]	train-error:0.000998	eval-error:0.001076
#
# [5]	train-error:0.000979	eval-error:0.001051
#
# [6]	train-error:0.000956	eval-error:0.001026
#
# [7]	train-error:0.000932	eval-error:0.001006
#
# [8]	train-error:0.000867	eval-error:0.00094
#
# [9]	train-error:0.000709	eval-error:0.00077
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 6.359525269939452e-07, 'max_depth': 7, 'min_child_weight': 0.4381377136970967, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.000734	eval-error:0.000797
#
# [1]	train-error:0.000611	eval-error:0.000702
#
# [2]	train-error:0.000645	eval-error:0.0007
#
# [3]	train-error:0.00064	eval-error:0.000734
#
# [4]	train-error:0.000615	eval-error:0.000662
#
# [5]	train-error:0.000538	eval-error:0.000573
#
# [6]	train-error:0.000534	eval-error:0.000571
#
# [7]	train-error:0.000516	eval-error:0.000569
#
# [8]	train-error:0.000383	eval-error:0.000444
#
# [9]	train-error:0.000356	eval-error:0.000419
#
# params: {'colsample_bytree': 0.75, 'gamma': 6.148841286746415e-05, 'max_depth': 9, 'min_child_weight': 0.8561740965512137, 'subsample': 0.7000000000000001}, logloss: 0.1989
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006244	eval-error:0.006416
#
# [2]	train-error:0.007718	eval-error:0.007916
#
# [3]	train-error:0.007756	eval-error:0.007954
#
# [4]	train-error:0.007137	eval-error:0.007327
#
# [5]	train-error:0.006202	eval-error:0.006362
#
# [6]	train-error:0.007137	eval-error:0.007327
#
# [7]	train-error:0.007162	eval-error:0.007343
#
# [8]	train-error:0.00622	eval-error:0.006375
#
# [9]	train-error:0.006195	eval-error:0.00636
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0036653004223645e-05, 'max_depth': 3, 'min_child_weight': 2.564692514393784, 'subsample': 0.8500000000000001}, logloss: 0.2092
# [0]	train-error:0.00134	eval-error:0.001434
#
# [1]	train-error:0.001139	eval-error:0.001228
#
# [2]	train-error:0.003099	eval-error:0.003269
#
# [3]	train-error:0.001784	eval-error:0.001887
#
# [4]	train-error:0.002104	eval-error:0.002268
#
# [5]	train-error:0.001387	eval-error:0.001509
#
# [6]	train-error:0.001538	eval-error:0.001654
#
# [7]	train-error:0.001316	eval-error:0.001411
#
# [8]	train-error:0.00115	eval-error:0.001255
#
# [9]	train-error:0.001098	eval-error:0.001194
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.060227553689368e-08, 'max_depth': 6, 'min_child_weight': 0.998617060442965, 'subsample': 0.9500000000000001}, logloss: 0.2009
# [0]	train-error:0.002461	eval-error:0.00249
#
# [1]	train-error:0.001387	eval-error:0.001495
#
# [2]	train-error:0.004317	eval-error:0.004465
#
# [3]	train-error:0.003511	eval-error:0.00379
#
# [4]	train-error:0.001888	eval-error:0.002007
#
# [5]	train-error:0.001995	eval-error:0.002118
#
# [6]	train-error:0.002737	eval-error:0.002775
#
# [7]	train-error:0.002776	eval-error:0.002766
#
# [8]	train-error:0.002657	eval-error:0.002687
#
# [9]	train-error:0.001769	eval-error:0.001892
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0004564062888497942, 'max_depth': 5, 'min_child_weight': 0.29804642130595765, 'subsample': 0.8}, logloss: 0.2029
# [0]	train-error:0.000828	eval-error:0.00092
#
# [1]	train-error:0.000802	eval-error:0.000893
#
# [2]	train-error:0.001614	eval-error:0.001726
#
# [3]	train-error:0.000928	eval-error:0.000974
#
# [4]	train-error:0.000916	eval-error:0.000952
#
# [5]	train-error:0.000725	eval-error:0.000768
#
# [6]	train-error:0.000886	eval-error:0.000924
#
# [7]	train-error:0.000706	eval-error:0.000754
#
# [8]	train-error:0.00075	eval-error:0.000818
#
# [9]	train-error:0.000746	eval-error:0.000827
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.3205899349651617e-06, 'max_depth': 7, 'min_child_weight': 2.1470546590174298, 'subsample': 0.9}, logloss: 0.2000
# [0]	train-error:0.000844	eval-error:0.000931
#
# [1]	train-error:0.000744	eval-error:0.000829
#
# [2]	train-error:0.001322	eval-error:0.001443
#
# [3]	train-error:0.001245	eval-error:0.001339
#
# [4]	train-error:0.000785	eval-error:0.000804
#
# [5]	train-error:0.000822	eval-error:0.000829
#
# [6]	train-error:0.000785	eval-error:0.000804
#
# [7]	train-error:0.000736	eval-error:0.000743
#
# [8]	train-error:0.000635	eval-error:0.000657
#
# [9]	train-error:0.000635	eval-error:0.000666
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.358042366951816e-06, 'max_depth': 8, 'min_child_weight': 0.45514394516236534, 'subsample': 0.75}, logloss: 0.1994
# [0]	train-error:0.000824	eval-error:0.000918
#
# [1]	train-error:0.000714	eval-error:0.000788
#
# [2]	train-error:0.000835	eval-error:0.000879
#
# [3]	train-error:0.000697	eval-error:0.000775
#
# [4]	train-error:0.000672	eval-error:0.000711
#
# [5]	train-error:0.000695	eval-error:0.000743
#
# [6]	train-error:0.000681	eval-error:0.000748
#
# [7]	train-error:0.000566	eval-error:0.000603
#
# [8]	train-error:0.000444	eval-error:0.000485
#
# [9]	train-error:0.000353	eval-error:0.000401
#
# params: {'colsample_bytree': 0.8, 'gamma': 3.0698311903760764e-05, 'max_depth': 9, 'min_child_weight': 9.771507456179313, 'subsample': 0.8500000000000001}, logloss: 0.1990
# [0]	train-error:0.000994	eval-error:0.001119
#
# [1]	train-error:0.00086	eval-error:0.000952
#
# [2]	train-error:0.001795	eval-error:0.001942
#
# [3]	train-error:0.001047	eval-error:0.001115
#
# [4]	train-error:0.000933	eval-error:0.000965
#
# [5]	train-error:0.000783	eval-error:0.000841
#
# [6]	train-error:0.000899	eval-error:0.000924
#
# [7]	train-error:0.000714	eval-error:0.000754
#
# [8]	train-error:0.000704	eval-error:0.000761
#
# [9]	train-error:0.000696	eval-error:0.000754
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.7032936261016675e-07, 'max_depth': 7, 'min_child_weight': 0.15212748627894784, 'subsample': 0.8}, logloss: 0.1999
# [0]	train-error:0.00134	eval-error:0.001443
#
# [1]	train-error:0.001144	eval-error:0.001246
#
# [2]	train-error:0.00304	eval-error:0.003208
#
# [3]	train-error:0.001563	eval-error:0.00169
#
# [4]	train-error:0.001652	eval-error:0.001803
#
# [5]	train-error:0.002037	eval-error:0.002182
#
# [6]	train-error:0.001572	eval-error:0.001692
#
# [7]	train-error:0.001511	eval-error:0.001611
#
# [8]	train-error:0.001192	eval-error:0.001271
#
# [9]	train-error:0.000975	eval-error:0.001069
#
# params: {'colsample_bytree': 0.75, 'gamma': 4.769155891863907e-07, 'max_depth': 6, 'min_child_weight': 0.6087105358272469, 'subsample': 0.7000000000000001}, logloss: 0.2012
# [0]	train-error:0.000758	eval-error:0.00085
#
# [1]	train-error:0.000517	eval-error:0.000598
#
# [2]	train-error:0.000671	eval-error:0.000732
#
# [3]	train-error:0.000606	eval-error:0.000686
#
# [4]	train-error:0.00062	eval-error:0.000668
#
# [5]	train-error:0.00063	eval-error:0.000693
#
# [6]	train-error:0.000635	eval-error:0.0007
#
# [7]	train-error:0.000563	eval-error:0.000609
#
# [8]	train-error:0.000489	eval-error:0.000537
#
# [9]	train-error:0.000402	eval-error:0.000449
#
# params: {'colsample_bytree': 0.8, 'gamma': 9.684557951872333e-05, 'max_depth': 9, 'min_child_weight': 0.2722088166566007, 'subsample': 0.9}, logloss: 0.1989
# [0]	train-error:0.000851	eval-error:0.000922
#
# [1]	train-error:0.000674	eval-error:0.000773
#
# [2]	train-error:0.000962	eval-error:0.001076
#
# [3]	train-error:0.000948	eval-error:0.001047
#
# [4]	train-error:0.00081	eval-error:0.000922
#
# [5]	train-error:0.000908	eval-error:0.000992
#
# [6]	train-error:0.000805	eval-error:0.000897
#
# [7]	train-error:0.000587	eval-error:0.000657
#
# [8]	train-error:0.000674	eval-error:0.000782
#
# [9]	train-error:0.00047	eval-error:0.000551
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.5983273370482874e-06, 'max_depth': 8, 'min_child_weight': 1.3274252547068548, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.002463	eval-error:0.002483
#
# [1]	train-error:0.002089	eval-error:0.00208
#
# [2]	train-error:0.004267	eval-error:0.004456
#
# [3]	train-error:0.004395	eval-error:0.00454
#
# [4]	train-error:0.001518	eval-error:0.001595
#
# [5]	train-error:0.001237	eval-error:0.001353
#
# [6]	train-error:0.001424	eval-error:0.001491
#
# [7]	train-error:0.00122	eval-error:0.001355
#
# [8]	train-error:0.001185	eval-error:0.001314
#
# [9]	train-error:0.001248	eval-error:0.00135
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0006300202285133728, 'max_depth': 5, 'min_child_weight': 1.03515812806947, 'subsample': 0.8}, logloss: 0.2023
# [0]	train-error:0.001053	eval-error:0.001162
#
# [1]	train-error:0.000864	eval-error:0.000976
#
# [2]	train-error:0.001865	eval-error:0.002055
#
# [3]	train-error:0.000883	eval-error:0.000954
#
# [4]	train-error:0.000946	eval-error:0.001029
#
# [5]	train-error:0.000859	eval-error:0.000922
#
# [6]	train-error:0.000924	eval-error:0.000986
#
# [7]	train-error:0.000813	eval-error:0.000877
#
# [8]	train-error:0.000792	eval-error:0.000847
#
# [9]	train-error:0.000804	eval-error:0.000861
#
# params: {'colsample_bytree': 0.75, 'gamma': 3.6085723599728355e-08, 'max_depth': 7, 'min_child_weight': 7.78139284801187, 'subsample': 0.8500000000000001}, logloss: 0.2002
# [0]	train-error:0.000851	eval-error:0.000924
#
# [1]	train-error:0.000823	eval-error:0.000884
#
# [2]	train-error:0.001333	eval-error:0.001448
#
# [3]	train-error:0.001257	eval-error:0.001341
#
# [4]	train-error:0.000795	eval-error:0.000804
#
# [5]	train-error:0.000825	eval-error:0.000838
#
# [6]	train-error:0.000793	eval-error:0.000811
#
# [7]	train-error:0.000719	eval-error:0.000741
#
# [8]	train-error:0.000569	eval-error:0.000594
#
# [9]	train-error:0.000572	eval-error:0.000603
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.023157789495036576, 'max_depth': 8, 'min_child_weight': 1.6994460074124804, 'subsample': 0.8}, logloss: 0.1994
# [0]	train-error:0.00075	eval-error:0.000829
#
# [1]	train-error:0.000547	eval-error:0.000619
#
# [2]	train-error:0.000673	eval-error:0.000716
#
# [3]	train-error:0.000751	eval-error:0.000788
#
# [4]	train-error:0.000612	eval-error:0.000662
#
# [5]	train-error:0.000468	eval-error:0.000507
#
# [6]	train-error:0.000593	eval-error:0.000628
#
# [7]	train-error:0.000464	eval-error:0.000498
#
# [8]	train-error:0.000458	eval-error:0.00051
#
# [9]	train-error:0.000387	eval-error:0.000444
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.2771958074852692e-05, 'max_depth': 9, 'min_child_weight': 3.0701579828809087, 'subsample': 0.7000000000000001}, logloss: 0.1989
# [0]	train-error:0.001342	eval-error:0.001434
#
# [1]	train-error:0.001143	eval-error:0.001232
#
# [2]	train-error:0.003077	eval-error:0.00326
#
# [3]	train-error:0.001544	eval-error:0.001654
#
# [4]	train-error:0.001639	eval-error:0.001765
#
# [5]	train-error:0.002093	eval-error:0.002252
#
# [6]	train-error:0.001696	eval-error:0.001826
#
# [7]	train-error:0.001186	eval-error:0.001341
#
# [8]	train-error:0.001134	eval-error:0.001214
#
# [9]	train-error:0.001094	eval-error:0.001178
#
# params: {'colsample_bytree': 0.8, 'gamma': 6.098620325058068e-06, 'max_depth': 6, 'min_child_weight': 0.6303122614369896, 'subsample': 0.75}, logloss: 0.2011
# [0]	train-error:0.000844	eval-error:0.000922
#
# [1]	train-error:0.00066	eval-error:0.000743
#
# [2]	train-error:0.000958	eval-error:0.001074
#
# [3]	train-error:0.000924	eval-error:0.001035
#
# [4]	train-error:0.000802	eval-error:0.000922
#
# [5]	train-error:0.000886	eval-error:0.000981
#
# [6]	train-error:0.000803	eval-error:0.000899
#
# [7]	train-error:0.000585	eval-error:0.000652
#
# [8]	train-error:0.000668	eval-error:0.000777
#
# [9]	train-error:0.000461	eval-error:0.000539
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.00023643221895907124, 'max_depth': 8, 'min_child_weight': 0.5197195965205971, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006205	eval-error:0.006369
#
# [2]	train-error:0.007748	eval-error:0.007973
#
# [3]	train-error:0.007816	eval-error:0.008027
#
# [4]	train-error:0.007371	eval-error:0.007606
#
# [5]	train-error:0.007346	eval-error:0.007567
#
# [6]	train-error:0.007969	eval-error:0.008199
#
# [7]	train-error:0.007343	eval-error:0.007563
#
# [8]	train-error:0.007173	eval-error:0.007352
#
# [9]	train-error:0.00664	eval-error:0.006817
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.00279067007236491, 'max_depth': 3, 'min_child_weight': 0.15087451731492899, 'subsample': 0.9500000000000001}, logloss: 0.2094
# [0]	train-error:0.000736	eval-error:0.000811
#
# [1]	train-error:0.000612	eval-error:0.000686
#
# [2]	train-error:0.00073	eval-error:0.000784
#
# [3]	train-error:0.000628	eval-error:0.00068
#
# [4]	train-error:0.000677	eval-error:0.000711
#
# [5]	train-error:0.000642	eval-error:0.000668
#
# [6]	train-error:0.000625	eval-error:0.000659
#
# [7]	train-error:0.00052	eval-error:0.000553
#
# [8]	train-error:0.000443	eval-error:0.000474
#
# [9]	train-error:0.000352	eval-error:0.000383
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.0745772120824896e-07, 'max_depth': 9, 'min_child_weight': 0.20187837041469606, 'subsample': 0.75}, logloss: 0.1989
# [0]	train-error:0.000772	eval-error:0.000838
#
# [1]	train-error:0.000627	eval-error:0.000707
#
# [2]	train-error:0.001309	eval-error:0.001434
#
# [3]	train-error:0.000902	eval-error:0.001024
#
# [4]	train-error:0.001195	eval-error:0.001319
#
# [5]	train-error:0.000859	eval-error:0.000949
#
# [6]	train-error:0.000933	eval-error:0.001013
#
# [7]	train-error:0.000801	eval-error:0.000859
#
# [8]	train-error:0.000736	eval-error:0.000822
#
# [9]	train-error:0.000677	eval-error:0.000752
#
# params: {'colsample_bytree': 0.75, 'gamma': 2.719412333641151e-05, 'max_depth': 8, 'min_child_weight': 0.7780703012617969, 'subsample': 0.65}, logloss: 0.1995
# [0]	train-error:0.001035	eval-error:0.00114
#
# [1]	train-error:0.000796	eval-error:0.000877
#
# [2]	train-error:0.001834	eval-error:0.001987
#
# [3]	train-error:0.000969	eval-error:0.001022
#
# [4]	train-error:0.001073	eval-error:0.001167
#
# [5]	train-error:0.000992	eval-error:0.001056
#
# [6]	train-error:0.001058	eval-error:0.001142
#
# [7]	train-error:0.000918	eval-error:0.000972
#
# [8]	train-error:0.00092	eval-error:0.000976
#
# [9]	train-error:0.000911	eval-error:0.000947
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0013854239935158158, 'max_depth': 7, 'min_child_weight': 4.056500599324168, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.000735	eval-error:0.000829
#
# [1]	train-error:0.000599	eval-error:0.000696
#
# [2]	train-error:0.000629	eval-error:0.000702
#
# [3]	train-error:0.000633	eval-error:0.00072
#
# [4]	train-error:0.000539	eval-error:0.000585
#
# [5]	train-error:0.00052	eval-error:0.000575
#
# [6]	train-error:0.000526	eval-error:0.000564
#
# [7]	train-error:0.000474	eval-error:0.000512
#
# [8]	train-error:0.0004	eval-error:0.00046
#
# [9]	train-error:0.00038	eval-error:0.000446
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.6523594638455643e-08, 'max_depth': 9, 'min_child_weight': 0.3908930815930634, 'subsample': 0.8500000000000001}, logloss: 0.1989
# [0]	train-error:0.000803	eval-error:0.000895
#
# [1]	train-error:0.000522	eval-error:0.000573
#
# [2]	train-error:0.000533	eval-error:0.000603
#
# [3]	train-error:0.00055	eval-error:0.000623
#
# [4]	train-error:0.000479	eval-error:0.000551
#
# [5]	train-error:0.000446	eval-error:0.000512
#
# [6]	train-error:0.000537	eval-error:0.000623
#
# [7]	train-error:0.000402	eval-error:0.00048
#
# [8]	train-error:0.000367	eval-error:0.000444
#
# [9]	train-error:0.000356	eval-error:0.000417
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 2.3863902458516803e-07, 'max_depth': 9, 'min_child_weight': 6.539046566052738, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.002451	eval-error:0.002472
#
# [1]	train-error:0.002105	eval-error:0.002102
#
# [2]	train-error:0.004284	eval-error:0.004484
#
# [3]	train-error:0.003688	eval-error:0.003919
#
# [4]	train-error:0.001983	eval-error:0.002105
#
# [5]	train-error:0.001895	eval-error:0.002053
#
# [6]	train-error:0.002044	eval-error:0.002166
#
# [7]	train-error:0.001731	eval-error:0.00193
#
# [8]	train-error:0.001667	eval-error:0.001865
#
# [9]	train-error:0.001832	eval-error:0.001996
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.3583640025522053, 'max_depth': 5, 'min_child_weight': 0.2046853389061963, 'subsample': 0.6000000000000001}, logloss: 0.2027
# [0]	train-error:0.000769	eval-error:0.000863
#
# [1]	train-error:0.000717	eval-error:0.000793
#
# [2]	train-error:0.001303	eval-error:0.001418
#
# [3]	train-error:0.000997	eval-error:0.001083
#
# [4]	train-error:0.000841	eval-error:0.000913
#
# [5]	train-error:0.00062	eval-error:0.000682
#
# [6]	train-error:0.00069	eval-error:0.000739
#
# [7]	train-error:0.000511	eval-error:0.000548
#
# [8]	train-error:0.000517	eval-error:0.000562
#
# [9]	train-error:0.000572	eval-error:0.000643
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.200222667549315e-06, 'max_depth': 8, 'min_child_weight': 0.3189247339155926, 'subsample': 0.9500000000000001}, logloss: 0.1993
# [0]	train-error:0.001959	eval-error:0.002225
#
# [1]	train-error:0.000703	eval-error:0.000813
#
# [2]	train-error:0.000575	eval-error:0.000655
#
# [3]	train-error:0.000511	eval-error:0.000609
#
# [4]	train-error:0.000536	eval-error:0.000628
#
# [5]	train-error:0.000454	eval-error:0.000532
#
# [6]	train-error:0.000443	eval-error:0.000501
#
# [7]	train-error:0.000397	eval-error:0.000451
#
# [8]	train-error:0.000391	eval-error:0.000455
#
# [9]	train-error:0.000383	eval-error:0.000453
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 6.093318448422842e-05, 'max_depth': 9, 'min_child_weight': 2.1184663512995177, 'subsample': 0.8500000000000001}, logloss: 0.1990
# [0]	train-error:0.005713	eval-error:0.005766
#
# [1]	train-error:0.002531	eval-error:0.002458
#
# [2]	train-error:0.005992	eval-error:0.006169
#
# [3]	train-error:0.006086	eval-error:0.006296
#
# [4]	train-error:0.005974	eval-error:0.006144
#
# [5]	train-error:0.005974	eval-error:0.006153
#
# [6]	train-error:0.005975	eval-error:0.006144
#
# [7]	train-error:0.004418	eval-error:0.004529
#
# [8]	train-error:0.004589	eval-error:0.004731
#
# [9]	train-error:0.004576	eval-error:0.00471
#
# params: {'colsample_bytree': 0.8, 'gamma': 9.349993656266868e-07, 'max_depth': 4, 'min_child_weight': 0.962587822303379, 'subsample': 0.9500000000000001}, logloss: 0.2054
# [0]	train-error:0.00083	eval-error:0.000924
#
# [1]	train-error:0.000807	eval-error:0.000902
#
# [2]	train-error:0.00162	eval-error:0.001733
#
# [3]	train-error:0.000929	eval-error:0.00097
#
# [4]	train-error:0.000924	eval-error:0.000956
#
# [5]	train-error:0.000729	eval-error:0.00077
#
# [6]	train-error:0.000893	eval-error:0.000927
#
# [7]	train-error:0.000713	eval-error:0.000757
#
# [8]	train-error:0.000754	eval-error:0.00082
#
# [9]	train-error:0.000746	eval-error:0.000827
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0078955098744669, 'max_depth': 7, 'min_child_weight': 2.9335769846704296, 'subsample': 0.9}, logloss: 0.2000
# [0]	train-error:0.000516	eval-error:0.000557
#
# [1]	train-error:0.000476	eval-error:0.000548
#
# [2]	train-error:0.000689	eval-error:0.000725
#
# [3]	train-error:0.000788	eval-error:0.00082
#
# [4]	train-error:0.000625	eval-error:0.000655
#
# [5]	train-error:0.000446	eval-error:0.000496
#
# [6]	train-error:0.000605	eval-error:0.000639
#
# [7]	train-error:0.000467	eval-error:0.000494
#
# [8]	train-error:0.000428	eval-error:0.000483
#
# [9]	train-error:0.000409	eval-error:0.000469
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.4334974660967129e-05, 'max_depth': 9, 'min_child_weight': 5.1067252688272, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.00052	eval-error:0.000564
#
# [1]	train-error:0.000481	eval-error:0.000557
#
# [2]	train-error:0.000696	eval-error:0.000732
#
# [3]	train-error:0.000775	eval-error:0.000809
#
# [4]	train-error:0.000617	eval-error:0.000639
#
# [5]	train-error:0.000479	eval-error:0.000514
#
# [6]	train-error:0.000603	eval-error:0.000637
#
# [7]	train-error:0.000464	eval-error:0.000496
#
# [8]	train-error:0.000443	eval-error:0.000494
#
# [9]	train-error:0.000415	eval-error:0.000476
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 5.051851551491952e-06, 'max_depth': 9, 'min_child_weight': 4.911020391626479, 'subsample': 0.65}, logloss: 0.1989
# [0]	train-error:0.000795	eval-error:0.000875
#
# [1]	train-error:0.000727	eval-error:0.000793
#
# [2]	train-error:0.00119	eval-error:0.001325
#
# [3]	train-error:0.001201	eval-error:0.001328
#
# [4]	train-error:0.00122	eval-error:0.001355
#
# [5]	train-error:0.000686	eval-error:0.000773
#
# [6]	train-error:0.000694	eval-error:0.00077
#
# [7]	train-error:0.000637	eval-error:0.000734
#
# [8]	train-error:0.000637	eval-error:0.00072
#
# [9]	train-error:0.00063	eval-error:0.000723
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.293089312786786e-05, 'max_depth': 8, 'min_child_weight': 3.613332596874744, 'subsample': 0.7000000000000001}, logloss: 0.1993
# [0]	train-error:0.000535	eval-error:0.000582
#
# [1]	train-error:0.000511	eval-error:0.000573
#
# [2]	train-error:0.00071	eval-error:0.000745
#
# [3]	train-error:0.000785	eval-error:0.000822
#
# [4]	train-error:0.000642	eval-error:0.000652
#
# [5]	train-error:0.000523	eval-error:0.000544
#
# [6]	train-error:0.000622	eval-error:0.000643
#
# [7]	train-error:0.00047	eval-error:0.000505
#
# [8]	train-error:0.000452	eval-error:0.000507
#
# [9]	train-error:0.000451	eval-error:0.000521
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00016771034880876858, 'max_depth': 9, 'min_child_weight': 7.2540461821988975, 'subsample': 0.65}, logloss: 0.1989
# [0]	train-error:0.000805	eval-error:0.00087
#
# [1]	train-error:0.000746	eval-error:0.000829
#
# [2]	train-error:0.000878	eval-error:0.000915
#
# [3]	train-error:0.001012	eval-error:0.001076
#
# [4]	train-error:0.000891	eval-error:0.000958
#
# [5]	train-error:0.000693	eval-error:0.00077
#
# [6]	train-error:0.000762	eval-error:0.000838
#
# [7]	train-error:0.000541	eval-error:0.0006
#
# [8]	train-error:0.000532	eval-error:0.000591
#
# [9]	train-error:0.000532	eval-error:0.000582
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.1896467538132667e-07, 'max_depth': 8, 'min_child_weight': 5.6021432645717635, 'subsample': 0.75}, logloss: 0.1993
# [0]	train-error:0.000723	eval-error:0.000809
#
# [1]	train-error:0.000548	eval-error:0.000619
#
# [2]	train-error:0.000648	eval-error:0.000684
#
# [3]	train-error:0.000742	eval-error:0.000779
#
# [4]	train-error:0.000598	eval-error:0.00063
#
# [5]	train-error:0.000461	eval-error:0.000487
#
# [6]	train-error:0.000572	eval-error:0.000594
#
# [7]	train-error:0.00044	eval-error:0.000471
#
# [8]	train-error:0.000413	eval-error:0.000469
#
# [9]	train-error:0.000372	eval-error:0.000424
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.232336744255673e-08, 'max_depth': 9, 'min_child_weight': 0.6845934370761219, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.000728	eval-error:0.000811
#
# [1]	train-error:0.000549	eval-error:0.000619
#
# [2]	train-error:0.000654	eval-error:0.0007
#
# [3]	train-error:0.000738	eval-error:0.000779
#
# [4]	train-error:0.000605	eval-error:0.000646
#
# [5]	train-error:0.000458	eval-error:0.000494
#
# [6]	train-error:0.000578	eval-error:0.0006
#
# [7]	train-error:0.00045	eval-error:0.000476
#
# [8]	train-error:0.000437	eval-error:0.000489
#
# [9]	train-error:0.000377	eval-error:0.000433
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.333761761207308e-08, 'max_depth': 9, 'min_child_weight': 1.53449979330838, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.000763	eval-error:0.000847
#
# [1]	train-error:0.000789	eval-error:0.000834
#
# [2]	train-error:0.001273	eval-error:0.001364
#
# [3]	train-error:0.00131	eval-error:0.001423
#
# [4]	train-error:0.00126	eval-error:0.001348
#
# [5]	train-error:0.000715	eval-error:0.000768
#
# [6]	train-error:0.000767	eval-error:0.000818
#
# [7]	train-error:0.000676	eval-error:0.000732
#
# [8]	train-error:0.000609	eval-error:0.000673
#
# [9]	train-error:0.000606	eval-error:0.00068
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00040247964012227986, 'max_depth': 8, 'min_child_weight': 1.115209831641628, 'subsample': 0.6000000000000001}, logloss: 0.1994
# [0]	train-error:0.000726	eval-error:0.000811
#
# [1]	train-error:0.000501	eval-error:0.000587
#
# [2]	train-error:0.000641	eval-error:0.000689
#
# [3]	train-error:0.000723	eval-error:0.000777
#
# [4]	train-error:0.000581	eval-error:0.000614
#
# [5]	train-error:0.000411	eval-error:0.000446
#
# [6]	train-error:0.000575	eval-error:0.000609
#
# [7]	train-error:0.000418	eval-error:0.000458
#
# [8]	train-error:0.000411	eval-error:0.00046
#
# [9]	train-error:0.000393	eval-error:0.000449
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.6792711417598976e-08, 'max_depth': 9, 'min_child_weight': 0.714750966460842, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.00076	eval-error:0.000841
#
# [1]	train-error:0.000792	eval-error:0.000845
#
# [2]	train-error:0.001243	eval-error:0.001391
#
# [3]	train-error:0.000905	eval-error:0.001017
#
# [4]	train-error:0.000886	eval-error:0.000981
#
# [5]	train-error:0.000745	eval-error:0.000834
#
# [6]	train-error:0.000672	eval-error:0.000725
#
# [7]	train-error:0.000498	eval-error:0.000541
#
# [8]	train-error:0.000486	eval-error:0.000532
#
# [9]	train-error:0.000492	eval-error:0.000535
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.02920071791500517, 'max_depth': 8, 'min_child_weight': 0.5202500199375256, 'subsample': 0.65}, logloss: 0.1993
# [0]	train-error:0.000721	eval-error:0.000818
#
# [1]	train-error:0.000494	eval-error:0.000573
#
# [2]	train-error:0.000625	eval-error:0.000671
#
# [3]	train-error:0.000717	eval-error:0.000761
#
# [4]	train-error:0.000569	eval-error:0.000594
#
# [5]	train-error:0.000418	eval-error:0.000455
#
# [6]	train-error:0.000559	eval-error:0.000587
#
# [7]	train-error:0.000423	eval-error:0.000458
#
# [8]	train-error:0.000412	eval-error:0.00046
#
# [9]	train-error:0.000391	eval-error:0.000433
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.04290832253323943, 'max_depth': 9, 'min_child_weight': 0.1701479089601252, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.000722	eval-error:0.000816
#
# [1]	train-error:0.000546	eval-error:0.000609
#
# [2]	train-error:0.000649	eval-error:0.000696
#
# [3]	train-error:0.000736	eval-error:0.000782
#
# [4]	train-error:0.00062	eval-error:0.000648
#
# [5]	train-error:0.000452	eval-error:0.00048
#
# [6]	train-error:0.000615	eval-error:0.000646
#
# [7]	train-error:0.000433	eval-error:0.000458
#
# [8]	train-error:0.000417	eval-error:0.000467
#
# [9]	train-error:0.000393	eval-error:0.000451
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00011181114833930745, 'max_depth': 9, 'min_child_weight': 0.11311051334039249, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.000754	eval-error:0.000843
#
# [1]	train-error:0.000782	eval-error:0.000829
#
# [2]	train-error:0.001281	eval-error:0.00138
#
# [3]	train-error:0.001303	eval-error:0.001414
#
# [4]	train-error:0.00126	eval-error:0.00135
#
# [5]	train-error:0.000708	eval-error:0.000768
#
# [6]	train-error:0.00077	eval-error:0.000816
#
# [7]	train-error:0.000647	eval-error:0.000702
#
# [8]	train-error:0.000588	eval-error:0.000646
#
# [9]	train-error:0.000595	eval-error:0.000666
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.7809442212820597e-05, 'max_depth': 8, 'min_child_weight': 0.44398200849169733, 'subsample': 0.6000000000000001}, logloss: 0.1993
# [0]	train-error:0.000723	eval-error:0.000818
#
# [1]	train-error:0.000545	eval-error:0.000609
#
# [2]	train-error:0.00065	eval-error:0.000693
#
# [3]	train-error:0.000736	eval-error:0.000782
#
# [4]	train-error:0.000623	eval-error:0.00065
#
# [5]	train-error:0.000452	eval-error:0.000478
#
# [6]	train-error:0.000615	eval-error:0.000646
#
# [7]	train-error:0.000433	eval-error:0.000458
#
# [8]	train-error:0.000417	eval-error:0.000467
#
# [9]	train-error:0.000394	eval-error:0.000449
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.000761031304811043, 'max_depth': 9, 'min_child_weight': 0.25653040048827974, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.001078	eval-error:0.00118
#
# [1]	train-error:0.000878	eval-error:0.000999
#
# [2]	train-error:0.001901	eval-error:0.002084
#
# [3]	train-error:0.001017	eval-error:0.001081
#
# [4]	train-error:0.001106	eval-error:0.001214
#
# [5]	train-error:0.001139	eval-error:0.001255
#
# [6]	train-error:0.001118	eval-error:0.001228
#
# [7]	train-error:0.001013	eval-error:0.001085
#
# [8]	train-error:0.000931	eval-error:0.001008
#
# [9]	train-error:0.000914	eval-error:0.000988
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0010814715672434931, 'max_depth': 7, 'min_child_weight': 9.946583983611218, 'subsample': 0.7000000000000001}, logloss: 0.2002
# [0]	train-error:0.000767	eval-error:0.000845
#
# [1]	train-error:0.000788	eval-error:0.000836
#
# [2]	train-error:0.001275	eval-error:0.001366
#
# [3]	train-error:0.001311	eval-error:0.001418
#
# [4]	train-error:0.001261	eval-error:0.001348
#
# [5]	train-error:0.000715	eval-error:0.000768
#
# [6]	train-error:0.000764	eval-error:0.000816
#
# [7]	train-error:0.000652	eval-error:0.000707
#
# [8]	train-error:0.000602	eval-error:0.000662
#
# [9]	train-error:0.000575	eval-error:0.000639
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.817864865053633e-08, 'max_depth': 8, 'min_child_weight': 1.312003178931432, 'subsample': 0.6000000000000001}, logloss: 0.1993
# [0]	train-error:0.000819	eval-error:0.000897
#
# [1]	train-error:0.000764	eval-error:0.000834
#
# [2]	train-error:0.001793	eval-error:0.001942
#
# [3]	train-error:0.000929	eval-error:0.00097
#
# [4]	train-error:0.000924	eval-error:0.000965
#
# [5]	train-error:0.0008	eval-error:0.00089
#
# [6]	train-error:0.000927	eval-error:0.00099
#
# [7]	train-error:0.00073	eval-error:0.000784
#
# [8]	train-error:0.000777	eval-error:0.00085
#
# [9]	train-error:0.000696	eval-error:0.000786
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.535880166059732e-06, 'max_depth': 7, 'min_child_weight': 1.7650711191654356, 'subsample': 0.7000000000000001}, logloss: 0.2000
# [0]	train-error:0.001347	eval-error:0.001443
#
# [1]	train-error:0.001171	eval-error:0.001269
#
# [2]	train-error:0.003071	eval-error:0.003247
#
# [3]	train-error:0.001738	eval-error:0.001844
#
# [4]	train-error:0.001784	eval-error:0.001894
#
# [5]	train-error:0.001775	eval-error:0.001896
#
# [6]	train-error:0.001746	eval-error:0.001865
#
# [7]	train-error:0.001699	eval-error:0.001815
#
# [8]	train-error:0.001154	eval-error:0.001239
#
# [9]	train-error:0.001155	eval-error:0.00126
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 4.577300269948544e-07, 'max_depth': 6, 'min_child_weight': 2.445824513278567, 'subsample': 0.75}, logloss: 0.2011
# [0]	train-error:0.000722	eval-error:0.000816
#
# [1]	train-error:0.000499	eval-error:0.00058
#
# [2]	train-error:0.000635	eval-error:0.000686
#
# [3]	train-error:0.00072	eval-error:0.000773
#
# [4]	train-error:0.000574	eval-error:0.000619
#
# [5]	train-error:0.000409	eval-error:0.000449
#
# [6]	train-error:0.000568	eval-error:0.000616
#
# [7]	train-error:0.000416	eval-error:0.000455
#
# [8]	train-error:0.000409	eval-error:0.000458
#
# [9]	train-error:0.000388	eval-error:0.00044
#
# params: {'colsample_bytree': 0.9, 'gamma': 5.0650730807595366e-05, 'max_depth': 9, 'min_child_weight': 0.130489156143539, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.000773	eval-error:0.000852
#
# [1]	train-error:0.000683	eval-error:0.00075
#
# [2]	train-error:0.001287	eval-error:0.001396
#
# [3]	train-error:0.000973	eval-error:0.001051
#
# [4]	train-error:0.00102	eval-error:0.001072
#
# [5]	train-error:0.000942	eval-error:0.000992
#
# [6]	train-error:0.000943	eval-error:0.001001
#
# [7]	train-error:0.000773	eval-error:0.000818
#
# [8]	train-error:0.000652	eval-error:0.000691
#
# [9]	train-error:0.000553	eval-error:0.000596
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.004346030095193618, 'max_depth': 8, 'min_child_weight': 0.21419516060195726, 'subsample': 0.6000000000000001}, logloss: 0.1994
# [0]	train-error:0.005746	eval-error:0.0058
#
# [1]	train-error:0.00252	eval-error:0.002451
#
# [2]	train-error:0.005981	eval-error:0.006147
#
# [3]	train-error:0.004948	eval-error:0.005018
#
# [4]	train-error:0.00502	eval-error:0.00512
#
# [5]	train-error:0.002529	eval-error:0.002492
#
# [6]	train-error:0.002645	eval-error:0.00266
#
# [7]	train-error:0.002494	eval-error:0.002494
#
# [8]	train-error:0.002611	eval-error:0.002633
#
# [9]	train-error:0.002607	eval-error:0.00263
#
# params: {'colsample_bytree': 0.9, 'gamma': 4.090297587847213e-05, 'max_depth': 4, 'min_child_weight': 0.13827887150371596, 'subsample': 0.65}, logloss: 0.2050
# [0]	train-error:0.000722	eval-error:0.000816
#
# [1]	train-error:0.000499	eval-error:0.00058
#
# [2]	train-error:0.000635	eval-error:0.000686
#
# [3]	train-error:0.00072	eval-error:0.000773
#
# [4]	train-error:0.000574	eval-error:0.000619
#
# [5]	train-error:0.000409	eval-error:0.000449
#
# [6]	train-error:0.000568	eval-error:0.000616
#
# [7]	train-error:0.000416	eval-error:0.000455
#
# [8]	train-error:0.000409	eval-error:0.000458
#
# [9]	train-error:0.000388	eval-error:0.00044
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.009859514973765056, 'max_depth': 9, 'min_child_weight': 0.17683005611166897, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.000694	eval-error:0.000791
#
# [1]	train-error:0.000601	eval-error:0.000686
#
# [2]	train-error:0.000735	eval-error:0.000793
#
# [3]	train-error:0.000659	eval-error:0.000702
#
# [4]	train-error:0.000633	eval-error:0.000682
#
# [5]	train-error:0.000656	eval-error:0.000705
#
# [6]	train-error:0.000566	eval-error:0.000625
#
# [7]	train-error:0.000571	eval-error:0.000612
#
# [8]	train-error:0.000474	eval-error:0.000535
#
# [9]	train-error:0.000433	eval-error:0.000464
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.08580704370582719, 'max_depth': 9, 'min_child_weight': 0.17448633749771297, 'subsample': 0.6000000000000001}, logloss: 0.1990
# [0]	train-error:0.000756	eval-error:0.000845
#
# [1]	train-error:0.00079	eval-error:0.000838
#
# [2]	train-error:0.001239	eval-error:0.001382
#
# [3]	train-error:0.000901	eval-error:0.001008
#
# [4]	train-error:0.000881	eval-error:0.000976
#
# [5]	train-error:0.000742	eval-error:0.000834
#
# [6]	train-error:0.00067	eval-error:0.00072
#
# [7]	train-error:0.000496	eval-error:0.000537
#
# [8]	train-error:0.000482	eval-error:0.000523
#
# [9]	train-error:0.000488	eval-error:0.00053
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.010654160254300273, 'max_depth': 8, 'min_child_weight': 0.1044954063394301, 'subsample': 0.65}, logloss: 0.1993
# [0]	train-error:0.001418	eval-error:0.001491
#
# [1]	train-error:0.001774	eval-error:0.001921
#
# [2]	train-error:0.00304	eval-error:0.003222
#
# [3]	train-error:0.001704	eval-error:0.001819
#
# [4]	train-error:0.001559	eval-error:0.001708
#
# [5]	train-error:0.001077	eval-error:0.001194
#
# [6]	train-error:0.001181	eval-error:0.001285
#
# [7]	train-error:0.001078	eval-error:0.001192
#
# [8]	train-error:0.001054	eval-error:0.001169
#
# [9]	train-error:0.00105	eval-error:0.001165
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.7216871140106421, 'max_depth': 6, 'min_child_weight': 0.28850912921487637, 'subsample': 0.75}, logloss: 0.2008
# [0]	train-error:0.002243	eval-error:0.002241
#
# [1]	train-error:0.002349	eval-error:0.002313
#
# [2]	train-error:0.004243	eval-error:0.004407
#
# [3]	train-error:0.003508	eval-error:0.003759
#
# [4]	train-error:0.001271	eval-error:0.001411
#
# [5]	train-error:0.001503	eval-error:0.001581
#
# [6]	train-error:0.00125	eval-error:0.001375
#
# [7]	train-error:0.001192	eval-error:0.00133
#
# [8]	train-error:0.001215	eval-error:0.001366
#
# [9]	train-error:0.001252	eval-error:0.001384
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0002804458794139654, 'max_depth': 5, 'min_child_weight': 0.13479653133215624, 'subsample': 0.6000000000000001}, logloss: 0.2024
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.006279	eval-error:0.006466
#
# [2]	train-error:0.007733	eval-error:0.007959
#
# [3]	train-error:0.007751	eval-error:0.00795
#
# [4]	train-error:0.007955	eval-error:0.008183
#
# [5]	train-error:0.007955	eval-error:0.008183
#
# [6]	train-error:0.007953	eval-error:0.008183
#
# [7]	train-error:0.007323	eval-error:0.007542
#
# [8]	train-error:0.007162	eval-error:0.007338
#
# [9]	train-error:0.007139	eval-error:0.007327
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0025007644858749, 'max_depth': 3, 'min_child_weight': 0.112182768539731, 'subsample': 0.75}, logloss: 0.2093
# [0]	train-error:0.000768	eval-error:0.000841
#
# [1]	train-error:0.00068	eval-error:0.000716
#
# [2]	train-error:0.001328	eval-error:0.001445
#
# [3]	train-error:0.000899	eval-error:0.000974
#
# [4]	train-error:0.001237	eval-error:0.001319
#
# [5]	train-error:0.000965	eval-error:0.001031
#
# [6]	train-error:0.000899	eval-error:0.000945
#
# [7]	train-error:0.000779	eval-error:0.000818
#
# [8]	train-error:0.000636	eval-error:0.000684
#
# [9]	train-error:0.000524	eval-error:0.000575
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.12697710178190347, 'max_depth': 8, 'min_child_weight': 0.3535711523614866, 'subsample': 0.65}, logloss: 0.1995
# [0]	train-error:0.001016	eval-error:0.001133
#
# [1]	train-error:0.000766	eval-error:0.000852
#
# [2]	train-error:0.00182	eval-error:0.001973
#
# [3]	train-error:0.000939	eval-error:0.001006
#
# [4]	train-error:0.001055	eval-error:0.001137
#
# [5]	train-error:0.000988	eval-error:0.001069
#
# [6]	train-error:0.001049	eval-error:0.00114
#
# [7]	train-error:0.000905	eval-error:0.000954
#
# [8]	train-error:0.000863	eval-error:0.000902
#
# [9]	train-error:0.000964	eval-error:0.00101
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.3724703317784845, 'max_depth': 7, 'min_child_weight': 0.22237979270620645, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.000718	eval-error:0.000813
#
# [1]	train-error:0.000545	eval-error:0.000616
#
# [2]	train-error:0.000646	eval-error:0.000684
#
# [3]	train-error:0.00074	eval-error:0.000782
#
# [4]	train-error:0.000592	eval-error:0.000628
#
# [5]	train-error:0.000457	eval-error:0.000489
#
# [6]	train-error:0.000566	eval-error:0.000585
#
# [7]	train-error:0.000437	eval-error:0.000469
#
# [8]	train-error:0.000412	eval-error:0.000467
#
# [9]	train-error:0.00037	eval-error:0.000421
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.007110709350483384, 'max_depth': 9, 'min_child_weight': 0.18228391699857668, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.000721	eval-error:0.000818
#
# [1]	train-error:0.000494	eval-error:0.000573
#
# [2]	train-error:0.000625	eval-error:0.000671
#
# [3]	train-error:0.000717	eval-error:0.000761
#
# [4]	train-error:0.000569	eval-error:0.000594
#
# [5]	train-error:0.000418	eval-error:0.000455
#
# [6]	train-error:0.000559	eval-error:0.000587
#
# [7]	train-error:0.000423	eval-error:0.000458
#
# [8]	train-error:0.000412	eval-error:0.00046
#
# [9]	train-error:0.000391	eval-error:0.000433
#
# params: {'colsample_bytree': 0.9, 'gamma': 8.992115599785696e-05, 'max_depth': 9, 'min_child_weight': 0.12428668463892598, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.001028	eval-error:0.001137
#
# [1]	train-error:0.000762	eval-error:0.000847
#
# [2]	train-error:0.001801	eval-error:0.001953
#
# [3]	train-error:0.001507	eval-error:0.001602
#
# [4]	train-error:0.001068	eval-error:0.001155
#
# [5]	train-error:0.000969	eval-error:0.001042
#
# [6]	train-error:0.00096	eval-error:0.001017
#
# [7]	train-error:0.000939	eval-error:0.001004
#
# [8]	train-error:0.000766	eval-error:0.000829
#
# [9]	train-error:0.00076	eval-error:0.000804
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 7.4778232081070736e-06, 'max_depth': 7, 'min_child_weight': 0.1452511135232805, 'subsample': 0.65}, logloss: 0.2002
# [0]	train-error:0.000767	eval-error:0.000845
#
# [1]	train-error:0.00072	eval-error:0.000804
#
# [2]	train-error:0.000816	eval-error:0.000854
#
# [3]	train-error:0.000955	eval-error:0.001029
#
# [4]	train-error:0.00087	eval-error:0.000929
#
# [5]	train-error:0.000668	eval-error:0.000725
#
# [6]	train-error:0.000767	eval-error:0.000816
#
# [7]	train-error:0.000623	eval-error:0.000686
#
# [8]	train-error:0.000614	eval-error:0.000677
#
# [9]	train-error:0.000615	eval-error:0.00068
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.680472536787851e-06, 'max_depth': 8, 'min_child_weight': 0.2438627134472468, 'subsample': 0.75}, logloss: 0.1993
# [0]	train-error:0.000717	eval-error:0.000813
#
# [1]	train-error:0.000498	eval-error:0.000585
#
# [2]	train-error:0.000628	eval-error:0.000673
#
# [3]	train-error:0.000725	eval-error:0.00077
#
# [4]	train-error:0.000582	eval-error:0.000623
#
# [5]	train-error:0.00042	eval-error:0.00046
#
# [6]	train-error:0.000561	eval-error:0.000587
#
# [7]	train-error:0.000427	eval-error:0.000469
#
# [8]	train-error:0.000412	eval-error:0.000455
#
# [9]	train-error:0.00039	eval-error:0.000435
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.6100966767806937e-05, 'max_depth': 9, 'min_child_weight': 0.18523661492377344, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.000828	eval-error:0.000913
#
# [1]	train-error:0.000742	eval-error:0.000811
#
# [2]	train-error:0.001325	eval-error:0.001457
#
# [3]	train-error:0.000924	eval-error:0.000999
#
# [4]	train-error:0.001025	eval-error:0.00111
#
# [5]	train-error:0.000957	eval-error:0.001024
#
# [6]	train-error:0.000946	eval-error:0.001026
#
# [7]	train-error:0.000767	eval-error:0.000834
#
# [8]	train-error:0.000692	eval-error:0.000745
#
# [9]	train-error:0.00059	eval-error:0.000643
#
# params: {'colsample_bytree': 0.8, 'gamma': 2.8233393253596817e-05, 'max_depth': 8, 'min_child_weight': 0.10013349934289194, 'subsample': 0.7000000000000001}, logloss: 0.1994
# 100%|██████████| 100/100 [43:15<00:00, 25.95s/it, best loss: 0.19872636520076728]
# best params:{'colsample_bytree': 0.9500000000000001, 'gamma': 6.395076340533998e-06, 'max_depth': 9, 'min_child_weight': 0.1864220538154882, 'subsample': 0.9}, score:0.1987

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 6.395076340533998e-06,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 0.1864220538154882,
    'max_depth': 9,
    'subsample': 0.9,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.000472	eval-error:0.000498
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000446	eval-error:0.000487
# [2]	train-error:0.000454	eval-error:0.00048
# [3]	train-error:0.000399	eval-error:0.000428
# [4]	train-error:0.000422	eval-error:0.000437
# [5]	train-error:0.000402	eval-error:0.000426
# [6]	train-error:0.000428	eval-error:0.000455
# [7]	train-error:0.000416	eval-error:0.000451
# [8]	train-error:0.0004	eval-error:0.000421
# [9]	train-error:0.000372	eval-error:0.000392
# [10]	train-error:0.000393	eval-error:0.000412
# [11]	train-error:0.000367	eval-error:0.000392
# [12]	train-error:0.00034	eval-error:0.000358
# [13]	train-error:0.000323	eval-error:0.00034
# [14]	train-error:0.000319	eval-error:0.000338
# [15]	train-error:0.000242	eval-error:0.000256
# [16]	train-error:0.000229	eval-error:0.00024
# [17]	train-error:0.000223	eval-error:0.000233
# [18]	train-error:0.000186	eval-error:0.000208
# [19]	train-error:0.000176	eval-error:0.00019
# [20]	train-error:0.000175	eval-error:0.000199
# [21]	train-error:0.000153	eval-error:0.000184
# [22]	train-error:0.000153	eval-error:0.000181
# [23]	train-error:0.000153	eval-error:0.000181
# [24]	train-error:0.000148	eval-error:0.000172
# [25]	train-error:0.000145	eval-error:0.000168
# [26]	train-error:0.00014	eval-error:0.000163
# [27]	train-error:0.000138	eval-error:0.000163
# [28]	train-error:0.00013	eval-error:0.000156
# [29]	train-error:0.000125	eval-error:0.00015
# [30]	train-error:0.000112	eval-error:0.000136
# [31]	train-error:9.9e-05	eval-error:0.000127
# [32]	train-error:9.9e-05	eval-error:0.000127
# [33]	train-error:9.9e-05	eval-error:0.000125
# [34]	train-error:8e-05	eval-error:9.5e-05
# [35]	train-error:8.3e-05	eval-error:0.000104
# [36]	train-error:7.2e-05	eval-error:8.2e-05
# [37]	train-error:6.7e-05	eval-error:7.9e-05
# [38]	train-error:4.7e-05	eval-error:5e-05
# [39]	train-error:4.5e-05	eval-error:5e-05
# [40]	train-error:4.3e-05	eval-error:4.5e-05
# [41]	train-error:3.4e-05	eval-error:3.6e-05
# [42]	train-error:3.1e-05	eval-error:2.9e-05
# [43]	train-error:2.8e-05	eval-error:2.5e-05
# [44]	train-error:2.5e-05	eval-error:2.5e-05
# [45]	train-error:2.5e-05	eval-error:2.3e-05
# [46]	train-error:2.3e-05	eval-error:2e-05
# [47]	train-error:2.1e-05	eval-error:1.8e-05
# [48]	train-error:2e-05	eval-error:1.8e-05
# [49]	train-error:2e-05	eval-error:1.8e-05
# [50]	train-error:1.6e-05	eval-error:1.8e-05
# [51]	train-error:1.5e-05	eval-error:1.8e-05
# [52]	train-error:1.5e-05	eval-error:1.8e-05
# [53]	train-error:1.5e-05	eval-error:1.8e-05
# [54]	train-error:1.5e-05	eval-error:1.8e-05
# [55]	train-error:1.4e-05	eval-error:1.6e-05
# [56]	train-error:8e-06	eval-error:1.1e-05
# [57]	train-error:6e-06	eval-error:9e-06
# [58]	train-error:5e-06	eval-error:9e-06
# [59]	train-error:5e-06	eval-error:9e-06
# [60]	train-error:5e-06	eval-error:9e-06
# [61]	train-error:5e-06	eval-error:9e-06
# [62]	train-error:3e-06	eval-error:9e-06
# [63]	train-error:3e-06	eval-error:9e-06
# [64]	train-error:3e-06	eval-error:9e-06
# [65]	train-error:3e-06	eval-error:9e-06
# [66]	train-error:3e-06	eval-error:9e-06
# [67]	train-error:3e-06	eval-error:9e-06
# [68]	train-error:3e-06	eval-error:9e-06
# [69]	train-error:3e-06	eval-error:7e-06
# [70]	train-error:3e-06	eval-error:7e-06
# [71]	train-error:3e-06	eval-error:7e-06
# [72]	train-error:3e-06	eval-error:7e-06
# [73]	train-error:3e-06	eval-error:7e-06
# [74]	train-error:3e-06	eval-error:7e-06
# [75]	train-error:3e-06	eval-error:7e-06
# [76]	train-error:3e-06	eval-error:7e-06
# [77]	train-error:3e-06	eval-error:7e-06
# [78]	train-error:3e-06	eval-error:7e-06
# [79]	train-error:3e-06	eval-error:7e-06
# [80]	train-error:3e-06	eval-error:7e-06
# [81]	train-error:3e-06	eval-error:7e-06
# [82]	train-error:3e-06	eval-error:7e-06
# [83]	train-error:3e-06	eval-error:7e-06
# [84]	train-error:3e-06	eval-error:7e-06
# [85]	train-error:3e-06	eval-error:7e-06
# [86]	train-error:3e-06	eval-error:7e-06
# [87]	train-error:3e-06	eval-error:7e-06
# [88]	train-error:3e-06	eval-error:7e-06
# [89]	train-error:3e-06	eval-error:7e-06
# Stopping. Best iteration:
# [69]	train-error:3e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0001

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_23_param_tuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_23_param_tuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000443
# 1  0.000443
# 2  0.000443
# 3  0.000443
# 4  0.000443

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000443
# 1   1  0.000443
# 2   2  0.000443
# 3   3  0.000443
# 4   4  0.000443

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_23_param_tuning.csv',index=False)

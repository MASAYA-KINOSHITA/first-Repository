# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.006162	eval-error:0.006285
#
# [1]	train-error:0.005944	eval-error:0.006133
#
# [2]	train-error:0.006281	eval-error:0.006495
#
# [3]	train-error:0.001791	eval-error:0.00189
#
# [4]	train-error:0.002295	eval-error:0.002313
#
# [5]	train-error:0.002454	eval-error:0.002501
#
# [6]	train-error:0.002309	eval-error:0.00244
#
# [7]	train-error:0.001637	eval-error:0.001742
#
# [8]	train-error:0.002275	eval-error:0.002297
#
# [9]	train-error:0.001572	eval-error:0.001695
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0005864125611843032, 'max_depth': 4, 'min_child_weight': 0.5259282828950771, 'subsample': 0.9500000000000001}, logloss: 0.2058
# [0]	train-error:0.011315	eval-error:0.011389
#
# [1]	train-error:0.006458	eval-error:0.006582
#
# [2]	train-error:0.006505	eval-error:0.00667
#
# [3]	train-error:0.007246	eval-error:0.007424
#
# [4]	train-error:0.007239	eval-error:0.007415
#
# [5]	train-error:0.007339	eval-error:0.007556
#
# [6]	train-error:0.00776	eval-error:0.007954
#
# [7]	train-error:0.007308	eval-error:0.007524
#
# [8]	train-error:0.007165	eval-error:0.007345
#
# [9]	train-error:0.006326	eval-error:0.006523
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.048430453300745385, 'max_depth': 3, 'min_child_weight': 0.4148421741030059, 'subsample': 0.9500000000000001}, logloss: 0.2096
# [0]	train-error:0.001293	eval-error:0.001387
#
# [1]	train-error:0.0011	eval-error:0.001248
#
# [2]	train-error:0.000924	eval-error:0.001083
#
# [3]	train-error:0.000838	eval-error:0.000976
#
# [4]	train-error:0.000846	eval-error:0.000974
#
# [5]	train-error:0.000808	eval-error:0.000918
#
# [6]	train-error:0.000697	eval-error:0.000788
#
# [7]	train-error:0.000578	eval-error:0.000675
#
# [8]	train-error:0.000549	eval-error:0.000634
#
# [9]	train-error:0.000554	eval-error:0.00065
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.05191384732197518, 'max_depth': 8, 'min_child_weight': 0.7067609769089688, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.000544	eval-error:0.0006
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000479	eval-error:0.000589
#
# [3]	train-error:0.000453	eval-error:0.000555
#
# [4]	train-error:0.000443	eval-error:0.000501
#
# [5]	train-error:0.000386	eval-error:0.000469
#
# [6]	train-error:0.000365	eval-error:0.000408
#
# [7]	train-error:0.000356	eval-error:0.000415
#
# [8]	train-error:0.000351	eval-error:0.000408
#
# [9]	train-error:0.00035	eval-error:0.000399
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 3.71815578101404e-07, 'max_depth': 9, 'min_child_weight': 0.23638671475773687, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.001411	eval-error:0.001477
#
# [1]	train-error:0.00101	eval-error:0.001128
#
# [2]	train-error:0.001325	eval-error:0.00143
#
# [3]	train-error:0.00122	eval-error:0.001321
#
# [4]	train-error:0.001269	eval-error:0.001355
#
# [5]	train-error:0.001225	eval-error:0.001341
#
# [6]	train-error:0.001172	eval-error:0.00128
#
# [7]	train-error:0.001149	eval-error:0.001253
#
# [8]	train-error:0.001123	eval-error:0.001239
#
# [9]	train-error:0.001096	eval-error:0.001212
#
# params: {'colsample_bytree': 0.8, 'gamma': 3.837470244268703e-06, 'max_depth': 6, 'min_child_weight': 1.7552835954656534, 'subsample': 0.65}, logloss: 0.2009
# [0]	train-error:0.001416	eval-error:0.001491
#
# [1]	train-error:0.00099	eval-error:0.001108
#
# [2]	train-error:0.001048	eval-error:0.001183
#
# [3]	train-error:0.001263	eval-error:0.001382
#
# [4]	train-error:0.001138	eval-error:0.00126
#
# [5]	train-error:0.001114	eval-error:0.001228
#
# [6]	train-error:0.001088	eval-error:0.001189
#
# [7]	train-error:0.001097	eval-error:0.001217
#
# [8]	train-error:0.001109	eval-error:0.00123
#
# [9]	train-error:0.001097	eval-error:0.001219
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.624521195500755, 'max_depth': 6, 'min_child_weight': 0.18125421669087968, 'subsample': 0.75}, logloss: 0.2006
# [0]	train-error:0.001403	eval-error:0.001473
#
# [1]	train-error:0.000904	eval-error:0.001022
#
# [2]	train-error:0.001044	eval-error:0.001155
#
# [3]	train-error:0.001006	eval-error:0.001112
#
# [4]	train-error:0.001088	eval-error:0.001214
#
# [5]	train-error:0.00097	eval-error:0.001094
#
# [6]	train-error:0.000908	eval-error:0.001042
#
# [7]	train-error:0.000902	eval-error:0.001017
#
# [8]	train-error:0.001066	eval-error:0.001187
#
# [9]	train-error:0.001043	eval-error:0.00116
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.9660999916928382e-08, 'max_depth': 6, 'min_child_weight': 0.7289175321768143, 'subsample': 0.75}, logloss: 0.2009
# [0]	train-error:0.011316	eval-error:0.011389
#
# [1]	train-error:0.006498	eval-error:0.00664
#
# [2]	train-error:0.006498	eval-error:0.006668
#
# [3]	train-error:0.007258	eval-error:0.00744
#
# [4]	train-error:0.007368	eval-error:0.007587
#
# [5]	train-error:0.007732	eval-error:0.007918
#
# [6]	train-error:0.007774	eval-error:0.007964
#
# [7]	train-error:0.007347	eval-error:0.007553
#
# [8]	train-error:0.007201	eval-error:0.00737
#
# [9]	train-error:0.006324	eval-error:0.00652
#
# params: {'colsample_bytree': 0.75, 'gamma': 5.7883674809159656e-05, 'max_depth': 3, 'min_child_weight': 0.28083671152839124, 'subsample': 0.6000000000000001}, logloss: 0.2096
# [0]	train-error:0.002297	eval-error:0.002293
#
# [1]	train-error:0.001327	eval-error:0.001452
#
# [2]	train-error:0.001278	eval-error:0.001427
#
# [3]	train-error:0.001229	eval-error:0.001402
#
# [4]	train-error:0.001186	eval-error:0.001298
#
# [5]	train-error:0.001029	eval-error:0.001144
#
# [6]	train-error:0.001041	eval-error:0.001169
#
# [7]	train-error:0.000979	eval-error:0.001083
#
# [8]	train-error:0.000932	eval-error:0.001076
#
# [9]	train-error:0.000919	eval-error:0.001042
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.2812358038277519, 'max_depth': 6, 'min_child_weight': 0.3761280932105986, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.008467	eval-error:0.008713
#
# [1]	train-error:0.00788	eval-error:0.008131
#
# [2]	train-error:0.008288	eval-error:0.00853
#
# [3]	train-error:0.007152	eval-error:0.007377
#
# [4]	train-error:0.007108	eval-error:0.007322
#
# [5]	train-error:0.007094	eval-error:0.007318
#
# [6]	train-error:0.007069	eval-error:0.00732
#
# [7]	train-error:0.006741	eval-error:0.006989
#
# [8]	train-error:0.006363	eval-error:0.006618
#
# [9]	train-error:0.00612	eval-error:0.006339
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 2.0006824363933872e-07, 'max_depth': 3, 'min_child_weight': 8.854030143429343, 'subsample': 0.8}, logloss: 0.2108
# [0]	train-error:0.000788	eval-error:0.000879
#
# [1]	train-error:0.00071	eval-error:0.000804
#
# [2]	train-error:0.000532	eval-error:0.000585
#
# [3]	train-error:0.000687	eval-error:0.000766
#
# [4]	train-error:0.000685	eval-error:0.000766
#
# [5]	train-error:0.000662	eval-error:0.000745
#
# [6]	train-error:0.000673	eval-error:0.000745
#
# [7]	train-error:0.000656	eval-error:0.00073
#
# [8]	train-error:0.000649	eval-error:0.000734
#
# [9]	train-error:0.00063	eval-error:0.000723
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0844150413085912e-06, 'max_depth': 8, 'min_child_weight': 3.399277304732081, 'subsample': 0.9}, logloss: 0.1992
# [0]	train-error:0.000891	eval-error:0.000965
#
# [1]	train-error:0.000725	eval-error:0.000827
#
# [2]	train-error:0.000797	eval-error:0.000909
#
# [3]	train-error:0.000784	eval-error:0.000913
#
# [4]	train-error:0.000683	eval-error:0.000784
#
# [5]	train-error:0.000732	eval-error:0.000856
#
# [6]	train-error:0.000731	eval-error:0.000859
#
# [7]	train-error:0.000591	eval-error:0.000682
#
# [8]	train-error:0.00061	eval-error:0.000696
#
# [9]	train-error:0.000652	eval-error:0.000743
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 5.663287230135024e-06, 'max_depth': 7, 'min_child_weight': 0.5432931797406539, 'subsample': 0.8}, logloss: 0.1999
# [0]	train-error:0.001414	eval-error:0.001479
#
# [1]	train-error:0.000987	eval-error:0.001103
#
# [2]	train-error:0.001224	eval-error:0.001346
#
# [3]	train-error:0.001094	eval-error:0.001185
#
# [4]	train-error:0.001047	eval-error:0.001153
#
# [5]	train-error:0.001118	eval-error:0.001239
#
# [6]	train-error:0.001135	eval-error:0.001246
#
# [7]	train-error:0.001115	eval-error:0.001235
#
# [8]	train-error:0.00112	eval-error:0.001237
#
# [9]	train-error:0.001118	eval-error:0.001235
#
# params: {'colsample_bytree': 0.9, 'gamma': 4.932516608473859e-06, 'max_depth': 6, 'min_child_weight': 0.16158953109310964, 'subsample': 0.8500000000000001}, logloss: 0.2005
# [0]	train-error:0.006346	eval-error:0.006536
#
# [1]	train-error:0.00592	eval-error:0.005936
#
# [2]	train-error:0.00275	eval-error:0.002848
#
# [3]	train-error:0.001946	eval-error:0.002102
#
# [4]	train-error:0.002618	eval-error:0.002667
#
# [5]	train-error:0.002629	eval-error:0.002685
#
# [6]	train-error:0.002375	eval-error:0.002517
#
# [7]	train-error:0.001877	eval-error:0.002057
#
# [8]	train-error:0.002362	eval-error:0.002402
#
# [9]	train-error:0.002294	eval-error:0.00232
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.028184366307420092, 'max_depth': 4, 'min_child_weight': 6.59782200628263, 'subsample': 0.7000000000000001}, logloss: 0.2055
# [0]	train-error:0.001414	eval-error:0.001479
#
# [1]	train-error:0.000988	eval-error:0.001103
#
# [2]	train-error:0.001067	eval-error:0.001178
#
# [3]	train-error:0.001091	eval-error:0.001183
#
# [4]	train-error:0.001045	eval-error:0.001144
#
# [5]	train-error:0.001121	eval-error:0.001242
#
# [6]	train-error:0.001131	eval-error:0.001248
#
# [7]	train-error:0.001103	eval-error:0.001226
#
# [8]	train-error:0.001118	eval-error:0.001244
#
# [9]	train-error:0.001108	eval-error:0.001219
#
# params: {'colsample_bytree': 0.9, 'gamma': 6.329349834042407e-07, 'max_depth': 6, 'min_child_weight': 0.2643129868722965, 'subsample': 0.9}, logloss: 0.2005
# [0]	train-error:0.000822	eval-error:0.000913
#
# [1]	train-error:0.000929	eval-error:0.001049
#
# [2]	train-error:0.000828	eval-error:0.000927
#
# [3]	train-error:0.000813	eval-error:0.000918
#
# [4]	train-error:0.000807	eval-error:0.00089
#
# [5]	train-error:0.000776	eval-error:0.00087
#
# [6]	train-error:0.000779	eval-error:0.000856
#
# [7]	train-error:0.000715	eval-error:0.000773
#
# [8]	train-error:0.000745	eval-error:0.000836
#
# [9]	train-error:0.00072	eval-error:0.000804
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0010512469595453015, 'max_depth': 7, 'min_child_weight': 0.41929012449680825, 'subsample': 0.8500000000000001}, logloss: 0.1997
# [0]	train-error:0.0041	eval-error:0.0043
#
# [1]	train-error:0.00141	eval-error:0.001559
#
# [2]	train-error:0.001041	eval-error:0.001169
#
# [3]	train-error:0.000902	eval-error:0.001031
#
# [4]	train-error:0.000811	eval-error:0.00092
#
# [5]	train-error:0.000853	eval-error:0.000956
#
# [6]	train-error:0.000718	eval-error:0.000804
#
# [7]	train-error:0.000751	eval-error:0.000843
#
# [8]	train-error:0.000727	eval-error:0.000818
#
# [9]	train-error:0.000708	eval-error:0.000782
#
# params: {'colsample_bytree': 0.65, 'gamma': 3.2299857496483002e-06, 'max_depth': 7, 'min_child_weight': 9.413094543165476, 'subsample': 0.8500000000000001}, logloss: 0.2002
# [0]	train-error:0.001439	eval-error:0.001507
#
# [1]	train-error:0.001057	eval-error:0.00118
#
# [2]	train-error:0.001189	eval-error:0.001314
#
# [3]	train-error:0.001286	eval-error:0.001355
#
# [4]	train-error:0.001295	eval-error:0.001359
#
# [5]	train-error:0.001109	eval-error:0.001187
#
# [6]	train-error:0.001228	eval-error:0.001334
#
# [7]	train-error:0.001202	eval-error:0.001319
#
# [8]	train-error:0.001141	eval-error:0.001262
#
# [9]	train-error:0.001109	eval-error:0.001255
#
# params: {'colsample_bytree': 0.8, 'gamma': 3.241641524037846e-05, 'max_depth': 6, 'min_child_weight': 9.753785515214824, 'subsample': 0.75}, logloss: 0.2009
# [0]	train-error:0.006173	eval-error:0.006298
#
# [1]	train-error:0.006292	eval-error:0.006418
#
# [2]	train-error:0.002859	eval-error:0.002825
#
# [3]	train-error:0.002705	eval-error:0.002644
#
# [4]	train-error:0.002716	eval-error:0.002707
#
# [5]	train-error:0.002064	eval-error:0.002136
#
# [6]	train-error:0.002724	eval-error:0.002714
#
# [7]	train-error:0.002698	eval-error:0.002689
#
# [8]	train-error:0.002625	eval-error:0.002642
#
# [9]	train-error:0.002593	eval-error:0.002614
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.11236298462868302, 'max_depth': 4, 'min_child_weight': 8.137047382019599, 'subsample': 0.9}, logloss: 0.2048
# [0]	train-error:0.004055	eval-error:0.004282
#
# [1]	train-error:0.001383	eval-error:0.001529
#
# [2]	train-error:0.001001	eval-error:0.001121
#
# [3]	train-error:0.00084	eval-error:0.000965
#
# [4]	train-error:0.000764	eval-error:0.000875
#
# [5]	train-error:0.000782	eval-error:0.000877
#
# [6]	train-error:0.000702	eval-error:0.000788
#
# [7]	train-error:0.000683	eval-error:0.000759
#
# [8]	train-error:0.000683	eval-error:0.000754
#
# [9]	train-error:0.000672	eval-error:0.00075
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.16147901233788262, 'max_depth': 7, 'min_child_weight': 4.507888430278641, 'subsample': 0.8500000000000001}, logloss: 0.2001
# [0]	train-error:0.000742	eval-error:0.000827
#
# [1]	train-error:0.000683	eval-error:0.000764
#
# [2]	train-error:0.000668	eval-error:0.000748
#
# [3]	train-error:0.000661	eval-error:0.000745
#
# [4]	train-error:0.000654	eval-error:0.000718
#
# [5]	train-error:0.000664	eval-error:0.000743
#
# [6]	train-error:0.000465	eval-error:0.000498
#
# [7]	train-error:0.00042	eval-error:0.000471
#
# [8]	train-error:0.000432	eval-error:0.000483
#
# [9]	train-error:0.000421	eval-error:0.000478
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.1472122721874076e-08, 'max_depth': 9, 'min_child_weight': 1.7954193118187165, 'subsample': 0.6000000000000001}, logloss: 0.1987
# [0]	train-error:0.000575	eval-error:0.000632
#
# [1]	train-error:0.000579	eval-error:0.000641
#
# [2]	train-error:0.000594	eval-error:0.000677
#
# [3]	train-error:0.000456	eval-error:0.000523
#
# [4]	train-error:0.000479	eval-error:0.000557
#
# [5]	train-error:0.000381	eval-error:0.000433
#
# [6]	train-error:0.000385	eval-error:0.000442
#
# [7]	train-error:0.000351	eval-error:0.000401
#
# [8]	train-error:0.000343	eval-error:0.000392
#
# [9]	train-error:0.000347	eval-error:0.000392
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.4158897689148328e-08, 'max_depth': 9, 'min_child_weight': 1.4631659521849951, 'subsample': 0.6000000000000001}, logloss: 0.1987
# [0]	train-error:0.000622	eval-error:0.000673
#
# [1]	train-error:0.000551	eval-error:0.000623
#
# [2]	train-error:0.000597	eval-error:0.000673
#
# [3]	train-error:0.000512	eval-error:0.000589
#
# [4]	train-error:0.000548	eval-error:0.000609
#
# [5]	train-error:0.000437	eval-error:0.000501
#
# [6]	train-error:0.000409	eval-error:0.000476
#
# [7]	train-error:0.000396	eval-error:0.000464
#
# [8]	train-error:0.000396	eval-error:0.000446
#
# [9]	train-error:0.000397	eval-error:0.000451
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.9296988757678562e-08, 'max_depth': 9, 'min_child_weight': 1.737835408569636, 'subsample': 0.65}, logloss: 0.1989
# [0]	train-error:0.000766	eval-error:0.000843
#
# [1]	train-error:0.000764	eval-error:0.000852
#
# [2]	train-error:0.000841	eval-error:0.000936
#
# [3]	train-error:0.000702	eval-error:0.000782
#
# [4]	train-error:0.000701	eval-error:0.000777
#
# [5]	train-error:0.000705	eval-error:0.000784
#
# [6]	train-error:0.00068	eval-error:0.000768
#
# [7]	train-error:0.000669	eval-error:0.000741
#
# [8]	train-error:0.000667	eval-error:0.000734
#
# [9]	train-error:0.000674	eval-error:0.000754
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 7.907227632917233e-08, 'max_depth': 8, 'min_child_weight': 1.7006465655007834, 'subsample': 0.65}, logloss: 0.1991
# [0]	train-error:0.000575	eval-error:0.000632
#
# [1]	train-error:0.000577	eval-error:0.000643
#
# [2]	train-error:0.000557	eval-error:0.000621
#
# [3]	train-error:0.000412	eval-error:0.00046
#
# [4]	train-error:0.000403	eval-error:0.000458
#
# [5]	train-error:0.000485	eval-error:0.000546
#
# [6]	train-error:0.000402	eval-error:0.000451
#
# [7]	train-error:0.00039	eval-error:0.000424
#
# [8]	train-error:0.000393	eval-error:0.000435
#
# [9]	train-error:0.000384	eval-error:0.000437
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.1000797128151871e-08, 'max_depth': 9, 'min_child_weight': 1.2785948441571158, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.00066	eval-error:0.00072
#
# [1]	train-error:0.000625	eval-error:0.000696
#
# [2]	train-error:0.000646	eval-error:0.000732
#
# [3]	train-error:0.000594	eval-error:0.000666
#
# [4]	train-error:0.000623	eval-error:0.000673
#
# [5]	train-error:0.000472	eval-error:0.000519
#
# [6]	train-error:0.000493	eval-error:0.000546
#
# [7]	train-error:0.000492	eval-error:0.00053
#
# [8]	train-error:0.000486	eval-error:0.000526
#
# [9]	train-error:0.000486	eval-error:0.000528
#
# params: {'colsample_bytree': 0.75, 'gamma': 5.5958427950772954e-08, 'max_depth': 8, 'min_child_weight': 2.662556865150531, 'subsample': 0.7000000000000001}, logloss: 0.1992
# [0]	train-error:0.000592	eval-error:0.000652
#
# [1]	train-error:0.000594	eval-error:0.000652
#
# [2]	train-error:0.000599	eval-error:0.000662
#
# [3]	train-error:0.000524	eval-error:0.000591
#
# [4]	train-error:0.000447	eval-error:0.000487
#
# [5]	train-error:0.000562	eval-error:0.000655
#
# [6]	train-error:0.00042	eval-error:0.000458
#
# [7]	train-error:0.00039	eval-error:0.00043
#
# [8]	train-error:0.000415	eval-error:0.000464
#
# [9]	train-error:0.000372	eval-error:0.000428
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.007105475269431501, 'max_depth': 9, 'min_child_weight': 3.3128530785655355, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.00076	eval-error:0.000843
#
# [1]	train-error:0.000763	eval-error:0.00085
#
# [2]	train-error:0.000839	eval-error:0.000936
#
# [3]	train-error:0.000698	eval-error:0.000777
#
# [4]	train-error:0.000696	eval-error:0.000775
#
# [5]	train-error:0.000696	eval-error:0.000779
#
# [6]	train-error:0.000682	eval-error:0.000768
#
# [7]	train-error:0.000667	eval-error:0.000741
#
# [8]	train-error:0.000661	eval-error:0.000736
#
# [9]	train-error:0.000664	eval-error:0.000736
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.212276328521351e-08, 'max_depth': 8, 'min_child_weight': 1.0427577680172084, 'subsample': 0.65}, logloss: 0.1991
# [0]	train-error:0.002323	eval-error:0.002277
#
# [1]	train-error:0.001661	eval-error:0.001699
#
# [2]	train-error:0.002448	eval-error:0.002404
#
# [3]	train-error:0.001371	eval-error:0.001455
#
# [4]	train-error:0.001676	eval-error:0.001742
#
# [5]	train-error:0.001351	eval-error:0.001448
#
# [6]	train-error:0.001519	eval-error:0.001588
#
# [7]	train-error:0.001346	eval-error:0.001452
#
# [8]	train-error:0.001306	eval-error:0.001405
#
# [9]	train-error:0.001274	eval-error:0.001364
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.00023088359952503642, 'max_depth': 5, 'min_child_weight': 2.441877482934512, 'subsample': 0.6000000000000001}, logloss: 0.2027
# [0]	train-error:0.002319	eval-error:0.002281
#
# [1]	train-error:0.001336	eval-error:0.001439
#
# [2]	train-error:0.002223	eval-error:0.002402
#
# [3]	train-error:0.00139	eval-error:0.001527
#
# [4]	train-error:0.001509	eval-error:0.001618
#
# [5]	train-error:0.00126	eval-error:0.001368
#
# [6]	train-error:0.001291	eval-error:0.001414
#
# [7]	train-error:0.001274	eval-error:0.0014
#
# [8]	train-error:0.001367	eval-error:0.0015
#
# [9]	train-error:0.001188	eval-error:0.001348
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.2613974566517524e-08, 'max_depth': 5, 'min_child_weight': 0.11558207879074531, 'subsample': 0.65}, logloss: 0.2027
# [0]	train-error:0.000601	eval-error:0.000668
#
# [1]	train-error:0.000557	eval-error:0.000655
#
# [2]	train-error:0.000609	eval-error:0.000677
#
# [3]	train-error:0.000557	eval-error:0.000637
#
# [4]	train-error:0.000491	eval-error:0.000541
#
# [5]	train-error:0.000423	eval-error:0.000492
#
# [6]	train-error:0.000426	eval-error:0.000496
#
# [7]	train-error:0.000397	eval-error:0.000455
#
# [8]	train-error:0.000415	eval-error:0.000474
#
# [9]	train-error:0.000398	eval-error:0.000451
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.3315253990756275e-05, 'max_depth': 9, 'min_child_weight': 4.755827219637668, 'subsample': 0.7000000000000001}, logloss: 0.1989
# [0]	train-error:0.000649	eval-error:0.000705
#
# [1]	train-error:0.00062	eval-error:0.000684
#
# [2]	train-error:0.000631	eval-error:0.000702
#
# [3]	train-error:0.000604	eval-error:0.000666
#
# [4]	train-error:0.000671	eval-error:0.000741
#
# [5]	train-error:0.000696	eval-error:0.000779
#
# [6]	train-error:0.000671	eval-error:0.000736
#
# [7]	train-error:0.000652	eval-error:0.000709
#
# [8]	train-error:0.000642	eval-error:0.000705
#
# [9]	train-error:0.000652	eval-error:0.000716
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.1662258066495059e-07, 'max_depth': 8, 'min_child_weight': 0.8176515912049023, 'subsample': 0.6000000000000001}, logloss: 0.1992
# [0]	train-error:0.000621	eval-error:0.000673
#
# [1]	train-error:0.000548	eval-error:0.000621
#
# [2]	train-error:0.000586	eval-error:0.000646
#
# [3]	train-error:0.00052	eval-error:0.000591
#
# [4]	train-error:0.000524	eval-error:0.000585
#
# [5]	train-error:0.00047	eval-error:0.00053
#
# [6]	train-error:0.000409	eval-error:0.000469
#
# [7]	train-error:0.000362	eval-error:0.000437
#
# [8]	train-error:0.000358	eval-error:0.000403
#
# [9]	train-error:0.000345	eval-error:0.000385
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0018075199749826708, 'max_depth': 9, 'min_child_weight': 1.2548716014005705, 'subsample': 0.65}, logloss: 0.1987
# [0]	train-error:0.00225	eval-error:0.002241
#
# [1]	train-error:0.002013	eval-error:0.002064
#
# [2]	train-error:0.002256	eval-error:0.00225
#
# [3]	train-error:0.002233	eval-error:0.002241
#
# [4]	train-error:0.002281	eval-error:0.002291
#
# [5]	train-error:0.002027	eval-error:0.002084
#
# [6]	train-error:0.001578	eval-error:0.001663
#
# [7]	train-error:0.001547	eval-error:0.001631
#
# [8]	train-error:0.001555	eval-error:0.001636
#
# [9]	train-error:0.001504	eval-error:0.001595
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.002007852282848481, 'max_depth': 5, 'min_child_weight': 1.0348326216561763, 'subsample': 0.65}, logloss: 0.2017
# [0]	train-error:0.000724	eval-error:0.000809
#
# [1]	train-error:0.000674	eval-error:0.00075
#
# [2]	train-error:0.000661	eval-error:0.000736
#
# [3]	train-error:0.000662	eval-error:0.000739
#
# [4]	train-error:0.000459	eval-error:0.000503
#
# [5]	train-error:0.000463	eval-error:0.00051
#
# [6]	train-error:0.000438	eval-error:0.000492
#
# [7]	train-error:0.000414	eval-error:0.00048
#
# [8]	train-error:0.0004	eval-error:0.000476
#
# [9]	train-error:0.000396	eval-error:0.000471
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00020883926631721432, 'max_depth': 9, 'min_child_weight': 0.5756645231433615, 'subsample': 0.7000000000000001}, logloss: 0.1986
# [0]	train-error:0.000769	eval-error:0.000836
#
# [1]	train-error:0.000723	eval-error:0.000813
#
# [2]	train-error:0.000838	eval-error:0.000947
#
# [3]	train-error:0.0007	eval-error:0.000793
#
# [4]	train-error:0.000677	eval-error:0.000757
#
# [5]	train-error:0.000679	eval-error:0.000757
#
# [6]	train-error:0.000661	eval-error:0.000736
#
# [7]	train-error:0.000663	eval-error:0.000754
#
# [8]	train-error:0.000632	eval-error:0.000716
#
# [9]	train-error:0.000628	eval-error:0.000716
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0002176461800515858, 'max_depth': 8, 'min_child_weight': 0.5236001712785215, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.000822	eval-error:0.000904
#
# [1]	train-error:0.000944	eval-error:0.001049
#
# [2]	train-error:0.000945	eval-error:0.001058
#
# [3]	train-error:0.000912	eval-error:0.001031
#
# [4]	train-error:0.000938	eval-error:0.001049
#
# [5]	train-error:0.00081	eval-error:0.000895
#
# [6]	train-error:0.000803	eval-error:0.000902
#
# [7]	train-error:0.000745	eval-error:0.000822
#
# [8]	train-error:0.000847	eval-error:0.000952
#
# [9]	train-error:0.000813	eval-error:0.000909
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.009309018468201709, 'max_depth': 7, 'min_child_weight': 2.275175152599755, 'subsample': 0.7000000000000001}, logloss: 0.1996
# [0]	train-error:0.000739	eval-error:0.000816
#
# [1]	train-error:0.000832	eval-error:0.00094
#
# [2]	train-error:0.000671	eval-error:0.000757
#
# [3]	train-error:0.000472	eval-error:0.000526
#
# [4]	train-error:0.000462	eval-error:0.00053
#
# [5]	train-error:0.000457	eval-error:0.000526
#
# [6]	train-error:0.000409	eval-error:0.000458
#
# [7]	train-error:0.000409	eval-error:0.000462
#
# [8]	train-error:0.000345	eval-error:0.000406
#
# [9]	train-error:0.000332	eval-error:0.000394
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00046622013338633783, 'max_depth': 9, 'min_child_weight': 0.10285081740914057, 'subsample': 0.8}, logloss: 0.1986
# [0]	train-error:0.000994	eval-error:0.001119
#
# [1]	train-error:0.000961	eval-error:0.001081
#
# [2]	train-error:0.00096	eval-error:0.001063
#
# [3]	train-error:0.000918	eval-error:0.001024
#
# [4]	train-error:0.000743	eval-error:0.000841
#
# [5]	train-error:0.000788	eval-error:0.000886
#
# [6]	train-error:0.000782	eval-error:0.000861
#
# [7]	train-error:0.000761	eval-error:0.000847
#
# [8]	train-error:0.000731	eval-error:0.000818
#
# [9]	train-error:0.000785	eval-error:0.000865
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.000299496245678228, 'max_depth': 7, 'min_child_weight': 0.11779048408400238, 'subsample': 0.8}, logloss: 0.1997
# [0]	train-error:0.000648	eval-error:0.000723
#
# [1]	train-error:0.000632	eval-error:0.0007
#
# [2]	train-error:0.000631	eval-error:0.000707
#
# [3]	train-error:0.000609	eval-error:0.000668
#
# [4]	train-error:0.000659	eval-error:0.000727
#
# [5]	train-error:0.000685	eval-error:0.000766
#
# [6]	train-error:0.00067	eval-error:0.000741
#
# [7]	train-error:0.000526	eval-error:0.000582
#
# [8]	train-error:0.000638	eval-error:0.000711
#
# [9]	train-error:0.000601	eval-error:0.000682
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 5.112838892959987e-05, 'max_depth': 8, 'min_child_weight': 0.18168462250659528, 'subsample': 0.75}, logloss: 0.1991
# [0]	train-error:0.000477	eval-error:0.000517
#
# [1]	train-error:0.000464	eval-error:0.000503
#
# [2]	train-error:0.000467	eval-error:0.000528
#
# [3]	train-error:0.000378	eval-error:0.000419
#
# [4]	train-error:0.000418	eval-error:0.000462
#
# [5]	train-error:0.000411	eval-error:0.000449
#
# [6]	train-error:0.000404	eval-error:0.000449
#
# [7]	train-error:0.000367	eval-error:0.000412
#
# [8]	train-error:0.000359	eval-error:0.000399
#
# [9]	train-error:0.000347	eval-error:0.000401
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.005649612307648022, 'max_depth': 9, 'min_child_weight': 0.338469691543776, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000768	eval-error:0.000863
#
# [1]	train-error:0.000698	eval-error:0.000793
#
# [2]	train-error:0.000498	eval-error:0.000544
#
# [3]	train-error:0.000662	eval-error:0.000739
#
# [4]	train-error:0.000633	eval-error:0.000702
#
# [5]	train-error:0.000631	eval-error:0.000696
#
# [6]	train-error:0.000648	eval-error:0.000716
#
# [7]	train-error:0.000635	eval-error:0.0007
#
# [8]	train-error:0.000627	eval-error:0.000696
#
# [9]	train-error:0.000608	eval-error:0.000673
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.006525639944653271, 'max_depth': 8, 'min_child_weight': 0.10233115395996803, 'subsample': 0.9500000000000001}, logloss: 0.1991
# [0]	train-error:0.011315	eval-error:0.011389
#
# [1]	train-error:0.00645	eval-error:0.006575
#
# [2]	train-error:0.006501	eval-error:0.006647
#
# [3]	train-error:0.007267	eval-error:0.007454
#
# [4]	train-error:0.00636	eval-error:0.006505
#
# [5]	train-error:0.00626	eval-error:0.006418
#
# [6]	train-error:0.006275	eval-error:0.00643
#
# [7]	train-error:0.006252	eval-error:0.006416
#
# [8]	train-error:0.006274	eval-error:0.006427
#
# [9]	train-error:0.006274	eval-error:0.006427
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.02873081023164552, 'max_depth': 3, 'min_child_weight': 0.32339735515274204, 'subsample': 0.8}, logloss: 0.2094
# [0]	train-error:0.000474	eval-error:0.000514
#
# [1]	train-error:0.000463	eval-error:0.000496
#
# [2]	train-error:0.000466	eval-error:0.000523
#
# [3]	train-error:0.000376	eval-error:0.000415
#
# [4]	train-error:0.000415	eval-error:0.000458
#
# [5]	train-error:0.00041	eval-error:0.000449
#
# [6]	train-error:0.000403	eval-error:0.000449
#
# [7]	train-error:0.000366	eval-error:0.000417
#
# [8]	train-error:0.000349	eval-error:0.00039
#
# [9]	train-error:0.000347	eval-error:0.000401
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0005856065717466329, 'max_depth': 9, 'min_child_weight': 0.20053853105429434, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.00225	eval-error:0.00225
#
# [1]	train-error:0.001985	eval-error:0.002023
#
# [2]	train-error:0.002314	eval-error:0.002279
#
# [3]	train-error:0.001399	eval-error:0.001484
#
# [4]	train-error:0.001393	eval-error:0.001495
#
# [5]	train-error:0.001509	eval-error:0.001588
#
# [6]	train-error:0.001553	eval-error:0.00162
#
# [7]	train-error:0.001472	eval-error:0.001563
#
# [8]	train-error:0.001543	eval-error:0.001647
#
# [9]	train-error:0.001481	eval-error:0.001572
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0032433803752503335, 'max_depth': 5, 'min_child_weight': 0.21260956143799123, 'subsample': 0.9500000000000001}, logloss: 0.2021
# [0]	train-error:0.000887	eval-error:0.000963
#
# [1]	train-error:0.000908	eval-error:0.00102
#
# [2]	train-error:0.000884	eval-error:0.000986
#
# [3]	train-error:0.000918	eval-error:0.001042
#
# [4]	train-error:0.000796	eval-error:0.000881
#
# [5]	train-error:0.000884	eval-error:0.000992
#
# [6]	train-error:0.000784	eval-error:0.000875
#
# [7]	train-error:0.00082	eval-error:0.000902
#
# [8]	train-error:0.000826	eval-error:0.000913
#
# [9]	train-error:0.000833	eval-error:0.00092
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.017360701852225744, 'max_depth': 7, 'min_child_weight': 0.14522158017277553, 'subsample': 0.9500000000000001}, logloss: 0.1997
# [0]	train-error:0.000631	eval-error:0.000693
#
# [1]	train-error:0.000554	eval-error:0.000614
#
# [2]	train-error:0.000583	eval-error:0.000634
#
# [3]	train-error:0.000526	eval-error:0.000582
#
# [4]	train-error:0.000569	eval-error:0.000607
#
# [5]	train-error:0.000491	eval-error:0.000541
#
# [6]	train-error:0.000503	eval-error:0.000546
#
# [7]	train-error:0.000464	eval-error:0.000503
#
# [8]	train-error:0.000493	eval-error:0.000537
#
# [9]	train-error:0.00044	eval-error:0.000474
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.06186891287865824, 'max_depth': 8, 'min_child_weight': 0.3517055323963849, 'subsample': 0.9500000000000001}, logloss: 0.1991
# [0]	train-error:0.000633	eval-error:0.000693
#
# [1]	train-error:0.000593	eval-error:0.000666
#
# [2]	train-error:0.000622	eval-error:0.000705
#
# [3]	train-error:0.000566	eval-error:0.000639
#
# [4]	train-error:0.000594	eval-error:0.000634
#
# [5]	train-error:0.000467	eval-error:0.000519
#
# [6]	train-error:0.000532	eval-error:0.000575
#
# [7]	train-error:0.000439	eval-error:0.000476
#
# [8]	train-error:0.000459	eval-error:0.000496
#
# [9]	train-error:0.000489	eval-error:0.000539
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.8568127697123142, 'max_depth': 8, 'min_child_weight': 0.2570613949037513, 'subsample': 0.9}, logloss: 0.1992
# [0]	train-error:0.000888	eval-error:0.000963
#
# [1]	train-error:0.000909	eval-error:0.00102
#
# [2]	train-error:0.000884	eval-error:0.000986
#
# [3]	train-error:0.000918	eval-error:0.001044
#
# [4]	train-error:0.000779	eval-error:0.000861
#
# [5]	train-error:0.000884	eval-error:0.000992
#
# [6]	train-error:0.000783	eval-error:0.000877
#
# [7]	train-error:0.000872	eval-error:0.000972
#
# [8]	train-error:0.000834	eval-error:0.000929
#
# [9]	train-error:0.000838	eval-error:0.000924
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 8.84896414581347e-05, 'max_depth': 7, 'min_child_weight': 0.44763996817831053, 'subsample': 0.9}, logloss: 0.1998
# [0]	train-error:0.000481	eval-error:0.000519
#
# [1]	train-error:0.000468	eval-error:0.000503
#
# [2]	train-error:0.000466	eval-error:0.000526
#
# [3]	train-error:0.000361	eval-error:0.000419
#
# [4]	train-error:0.000402	eval-error:0.000451
#
# [5]	train-error:0.000396	eval-error:0.00044
#
# [6]	train-error:0.000403	eval-error:0.000446
#
# [7]	train-error:0.000371	eval-error:0.000419
#
# [8]	train-error:0.000359	eval-error:0.000403
#
# [9]	train-error:0.000349	eval-error:0.000406
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.4875347904950396, 'max_depth': 9, 'min_child_weight': 0.8184024437497723, 'subsample': 0.9500000000000001}, logloss: 0.1985
# [0]	train-error:0.001418	eval-error:0.001484
#
# [1]	train-error:0.001226	eval-error:0.001303
#
# [2]	train-error:0.000974	eval-error:0.001083
#
# [3]	train-error:0.001128	eval-error:0.001239
#
# [4]	train-error:0.001152	eval-error:0.001257
#
# [5]	train-error:0.001127	eval-error:0.001239
#
# [6]	train-error:0.001134	eval-error:0.001255
#
# [7]	train-error:0.001127	eval-error:0.001237
#
# [8]	train-error:0.001121	eval-error:0.001253
#
# [9]	train-error:0.001126	eval-error:0.001244
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.500045116630384e-06, 'max_depth': 6, 'min_child_weight': 0.8272284642563074, 'subsample': 0.9}, logloss: 0.2002
# [0]	train-error:0.005713	eval-error:0.005766
#
# [1]	train-error:0.005664	eval-error:0.005786
#
# [2]	train-error:0.00304	eval-error:0.003018
#
# [3]	train-error:0.002765	eval-error:0.002762
#
# [4]	train-error:0.002736	eval-error:0.002726
#
# [5]	train-error:0.002649	eval-error:0.002658
#
# [6]	train-error:0.002697	eval-error:0.002689
#
# [7]	train-error:0.002612	eval-error:0.00263
#
# [8]	train-error:0.002593	eval-error:0.002612
#
# [9]	train-error:0.002608	eval-error:0.002624
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.5632718408489493, 'max_depth': 4, 'min_child_weight': 0.6406844898563964, 'subsample': 0.8500000000000001}, logloss: 0.2049
# [0]	train-error:0.000541	eval-error:0.000594
#
# [1]	train-error:0.000476	eval-error:0.000541
#
# [2]	train-error:0.000494	eval-error:0.000589
#
# [3]	train-error:0.000395	eval-error:0.000483
#
# [4]	train-error:0.000421	eval-error:0.00048
#
# [5]	train-error:0.000403	eval-error:0.000446
#
# [6]	train-error:0.00035	eval-error:0.000376
#
# [7]	train-error:0.000298	eval-error:0.000349
#
# [8]	train-error:0.000276	eval-error:0.000313
#
# [9]	train-error:0.000298	eval-error:0.000333
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.32702988855024573, 'max_depth': 9, 'min_child_weight': 0.1401372777856484, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.004011	eval-error:0.004241
#
# [1]	train-error:0.001241	eval-error:0.001328
#
# [2]	train-error:0.000867	eval-error:0.000911
#
# [3]	train-error:0.000713	eval-error:0.000797
#
# [4]	train-error:0.000763	eval-error:0.000854
#
# [5]	train-error:0.000703	eval-error:0.000779
#
# [6]	train-error:0.000724	eval-error:0.000802
#
# [7]	train-error:0.000608	eval-error:0.000698
#
# [8]	train-error:0.000612	eval-error:0.000693
#
# [9]	train-error:0.000603	eval-error:0.000682
#
# params: {'colsample_bytree': 0.65, 'gamma': 9.137718349825549e-06, 'max_depth': 7, 'min_child_weight': 0.22375354226299485, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.001409	eval-error:0.001493
#
# [1]	train-error:0.000999	eval-error:0.001108
#
# [2]	train-error:0.001125	eval-error:0.001232
#
# [3]	train-error:0.001247	eval-error:0.001332
#
# [4]	train-error:0.00114	eval-error:0.001253
#
# [5]	train-error:0.001108	eval-error:0.001226
#
# [6]	train-error:0.001097	eval-error:0.001214
#
# [7]	train-error:0.001076	eval-error:0.001196
#
# [8]	train-error:0.001055	eval-error:0.001167
#
# [9]	train-error:0.00106	eval-error:0.001171
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0008576570374805864, 'max_depth': 6, 'min_child_weight': 0.4200430518855979, 'subsample': 0.8500000000000001}, logloss: 0.2007
# [0]	train-error:0.000546	eval-error:0.000616
#
# [1]	train-error:0.000567	eval-error:0.000641
#
# [2]	train-error:0.000561	eval-error:0.000648
#
# [3]	train-error:0.000485	eval-error:0.000571
#
# [4]	train-error:0.000424	eval-error:0.000464
#
# [5]	train-error:0.000399	eval-error:0.000446
#
# [6]	train-error:0.000418	eval-error:0.000464
#
# [7]	train-error:0.000341	eval-error:0.000406
#
# [8]	train-error:0.000359	eval-error:0.000417
#
# [9]	train-error:0.000344	eval-error:0.000399
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.09794378112226004, 'max_depth': 9, 'min_child_weight': 0.19320190312784963, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.0008	eval-error:0.000886
#
# [1]	train-error:0.000717	eval-error:0.000816
#
# [2]	train-error:0.000537	eval-error:0.000585
#
# [3]	train-error:0.000683	eval-error:0.000773
#
# [4]	train-error:0.000692	eval-error:0.000768
#
# [5]	train-error:0.000674	eval-error:0.000739
#
# [6]	train-error:0.000684	eval-error:0.00075
#
# [7]	train-error:0.000674	eval-error:0.000734
#
# [8]	train-error:0.000635	eval-error:0.000698
#
# [9]	train-error:0.000639	eval-error:0.000707
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.6107612675313447e-05, 'max_depth': 8, 'min_child_weight': 6.168531878803928, 'subsample': 0.9500000000000001}, logloss: 0.1992
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.007415	eval-error:0.007617
#
# [2]	train-error:0.007415	eval-error:0.007617
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.006172	eval-error:0.006321
#
# [7]	train-error:0.006172	eval-error:0.006321
#
# [8]	train-error:0.006172	eval-error:0.006321
#
# [9]	train-error:0.006172	eval-error:0.006321
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.201419445554897e-07, 'max_depth': 3, 'min_child_weight': 0.8319430565523872, 'subsample': 0.8500000000000001}, logloss: 0.2094
# [0]	train-error:0.00616	eval-error:0.006285
#
# [1]	train-error:0.006285	eval-error:0.006414
#
# [2]	train-error:0.002868	eval-error:0.00285
#
# [3]	train-error:0.002665	eval-error:0.002601
#
# [4]	train-error:0.004885	eval-error:0.005021
#
# [5]	train-error:0.002329	eval-error:0.002361
#
# [6]	train-error:0.004822	eval-error:0.00498
#
# [7]	train-error:0.00222	eval-error:0.002243
#
# [8]	train-error:0.002255	eval-error:0.00227
#
# [9]	train-error:0.002446	eval-error:0.002417
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.29006952669255437, 'max_depth': 4, 'min_child_weight': 0.4913159279423224, 'subsample': 0.9}, logloss: 0.2055
# [0]	train-error:0.001126	eval-error:0.001282
#
# [1]	train-error:0.000648	eval-error:0.000702
#
# [2]	train-error:0.000635	eval-error:0.000734
#
# [3]	train-error:0.000571	eval-error:0.000643
#
# [4]	train-error:0.000711	eval-error:0.000809
#
# [5]	train-error:0.000499	eval-error:0.000569
#
# [6]	train-error:0.00044	eval-error:0.000487
#
# [7]	train-error:0.000443	eval-error:0.000498
#
# [8]	train-error:0.000381	eval-error:0.000417
#
# [9]	train-error:0.000365	eval-error:0.000403
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 2.1144654495517426e-06, 'max_depth': 9, 'min_child_weight': 0.28959082821109366, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.00089	eval-error:0.000963
#
# [1]	train-error:0.000918	eval-error:0.001022
#
# [2]	train-error:0.000931	eval-error:0.001035
#
# [3]	train-error:0.000942	eval-error:0.001056
#
# [4]	train-error:0.00088	eval-error:0.000963
#
# [5]	train-error:0.000736	eval-error:0.000813
#
# [6]	train-error:0.000819	eval-error:0.000906
#
# [7]	train-error:0.000581	eval-error:0.000616
#
# [8]	train-error:0.00052	eval-error:0.000557
#
# [9]	train-error:0.000738	eval-error:0.000802
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.029203383408217497, 'max_depth': 7, 'min_child_weight': 0.6778314017609357, 'subsample': 0.8500000000000001}, logloss: 0.2000
# [0]	train-error:0.002464	eval-error:0.002485
#
# [1]	train-error:0.00215	eval-error:0.00222
#
# [2]	train-error:0.002106	eval-error:0.00213
#
# [3]	train-error:0.001429	eval-error:0.00152
#
# [4]	train-error:0.001382	eval-error:0.001491
#
# [5]	train-error:0.00151	eval-error:0.001595
#
# [6]	train-error:0.001311	eval-error:0.001405
#
# [7]	train-error:0.001475	eval-error:0.001563
#
# [8]	train-error:0.00154	eval-error:0.00164
#
# [9]	train-error:0.001479	eval-error:0.00157
#
# params: {'colsample_bytree': 0.9, 'gamma': 7.922261855263385e-07, 'max_depth': 5, 'min_child_weight': 1.9934232808514385, 'subsample': 0.8}, logloss: 0.2022
# [0]	train-error:0.000654	eval-error:0.000718
#
# [1]	train-error:0.000637	eval-error:0.000702
#
# [2]	train-error:0.000635	eval-error:0.000709
#
# [3]	train-error:0.00061	eval-error:0.000668
#
# [4]	train-error:0.000656	eval-error:0.000723
#
# [5]	train-error:0.000686	eval-error:0.000766
#
# [6]	train-error:0.00067	eval-error:0.000736
#
# [7]	train-error:0.000551	eval-error:0.000609
#
# [8]	train-error:0.000657	eval-error:0.000725
#
# [9]	train-error:0.000606	eval-error:0.000693
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.585411006960709e-05, 'max_depth': 8, 'min_child_weight': 1.1530659142601563, 'subsample': 0.75}, logloss: 0.1991
# [0]	train-error:0.000474	eval-error:0.000517
#
# [1]	train-error:0.000583	eval-error:0.000659
#
# [2]	train-error:0.000476	eval-error:0.000526
#
# [3]	train-error:0.000474	eval-error:0.000526
#
# [4]	train-error:0.000415	eval-error:0.000462
#
# [5]	train-error:0.000454	eval-error:0.000489
#
# [6]	train-error:0.000441	eval-error:0.00048
#
# [7]	train-error:0.00043	eval-error:0.000467
#
# [8]	train-error:0.000395	eval-error:0.000435
#
# [9]	train-error:0.000381	eval-error:0.000426
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 9.45784326488589e-05, 'max_depth': 9, 'min_child_weight': 0.14378970848176864, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.006163	eval-error:0.006287
#
# [1]	train-error:0.006291	eval-error:0.006418
#
# [2]	train-error:0.002946	eval-error:0.002923
#
# [3]	train-error:0.002676	eval-error:0.002608
#
# [4]	train-error:0.004885	eval-error:0.005016
#
# [5]	train-error:0.002346	eval-error:0.002377
#
# [6]	train-error:0.004836	eval-error:0.004993
#
# [7]	train-error:0.002201	eval-error:0.002216
#
# [8]	train-error:0.002235	eval-error:0.002238
#
# [9]	train-error:0.002434	eval-error:0.002397
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.12673881629780237, 'max_depth': 4, 'min_child_weight': 3.433224862610159, 'subsample': 0.9500000000000001}, logloss: 0.2055
# [0]	train-error:0.000477	eval-error:0.000517
#
# [1]	train-error:0.000464	eval-error:0.000503
#
# [2]	train-error:0.000467	eval-error:0.000528
#
# [3]	train-error:0.000378	eval-error:0.000419
#
# [4]	train-error:0.000418	eval-error:0.000462
#
# [5]	train-error:0.000411	eval-error:0.000449
#
# [6]	train-error:0.000404	eval-error:0.000449
#
# [7]	train-error:0.000367	eval-error:0.000412
#
# [8]	train-error:0.000359	eval-error:0.000399
#
# [9]	train-error:0.000347	eval-error:0.000401
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0028097618098151173, 'max_depth': 9, 'min_child_weight': 0.3203976654520562, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000477	eval-error:0.000519
#
# [1]	train-error:0.000483	eval-error:0.000519
#
# [2]	train-error:0.000467	eval-error:0.000507
#
# [3]	train-error:0.000466	eval-error:0.000507
#
# [4]	train-error:0.000393	eval-error:0.000444
#
# [5]	train-error:0.000453	eval-error:0.000485
#
# [6]	train-error:0.000421	eval-error:0.000464
#
# [7]	train-error:0.000372	eval-error:0.000417
#
# [8]	train-error:0.000368	eval-error:0.000415
#
# [9]	train-error:0.000355	eval-error:0.000399
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.013834906611704539, 'max_depth': 9, 'min_child_weight': 0.2972897210813414, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000484	eval-error:0.000521
#
# [1]	train-error:0.000477	eval-error:0.000514
#
# [2]	train-error:0.000472	eval-error:0.00053
#
# [3]	train-error:0.000378	eval-error:0.000428
#
# [4]	train-error:0.000397	eval-error:0.000451
#
# [5]	train-error:0.0004	eval-error:0.000453
#
# [6]	train-error:0.000384	eval-error:0.000437
#
# [7]	train-error:0.000386	eval-error:0.000442
#
# [8]	train-error:0.000336	eval-error:0.000381
#
# [9]	train-error:0.000347	eval-error:0.000406
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0013633028490764915, 'max_depth': 9, 'min_child_weight': 1.4577510731636552, 'subsample': 0.9}, logloss: 0.1985
# [0]	train-error:0.000777	eval-error:0.00087
#
# [1]	train-error:0.000707	eval-error:0.000807
#
# [2]	train-error:0.000503	eval-error:0.000551
#
# [3]	train-error:0.000668	eval-error:0.000741
#
# [4]	train-error:0.000657	eval-error:0.00072
#
# [5]	train-error:0.00064	eval-error:0.000714
#
# [6]	train-error:0.000651	eval-error:0.000718
#
# [7]	train-error:0.00064	eval-error:0.000707
#
# [8]	train-error:0.000637	eval-error:0.000711
#
# [9]	train-error:0.00064	eval-error:0.00072
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0010942386867466658, 'max_depth': 8, 'min_child_weight': 1.6024018600439331, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.000566	eval-error:0.000632
#
# [1]	train-error:0.000586	eval-error:0.000657
#
# [2]	train-error:0.000582	eval-error:0.000648
#
# [3]	train-error:0.000497	eval-error:0.000569
#
# [4]	train-error:0.000427	eval-error:0.000462
#
# [5]	train-error:0.000478	eval-error:0.000539
#
# [6]	train-error:0.000395	eval-error:0.000442
#
# [7]	train-error:0.000397	eval-error:0.000435
#
# [8]	train-error:0.000386	eval-error:0.000428
#
# [9]	train-error:0.000393	eval-error:0.000455
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.05891033715851995, 'max_depth': 9, 'min_child_weight': 3.0131371274087004, 'subsample': 0.8500000000000001}, logloss: 0.1987
# [0]	train-error:0.000773	eval-error:0.000868
#
# [1]	train-error:0.00072	eval-error:0.000809
#
# [2]	train-error:0.000714	eval-error:0.000797
#
# [3]	train-error:0.000701	eval-error:0.000788
#
# [4]	train-error:0.000788	eval-error:0.000881
#
# [5]	train-error:0.000675	eval-error:0.000766
#
# [6]	train-error:0.000665	eval-error:0.000743
#
# [7]	train-error:0.000674	eval-error:0.000761
#
# [8]	train-error:0.000671	eval-error:0.000757
#
# [9]	train-error:0.000653	eval-error:0.000759
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0007328715874823451, 'max_depth': 8, 'min_child_weight': 0.9487411858404758, 'subsample': 0.9}, logloss: 0.1992
# [0]	train-error:0.000572	eval-error:0.000646
#
# [1]	train-error:0.000585	eval-error:0.000671
#
# [2]	train-error:0.000567	eval-error:0.000632
#
# [3]	train-error:0.000484	eval-error:0.000553
#
# [4]	train-error:0.000413	eval-error:0.000455
#
# [5]	train-error:0.000406	eval-error:0.000464
#
# [6]	train-error:0.00039	eval-error:0.000446
#
# [7]	train-error:0.000379	eval-error:0.000435
#
# [8]	train-error:0.000375	eval-error:0.00043
#
# [9]	train-error:0.000309	eval-error:0.000362
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0016601291758589368, 'max_depth': 9, 'min_child_weight': 4.3085026910748185, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000776	eval-error:0.00087
#
# [1]	train-error:0.00072	eval-error:0.000811
#
# [2]	train-error:0.000718	eval-error:0.000804
#
# [3]	train-error:0.000702	eval-error:0.000793
#
# [4]	train-error:0.000789	eval-error:0.000888
#
# [5]	train-error:0.000676	eval-error:0.00077
#
# [6]	train-error:0.000668	eval-error:0.000752
#
# [7]	train-error:0.000675	eval-error:0.000768
#
# [8]	train-error:0.000674	eval-error:0.000764
#
# [9]	train-error:0.000656	eval-error:0.000764
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0005292114887089092, 'max_depth': 8, 'min_child_weight': 1.4374724033482957, 'subsample': 0.9}, logloss: 0.1992
# [0]	train-error:0.000487	eval-error:0.000526
#
# [1]	train-error:0.000486	eval-error:0.000507
#
# [2]	train-error:0.000482	eval-error:0.000535
#
# [3]	train-error:0.000383	eval-error:0.000426
#
# [4]	train-error:0.000451	eval-error:0.000514
#
# [5]	train-error:0.000405	eval-error:0.000453
#
# [6]	train-error:0.000403	eval-error:0.000444
#
# [7]	train-error:0.000425	eval-error:0.000474
#
# [8]	train-error:0.000354	eval-error:0.000412
#
# [9]	train-error:0.000359	eval-error:0.000412
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.0304968698034e-05, 'max_depth': 9, 'min_child_weight': 2.071495112606383, 'subsample': 0.8500000000000001}, logloss: 0.1986
# [0]	train-error:0.000794	eval-error:0.000884
#
# [1]	train-error:0.00071	eval-error:0.000811
#
# [2]	train-error:0.000537	eval-error:0.000591
#
# [3]	train-error:0.000681	eval-error:0.000768
#
# [4]	train-error:0.000683	eval-error:0.000761
#
# [5]	train-error:0.000668	eval-error:0.000736
#
# [6]	train-error:0.000683	eval-error:0.000754
#
# [7]	train-error:0.000639	eval-error:0.000702
#
# [8]	train-error:0.000637	eval-error:0.000698
#
# [9]	train-error:0.000636	eval-error:0.000709
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00012441545653922567, 'max_depth': 8, 'min_child_weight': 5.433203778666235, 'subsample': 0.9500000000000001}, logloss: 0.1992
# [0]	train-error:0.000567	eval-error:0.000616
#
# [1]	train-error:0.000432	eval-error:0.000503
#
# [2]	train-error:0.000486	eval-error:0.000575
#
# [3]	train-error:0.000415	eval-error:0.000505
#
# [4]	train-error:0.000418	eval-error:0.00048
#
# [5]	train-error:0.000386	eval-error:0.000419
#
# [6]	train-error:0.000365	eval-error:0.000408
#
# [7]	train-error:0.000302	eval-error:0.000315
#
# [8]	train-error:0.000285	eval-error:0.000317
#
# [9]	train-error:0.00032	eval-error:0.000353
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 5.445093158600837e-06, 'max_depth': 9, 'min_child_weight': 3.94642419822832, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.000668	eval-error:0.000734
#
# [1]	train-error:0.000644	eval-error:0.00072
#
# [2]	train-error:0.000659	eval-error:0.000725
#
# [3]	train-error:0.000622	eval-error:0.000696
#
# [4]	train-error:0.000529	eval-error:0.000582
#
# [5]	train-error:0.000717	eval-error:0.000807
#
# [6]	train-error:0.000652	eval-error:0.000714
#
# [7]	train-error:0.000631	eval-error:0.000684
#
# [8]	train-error:0.000606	eval-error:0.000652
#
# [9]	train-error:0.000606	eval-error:0.000655
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0003313247386123591, 'max_depth': 8, 'min_child_weight': 7.40883055117139, 'subsample': 0.9500000000000001}, logloss: 0.1992
# [0]	train-error:0.001004	eval-error:0.001121
#
# [1]	train-error:0.000999	eval-error:0.001117
#
# [2]	train-error:0.000947	eval-error:0.001058
#
# [3]	train-error:0.00093	eval-error:0.001042
#
# [4]	train-error:0.0009	eval-error:0.001001
#
# [5]	train-error:0.000802	eval-error:0.000879
#
# [6]	train-error:0.000807	eval-error:0.00089
#
# [7]	train-error:0.000796	eval-error:0.000893
#
# [8]	train-error:0.00085	eval-error:0.000945
#
# [9]	train-error:0.00081	eval-error:0.000909
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00015029596141274789, 'max_depth': 7, 'min_child_weight': 2.68844051686727, 'subsample': 0.8}, logloss: 0.1996
# [0]	train-error:0.00056	eval-error:0.000621
#
# [1]	train-error:0.000582	eval-error:0.000655
#
# [2]	train-error:0.00056	eval-error:0.000628
#
# [3]	train-error:0.000488	eval-error:0.000551
#
# [4]	train-error:0.000366	eval-error:0.000421
#
# [5]	train-error:0.000394	eval-error:0.000446
#
# [6]	train-error:0.000359	eval-error:0.000417
#
# [7]	train-error:0.000348	eval-error:0.000401
#
# [8]	train-error:0.000328	eval-error:0.000374
#
# [9]	train-error:0.000328	eval-error:0.000381
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.004803728932714043, 'max_depth': 9, 'min_child_weight': 1.3423920763751336, 'subsample': 0.8500000000000001}, logloss: 0.1986
# [0]	train-error:0.000556	eval-error:0.000621
#
# [1]	train-error:0.000573	eval-error:0.000646
#
# [2]	train-error:0.000563	eval-error:0.000641
#
# [3]	train-error:0.000489	eval-error:0.000573
#
# [4]	train-error:0.00043	eval-error:0.000471
#
# [5]	train-error:0.000404	eval-error:0.000446
#
# [6]	train-error:0.000425	eval-error:0.000469
#
# [7]	train-error:0.000344	eval-error:0.000403
#
# [8]	train-error:0.000358	eval-error:0.000421
#
# [9]	train-error:0.000339	eval-error:0.000399
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.48008860582215784, 'max_depth': 9, 'min_child_weight': 1.1341106609814096, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.000771	eval-error:0.000865
#
# [1]	train-error:0.000699	eval-error:0.000795
#
# [2]	train-error:0.0005	eval-error:0.000544
#
# [3]	train-error:0.000648	eval-error:0.000716
#
# [4]	train-error:0.000632	eval-error:0.0007
#
# [5]	train-error:0.000633	eval-error:0.000696
#
# [6]	train-error:0.000649	eval-error:0.000714
#
# [7]	train-error:0.000604	eval-error:0.000666
#
# [8]	train-error:0.000597	eval-error:0.000662
#
# [9]	train-error:0.000603	eval-error:0.000664
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.01335594493235681, 'max_depth': 8, 'min_child_weight': 0.5775983160164353, 'subsample': 0.9500000000000001}, logloss: 0.1991
# [0]	train-error:0.000825	eval-error:0.000918
#
# [1]	train-error:0.000945	eval-error:0.001053
#
# [2]	train-error:0.000824	eval-error:0.00092
#
# [3]	train-error:0.000812	eval-error:0.000893
#
# [4]	train-error:0.000906	eval-error:0.001013
#
# [5]	train-error:0.000807	eval-error:0.00089
#
# [6]	train-error:0.000803	eval-error:0.000888
#
# [7]	train-error:0.00081	eval-error:0.000897
#
# [8]	train-error:0.00089	eval-error:0.000999
#
# [9]	train-error:0.000809	eval-error:0.000904
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 4.80016915333895e-05, 'max_depth': 7, 'min_child_weight': 0.7528942395276208, 'subsample': 0.9}, logloss: 0.1996
# [0]	train-error:0.000477	eval-error:0.000517
#
# [1]	train-error:0.000464	eval-error:0.000503
#
# [2]	train-error:0.000467	eval-error:0.000528
#
# [3]	train-error:0.000378	eval-error:0.000419
#
# [4]	train-error:0.000418	eval-error:0.000462
#
# [5]	train-error:0.000411	eval-error:0.000449
#
# [6]	train-error:0.000404	eval-error:0.000449
#
# [7]	train-error:0.000367	eval-error:0.000412
#
# [8]	train-error:0.000359	eval-error:0.000399
#
# [9]	train-error:0.000347	eval-error:0.000401
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.19033682568006094, 'max_depth': 9, 'min_child_weight': 0.3873808204317746, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.001409	eval-error:0.001502
#
# [1]	train-error:0.000995	eval-error:0.001103
#
# [2]	train-error:0.001322	eval-error:0.001432
#
# [3]	train-error:0.001203	eval-error:0.001316
#
# [4]	train-error:0.001261	eval-error:0.001346
#
# [5]	train-error:0.001209	eval-error:0.001337
#
# [6]	train-error:0.001169	eval-error:0.001269
#
# [7]	train-error:0.001149	eval-error:0.001273
#
# [8]	train-error:0.001229	eval-error:0.001348
#
# [9]	train-error:0.001072	eval-error:0.001187
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.038322246119370254, 'max_depth': 6, 'min_child_weight': 0.24628128322215895, 'subsample': 0.8}, logloss: 0.2009
# [0]	train-error:0.002857	eval-error:0.002934
#
# [1]	train-error:0.000874	eval-error:0.000909
#
# [2]	train-error:0.000847	eval-error:0.001029
#
# [3]	train-error:0.000739	eval-error:0.000865
#
# [4]	train-error:0.000728	eval-error:0.000877
#
# [5]	train-error:0.000667	eval-error:0.000782
#
# [6]	train-error:0.000581	eval-error:0.000686
#
# [7]	train-error:0.000445	eval-error:0.000521
#
# [8]	train-error:0.000433	eval-error:0.000498
#
# [9]	train-error:0.000465	eval-error:0.000539
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.9655022699121312, 'max_depth': 8, 'min_child_weight': 0.910132050793406, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.002334	eval-error:0.002293
#
# [1]	train-error:0.001658	eval-error:0.001683
#
# [2]	train-error:0.002423	eval-error:0.002361
#
# [3]	train-error:0.001362	eval-error:0.001443
#
# [4]	train-error:0.001568	eval-error:0.001631
#
# [5]	train-error:0.001496	eval-error:0.001561
#
# [6]	train-error:0.001274	eval-error:0.001377
#
# [7]	train-error:0.001472	eval-error:0.00155
#
# [8]	train-error:0.001529	eval-error:0.001613
#
# [9]	train-error:0.001468	eval-error:0.001547
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.003955630889596933, 'max_depth': 5, 'min_child_weight': 1.8957524489362028, 'subsample': 0.8500000000000001}, logloss: 0.2021
# [0]	train-error:0.000485	eval-error:0.000526
#
# [1]	train-error:0.000491	eval-error:0.000528
#
# [2]	train-error:0.000475	eval-error:0.000519
#
# [3]	train-error:0.000474	eval-error:0.000517
#
# [4]	train-error:0.000398	eval-error:0.000453
#
# [5]	train-error:0.000459	eval-error:0.000494
#
# [6]	train-error:0.000425	eval-error:0.000471
#
# [7]	train-error:0.000375	eval-error:0.000426
#
# [8]	train-error:0.000366	eval-error:0.000415
#
# [9]	train-error:0.00036	eval-error:0.000406
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.008398520844896862, 'max_depth': 9, 'min_child_weight': 1.5798826464635858, 'subsample': 0.9500000000000001}, logloss: 0.1985
# [0]	train-error:0.000779	eval-error:0.000845
#
# [1]	train-error:0.000727	eval-error:0.000818
#
# [2]	train-error:0.000848	eval-error:0.000958
#
# [3]	train-error:0.000714	eval-error:0.000811
#
# [4]	train-error:0.000689	eval-error:0.000761
#
# [5]	train-error:0.000686	eval-error:0.000757
#
# [6]	train-error:0.000671	eval-error:0.000745
#
# [7]	train-error:0.000671	eval-error:0.000764
#
# [8]	train-error:0.000677	eval-error:0.000766
#
# [9]	train-error:0.000667	eval-error:0.000764
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.08614407001408435, 'max_depth': 8, 'min_child_weight': 2.218047602996134, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.000828	eval-error:0.000922
#
# [1]	train-error:0.000939	eval-error:0.001051
#
# [2]	train-error:0.000827	eval-error:0.000924
#
# [3]	train-error:0.00094	eval-error:0.001049
#
# [4]	train-error:0.000897	eval-error:0.001001
#
# [5]	train-error:0.000837	eval-error:0.00094
#
# [6]	train-error:0.000841	eval-error:0.000938
#
# [7]	train-error:0.000844	eval-error:0.00094
#
# [8]	train-error:0.000855	eval-error:0.000961
#
# [9]	train-error:0.000806	eval-error:0.000893
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.008008375818866223, 'max_depth': 7, 'min_child_weight': 1.525334212681623, 'subsample': 0.9500000000000001}, logloss: 0.1996
# [0]	train-error:0.00049	eval-error:0.00053
#
# [1]	train-error:0.000594	eval-error:0.000668
#
# [2]	train-error:0.000483	eval-error:0.000519
#
# [3]	train-error:0.000478	eval-error:0.000517
#
# [4]	train-error:0.000428	eval-error:0.000471
#
# [5]	train-error:0.000468	eval-error:0.000498
#
# [6]	train-error:0.000415	eval-error:0.000462
#
# [7]	train-error:0.000412	eval-error:0.000462
#
# [8]	train-error:0.000379	eval-error:0.000428
#
# [9]	train-error:0.000374	eval-error:0.000435
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.01996234312969307, 'max_depth': 9, 'min_child_weight': 2.6510173351131376, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.001345	eval-error:0.001445
#
# [1]	train-error:0.00114	eval-error:0.001248
#
# [2]	train-error:0.00121	eval-error:0.00131
#
# [3]	train-error:0.001265	eval-error:0.001341
#
# [4]	train-error:0.001152	eval-error:0.001269
#
# [5]	train-error:0.001104	eval-error:0.001217
#
# [6]	train-error:0.001094	eval-error:0.001201
#
# [7]	train-error:0.001061	eval-error:0.001171
#
# [8]	train-error:0.001072	eval-error:0.001183
#
# [9]	train-error:0.001097	eval-error:0.001208
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.018701077920687644, 'max_depth': 6, 'min_child_weight': 2.5676983604611636, 'subsample': 0.8}, logloss: 0.2006
# [0]	train-error:0.000792	eval-error:0.000884
#
# [1]	train-error:0.000728	eval-error:0.000818
#
# [2]	train-error:0.00073	eval-error:0.000807
#
# [3]	train-error:0.00072	eval-error:0.000807
#
# [4]	train-error:0.000708	eval-error:0.000786
#
# [5]	train-error:0.000707	eval-error:0.000784
#
# [6]	train-error:0.0007	eval-error:0.00077
#
# [7]	train-error:0.000697	eval-error:0.00077
#
# [8]	train-error:0.000679	eval-error:0.000757
#
# [9]	train-error:0.000684	eval-error:0.000775
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.17004310842390538, 'max_depth': 8, 'min_child_weight': 3.5071459677728503, 'subsample': 0.8500000000000001}, logloss: 0.1992
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.007862	eval-error:0.008088
#
# [2]	train-error:0.00755	eval-error:0.007746
#
# [3]	train-error:0.006365	eval-error:0.006527
#
# [4]	train-error:0.0075	eval-error:0.007689
#
# [5]	train-error:0.00626	eval-error:0.006418
#
# [6]	train-error:0.006275	eval-error:0.00643
#
# [7]	train-error:0.00626	eval-error:0.006418
#
# [8]	train-error:0.006274	eval-error:0.006427
#
# [9]	train-error:0.00626	eval-error:0.006418
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.002030322853293132, 'max_depth': 3, 'min_child_weight': 3.031502916135073, 'subsample': 0.8}, logloss: 0.2094
# [0]	train-error:0.000575	eval-error:0.00065
#
# [1]	train-error:0.000559	eval-error:0.000657
#
# [2]	train-error:0.0006	eval-error:0.000684
#
# [3]	train-error:0.000472	eval-error:0.000553
#
# [4]	train-error:0.000514	eval-error:0.000573
#
# [5]	train-error:0.000432	eval-error:0.000469
#
# [6]	train-error:0.000415	eval-error:0.000474
#
# [7]	train-error:0.000371	eval-error:0.000408
#
# [8]	train-error:0.00039	eval-error:0.00043
#
# [9]	train-error:0.000378	eval-error:0.000426
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.7087453992620733, 'max_depth': 9, 'min_child_weight': 3.9162098756214703, 'subsample': 0.8500000000000001}, logloss: 0.1988
# [0]	train-error:0.000505	eval-error:0.000537
#
# [1]	train-error:0.000606	eval-error:0.000677
#
# [2]	train-error:0.000497	eval-error:0.000535
#
# [3]	train-error:0.000497	eval-error:0.000532
#
# [4]	train-error:0.000492	eval-error:0.000528
#
# [5]	train-error:0.000489	eval-error:0.000528
#
# [6]	train-error:0.00048	eval-error:0.000514
#
# [7]	train-error:0.000474	eval-error:0.00051
#
# [8]	train-error:0.000438	eval-error:0.000474
#
# [9]	train-error:0.000397	eval-error:0.000433
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.4642441081825619, 'max_depth': 9, 'min_child_weight': 5.431207496006251, 'subsample': 0.8500000000000001}, logloss: 0.1986
# [0]	train-error:0.000891	eval-error:0.000965
#
# [1]	train-error:0.000913	eval-error:0.001024
#
# [2]	train-error:0.000895	eval-error:0.000997
#
# [3]	train-error:0.000925	eval-error:0.001053
#
# [4]	train-error:0.000783	eval-error:0.000865
#
# [5]	train-error:0.000886	eval-error:0.000995
#
# [6]	train-error:0.000789	eval-error:0.000884
#
# [7]	train-error:0.000869	eval-error:0.000958
#
# [8]	train-error:0.000833	eval-error:0.00092
#
# [9]	train-error:0.000834	eval-error:0.00092
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0012193906582762147, 'max_depth': 7, 'min_child_weight': 1.0993372741615868, 'subsample': 0.8500000000000001}, logloss: 0.1998
# [0]	train-error:0.000771	eval-error:0.000865
#
# [1]	train-error:0.000702	eval-error:0.0008
#
# [2]	train-error:0.0005	eval-error:0.000544
#
# [3]	train-error:0.000662	eval-error:0.000736
#
# [4]	train-error:0.000656	eval-error:0.000716
#
# [5]	train-error:0.000637	eval-error:0.000709
#
# [6]	train-error:0.000649	eval-error:0.000716
#
# [7]	train-error:0.000642	eval-error:0.000709
#
# [8]	train-error:0.000634	eval-error:0.000707
#
# [9]	train-error:0.000637	eval-error:0.000716
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.04928663905990122, 'max_depth': 8, 'min_child_weight': 0.6163939062821737, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.000551	eval-error:0.000625
#
# [1]	train-error:0.000543	eval-error:0.000625
#
# [2]	train-error:0.000527	eval-error:0.000609
#
# [3]	train-error:0.000491	eval-error:0.000564
#
# [4]	train-error:0.000456	eval-error:0.00051
#
# [5]	train-error:0.000374	eval-error:0.000424
#
# [6]	train-error:0.000374	eval-error:0.000437
#
# [7]	train-error:0.000335	eval-error:0.000392
#
# [8]	train-error:0.00035	eval-error:0.00041
#
# [9]	train-error:0.000333	eval-error:0.000383
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.022016854479820908, 'max_depth': 9, 'min_child_weight': 0.4798124355691758, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.000775	eval-error:0.000843
#
# [1]	train-error:0.000727	eval-error:0.00082
#
# [2]	train-error:0.000846	eval-error:0.000956
#
# [3]	train-error:0.000708	eval-error:0.0008
#
# [4]	train-error:0.000681	eval-error:0.000764
#
# [5]	train-error:0.000683	eval-error:0.000766
#
# [6]	train-error:0.000664	eval-error:0.000748
#
# [7]	train-error:0.000668	eval-error:0.000764
#
# [8]	train-error:0.000666	eval-error:0.000759
#
# [9]	train-error:0.00066	eval-error:0.000754
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.22502653721220783, 'max_depth': 8, 'min_child_weight': 1.268047298158911, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.000553	eval-error:0.000619
#
# [1]	train-error:0.000565	eval-error:0.000637
#
# [2]	train-error:0.000551	eval-error:0.000621
#
# [3]	train-error:0.000477	eval-error:0.000544
#
# [4]	train-error:0.000362	eval-error:0.000424
#
# [5]	train-error:0.00045	eval-error:0.000514
#
# [6]	train-error:0.00036	eval-error:0.000419
#
# [7]	train-error:0.000344	eval-error:0.000385
#
# [8]	train-error:0.000325	eval-error:0.000367
#
# [9]	train-error:0.000326	eval-error:0.000376
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00037125441542268974, 'max_depth': 9, 'min_child_weight': 0.7302747290872248, 'subsample': 0.9}, logloss: 0.1986
# 100%|██████████| 100/100 [48:38<00:00, 29.19s/it, best loss: 0.19852353622379515]
# best params:{'colsample_bytree': 0.9500000000000001, 'gamma': 0.01996234312969307, 'max_depth': 9, 'min_child_weight': 2.6510173351131376, 'subsample': 0.8500000000000001}, score:0.1985

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.01996234312969307,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 2.6510173351131376,
    'max_depth': 9,
    'subsample': 0.85,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.00049	eval-error:0.000521
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000447	eval-error:0.000483
# [2]	train-error:0.000463	eval-error:0.000485
# [3]	train-error:0.00043	eval-error:0.000455
# [4]	train-error:0.000443	eval-error:0.00046
# [5]	train-error:0.000435	eval-error:0.000446
# [6]	train-error:0.000429	eval-error:0.000444
# [7]	train-error:0.00041	eval-error:0.000433
# [8]	train-error:0.000389	eval-error:0.000421
# [9]	train-error:0.000389	eval-error:0.000424
# [10]	train-error:0.000368	eval-error:0.000399
# [11]	train-error:0.000364	eval-error:0.000392
# [12]	train-error:0.000338	eval-error:0.000365
# [13]	train-error:0.000335	eval-error:0.000356
# [14]	train-error:0.000325	eval-error:0.000347
# [15]	train-error:0.000202	eval-error:0.000227
# [16]	train-error:0.000197	eval-error:0.000222
# [17]	train-error:0.000181	eval-error:0.000208
# [18]	train-error:0.000182	eval-error:0.000206
# [19]	train-error:0.00018	eval-error:0.000202
# [20]	train-error:0.000177	eval-error:0.000202
# [21]	train-error:0.000176	eval-error:0.000199
# [22]	train-error:0.000176	eval-error:0.000199
# [23]	train-error:0.000175	eval-error:0.000199
# [24]	train-error:0.000173	eval-error:0.000197
# [25]	train-error:0.00017	eval-error:0.000195
# [26]	train-error:0.000169	eval-error:0.00019
# [27]	train-error:0.000167	eval-error:0.00019
# [28]	train-error:0.000151	eval-error:0.000177
# [29]	train-error:0.000123	eval-error:0.000156
# [30]	train-error:0.000123	eval-error:0.000156
# [31]	train-error:0.000117	eval-error:0.000147
# [32]	train-error:0.000116	eval-error:0.000145
# [33]	train-error:0.00011	eval-error:0.000138
# [34]	train-error:0.000106	eval-error:0.000131
# [35]	train-error:0.000104	eval-error:0.000129
# [36]	train-error:7.9e-05	eval-error:9.7e-05
# [37]	train-error:7.6e-05	eval-error:9.5e-05
# [38]	train-error:6.2e-05	eval-error:7.5e-05
# [39]	train-error:5.8e-05	eval-error:6.8e-05
# [40]	train-error:4.5e-05	eval-error:5.2e-05
# [41]	train-error:4.3e-05	eval-error:5.2e-05
# [42]	train-error:3.6e-05	eval-error:4.1e-05
# [43]	train-error:3.3e-05	eval-error:3.9e-05
# [44]	train-error:3.2e-05	eval-error:3.9e-05
# [45]	train-error:2.9e-05	eval-error:2.9e-05
# [46]	train-error:2.9e-05	eval-error:2.9e-05
# [47]	train-error:2.8e-05	eval-error:2.9e-05
# [48]	train-error:2.7e-05	eval-error:2.9e-05
# [49]	train-error:2.8e-05	eval-error:2.9e-05
# [50]	train-error:2.6e-05	eval-error:2.9e-05
# [51]	train-error:2.6e-05	eval-error:2.9e-05
# [52]	train-error:2.5e-05	eval-error:2.7e-05
# [53]	train-error:2.4e-05	eval-error:2.7e-05
# [54]	train-error:2.4e-05	eval-error:2.7e-05
# [55]	train-error:2.3e-05	eval-error:2.7e-05
# [56]	train-error:2.2e-05	eval-error:2.5e-05
# [57]	train-error:1.9e-05	eval-error:2.5e-05
# [58]	train-error:1.9e-05	eval-error:2.5e-05
# [59]	train-error:1.9e-05	eval-error:2.5e-05
# [60]	train-error:1.9e-05	eval-error:2.5e-05
# [61]	train-error:1.8e-05	eval-error:2.5e-05
# [62]	train-error:1.7e-05	eval-error:2.3e-05
# [63]	train-error:1.6e-05	eval-error:2.3e-05
# [64]	train-error:1.7e-05	eval-error:2.3e-05
# [65]	train-error:1.6e-05	eval-error:2.3e-05
# [66]	train-error:1.6e-05	eval-error:2.3e-05
# [67]	train-error:1.6e-05	eval-error:2.3e-05
# [68]	train-error:1.6e-05	eval-error:2.3e-05
# [69]	train-error:1.6e-05	eval-error:2.3e-05
# [70]	train-error:1.5e-05	eval-error:2e-05
# [71]	train-error:1.5e-05	eval-error:2e-05
# [72]	train-error:1.4e-05	eval-error:1.8e-05
# [73]	train-error:9e-06	eval-error:1.4e-05
# [74]	train-error:9e-06	eval-error:1.4e-05
# [75]	train-error:9e-06	eval-error:1.4e-05
# [76]	train-error:9e-06	eval-error:1.4e-05
# [77]	train-error:9e-06	eval-error:1.4e-05
# [78]	train-error:9e-06	eval-error:1.4e-05
# [79]	train-error:9e-06	eval-error:1.4e-05
# [80]	train-error:9e-06	eval-error:1.4e-05
# [81]	train-error:9e-06	eval-error:1.4e-05
# [82]	train-error:9e-06	eval-error:1.4e-05
# [83]	train-error:9e-06	eval-error:1.4e-05
# [84]	train-error:9e-06	eval-error:1.4e-05
# [85]	train-error:8e-06	eval-error:1.4e-05
# [86]	train-error:8e-06	eval-error:1.4e-05
# [87]	train-error:8e-06	eval-error:1.4e-05
# [88]	train-error:8e-06	eval-error:1.4e-05
# [89]	train-error:7e-06	eval-error:1.1e-05
# [90]	train-error:7e-06	eval-error:1.1e-05
# [91]	train-error:7e-06	eval-error:1.1e-05
# [92]	train-error:7e-06	eval-error:1.1e-05
# [93]	train-error:7e-06	eval-error:1.1e-05
# [94]	train-error:7e-06	eval-error:1.1e-05
# [95]	train-error:7e-06	eval-error:1.1e-05
# [96]	train-error:7e-06	eval-error:1.1e-05
# [97]	train-error:7e-06	eval-error:1.1e-05
# [98]	train-error:7e-06	eval-error:1.1e-05
# [99]	train-error:7e-06	eval-error:1.1e-05
# [100]	train-error:7e-06	eval-error:1.1e-05
# [101]	train-error:6e-06	eval-error:1.1e-05
# [102]	train-error:7e-06	eval-error:1.1e-05
# [103]	train-error:6e-06	eval-error:1.1e-05
# [104]	train-error:6e-06	eval-error:1.1e-05
# [105]	train-error:7e-06	eval-error:1.1e-05
# [106]	train-error:7e-06	eval-error:1.1e-05
# [107]	train-error:6e-06	eval-error:9e-06
# [108]	train-error:6e-06	eval-error:9e-06
# [109]	train-error:6e-06	eval-error:9e-06
# [110]	train-error:6e-06	eval-error:9e-06
# [111]	train-error:6e-06	eval-error:9e-06
# [112]	train-error:6e-06	eval-error:9e-06
# [113]	train-error:6e-06	eval-error:9e-06
# [114]	train-error:6e-06	eval-error:7e-06
# [115]	train-error:6e-06	eval-error:7e-06
# [116]	train-error:6e-06	eval-error:7e-06
# [117]	train-error:6e-06	eval-error:7e-06
# [118]	train-error:6e-06	eval-error:7e-06
# [119]	train-error:6e-06	eval-error:7e-06
# [120]	train-error:6e-06	eval-error:7e-06
# [121]	train-error:6e-06	eval-error:7e-06
# [122]	train-error:6e-06	eval-error:7e-06
# [123]	train-error:6e-06	eval-error:7e-06
# [124]	train-error:6e-06	eval-error:7e-06
# [125]	train-error:6e-06	eval-error:7e-06
# [126]	train-error:6e-06	eval-error:7e-06
# [127]	train-error:6e-06	eval-error:7e-06
# [128]	train-error:6e-06	eval-error:7e-06
# [129]	train-error:6e-06	eval-error:7e-06
# [130]	train-error:6e-06	eval-error:7e-06
# [131]	train-error:6e-06	eval-error:7e-06
# [132]	train-error:6e-06	eval-error:7e-06
# [133]	train-error:6e-06	eval-error:7e-06
# [134]	train-error:6e-06	eval-error:7e-06
# Stopping. Best iteration:
# [114]	train-error:6e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0001

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_24_param_tuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_24_param_tuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000006
# 1  0.000006
# 2  0.000006
# 3  0.000006
# 4  0.000006

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000006
# 1   1  0.000006
# 2   2  0.000006
# 3   3  0.000006
# 4   4  0.000006

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_24_param_tuning.csv',index=False)

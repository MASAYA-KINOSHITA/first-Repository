# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.001408	eval-error:0.001556
#
# [1]	train-error:0.00112	eval-error:0.001269
#
# [2]	train-error:0.001196	eval-error:0.001296
#
# [3]	train-error:0.001089	eval-error:0.001185
#
# [4]	train-error:0.001107	eval-error:0.001205
#
# [5]	train-error:0.001042	eval-error:0.001126
#
# [6]	train-error:0.000822	eval-error:0.000906
#
# [7]	train-error:0.00084	eval-error:0.000909
#
# [8]	train-error:0.000868	eval-error:0.000933
#
# [9]	train-error:0.000871	eval-error:0.000952
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.05520123095798636, 'max_depth': 7, 'min_child_weight': 0.5796237429235344, 'subsample': 0.8}, logloss: 0.2000
# [0]	train-error:0.001893	eval-error:0.00201
#
# [1]	train-error:0.00138	eval-error:0.001434
#
# [2]	train-error:0.001265	eval-error:0.001337
#
# [3]	train-error:0.001176	eval-error:0.001303
#
# [4]	train-error:0.000993	eval-error:0.001124
#
# [5]	train-error:0.000993	eval-error:0.001119
#
# [6]	train-error:0.001154	eval-error:0.001291
#
# [7]	train-error:0.001131	eval-error:0.001253
#
# [8]	train-error:0.000955	eval-error:0.00109
#
# [9]	train-error:0.001048	eval-error:0.00116
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.4584058680057523, 'max_depth': 6, 'min_child_weight': 5.953667602962483, 'subsample': 0.7000000000000001}, logloss: 0.2001
# [0]	train-error:0.005804	eval-error:0.005915
#
# [1]	train-error:0.00259	eval-error:0.002581
#
# [2]	train-error:0.005993	eval-error:0.006167
#
# [3]	train-error:0.004907	eval-error:0.005011
#
# [4]	train-error:0.004995	eval-error:0.005125
#
# [5]	train-error:0.002504	eval-error:0.00249
#
# [6]	train-error:0.002626	eval-error:0.002646
#
# [7]	train-error:0.002395	eval-error:0.002372
#
# [8]	train-error:0.002609	eval-error:0.002626
#
# [9]	train-error:0.002532	eval-error:0.002535
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.000979166142404818, 'max_depth': 4, 'min_child_weight': 0.4699767579670441, 'subsample': 0.6000000000000001}, logloss: 0.2047
# [0]	train-error:0.001323	eval-error:0.001455
#
# [1]	train-error:0.000948	eval-error:0.001053
#
# [2]	train-error:0.000919	eval-error:0.001006
#
# [3]	train-error:0.000983	eval-error:0.001047
#
# [4]	train-error:0.000856	eval-error:0.00094
#
# [5]	train-error:0.00085	eval-error:0.000924
#
# [6]	train-error:0.001009	eval-error:0.001099
#
# [7]	train-error:0.000779	eval-error:0.000861
#
# [8]	train-error:0.000832	eval-error:0.000906
#
# [9]	train-error:0.000733	eval-error:0.000811
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.4838946642863522e-07, 'max_depth': 7, 'min_child_weight': 0.41932359686449344, 'subsample': 0.8500000000000001}, logloss: 0.2000
# [0]	train-error:0.002155	eval-error:0.002306
#
# [1]	train-error:0.002038	eval-error:0.002184
#
# [2]	train-error:0.001717	eval-error:0.001831
#
# [3]	train-error:0.00139	eval-error:0.001457
#
# [4]	train-error:0.00163	eval-error:0.001772
#
# [5]	train-error:0.001376	eval-error:0.001504
#
# [6]	train-error:0.001286	eval-error:0.00138
#
# [7]	train-error:0.001149	eval-error:0.001244
#
# [8]	train-error:0.001051	eval-error:0.001142
#
# [9]	train-error:0.001054	eval-error:0.001171
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0022471532174683766, 'max_depth': 6, 'min_child_weight': 1.5362314391317962, 'subsample': 0.9}, logloss: 0.2014
# [0]	train-error:0.001873	eval-error:0.001996
#
# [1]	train-error:0.001212	eval-error:0.001294
#
# [2]	train-error:0.002004	eval-error:0.002107
#
# [3]	train-error:0.00193	eval-error:0.00203
#
# [4]	train-error:0.001742	eval-error:0.001874
#
# [5]	train-error:0.001341	eval-error:0.001432
#
# [6]	train-error:0.00135	eval-error:0.001468
#
# [7]	train-error:0.001288	eval-error:0.001371
#
# [8]	train-error:0.001257	eval-error:0.001343
#
# [9]	train-error:0.001155	eval-error:0.001255
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.7705851513676907e-06, 'max_depth': 6, 'min_child_weight': 1.0365639185554099, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.005764	eval-error:0.005872
#
# [1]	train-error:0.005763	eval-error:0.005872
#
# [2]	train-error:0.002636	eval-error:0.002651
#
# [3]	train-error:0.002636	eval-error:0.002651
#
# [4]	train-error:0.002637	eval-error:0.002651
#
# [5]	train-error:0.002636	eval-error:0.002651
#
# [6]	train-error:0.002636	eval-error:0.002651
#
# [7]	train-error:0.00261	eval-error:0.002594
#
# [8]	train-error:0.002636	eval-error:0.002651
#
# [9]	train-error:0.002608	eval-error:0.002594
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 4.38228153204771e-07, 'max_depth': 4, 'min_child_weight': 6.241684846175476, 'subsample': 0.9}, logloss: 0.2046
# [0]	train-error:0.000865	eval-error:0.000983
#
# [1]	train-error:0.000802	eval-error:0.000909
#
# [2]	train-error:0.000589	eval-error:0.000666
#
# [3]	train-error:0.000519	eval-error:0.000569
#
# [4]	train-error:0.00059	eval-error:0.000648
#
# [5]	train-error:0.000512	eval-error:0.000564
#
# [6]	train-error:0.000477	eval-error:0.000541
#
# [7]	train-error:0.000461	eval-error:0.000501
#
# [8]	train-error:0.000445	eval-error:0.00051
#
# [9]	train-error:0.000387	eval-error:0.000433
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.7614550825641326, 'max_depth': 9, 'min_child_weight': 1.1427758777367911, 'subsample': 0.9}, logloss: 0.1989
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.006233	eval-error:0.006387
#
# [2]	train-error:0.007416	eval-error:0.007619
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007416	eval-error:0.007619
#
# [5]	train-error:0.006221	eval-error:0.00638
#
# [6]	train-error:0.006172	eval-error:0.006323
#
# [7]	train-error:0.006172	eval-error:0.006323
#
# [8]	train-error:0.006172	eval-error:0.006323
#
# [9]	train-error:0.006172	eval-error:0.006323
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.8518718588276164, 'max_depth': 3, 'min_child_weight': 1.9585687247383032, 'subsample': 0.75}, logloss: 0.2094
# [0]	train-error:0.005804	eval-error:0.005909
#
# [1]	train-error:0.002592	eval-error:0.002581
#
# [2]	train-error:0.004988	eval-error:0.005127
#
# [3]	train-error:0.004476	eval-error:0.004588
#
# [4]	train-error:0.004515	eval-error:0.004665
#
# [5]	train-error:0.004458	eval-error:0.004604
#
# [6]	train-error:0.005092	eval-error:0.005374
#
# [7]	train-error:0.004382	eval-error:0.004495
#
# [8]	train-error:0.002523	eval-error:0.002481
#
# [9]	train-error:0.00263	eval-error:0.002585
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.4772363247264227e-08, 'max_depth': 4, 'min_child_weight': 0.652992366021475, 'subsample': 0.7000000000000001}, logloss: 0.2050
# [0]	train-error:0.00184	eval-error:0.001948
#
# [1]	train-error:0.00135	eval-error:0.001405
#
# [2]	train-error:0.00097	eval-error:0.001092
#
# [3]	train-error:0.001148	eval-error:0.001257
#
# [4]	train-error:0.000957	eval-error:0.001078
#
# [5]	train-error:0.000946	eval-error:0.001058
#
# [6]	train-error:0.00114	eval-error:0.001246
#
# [7]	train-error:0.00114	eval-error:0.001246
#
# [8]	train-error:0.001129	eval-error:0.001244
#
# [9]	train-error:0.001147	eval-error:0.00126
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.25223503473566744, 'max_depth': 6, 'min_child_weight': 0.24826018308878908, 'subsample': 0.9}, logloss: 0.2002
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006233	eval-error:0.006387
#
# [2]	train-error:0.007415	eval-error:0.007619
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007619
#
# [5]	train-error:0.006221	eval-error:0.00638
#
# [6]	train-error:0.006172	eval-error:0.006323
#
# [7]	train-error:0.006172	eval-error:0.006323
#
# [8]	train-error:0.006172	eval-error:0.006323
#
# [9]	train-error:0.006172	eval-error:0.006323
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.25757240123752e-05, 'max_depth': 3, 'min_child_weight': 0.4177006521870076, 'subsample': 0.8500000000000001}, logloss: 0.2094
# [0]	train-error:0.000911	eval-error:0.001069
#
# [1]	train-error:0.000848	eval-error:0.000967
#
# [2]	train-error:0.000586	eval-error:0.000691
#
# [3]	train-error:0.000482	eval-error:0.000564
#
# [4]	train-error:0.000481	eval-error:0.000541
#
# [5]	train-error:0.000485	eval-error:0.00053
#
# [6]	train-error:0.000484	eval-error:0.00053
#
# [7]	train-error:0.00044	eval-error:0.000487
#
# [8]	train-error:0.000421	eval-error:0.000476
#
# [9]	train-error:0.000396	eval-error:0.000428
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.19503526684636333, 'max_depth': 9, 'min_child_weight': 0.14854125152238531, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.001875	eval-error:0.001982
#
# [1]	train-error:0.001389	eval-error:0.001441
#
# [2]	train-error:0.001257	eval-error:0.001334
#
# [3]	train-error:0.001186	eval-error:0.001314
#
# [4]	train-error:0.001019	eval-error:0.001137
#
# [5]	train-error:0.001028	eval-error:0.001142
#
# [6]	train-error:0.001184	eval-error:0.001303
#
# [7]	train-error:0.001149	eval-error:0.001276
#
# [8]	train-error:0.001151	eval-error:0.001276
#
# [9]	train-error:0.001155	eval-error:0.001282
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.05775697902097309, 'max_depth': 6, 'min_child_weight': 6.0069025494709525, 'subsample': 0.6000000000000001}, logloss: 0.2004
# [0]	train-error:0.005817	eval-error:0.005922
#
# [1]	train-error:0.002595	eval-error:0.002583
#
# [2]	train-error:0.005999	eval-error:0.006181
#
# [3]	train-error:0.004911	eval-error:0.005023
#
# [4]	train-error:0.005004	eval-error:0.005179
#
# [5]	train-error:0.004873	eval-error:0.005023
#
# [6]	train-error:0.00511	eval-error:0.005397
#
# [7]	train-error:0.004392	eval-error:0.004506
#
# [8]	train-error:0.002519	eval-error:0.002472
#
# [9]	train-error:0.002638	eval-error:0.002592
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.06947523885344153, 'max_depth': 4, 'min_child_weight': 7.58114435557993, 'subsample': 0.75}, logloss: 0.2050
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.006233	eval-error:0.006389
#
# [2]	train-error:0.007416	eval-error:0.007619
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007416	eval-error:0.007619
#
# [5]	train-error:0.006221	eval-error:0.00638
#
# [6]	train-error:0.006172	eval-error:0.006321
#
# [7]	train-error:0.006173	eval-error:0.006323
#
# [8]	train-error:0.006173	eval-error:0.006321
#
# [9]	train-error:0.006173	eval-error:0.006321
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.03436541150495077, 'max_depth': 3, 'min_child_weight': 0.18913615251352658, 'subsample': 0.6000000000000001}, logloss: 0.2094
# [0]	train-error:0.002323	eval-error:0.002433
#
# [1]	train-error:0.001852	eval-error:0.001982
#
# [2]	train-error:0.004439	eval-error:0.004581
#
# [3]	train-error:0.004403	eval-error:0.004533
#
# [4]	train-error:0.004398	eval-error:0.004531
#
# [5]	train-error:0.003151	eval-error:0.003376
#
# [6]	train-error:0.003525	eval-error:0.003774
#
# [7]	train-error:0.003216	eval-error:0.003412
#
# [8]	train-error:0.001377	eval-error:0.001434
#
# [9]	train-error:0.001322	eval-error:0.0014
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.049075366377293934, 'max_depth': 5, 'min_child_weight': 3.2119643378671907, 'subsample': 0.6000000000000001}, logloss: 0.2028
# [0]	train-error:0.007429	eval-error:0.007635
#
# [1]	train-error:0.006258	eval-error:0.006434
#
# [2]	train-error:0.007728	eval-error:0.00793
#
# [3]	train-error:0.007788	eval-error:0.007986
#
# [4]	train-error:0.007348	eval-error:0.007576
#
# [5]	train-error:0.007369	eval-error:0.007585
#
# [6]	train-error:0.007367	eval-error:0.007581
#
# [7]	train-error:0.007365	eval-error:0.007576
#
# [8]	train-error:0.002781	eval-error:0.002773
#
# [9]	train-error:0.006532	eval-error:0.006706
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.031073188668591444, 'max_depth': 3, 'min_child_weight': 0.19188898857612904, 'subsample': 0.65}, logloss: 0.2095
# [0]	train-error:0.005816	eval-error:0.005922
#
# [1]	train-error:0.002604	eval-error:0.002594
#
# [2]	train-error:0.006003	eval-error:0.006174
#
# [3]	train-error:0.004926	eval-error:0.00505
#
# [4]	train-error:0.005005	eval-error:0.005179
#
# [5]	train-error:0.004491	eval-error:0.004644
#
# [6]	train-error:0.005118	eval-error:0.005403
#
# [7]	train-error:0.004391	eval-error:0.004506
#
# [8]	train-error:0.002547	eval-error:0.00251
#
# [9]	train-error:0.002641	eval-error:0.002594
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.9800713104755844, 'max_depth': 4, 'min_child_weight': 5.762177556502212, 'subsample': 0.65}, logloss: 0.2050
# [0]	train-error:0.007429	eval-error:0.007635
#
# [1]	train-error:0.006257	eval-error:0.006434
#
# [2]	train-error:0.007731	eval-error:0.007932
#
# [3]	train-error:0.007769	eval-error:0.007964
#
# [4]	train-error:0.00715	eval-error:0.007343
#
# [5]	train-error:0.006215	eval-error:0.006371
#
# [6]	train-error:0.007107	eval-error:0.007304
#
# [7]	train-error:0.006232	eval-error:0.006384
#
# [8]	train-error:0.006227	eval-error:0.006382
#
# [9]	train-error:0.006227	eval-error:0.006382
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.00019493298155888418, 'max_depth': 3, 'min_child_weight': 1.6692399349849445, 'subsample': 0.7000000000000001}, logloss: 0.2094
# [0]	train-error:0.000989	eval-error:0.001171
#
# [1]	train-error:0.00094	eval-error:0.001135
#
# [2]	train-error:0.000783	eval-error:0.00092
#
# [3]	train-error:0.000554	eval-error:0.000632
#
# [4]	train-error:0.000717	eval-error:0.000779
#
# [5]	train-error:0.000493	eval-error:0.000537
#
# [6]	train-error:0.000532	eval-error:0.000589
#
# [7]	train-error:0.000438	eval-error:0.000485
#
# [8]	train-error:0.000433	eval-error:0.000498
#
# [9]	train-error:0.000415	eval-error:0.00046
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0048812580938479, 'max_depth': 9, 'min_child_weight': 0.13128458093388987, 'subsample': 0.8}, logloss: 0.1992
# [0]	train-error:0.000855	eval-error:0.000974
#
# [1]	train-error:0.000797	eval-error:0.000938
#
# [2]	train-error:0.000711	eval-error:0.000802
#
# [3]	train-error:0.000499	eval-error:0.000546
#
# [4]	train-error:0.000656	eval-error:0.000739
#
# [5]	train-error:0.000443	eval-error:0.000503
#
# [6]	train-error:0.000488	eval-error:0.000541
#
# [7]	train-error:0.000415	eval-error:0.000446
#
# [8]	train-error:0.000424	eval-error:0.000483
#
# [9]	train-error:0.000415	eval-error:0.000444
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.672030667429234e-05, 'max_depth': 9, 'min_child_weight': 0.10789740614748372, 'subsample': 0.8500000000000001}, logloss: 0.1989
# [0]	train-error:0.00094	eval-error:0.001022
#
# [1]	train-error:0.000896	eval-error:0.001024
#
# [2]	train-error:0.000918	eval-error:0.001013
#
# [3]	train-error:0.000738	eval-error:0.000818
#
# [4]	train-error:0.000883	eval-error:0.000972
#
# [5]	train-error:0.000717	eval-error:0.000791
#
# [6]	train-error:0.000742	eval-error:0.000811
#
# [7]	train-error:0.000668	eval-error:0.000748
#
# [8]	train-error:0.000739	eval-error:0.000813
#
# [9]	train-error:0.000727	eval-error:0.000797
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.9752680342347265e-05, 'max_depth': 8, 'min_child_weight': 3.049545971564634, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.00093	eval-error:0.001015
#
# [1]	train-error:0.000872	eval-error:0.000981
#
# [2]	train-error:0.000896	eval-error:0.000986
#
# [3]	train-error:0.000713	eval-error:0.000773
#
# [4]	train-error:0.000854	eval-error:0.00094
#
# [5]	train-error:0.000698	eval-error:0.000786
#
# [6]	train-error:0.000733	eval-error:0.000797
#
# [7]	train-error:0.000656	eval-error:0.000741
#
# [8]	train-error:0.000727	eval-error:0.000795
#
# [9]	train-error:0.000721	eval-error:0.000793
#
# params: {'colsample_bytree': 0.65, 'gamma': 6.25410526404277e-06, 'max_depth': 8, 'min_child_weight': 0.9101299345040031, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001052	eval-error:0.001201
#
# [1]	train-error:0.001004	eval-error:0.001194
#
# [2]	train-error:0.001032	eval-error:0.001194
#
# [3]	train-error:0.000772	eval-error:0.000865
#
# [4]	train-error:0.000979	eval-error:0.001108
#
# [5]	train-error:0.000732	eval-error:0.000845
#
# [6]	train-error:0.000761	eval-error:0.000847
#
# [7]	train-error:0.000665	eval-error:0.000736
#
# [8]	train-error:0.000816	eval-error:0.000902
#
# [9]	train-error:0.000753	eval-error:0.000836
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 9.867408947210762e-05, 'max_depth': 8, 'min_child_weight': 2.9827535953856192, 'subsample': 0.8500000000000001}, logloss: 0.1997
# [0]	train-error:0.000861	eval-error:0.000983
#
# [1]	train-error:0.000802	eval-error:0.000947
#
# [2]	train-error:0.000708	eval-error:0.000779
#
# [3]	train-error:0.000508	eval-error:0.000535
#
# [4]	train-error:0.000659	eval-error:0.000727
#
# [5]	train-error:0.000445	eval-error:0.000494
#
# [6]	train-error:0.000503	eval-error:0.000557
#
# [7]	train-error:0.000409	eval-error:0.000435
#
# [8]	train-error:0.00043	eval-error:0.000489
#
# [9]	train-error:0.000404	eval-error:0.000451
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.0183733128459719e-07, 'max_depth': 9, 'min_child_weight': 0.29268057583202234, 'subsample': 0.9500000000000001}, logloss: 0.1990
# [0]	train-error:0.001278	eval-error:0.001377
#
# [1]	train-error:0.001114	eval-error:0.001262
#
# [2]	train-error:0.001064	eval-error:0.001162
#
# [3]	train-error:0.001038	eval-error:0.001092
#
# [4]	train-error:0.001054	eval-error:0.001137
#
# [5]	train-error:0.000987	eval-error:0.001044
#
# [6]	train-error:0.000809	eval-error:0.000888
#
# [7]	train-error:0.000848	eval-error:0.000911
#
# [8]	train-error:0.000873	eval-error:0.00094
#
# [9]	train-error:0.000881	eval-error:0.000958
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.0003089267327767221, 'max_depth': 7, 'min_child_weight': 0.10253330079251734, 'subsample': 0.8500000000000001}, logloss: 0.2000
# [0]	train-error:0.001161	eval-error:0.001282
#
# [1]	train-error:0.000871	eval-error:0.000992
#
# [2]	train-error:0.000902	eval-error:0.000983
#
# [3]	train-error:0.000672	eval-error:0.000709
#
# [4]	train-error:0.00076	eval-error:0.000841
#
# [5]	train-error:0.000751	eval-error:0.000816
#
# [6]	train-error:0.00072	eval-error:0.000784
#
# [7]	train-error:0.000587	eval-error:0.000612
#
# [8]	train-error:0.000678	eval-error:0.000741
#
# [9]	train-error:0.000526	eval-error:0.00058
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.0217195992360963e-08, 'max_depth': 8, 'min_child_weight': 0.9704126282853657, 'subsample': 0.8}, logloss: 0.1994
# [0]	train-error:0.001013	eval-error:0.001169
#
# [1]	train-error:0.000961	eval-error:0.001149
#
# [2]	train-error:0.00079	eval-error:0.000922
#
# [3]	train-error:0.000575	eval-error:0.00065
#
# [4]	train-error:0.000726	eval-error:0.000822
#
# [5]	train-error:0.000541	eval-error:0.000619
#
# [6]	train-error:0.000537	eval-error:0.0006
#
# [7]	train-error:0.000465	eval-error:0.000517
#
# [8]	train-error:0.000442	eval-error:0.000517
#
# [9]	train-error:0.000427	eval-error:0.000471
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 1.9800869677770737e-06, 'max_depth': 9, 'min_child_weight': 2.2193850715072942, 'subsample': 0.8}, logloss: 0.1991
# [0]	train-error:0.001276	eval-error:0.001343
#
# [1]	train-error:0.001059	eval-error:0.001198
#
# [2]	train-error:0.001063	eval-error:0.001149
#
# [3]	train-error:0.001038	eval-error:0.001094
#
# [4]	train-error:0.001054	eval-error:0.001131
#
# [5]	train-error:0.000983	eval-error:0.00104
#
# [6]	train-error:0.000813	eval-error:0.00089
#
# [7]	train-error:0.000856	eval-error:0.000918
#
# [8]	train-error:0.000867	eval-error:0.000938
#
# [9]	train-error:0.000875	eval-error:0.000956
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.007433465435514045, 'max_depth': 7, 'min_child_weight': 0.6745010215749146, 'subsample': 0.9}, logloss: 0.2000
# [0]	train-error:0.000934	eval-error:0.001026
#
# [1]	train-error:0.000748	eval-error:0.000843
#
# [2]	train-error:0.000764	eval-error:0.000834
#
# [3]	train-error:0.000637	eval-error:0.000664
#
# [4]	train-error:0.000751	eval-error:0.000827
#
# [5]	train-error:0.000736	eval-error:0.000804
#
# [6]	train-error:0.00072	eval-error:0.000786
#
# [7]	train-error:0.000622	eval-error:0.000648
#
# [8]	train-error:0.000603	eval-error:0.00065
#
# [9]	train-error:0.000538	eval-error:0.000571
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 5.648530581377501e-05, 'max_depth': 8, 'min_child_weight': 1.3975048862095922, 'subsample': 0.8500000000000001}, logloss: 0.1994
# [0]	train-error:0.000876	eval-error:0.000988
#
# [1]	train-error:0.000683	eval-error:0.000759
#
# [2]	train-error:0.000682	eval-error:0.000761
#
# [3]	train-error:0.000545	eval-error:0.000616
#
# [4]	train-error:0.000496	eval-error:0.000544
#
# [5]	train-error:0.000415	eval-error:0.000471
#
# [6]	train-error:0.000415	eval-error:0.000462
#
# [7]	train-error:0.000381	eval-error:0.000435
#
# [8]	train-error:0.000383	eval-error:0.000433
#
# [9]	train-error:0.000356	eval-error:0.000403
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0006877988841293905, 'max_depth': 9, 'min_child_weight': 4.469999170509959, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.0013	eval-error:0.001377
#
# [1]	train-error:0.000974	eval-error:0.001087
#
# [2]	train-error:0.000833	eval-error:0.000927
#
# [3]	train-error:0.000942	eval-error:0.001051
#
# [4]	train-error:0.000928	eval-error:0.001038
#
# [5]	train-error:0.000909	eval-error:0.001006
#
# [6]	train-error:0.000912	eval-error:0.001013
#
# [7]	train-error:0.000881	eval-error:0.000997
#
# [8]	train-error:0.000895	eval-error:0.001015
#
# [9]	train-error:0.000887	eval-error:0.000997
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0006724249560658686, 'max_depth': 7, 'min_child_weight': 4.231017568906241, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.002322	eval-error:0.002433
#
# [1]	train-error:0.001815	eval-error:0.00196
#
# [2]	train-error:0.004447	eval-error:0.004545
#
# [3]	train-error:0.004472	eval-error:0.004631
#
# [4]	train-error:0.004398	eval-error:0.004536
#
# [5]	train-error:0.001933	eval-error:0.00196
#
# [6]	train-error:0.001322	eval-error:0.001427
#
# [7]	train-error:0.001285	eval-error:0.001389
#
# [8]	train-error:0.00122	eval-error:0.001316
#
# [9]	train-error:0.001475	eval-error:0.001552
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.008014722558771609, 'max_depth': 5, 'min_child_weight': 3.9907183987079926, 'subsample': 0.9500000000000001}, logloss: 0.2024
# [0]	train-error:0.002352	eval-error:0.002465
#
# [1]	train-error:0.001803	eval-error:0.001935
#
# [2]	train-error:0.004434	eval-error:0.004581
#
# [3]	train-error:0.004374	eval-error:0.004502
#
# [4]	train-error:0.004385	eval-error:0.004518
#
# [5]	train-error:0.001939	eval-error:0.001969
#
# [6]	train-error:0.001266	eval-error:0.00138
#
# [7]	train-error:0.001223	eval-error:0.001341
#
# [8]	train-error:0.001182	eval-error:0.001287
#
# [9]	train-error:0.001439	eval-error:0.001511
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.001651208903439969, 'max_depth': 5, 'min_child_weight': 9.298582761876688, 'subsample': 0.9}, logloss: 0.2024
# [0]	train-error:0.000946	eval-error:0.001042
#
# [1]	train-error:0.000751	eval-error:0.000845
#
# [2]	train-error:0.000705	eval-error:0.000797
#
# [3]	train-error:0.000704	eval-error:0.000797
#
# [4]	train-error:0.000797	eval-error:0.00089
#
# [5]	train-error:0.000683	eval-error:0.000779
#
# [6]	train-error:0.000785	eval-error:0.000881
#
# [7]	train-error:0.000782	eval-error:0.000884
#
# [8]	train-error:0.000781	eval-error:0.000886
#
# [9]	train-error:0.000776	eval-error:0.000872
#
# params: {'colsample_bytree': 0.9, 'gamma': 4.786977086688639e-08, 'max_depth': 8, 'min_child_weight': 1.2598886411706016, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.000873	eval-error:0.000988
#
# [1]	train-error:0.000678	eval-error:0.000759
#
# [2]	train-error:0.000668	eval-error:0.000732
#
# [3]	train-error:0.000523	eval-error:0.000571
#
# [4]	train-error:0.000487	eval-error:0.000537
#
# [5]	train-error:0.000406	eval-error:0.000453
#
# [6]	train-error:0.000394	eval-error:0.00043
#
# [7]	train-error:0.000362	eval-error:0.000406
#
# [8]	train-error:0.00037	eval-error:0.000417
#
# [9]	train-error:0.000347	eval-error:0.00039
#
# params: {'colsample_bytree': 0.8, 'gamma': 5.04949205113105e-07, 'max_depth': 9, 'min_child_weight': 2.319111557737454, 'subsample': 0.9500000000000001}, logloss: 0.1988
# [0]	train-error:0.001285	eval-error:0.001353
#
# [1]	train-error:0.000913	eval-error:0.00102
#
# [2]	train-error:0.001002	eval-error:0.001097
#
# [3]	train-error:0.000905	eval-error:0.000961
#
# [4]	train-error:0.000922	eval-error:0.000986
#
# [5]	train-error:0.000801	eval-error:0.00087
#
# [6]	train-error:0.000865	eval-error:0.000938
#
# [7]	train-error:0.000794	eval-error:0.000865
#
# [8]	train-error:0.00088	eval-error:0.000972
#
# [9]	train-error:0.000804	eval-error:0.000902
#
# params: {'colsample_bytree': 0.8, 'gamma': 4.2863171584900486e-07, 'max_depth': 7, 'min_child_weight': 2.4140809845357287, 'subsample': 0.9500000000000001}, logloss: 0.1999
# [0]	train-error:0.000891	eval-error:0.001013
#
# [1]	train-error:0.00049	eval-error:0.000551
#
# [2]	train-error:0.000459	eval-error:0.00051
#
# [3]	train-error:0.00045	eval-error:0.00051
#
# [4]	train-error:0.000446	eval-error:0.000489
#
# [5]	train-error:0.000453	eval-error:0.000498
#
# [6]	train-error:0.000439	eval-error:0.000485
#
# [7]	train-error:0.000436	eval-error:0.000485
#
# [8]	train-error:0.000428	eval-error:0.000483
#
# [9]	train-error:0.000433	eval-error:0.000487
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.307176537986387e-06, 'max_depth': 9, 'min_child_weight': 4.2240302513715, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.000942	eval-error:0.001042
#
# [1]	train-error:0.000748	eval-error:0.000845
#
# [2]	train-error:0.000702	eval-error:0.000793
#
# [3]	train-error:0.000702	eval-error:0.000793
#
# [4]	train-error:0.000807	eval-error:0.000906
#
# [5]	train-error:0.000692	eval-error:0.000795
#
# [6]	train-error:0.000782	eval-error:0.000881
#
# [7]	train-error:0.000777	eval-error:0.00087
#
# [8]	train-error:0.000671	eval-error:0.000768
#
# [9]	train-error:0.000773	eval-error:0.000868
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.1969482631041929e-06, 'max_depth': 8, 'min_child_weight': 0.8097003473486465, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.001007	eval-error:0.001131
#
# [1]	train-error:0.000665	eval-error:0.000732
#
# [2]	train-error:0.000576	eval-error:0.000637
#
# [3]	train-error:0.00056	eval-error:0.000616
#
# [4]	train-error:0.000563	eval-error:0.000632
#
# [5]	train-error:0.000551	eval-error:0.000605
#
# [6]	train-error:0.000539	eval-error:0.0006
#
# [7]	train-error:0.000535	eval-error:0.0006
#
# [8]	train-error:0.000498	eval-error:0.000571
#
# [9]	train-error:0.000514	eval-error:0.000571
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.1245243515838884e-08, 'max_depth': 9, 'min_child_weight': 8.560990109902333, 'subsample': 0.65}, logloss: 0.1989
# [0]	train-error:0.001296	eval-error:0.001405
#
# [1]	train-error:0.000962	eval-error:0.001087
#
# [2]	train-error:0.000936	eval-error:0.001056
#
# [3]	train-error:0.000808	eval-error:0.000902
#
# [4]	train-error:0.000903	eval-error:0.001026
#
# [5]	train-error:0.000926	eval-error:0.001038
#
# [6]	train-error:0.000865	eval-error:0.000988
#
# [7]	train-error:0.000859	eval-error:0.000967
#
# [8]	train-error:0.000842	eval-error:0.000949
#
# [9]	train-error:0.00086	eval-error:0.000958
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 4.969230608645694e-06, 'max_depth': 7, 'min_child_weight': 0.5216806396352001, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.001886	eval-error:0.001991
#
# [1]	train-error:0.00137	eval-error:0.001423
#
# [2]	train-error:0.00125	eval-error:0.001321
#
# [3]	train-error:0.001162	eval-error:0.001285
#
# [4]	train-error:0.000995	eval-error:0.001115
#
# [5]	train-error:0.00099	eval-error:0.001117
#
# [6]	train-error:0.001158	eval-error:0.001285
#
# [7]	train-error:0.001131	eval-error:0.001246
#
# [8]	train-error:0.000955	eval-error:0.001078
#
# [9]	train-error:0.001048	eval-error:0.001149
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.386409258035786e-07, 'max_depth': 6, 'min_child_weight': 5.045407394365676, 'subsample': 0.7000000000000001}, logloss: 0.2001
# [0]	train-error:0.00113	eval-error:0.00123
#
# [1]	train-error:0.000771	eval-error:0.000875
#
# [2]	train-error:0.000744	eval-error:0.000843
#
# [3]	train-error:0.000702	eval-error:0.000786
#
# [4]	train-error:0.000681	eval-error:0.000782
#
# [5]	train-error:0.000676	eval-error:0.000754
#
# [6]	train-error:0.000686	eval-error:0.00077
#
# [7]	train-error:0.000683	eval-error:0.000779
#
# [8]	train-error:0.000679	eval-error:0.000764
#
# [9]	train-error:0.00068	eval-error:0.000775
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.2632453483164843e-06, 'max_depth': 8, 'min_child_weight': 1.8607977302082321, 'subsample': 0.8}, logloss: 0.1992
# [0]	train-error:0.000912	eval-error:0.001038
#
# [1]	train-error:0.000512	eval-error:0.000571
#
# [2]	train-error:0.000474	eval-error:0.00053
#
# [3]	train-error:0.000468	eval-error:0.000523
#
# [4]	train-error:0.00046	eval-error:0.000517
#
# [5]	train-error:0.000473	eval-error:0.000532
#
# [6]	train-error:0.000456	eval-error:0.000514
#
# [7]	train-error:0.000454	eval-error:0.000514
#
# [8]	train-error:0.000441	eval-error:0.000498
#
# [9]	train-error:0.00044	eval-error:0.000483
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 5.174027053021151e-06, 'max_depth': 9, 'min_child_weight': 7.462170847954085, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.001371	eval-error:0.001464
#
# [1]	train-error:0.001016	eval-error:0.001135
#
# [2]	train-error:0.000865	eval-error:0.000956
#
# [3]	train-error:0.000862	eval-error:0.000947
#
# [4]	train-error:0.000952	eval-error:0.001058
#
# [5]	train-error:0.000978	eval-error:0.001078
#
# [6]	train-error:0.000887	eval-error:0.000995
#
# [7]	train-error:0.000909	eval-error:0.001026
#
# [8]	train-error:0.000886	eval-error:0.000988
#
# [9]	train-error:0.000864	eval-error:0.000979
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 7.601066763340015e-06, 'max_depth': 7, 'min_child_weight': 9.817059957136012, 'subsample': 0.9}, logloss: 0.1996
# [0]	train-error:0.000994	eval-error:0.001081
#
# [1]	train-error:0.000793	eval-error:0.000877
#
# [2]	train-error:0.000745	eval-error:0.000818
#
# [3]	train-error:0.000733	eval-error:0.000813
#
# [4]	train-error:0.000731	eval-error:0.000825
#
# [5]	train-error:0.000736	eval-error:0.000816
#
# [6]	train-error:0.000723	eval-error:0.000816
#
# [7]	train-error:0.000721	eval-error:0.000818
#
# [8]	train-error:0.000707	eval-error:0.000795
#
# [9]	train-error:0.0007	eval-error:0.000791
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 4.009214811650428e-05, 'max_depth': 8, 'min_child_weight': 7.588281640164193, 'subsample': 0.75}, logloss: 0.1991
# [0]	train-error:0.002352	eval-error:0.002465
#
# [1]	train-error:0.00202	eval-error:0.00208
#
# [2]	train-error:0.002306	eval-error:0.002313
#
# [3]	train-error:0.002243	eval-error:0.002245
#
# [4]	train-error:0.002282	eval-error:0.002293
#
# [5]	train-error:0.002004	eval-error:0.002073
#
# [6]	train-error:0.00222	eval-error:0.002209
#
# [7]	train-error:0.002207	eval-error:0.002193
#
# [8]	train-error:0.001486	eval-error:0.001552
#
# [9]	train-error:0.002202	eval-error:0.002186
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0578055331166661e-07, 'max_depth': 5, 'min_child_weight': 7.012495392448599, 'subsample': 0.8500000000000001}, logloss: 0.2016
# [0]	train-error:0.000889	eval-error:0.001015
#
# [1]	train-error:0.000489	eval-error:0.000555
#
# [2]	train-error:0.000459	eval-error:0.000512
#
# [3]	train-error:0.000446	eval-error:0.000505
#
# [4]	train-error:0.000446	eval-error:0.000494
#
# [5]	train-error:0.00045	eval-error:0.000498
#
# [6]	train-error:0.000437	eval-error:0.000483
#
# [7]	train-error:0.000437	eval-error:0.000483
#
# [8]	train-error:0.000429	eval-error:0.00048
#
# [9]	train-error:0.000421	eval-error:0.000476
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.943128604782031e-06, 'max_depth': 9, 'min_child_weight': 3.462222472311429, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.001646	eval-error:0.001765
#
# [1]	train-error:0.001568	eval-error:0.001647
#
# [2]	train-error:0.001269	eval-error:0.001416
#
# [3]	train-error:0.001139	eval-error:0.001257
#
# [4]	train-error:0.001007	eval-error:0.001126
#
# [5]	train-error:0.001006	eval-error:0.001131
#
# [6]	train-error:0.001143	eval-error:0.001273
#
# [7]	train-error:0.001135	eval-error:0.001255
#
# [8]	train-error:0.001143	eval-error:0.001269
#
# [9]	train-error:0.00114	eval-error:0.001264
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.154178336162842e-08, 'max_depth': 6, 'min_child_weight': 4.916439483323374, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.000912	eval-error:0.001031
#
# [1]	train-error:0.000497	eval-error:0.000557
#
# [2]	train-error:0.000464	eval-error:0.000512
#
# [3]	train-error:0.000459	eval-error:0.00051
#
# [4]	train-error:0.000467	eval-error:0.000523
#
# [5]	train-error:0.00047	eval-error:0.000526
#
# [6]	train-error:0.000461	eval-error:0.000505
#
# [7]	train-error:0.000474	eval-error:0.000523
#
# [8]	train-error:0.000443	eval-error:0.000492
#
# [9]	train-error:0.000446	eval-error:0.000492
#
# params: {'colsample_bytree': 0.9, 'gamma': 6.530050765910336e-07, 'max_depth': 9, 'min_child_weight': 6.213023275506226, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.001286	eval-error:0.001371
#
# [1]	train-error:0.000963	eval-error:0.001076
#
# [2]	train-error:0.000821	eval-error:0.00092
#
# [3]	train-error:0.000935	eval-error:0.001042
#
# [4]	train-error:0.000918	eval-error:0.001035
#
# [5]	train-error:0.000901	eval-error:0.001029
#
# [6]	train-error:0.0009	eval-error:0.001029
#
# [7]	train-error:0.000871	eval-error:0.00099
#
# [8]	train-error:0.000843	eval-error:0.000965
#
# [9]	train-error:0.000843	eval-error:0.000947
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.3777316748027718e-05, 'max_depth': 7, 'min_child_weight': 0.36020932017668517, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.001853	eval-error:0.001955
#
# [1]	train-error:0.001367	eval-error:0.001418
#
# [2]	train-error:0.000979	eval-error:0.001092
#
# [3]	train-error:0.001158	eval-error:0.001278
#
# [4]	train-error:0.000989	eval-error:0.001115
#
# [5]	train-error:0.000985	eval-error:0.001103
#
# [6]	train-error:0.001151	eval-error:0.001278
#
# [7]	train-error:0.001131	eval-error:0.001255
#
# [8]	train-error:0.001134	eval-error:0.001257
#
# [9]	train-error:0.001129	eval-error:0.001253
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00018720859237444324, 'max_depth': 6, 'min_child_weight': 2.5695493072217914, 'subsample': 0.75}, logloss: 0.2004
# [0]	train-error:0.000955	eval-error:0.001053
#
# [1]	train-error:0.000759	eval-error:0.000852
#
# [2]	train-error:0.000727	eval-error:0.000813
#
# [3]	train-error:0.00072	eval-error:0.000809
#
# [4]	train-error:0.00081	eval-error:0.000899
#
# [5]	train-error:0.000701	eval-error:0.000784
#
# [6]	train-error:0.000805	eval-error:0.000895
#
# [7]	train-error:0.000699	eval-error:0.000782
#
# [8]	train-error:0.000706	eval-error:0.000797
#
# [9]	train-error:0.000696	eval-error:0.000782
#
# params: {'colsample_bytree': 0.9, 'gamma': 5.423645062222493e-08, 'max_depth': 8, 'min_child_weight': 3.8060326559636137, 'subsample': 0.8500000000000001}, logloss: 0.1991
# [0]	train-error:0.000884	eval-error:0.00101
#
# [1]	train-error:0.000477	eval-error:0.000539
#
# [2]	train-error:0.000439	eval-error:0.000496
#
# [3]	train-error:0.000436	eval-error:0.000496
#
# [4]	train-error:0.000432	eval-error:0.000483
#
# [5]	train-error:0.000438	eval-error:0.000492
#
# [6]	train-error:0.000422	eval-error:0.000474
#
# [7]	train-error:0.000418	eval-error:0.000474
#
# [8]	train-error:0.000413	eval-error:0.000474
#
# [9]	train-error:0.000408	eval-error:0.000469
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 4.811391737327204e-05, 'max_depth': 9, 'min_child_weight': 1.6344623450781888, 'subsample': 0.9}, logloss: 0.1988
# [0]	train-error:0.005804	eval-error:0.005911
#
# [1]	train-error:0.002599	eval-error:0.002585
#
# [2]	train-error:0.005988	eval-error:0.006174
#
# [3]	train-error:0.004912	eval-error:0.005014
#
# [4]	train-error:0.005001	eval-error:0.005172
#
# [5]	train-error:0.00447	eval-error:0.004606
#
# [6]	train-error:0.005587	eval-error:0.005766
#
# [7]	train-error:0.004357	eval-error:0.004479
#
# [8]	train-error:0.002559	eval-error:0.002515
#
# [9]	train-error:0.002472	eval-error:0.002404
#
# params: {'colsample_bytree': 0.75, 'gamma': 2.8045111660519077e-07, 'max_depth': 4, 'min_child_weight': 5.277903330780167, 'subsample': 0.9500000000000001}, logloss: 0.2051
# [0]	train-error:0.000995	eval-error:0.001106
#
# [1]	train-error:0.000527	eval-error:0.000585
#
# [2]	train-error:0.000482	eval-error:0.000541
#
# [3]	train-error:0.000473	eval-error:0.000526
#
# [4]	train-error:0.000478	eval-error:0.000535
#
# [5]	train-error:0.000474	eval-error:0.00053
#
# [6]	train-error:0.000467	eval-error:0.000523
#
# [7]	train-error:0.000486	eval-error:0.000537
#
# [8]	train-error:0.000446	eval-error:0.000496
#
# [9]	train-error:0.000448	eval-error:0.000505
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 9.819387786672897e-06, 'max_depth': 9, 'min_child_weight': 8.129436247263724, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.000947	eval-error:0.001044
#
# [1]	train-error:0.000754	eval-error:0.000847
#
# [2]	train-error:0.000708	eval-error:0.0008
#
# [3]	train-error:0.000707	eval-error:0.0008
#
# [4]	train-error:0.000801	eval-error:0.000895
#
# [5]	train-error:0.000689	eval-error:0.000786
#
# [6]	train-error:0.00079	eval-error:0.000888
#
# [7]	train-error:0.000787	eval-error:0.000886
#
# [8]	train-error:0.000785	eval-error:0.000886
#
# [9]	train-error:0.000781	eval-error:0.000872
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.876999459140918e-06, 'max_depth': 8, 'min_child_weight': 1.903114271462923, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.001301	eval-error:0.001407
#
# [1]	train-error:0.000976	eval-error:0.001103
#
# [2]	train-error:0.000942	eval-error:0.001053
#
# [3]	train-error:0.000816	eval-error:0.000902
#
# [4]	train-error:0.000914	eval-error:0.001031
#
# [5]	train-error:0.000936	eval-error:0.001042
#
# [6]	train-error:0.000853	eval-error:0.000952
#
# [7]	train-error:0.000849	eval-error:0.000936
#
# [8]	train-error:0.000843	eval-error:0.000949
#
# [9]	train-error:0.000838	eval-error:0.000938
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00010554488890175594, 'max_depth': 7, 'min_child_weight': 2.7584306157709646, 'subsample': 0.8500000000000001}, logloss: 0.1997
# [0]	train-error:0.002321	eval-error:0.002431
#
# [1]	train-error:0.00187	eval-error:0.002003
#
# [2]	train-error:0.004416	eval-error:0.004563
#
# [3]	train-error:0.00437	eval-error:0.004499
#
# [4]	train-error:0.004373	eval-error:0.004499
#
# [5]	train-error:0.00358	eval-error:0.003802
#
# [6]	train-error:0.001868	eval-error:0.002012
#
# [7]	train-error:0.001777	eval-error:0.001946
#
# [8]	train-error:0.001716	eval-error:0.001858
#
# [9]	train-error:0.00147	eval-error:0.001554
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.0094883282433403e-06, 'max_depth': 5, 'min_child_weight': 1.0899343325519708, 'subsample': 0.7000000000000001}, logloss: 0.2025
# [0]	train-error:0.000913	eval-error:0.001035
#
# [1]	train-error:0.000496	eval-error:0.000555
#
# [2]	train-error:0.000472	eval-error:0.000526
#
# [3]	train-error:0.00046	eval-error:0.00051
#
# [4]	train-error:0.000469	eval-error:0.000523
#
# [5]	train-error:0.000461	eval-error:0.000503
#
# [6]	train-error:0.000452	eval-error:0.000494
#
# [7]	train-error:0.000445	eval-error:0.000498
#
# [8]	train-error:0.000441	eval-error:0.000492
#
# [9]	train-error:0.000427	eval-error:0.000467
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.5577564132977978e-05, 'max_depth': 9, 'min_child_weight': 6.605359745297168, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.001084	eval-error:0.001198
#
# [1]	train-error:0.000893	eval-error:0.000992
#
# [2]	train-error:0.000767	eval-error:0.000845
#
# [3]	train-error:0.000766	eval-error:0.000841
#
# [4]	train-error:0.000754	eval-error:0.000852
#
# [5]	train-error:0.000748	eval-error:0.000822
#
# [6]	train-error:0.000728	eval-error:0.000807
#
# [7]	train-error:0.000727	eval-error:0.000813
#
# [8]	train-error:0.000718	eval-error:0.000802
#
# [9]	train-error:0.000717	eval-error:0.0008
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0030406506468933707, 'max_depth': 8, 'min_child_weight': 9.999672899904331, 'subsample': 0.65}, logloss: 0.1992
# [0]	train-error:0.001871	eval-error:0.001976
#
# [1]	train-error:0.001377	eval-error:0.001427
#
# [2]	train-error:0.000992	eval-error:0.001115
#
# [3]	train-error:0.00116	eval-error:0.001289
#
# [4]	train-error:0.000995	eval-error:0.001119
#
# [5]	train-error:0.000992	eval-error:0.001119
#
# [6]	train-error:0.00114	eval-error:0.001276
#
# [7]	train-error:0.001129	eval-error:0.001255
#
# [8]	train-error:0.001136	eval-error:0.001269
#
# [9]	train-error:0.001134	eval-error:0.001264
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.000317594669458774, 'max_depth': 6, 'min_child_weight': 7.0650692799315316, 'subsample': 0.8500000000000001}, logloss: 0.2001
# [0]	train-error:0.005761	eval-error:0.005868
#
# [1]	train-error:0.005758	eval-error:0.005868
#
# [2]	train-error:0.00263	eval-error:0.002646
#
# [3]	train-error:0.00263	eval-error:0.002646
#
# [4]	train-error:0.002629	eval-error:0.002644
#
# [5]	train-error:0.002629	eval-error:0.002644
#
# [6]	train-error:0.002415	eval-error:0.00239
#
# [7]	train-error:0.002415	eval-error:0.002388
#
# [8]	train-error:0.002415	eval-error:0.002388
#
# [9]	train-error:0.002414	eval-error:0.002388
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.019695088264954128, 'max_depth': 4, 'min_child_weight': 0.7466522437570359, 'subsample': 0.75}, logloss: 0.2047
# [0]	train-error:0.000953	eval-error:0.001047
#
# [1]	train-error:0.00076	eval-error:0.000847
#
# [2]	train-error:0.00072	eval-error:0.000797
#
# [3]	train-error:0.000708	eval-error:0.000779
#
# [4]	train-error:0.000714	eval-error:0.000793
#
# [5]	train-error:0.000714	eval-error:0.000791
#
# [6]	train-error:0.000692	eval-error:0.000779
#
# [7]	train-error:0.000686	eval-error:0.000779
#
# [8]	train-error:0.000688	eval-error:0.000784
#
# [9]	train-error:0.000688	eval-error:0.000788
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.4579043034274196e-05, 'max_depth': 8, 'min_child_weight': 3.587082903796064, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.0009	eval-error:0.00102
#
# [1]	train-error:0.000491	eval-error:0.000553
#
# [2]	train-error:0.000461	eval-error:0.000512
#
# [3]	train-error:0.000454	eval-error:0.000512
#
# [4]	train-error:0.000461	eval-error:0.000514
#
# [5]	train-error:0.000469	eval-error:0.000523
#
# [6]	train-error:0.000445	eval-error:0.000489
#
# [7]	train-error:0.000443	eval-error:0.000487
#
# [8]	train-error:0.000438	eval-error:0.000489
#
# [9]	train-error:0.00044	eval-error:0.000492
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.6842780316810885e-06, 'max_depth': 9, 'min_child_weight': 5.650654144931891, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.000893	eval-error:0.001017
#
# [1]	train-error:0.00049	eval-error:0.000553
#
# [2]	train-error:0.000461	eval-error:0.000519
#
# [3]	train-error:0.000452	eval-error:0.00051
#
# [4]	train-error:0.000458	eval-error:0.000517
#
# [5]	train-error:0.000456	eval-error:0.000507
#
# [6]	train-error:0.000439	eval-error:0.000487
#
# [7]	train-error:0.000439	eval-error:0.000487
#
# [8]	train-error:0.00043	eval-error:0.000485
#
# [9]	train-error:0.000418	eval-error:0.000464
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 7.915796918754663e-05, 'max_depth': 9, 'min_child_weight': 4.614703659455792, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000911	eval-error:0.001024
#
# [1]	train-error:0.000495	eval-error:0.000555
#
# [2]	train-error:0.000462	eval-error:0.000517
#
# [3]	train-error:0.000458	eval-error:0.00051
#
# [4]	train-error:0.000467	eval-error:0.000523
#
# [5]	train-error:0.00046	eval-error:0.000503
#
# [6]	train-error:0.00045	eval-error:0.000498
#
# [7]	train-error:0.000445	eval-error:0.000494
#
# [8]	train-error:0.00044	eval-error:0.000492
#
# [9]	train-error:0.000427	eval-error:0.000471
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0013460169068617797, 'max_depth': 9, 'min_child_weight': 6.4459448234409304, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000929	eval-error:0.001042
#
# [1]	train-error:0.000514	eval-error:0.000575
#
# [2]	train-error:0.000477	eval-error:0.000528
#
# [3]	train-error:0.000464	eval-error:0.000526
#
# [4]	train-error:0.000471	eval-error:0.00053
#
# [5]	train-error:0.000479	eval-error:0.000539
#
# [6]	train-error:0.000457	eval-error:0.000519
#
# [7]	train-error:0.000457	eval-error:0.000519
#
# [8]	train-error:0.000448	eval-error:0.000507
#
# [9]	train-error:0.000424	eval-error:0.000494
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.001226440469556036, 'max_depth': 9, 'min_child_weight': 8.956310366245615, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.000972	eval-error:0.00106
#
# [1]	train-error:0.000759	eval-error:0.000859
#
# [2]	train-error:0.00073	eval-error:0.000825
#
# [3]	train-error:0.000727	eval-error:0.000809
#
# [4]	train-error:0.000835	eval-error:0.000942
#
# [5]	train-error:0.000712	eval-error:0.000809
#
# [6]	train-error:0.000699	eval-error:0.000766
#
# [7]	train-error:0.000698	eval-error:0.000793
#
# [8]	train-error:0.000807	eval-error:0.00089
#
# [9]	train-error:0.000799	eval-error:0.000899
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.18065739534519054, 'max_depth': 8, 'min_child_weight': 6.474727946830994, 'subsample': 0.9500000000000001}, logloss: 0.1993
# [0]	train-error:0.000887	eval-error:0.001015
#
# [1]	train-error:0.00048	eval-error:0.000544
#
# [2]	train-error:0.000455	eval-error:0.00051
#
# [3]	train-error:0.000446	eval-error:0.000503
#
# [4]	train-error:0.000443	eval-error:0.000492
#
# [5]	train-error:0.00045	eval-error:0.000498
#
# [6]	train-error:0.000437	eval-error:0.000487
#
# [7]	train-error:0.000434	eval-error:0.000487
#
# [8]	train-error:0.000428	eval-error:0.000485
#
# [9]	train-error:0.00043	eval-error:0.000485
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00037058174002101314, 'max_depth': 9, 'min_child_weight': 3.1997097904856013, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.000956	eval-error:0.001053
#
# [1]	train-error:0.00076	eval-error:0.000852
#
# [2]	train-error:0.00073	eval-error:0.00082
#
# [3]	train-error:0.000719	eval-error:0.000795
#
# [4]	train-error:0.000825	eval-error:0.000929
#
# [5]	train-error:0.000716	eval-error:0.00082
#
# [6]	train-error:0.000804	eval-error:0.000913
#
# [7]	train-error:0.000804	eval-error:0.000911
#
# [8]	train-error:0.000692	eval-error:0.000791
#
# [9]	train-error:0.000791	eval-error:0.000893
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.016220844203887492, 'max_depth': 8, 'min_child_weight': 4.601104941919865, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.000885	eval-error:0.00101
#
# [1]	train-error:0.000478	eval-error:0.000541
#
# [2]	train-error:0.00044	eval-error:0.000498
#
# [3]	train-error:0.000437	eval-error:0.000496
#
# [4]	train-error:0.000433	eval-error:0.000483
#
# [5]	train-error:0.00044	eval-error:0.000492
#
# [6]	train-error:0.000428	eval-error:0.00048
#
# [7]	train-error:0.000426	eval-error:0.00048
#
# [8]	train-error:0.000415	eval-error:0.000478
#
# [9]	train-error:0.000421	eval-error:0.00048
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.002510930510338333, 'max_depth': 9, 'min_child_weight': 2.078872243600243, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.000884	eval-error:0.001008
#
# [1]	train-error:0.000477	eval-error:0.000539
#
# [2]	train-error:0.000437	eval-error:0.000496
#
# [3]	train-error:0.000432	eval-error:0.000494
#
# [4]	train-error:0.00043	eval-error:0.00048
#
# [5]	train-error:0.000438	eval-error:0.000489
#
# [6]	train-error:0.000425	eval-error:0.000478
#
# [7]	train-error:0.000422	eval-error:0.000476
#
# [8]	train-error:0.000395	eval-error:0.000451
#
# [9]	train-error:0.00038	eval-error:0.000444
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00014307741815837628, 'max_depth': 9, 'min_child_weight': 1.4034295969588149, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000946	eval-error:0.001042
#
# [1]	train-error:0.000752	eval-error:0.000847
#
# [2]	train-error:0.000706	eval-error:0.0008
#
# [3]	train-error:0.00071	eval-error:0.000795
#
# [4]	train-error:0.000795	eval-error:0.000886
#
# [5]	train-error:0.000686	eval-error:0.00077
#
# [6]	train-error:0.000791	eval-error:0.000881
#
# [7]	train-error:0.000683	eval-error:0.00077
#
# [8]	train-error:0.000686	eval-error:0.00077
#
# [9]	train-error:0.000781	eval-error:0.000884
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.11963500742378788, 'max_depth': 8, 'min_child_weight': 1.4331336467478086, 'subsample': 0.8500000000000001}, logloss: 0.1991
# [0]	train-error:0.001293	eval-error:0.001373
#
# [1]	train-error:0.000967	eval-error:0.001083
#
# [2]	train-error:0.000825	eval-error:0.000922
#
# [3]	train-error:0.000939	eval-error:0.001044
#
# [4]	train-error:0.000923	eval-error:0.00104
#
# [5]	train-error:0.000905	eval-error:0.001006
#
# [6]	train-error:0.000907	eval-error:0.001015
#
# [7]	train-error:0.000881	eval-error:0.000997
#
# [8]	train-error:0.000888	eval-error:0.001015
#
# [9]	train-error:0.000811	eval-error:0.000933
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0006926852497542869, 'max_depth': 7, 'min_child_weight': 1.2415322299211988, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.000873	eval-error:0.001008
#
# [1]	train-error:0.000469	eval-error:0.000541
#
# [2]	train-error:0.000433	eval-error:0.000494
#
# [3]	train-error:0.000428	eval-error:0.000494
#
# [4]	train-error:0.000424	eval-error:0.000478
#
# [5]	train-error:0.00043	eval-error:0.000483
#
# [6]	train-error:0.000412	eval-error:0.000464
#
# [7]	train-error:0.000413	eval-error:0.000467
#
# [8]	train-error:0.000408	eval-error:0.000467
#
# [9]	train-error:0.000404	eval-error:0.000464
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 9.680764878830736e-05, 'max_depth': 9, 'min_child_weight': 0.20294641794318682, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.00093	eval-error:0.001049
#
# [1]	train-error:0.000823	eval-error:0.00094
#
# [2]	train-error:0.000825	eval-error:0.000931
#
# [3]	train-error:0.000702	eval-error:0.000807
#
# [4]	train-error:0.000801	eval-error:0.000884
#
# [5]	train-error:0.000691	eval-error:0.000786
#
# [6]	train-error:0.000676	eval-error:0.000752
#
# [7]	train-error:0.000683	eval-error:0.000784
#
# [8]	train-error:0.000686	eval-error:0.000788
#
# [9]	train-error:0.000681	eval-error:0.000784
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.004213975093844752, 'max_depth': 8, 'min_child_weight': 0.5579734127281697, 'subsample': 0.6000000000000001}, logloss: 0.1991
# [0]	train-error:0.000878	eval-error:0.001006
#
# [1]	train-error:0.00047	eval-error:0.000541
#
# [2]	train-error:0.000432	eval-error:0.000489
#
# [3]	train-error:0.000427	eval-error:0.000489
#
# [4]	train-error:0.000424	eval-error:0.000476
#
# [5]	train-error:0.00043	eval-error:0.000485
#
# [6]	train-error:0.000419	eval-error:0.000474
#
# [7]	train-error:0.000414	eval-error:0.000469
#
# [8]	train-error:0.000407	eval-error:0.000469
#
# [9]	train-error:0.000412	eval-error:0.000474
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.011915027443836415, 'max_depth': 9, 'min_child_weight': 0.6583492377255479, 'subsample': 0.9500000000000001}, logloss: 0.1987
# [0]	train-error:0.001325	eval-error:0.001427
#
# [1]	train-error:0.000939	eval-error:0.001047
#
# [2]	train-error:0.001017	eval-error:0.001112
#
# [3]	train-error:0.000927	eval-error:0.000992
#
# [4]	train-error:0.000932	eval-error:0.001004
#
# [5]	train-error:0.000831	eval-error:0.000899
#
# [6]	train-error:0.000861	eval-error:0.000922
#
# [7]	train-error:0.00081	eval-error:0.000881
#
# [8]	train-error:0.000887	eval-error:0.000976
#
# [9]	train-error:0.000745	eval-error:0.000838
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0001783185025486276, 'max_depth': 7, 'min_child_weight': 0.847039923724978, 'subsample': 0.9}, logloss: 0.1999
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.007415	eval-error:0.007619
#
# [3]	train-error:0.006221	eval-error:0.00638
#
# [4]	train-error:0.007415	eval-error:0.007619
#
# [5]	train-error:0.006221	eval-error:0.00638
#
# [6]	train-error:0.007415	eval-error:0.007619
#
# [7]	train-error:0.006221	eval-error:0.00638
#
# [8]	train-error:0.007415	eval-error:0.007619
#
# [9]	train-error:0.006172	eval-error:0.006323
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.49852550374454624, 'max_depth': 3, 'min_child_weight': 0.40181566557682963, 'subsample': 0.9500000000000001}, logloss: 0.2097
# [0]	train-error:0.000885	eval-error:0.001024
#
# [1]	train-error:0.00079	eval-error:0.000895
#
# [2]	train-error:0.000633	eval-error:0.000707
#
# [3]	train-error:0.000575	eval-error:0.000639
#
# [4]	train-error:0.000588	eval-error:0.00065
#
# [5]	train-error:0.000528	eval-error:0.000594
#
# [6]	train-error:0.000523	eval-error:0.000589
#
# [7]	train-error:0.000489	eval-error:0.000544
#
# [8]	train-error:0.000474	eval-error:0.000544
#
# [9]	train-error:0.00042	eval-error:0.000478
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0013077448705148687, 'max_depth': 9, 'min_child_weight': 2.8797875558972206, 'subsample': 0.65}, logloss: 0.1990
# [0]	train-error:0.000942	eval-error:0.001042
#
# [1]	train-error:0.000748	eval-error:0.000845
#
# [2]	train-error:0.000702	eval-error:0.000793
#
# [3]	train-error:0.000702	eval-error:0.000793
#
# [4]	train-error:0.000807	eval-error:0.000906
#
# [5]	train-error:0.000693	eval-error:0.000795
#
# [6]	train-error:0.000783	eval-error:0.000879
#
# [7]	train-error:0.000777	eval-error:0.00087
#
# [8]	train-error:0.000672	eval-error:0.000768
#
# [9]	train-error:0.000773	eval-error:0.000868
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 7.187705098348675e-05, 'max_depth': 8, 'min_child_weight': 0.9652354305069928, 'subsample': 0.9}, logloss: 0.1991
# [0]	train-error:0.001028	eval-error:0.001187
#
# [1]	train-error:0.00097	eval-error:0.001146
#
# [2]	train-error:0.001014	eval-error:0.001174
#
# [3]	train-error:0.000785	eval-error:0.000879
#
# [4]	train-error:0.000964	eval-error:0.001087
#
# [5]	train-error:0.000734	eval-error:0.000809
#
# [6]	train-error:0.000742	eval-error:0.000829
#
# [7]	train-error:0.000676	eval-error:0.000739
#
# [8]	train-error:0.000801	eval-error:0.000893
#
# [9]	train-error:0.000742	eval-error:0.000822
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.00046796349627437745, 'max_depth': 8, 'min_child_weight': 0.4916315219926879, 'subsample': 0.8500000000000001}, logloss: 0.1997
# [0]	train-error:0.000877	eval-error:0.00101
#
# [1]	train-error:0.00047	eval-error:0.000541
#
# [2]	train-error:0.000433	eval-error:0.000494
#
# [3]	train-error:0.00043	eval-error:0.000489
#
# [4]	train-error:0.000427	eval-error:0.00048
#
# [5]	train-error:0.000432	eval-error:0.000487
#
# [6]	train-error:0.000412	eval-error:0.000467
#
# [7]	train-error:0.000415	eval-error:0.000467
#
# [8]	train-error:0.000408	eval-error:0.000467
#
# [9]	train-error:0.000403	eval-error:0.000464
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.036085860551107594, 'max_depth': 9, 'min_child_weight': 0.264728918929187, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.000975	eval-error:0.001101
#
# [1]	train-error:0.000855	eval-error:0.000961
#
# [2]	train-error:0.000595	eval-error:0.000675
#
# [3]	train-error:0.000511	eval-error:0.000596
#
# [4]	train-error:0.000535	eval-error:0.000621
#
# [5]	train-error:0.000487	eval-error:0.000557
#
# [6]	train-error:0.00052	eval-error:0.000575
#
# [7]	train-error:0.000471	eval-error:0.000532
#
# [8]	train-error:0.000443	eval-error:0.000521
#
# [9]	train-error:0.000409	eval-error:0.000462
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.00014442857797938743, 'max_depth': 9, 'min_child_weight': 2.587929199551307, 'subsample': 0.8}, logloss: 0.1989
# [0]	train-error:0.001294	eval-error:0.001375
#
# [1]	train-error:0.000968	eval-error:0.001085
#
# [2]	train-error:0.000827	eval-error:0.000924
#
# [3]	train-error:0.000939	eval-error:0.001047
#
# [4]	train-error:0.000922	eval-error:0.001042
#
# [5]	train-error:0.000904	eval-error:0.001008
#
# [6]	train-error:0.000907	eval-error:0.001017
#
# [7]	train-error:0.00088	eval-error:0.001001
#
# [8]	train-error:0.000888	eval-error:0.00102
#
# [9]	train-error:0.000812	eval-error:0.000938
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.006030676435825222, 'max_depth': 7, 'min_child_weight': 1.6061472583902177, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.00093	eval-error:0.001031
#
# [1]	train-error:0.000851	eval-error:0.000945
#
# [2]	train-error:0.000748	eval-error:0.000829
#
# [3]	train-error:0.000737	eval-error:0.000818
#
# [4]	train-error:0.000731	eval-error:0.000818
#
# [5]	train-error:0.0007	eval-error:0.000775
#
# [6]	train-error:0.000676	eval-error:0.000745
#
# [7]	train-error:0.000685	eval-error:0.00077
#
# [8]	train-error:0.000695	eval-error:0.000779
#
# [9]	train-error:0.000693	eval-error:0.000777
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0008530880344132363, 'max_depth': 8, 'min_child_weight': 1.8283891628444033, 'subsample': 0.7000000000000001}, logloss: 0.1992
# [0]	train-error:0.000877	eval-error:0.00101
#
# [1]	train-error:0.00047	eval-error:0.000541
#
# [2]	train-error:0.00043	eval-error:0.000494
#
# [3]	train-error:0.000427	eval-error:0.000494
#
# [4]	train-error:0.000424	eval-error:0.000485
#
# [5]	train-error:0.000429	eval-error:0.000487
#
# [6]	train-error:0.000417	eval-error:0.000474
#
# [7]	train-error:0.00041	eval-error:0.000469
#
# [8]	train-error:0.000403	eval-error:0.000469
#
# [9]	train-error:0.000395	eval-error:0.000464
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.290080867429023e-05, 'max_depth': 9, 'min_child_weight': 0.3259636376301744, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.001846	eval-error:0.001948
#
# [1]	train-error:0.001355	eval-error:0.001407
#
# [2]	train-error:0.000974	eval-error:0.00109
#
# [3]	train-error:0.001152	eval-error:0.001264
#
# [4]	train-error:0.00096	eval-error:0.001085
#
# [5]	train-error:0.000951	eval-error:0.001065
#
# [6]	train-error:0.00114	eval-error:0.001244
#
# [7]	train-error:0.001141	eval-error:0.001244
#
# [8]	train-error:0.000952	eval-error:0.001074
#
# [9]	train-error:0.001044	eval-error:0.001144
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0019676152085344755, 'max_depth': 6, 'min_child_weight': 1.343341783664619, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.00232	eval-error:0.002429
#
# [1]	train-error:0.002004	eval-error:0.002062
#
# [2]	train-error:0.002256	eval-error:0.002257
#
# [3]	train-error:0.002225	eval-error:0.002223
#
# [4]	train-error:0.002252	eval-error:0.002257
#
# [5]	train-error:0.002003	eval-error:0.002062
#
# [6]	train-error:0.002217	eval-error:0.002213
#
# [7]	train-error:0.002213	eval-error:0.002198
#
# [8]	train-error:0.001489	eval-error:0.001556
#
# [9]	train-error:0.002214	eval-error:0.002198
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0004870144733462565, 'max_depth': 5, 'min_child_weight': 2.262140528240826, 'subsample': 0.75}, logloss: 0.2016
# [0]	train-error:0.000866	eval-error:0.000981
#
# [1]	train-error:0.00067	eval-error:0.000754
#
# [2]	train-error:0.000656	eval-error:0.00072
#
# [3]	train-error:0.000532	eval-error:0.000598
#
# [4]	train-error:0.000524	eval-error:0.000585
#
# [5]	train-error:0.000432	eval-error:0.000494
#
# [6]	train-error:0.000405	eval-error:0.000446
#
# [7]	train-error:0.000384	eval-error:0.000426
#
# [8]	train-error:0.000359	eval-error:0.000417
#
# [9]	train-error:0.000358	eval-error:0.000412
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.1716038352113202e-05, 'max_depth': 9, 'min_child_weight': 1.1499683375994711, 'subsample': 0.8500000000000001}, logloss: 0.1988
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.007415	eval-error:0.007619
#
# [3]	train-error:0.006221	eval-error:0.00638
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.007415	eval-error:0.007619
#
# [7]	train-error:0.006221	eval-error:0.006378
#
# [8]	train-error:0.006221	eval-error:0.006378
#
# [9]	train-error:0.006172	eval-error:0.006321
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.011539843583366183, 'max_depth': 3, 'min_child_weight': 3.922025959495195, 'subsample': 0.9500000000000001}, logloss: 0.2094
# [0]	train-error:0.001291	eval-error:0.0014
#
# [1]	train-error:0.000961	eval-error:0.001087
#
# [2]	train-error:0.000935	eval-error:0.001053
#
# [3]	train-error:0.000807	eval-error:0.000895
#
# [4]	train-error:0.000905	eval-error:0.001017
#
# [5]	train-error:0.000927	eval-error:0.001031
#
# [6]	train-error:0.000853	eval-error:0.000961
#
# [7]	train-error:0.00084	eval-error:0.000927
#
# [8]	train-error:0.000844	eval-error:0.000961
#
# [9]	train-error:0.000838	eval-error:0.000949
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.000286653602210017, 'max_depth': 7, 'min_child_weight': 0.13479971681504585, 'subsample': 0.8500000000000001}, logloss: 0.1997
# [0]	train-error:0.00094	eval-error:0.001022
#
# [1]	train-error:0.000724	eval-error:0.000825
#
# [2]	train-error:0.001413	eval-error:0.001545
#
# [3]	train-error:0.001336	eval-error:0.001457
#
# [4]	train-error:0.000779	eval-error:0.000861
#
# [5]	train-error:0.00063	eval-error:0.000696
#
# [6]	train-error:0.000705	eval-error:0.000754
#
# [7]	train-error:0.000626	eval-error:0.000671
#
# [8]	train-error:0.000631	eval-error:0.000696
#
# [9]	train-error:0.000628	eval-error:0.000691
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.003930381507015448, 'max_depth': 8, 'min_child_weight': 3.39236341786132, 'subsample': 0.9}, logloss: 0.1993
# [0]	train-error:0.000982	eval-error:0.001094
#
# [1]	train-error:0.000481	eval-error:0.000526
#
# [2]	train-error:0.000448	eval-error:0.000496
#
# [3]	train-error:0.000458	eval-error:0.000496
#
# [4]	train-error:0.000458	eval-error:0.000519
#
# [5]	train-error:0.00047	eval-error:0.000526
#
# [6]	train-error:0.000449	eval-error:0.000512
#
# [7]	train-error:0.000449	eval-error:0.000514
#
# [8]	train-error:0.000436	eval-error:0.000492
#
# [9]	train-error:0.000421	eval-error:0.00048
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.670321726748434e-05, 'max_depth': 9, 'min_child_weight': 5.537766972834483, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.00094	eval-error:0.001022
#
# [1]	train-error:0.000753	eval-error:0.000838
#
# [2]	train-error:0.000788	eval-error:0.000879
#
# [3]	train-error:0.00064	eval-error:0.000659
#
# [4]	train-error:0.000766	eval-error:0.000834
#
# [5]	train-error:0.000752	eval-error:0.000804
#
# [6]	train-error:0.000732	eval-error:0.000795
#
# [7]	train-error:0.000639	eval-error:0.000664
#
# [8]	train-error:0.000615	eval-error:0.000657
#
# [9]	train-error:0.000538	eval-error:0.000566
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.08602805395208359, 'max_depth': 8, 'min_child_weight': 4.675262514643922, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.00577	eval-error:0.005881
#
# [1]	train-error:0.005768	eval-error:0.005881
#
# [2]	train-error:0.002636	eval-error:0.002658
#
# [3]	train-error:0.002636	eval-error:0.002658
#
# [4]	train-error:0.002636	eval-error:0.002658
#
# [5]	train-error:0.002636	eval-error:0.002658
#
# [6]	train-error:0.002423	eval-error:0.002402
#
# [7]	train-error:0.002423	eval-error:0.002402
#
# [8]	train-error:0.002423	eval-error:0.002402
#
# [9]	train-error:0.002423	eval-error:0.002402
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00012683045534346433, 'max_depth': 4, 'min_child_weight': 7.999113749913967, 'subsample': 0.9}, logloss: 0.2047
# [0]	train-error:0.000885	eval-error:0.00101
#
# [1]	train-error:0.000478	eval-error:0.000541
#
# [2]	train-error:0.00044	eval-error:0.000498
#
# [3]	train-error:0.000437	eval-error:0.000496
#
# [4]	train-error:0.000432	eval-error:0.000483
#
# [5]	train-error:0.000439	eval-error:0.000492
#
# [6]	train-error:0.000427	eval-error:0.00048
#
# [7]	train-error:0.000423	eval-error:0.00048
#
# [8]	train-error:0.000418	eval-error:0.00048
#
# [9]	train-error:0.000403	eval-error:0.000476
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 5.1187354765798e-05, 'max_depth': 9, 'min_child_weight': 2.0554322323983074, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.001293	eval-error:0.001373
#
# [1]	train-error:0.000966	eval-error:0.001083
#
# [2]	train-error:0.000826	eval-error:0.000924
#
# [3]	train-error:0.000939	eval-error:0.001047
#
# [4]	train-error:0.000922	eval-error:0.00104
#
# [5]	train-error:0.000904	eval-error:0.001006
#
# [6]	train-error:0.000893	eval-error:0.00099
#
# [7]	train-error:0.000871	eval-error:0.000979
#
# [8]	train-error:0.000885	eval-error:0.00101
#
# [9]	train-error:0.000842	eval-error:0.000961
#
# params: {'colsample_bytree': 0.9, 'gamma': 7.118521367819495e-05, 'max_depth': 7, 'min_child_weight': 1.487179000491603, 'subsample': 0.9}, logloss: 0.1995
# 100%|██████████| 100/100 [51:38<00:00, 30.99s/it, best loss: 0.1985846829723514]
# best params:{'colsample_bytree': 0.9500000000000001, 'gamma': 0.00014307741815837628, 'max_depth': 9, 'min_child_weight': 1.4034295969588149, 'subsample': 0.9500000000000001}, score:0.1986

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.00014307741815837628,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1.4034295969588149,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.000904	eval-error:0.000963
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000478	eval-error:0.000483
# [2]	train-error:0.000466	eval-error:0.000483
# [3]	train-error:0.000466	eval-error:0.000483
# [4]	train-error:0.000466	eval-error:0.000483
# [5]	train-error:0.000437	eval-error:0.000449
# [6]	train-error:0.00044	eval-error:0.000458
# [7]	train-error:0.000403	eval-error:0.000421
# [8]	train-error:0.000404	eval-error:0.00043
# [9]	train-error:0.00041	eval-error:0.000435
# [10]	train-error:0.000401	eval-error:0.000428
# [11]	train-error:0.000376	eval-error:0.000396
# [12]	train-error:0.000363	eval-error:0.000385
# [13]	train-error:0.000342	eval-error:0.000367
# [14]	train-error:0.000331	eval-error:0.000351
# [15]	train-error:0.000319	eval-error:0.000342
# [16]	train-error:0.000281	eval-error:0.000313
# [17]	train-error:0.000266	eval-error:0.000297
# [18]	train-error:0.000204	eval-error:0.000233
# [19]	train-error:0.000192	eval-error:0.000217
# [20]	train-error:0.000191	eval-error:0.000217
# [21]	train-error:0.000184	eval-error:0.000211
# [22]	train-error:0.000171	eval-error:0.000202
# [23]	train-error:0.000182	eval-error:0.000211
# [24]	train-error:0.000152	eval-error:0.000184
# [25]	train-error:0.000146	eval-error:0.000179
# [26]	train-error:0.000126	eval-error:0.000159
# [27]	train-error:0.000116	eval-error:0.000143
# [28]	train-error:0.000114	eval-error:0.000143
# [29]	train-error:0.000108	eval-error:0.000136
# [30]	train-error:0.000105	eval-error:0.000134
# [31]	train-error:9.3e-05	eval-error:0.000113
# [32]	train-error:8.7e-05	eval-error:0.000111
# [33]	train-error:7.5e-05	eval-error:9.1e-05
# [34]	train-error:5.9e-05	eval-error:7.2e-05
# [35]	train-error:5e-05	eval-error:6.1e-05
# [36]	train-error:4e-05	eval-error:4.5e-05
# [37]	train-error:3.9e-05	eval-error:4.5e-05
# [38]	train-error:3.8e-05	eval-error:4.5e-05
# [39]	train-error:2.8e-05	eval-error:2.7e-05
# [40]	train-error:2.8e-05	eval-error:2.7e-05
# [41]	train-error:2.7e-05	eval-error:2.5e-05
# [42]	train-error:2.6e-05	eval-error:2.3e-05
# [43]	train-error:2.4e-05	eval-error:2.3e-05
# [44]	train-error:2.4e-05	eval-error:2e-05
# [45]	train-error:2.3e-05	eval-error:2e-05
# [46]	train-error:2.2e-05	eval-error:2e-05
# [47]	train-error:2.2e-05	eval-error:2e-05
# [48]	train-error:2e-05	eval-error:2e-05
# [49]	train-error:1.9e-05	eval-error:1.8e-05
# [50]	train-error:1.9e-05	eval-error:1.8e-05
# [51]	train-error:1.8e-05	eval-error:1.8e-05
# [52]	train-error:1.7e-05	eval-error:1.8e-05
# [53]	train-error:1.5e-05	eval-error:1.8e-05
# [54]	train-error:1.5e-05	eval-error:1.8e-05
# [55]	train-error:1.5e-05	eval-error:1.6e-05
# [56]	train-error:1.4e-05	eval-error:1.6e-05
# [57]	train-error:1.2e-05	eval-error:1.4e-05
# [58]	train-error:1.2e-05	eval-error:1.4e-05
# [59]	train-error:1.2e-05	eval-error:1.4e-05
# [60]	train-error:1.2e-05	eval-error:1.4e-05
# [61]	train-error:1.2e-05	eval-error:1.4e-05
# [62]	train-error:1.2e-05	eval-error:1.1e-05
# [63]	train-error:6e-06	eval-error:7e-06
# [64]	train-error:5e-06	eval-error:7e-06
# [65]	train-error:6e-06	eval-error:7e-06
# [66]	train-error:5e-06	eval-error:7e-06
# [67]	train-error:5e-06	eval-error:7e-06
# [68]	train-error:5e-06	eval-error:7e-06
# [69]	train-error:5e-06	eval-error:7e-06
# [70]	train-error:4e-06	eval-error:7e-06
# [71]	train-error:4e-06	eval-error:7e-06
# [72]	train-error:4e-06	eval-error:7e-06
# [73]	train-error:4e-06	eval-error:7e-06
# [74]	train-error:4e-06	eval-error:7e-06
# [75]	train-error:5e-06	eval-error:7e-06
# [76]	train-error:5e-06	eval-error:7e-06
# [77]	train-error:5e-06	eval-error:7e-06
# [78]	train-error:5e-06	eval-error:7e-06
# [79]	train-error:5e-06	eval-error:7e-06
# [80]	train-error:5e-06	eval-error:7e-06
# [81]	train-error:5e-06	eval-error:7e-06
# [82]	train-error:4e-06	eval-error:7e-06
# [83]	train-error:4e-06	eval-error:7e-06
# Stopping. Best iteration:
# [63]	train-error:6e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0002

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_26_param_tuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_26_param_tuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000806
# 1  0.000806
# 2  0.000806
# 3  0.000806
# 4  0.000806

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000806
# 1   1  0.000806
# 2   2  0.000806
# 3   3  0.000806
# 4   4  0.000806

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_26_param_tuning.csv',index=False)

# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' ,
 'process'
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' ,
 'process'
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host","process"],axis=1)
test_x=test_df.drop(["host","process"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host','process']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host','process']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        ...,
#        [9., 1.],
#        [9., 1.],
#        [9., 1.]]), array([[0., 0.],
#        [0., 0.],
#        [0., 0.],
#        ...,
#        [9., 1.],
#        [9., 1.],
#        [9., 1.]])]
# 元に戻す:  [array([['lphost06', 'wls1'],
#        ['lphost06', 'wls1'],
#        ['lphost06', 'wls1'],
#        ...,
#        ['lphost18', 'wls2'],
#        ['lphost18', 'wls2'],
#        ['lphost18', 'wls2']], dtype=object), array([['lphost06', 'wls1'],
#        ['lphost06', 'wls1'],
#        ['lphost06', 'wls1'],
#        ...,
#        ['lphost18', 'wls2'],
#        ['lphost18', 'wls2'],
#        ['lphost18', 'wls2']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host','process']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host','process']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.002295	eval-error:0.002386
#
# [1]	train-error:0.001998	eval-error:0.002055
#
# [2]	train-error:0.002176	eval-error:0.002152
#
# [3]	train-error:0.002199	eval-error:0.002182
#
# [4]	train-error:0.002178	eval-error:0.002152
#
# [5]	train-error:0.001479	eval-error:0.001541
#
# [6]	train-error:0.002204	eval-error:0.002186
#
# [7]	train-error:0.002173	eval-error:0.002148
#
# [8]	train-error:0.001466	eval-error:0.001518
#
# [9]	train-error:0.002168	eval-error:0.002146
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.606025068715756e-06, 'max_depth': 5, 'min_child_weight': 0.12956690172605612, 'subsample': 0.9500000000000001}, logloss: 0.2016
# [0]	train-error:0.005757	eval-error:0.00585
#
# [1]	train-error:0.002542	eval-error:0.002515
#
# [2]	train-error:0.005997	eval-error:0.006167
#
# [3]	train-error:0.005999	eval-error:0.006165
#
# [4]	train-error:0.003201	eval-error:0.003258
#
# [5]	train-error:0.003185	eval-error:0.003235
#
# [6]	train-error:0.002683	eval-error:0.00283
#
# [7]	train-error:0.003189	eval-error:0.003194
#
# [8]	train-error:0.003139	eval-error:0.003133
#
# [9]	train-error:0.002625	eval-error:0.002581
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.00220404687146576, 'max_depth': 4, 'min_child_weight': 0.45668961534943503, 'subsample': 0.65}, logloss: 0.2048
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.006221	eval-error:0.006378
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.007416	eval-error:0.007617
#
# [7]	train-error:0.006221	eval-error:0.006378
#
# [8]	train-error:0.006221	eval-error:0.006378
#
# [9]	train-error:0.006221	eval-error:0.006378
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0692865738263813e-05, 'max_depth': 3, 'min_child_weight': 0.4514520809992586, 'subsample': 0.75}, logloss: 0.2095
# [0]	train-error:0.007416	eval-error:0.007619
#
# [1]	train-error:0.007427	eval-error:0.007626
#
# [2]	train-error:0.007416	eval-error:0.007617
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007615
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.006172	eval-error:0.006321
#
# [7]	train-error:0.006172	eval-error:0.006321
#
# [8]	train-error:0.006172	eval-error:0.006321
#
# [9]	train-error:0.006173	eval-error:0.006321
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.19737917624463047, 'max_depth': 3, 'min_child_weight': 0.9772737174166836, 'subsample': 0.7000000000000001}, logloss: 0.2092
# [0]	train-error:0.002303	eval-error:0.002395
#
# [1]	train-error:0.001778	eval-error:0.001905
#
# [2]	train-error:0.004441	eval-error:0.004536
#
# [3]	train-error:0.002983	eval-error:0.002988
#
# [4]	train-error:0.002979	eval-error:0.002986
#
# [5]	train-error:0.001568	eval-error:0.001701
#
# [6]	train-error:0.001805	eval-error:0.001928
#
# [7]	train-error:0.001549	eval-error:0.001663
#
# [8]	train-error:0.001408	eval-error:0.001507
#
# [9]	train-error:0.001546	eval-error:0.001606
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0005963692767538501, 'max_depth': 5, 'min_child_weight': 0.4773087800075097, 'subsample': 0.8500000000000001}, logloss: 0.2022
# [0]	train-error:0.000975	eval-error:0.001092
#
# [1]	train-error:0.000916	eval-error:0.001069
#
# [2]	train-error:0.000933	eval-error:0.00104
#
# [3]	train-error:0.000785	eval-error:0.000886
#
# [4]	train-error:0.000887	eval-error:0.001001
#
# [5]	train-error:0.000755	eval-error:0.00085
#
# [6]	train-error:0.000767	eval-error:0.000825
#
# [7]	train-error:0.000727	eval-error:0.000793
#
# [8]	train-error:0.000779	eval-error:0.000836
#
# [9]	train-error:0.000736	eval-error:0.000811
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 1.646175455537789e-05, 'max_depth': 8, 'min_child_weight': 4.164091454462022, 'subsample': 0.65}, logloss: 0.1996
# [0]	train-error:0.005745	eval-error:0.005829
#
# [1]	train-error:0.005725	eval-error:0.005814
#
# [2]	train-error:0.002589	eval-error:0.00259
#
# [3]	train-error:0.002647	eval-error:0.002664
#
# [4]	train-error:0.002574	eval-error:0.002574
#
# [5]	train-error:0.002479	eval-error:0.002472
#
# [6]	train-error:0.002633	eval-error:0.002651
#
# [7]	train-error:0.002569	eval-error:0.002574
#
# [8]	train-error:0.002568	eval-error:0.002574
#
# [9]	train-error:0.002558	eval-error:0.002567
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.1923130997701745e-06, 'max_depth': 4, 'min_child_weight': 3.6808423273106614, 'subsample': 0.65}, logloss: 0.2045
# [0]	train-error:0.001025	eval-error:0.001135
#
# [1]	train-error:0.000878	eval-error:0.00097
#
# [2]	train-error:0.001476	eval-error:0.0016
#
# [3]	train-error:0.000895	eval-error:0.000988
#
# [4]	train-error:0.000813	eval-error:0.000895
#
# [5]	train-error:0.000693	eval-error:0.000782
#
# [6]	train-error:0.000755	eval-error:0.000829
#
# [7]	train-error:0.000648	eval-error:0.000707
#
# [8]	train-error:0.000647	eval-error:0.000711
#
# [9]	train-error:0.000517	eval-error:0.000551
#
# params: {'colsample_bytree': 0.8, 'gamma': 2.5256540104567545e-06, 'max_depth': 8, 'min_child_weight': 9.999738862595006, 'subsample': 0.9}, logloss: 0.1993
# [0]	train-error:0.000915	eval-error:0.001031
#
# [1]	train-error:0.0007	eval-error:0.000786
#
# [2]	train-error:0.000501	eval-error:0.000548
#
# [3]	train-error:0.000504	eval-error:0.000546
#
# [4]	train-error:0.000515	eval-error:0.000553
#
# [5]	train-error:0.000505	eval-error:0.000548
#
# [6]	train-error:0.000489	eval-error:0.000546
#
# [7]	train-error:0.000499	eval-error:0.000541
#
# [8]	train-error:0.000489	eval-error:0.000535
#
# [9]	train-error:0.000477	eval-error:0.000528
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0033147646913981583, 'max_depth': 9, 'min_child_weight': 3.652503535807508, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.00129	eval-error:0.001377
#
# [1]	train-error:0.000921	eval-error:0.001024
#
# [2]	train-error:0.001047	eval-error:0.001135
#
# [3]	train-error:0.000757	eval-error:0.000825
#
# [4]	train-error:0.000844	eval-error:0.000942
#
# [5]	train-error:0.000785	eval-error:0.000875
#
# [6]	train-error:0.000709	eval-error:0.000777
#
# [7]	train-error:0.000705	eval-error:0.000773
#
# [8]	train-error:0.00069	eval-error:0.000748
#
# [9]	train-error:0.000685	eval-error:0.000732
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0006113193949914765, 'max_depth': 7, 'min_child_weight': 1.9174423960973692, 'subsample': 0.8500000000000001}, logloss: 0.1998
# [0]	train-error:0.007428	eval-error:0.007635
#
# [1]	train-error:0.006258	eval-error:0.006437
#
# [2]	train-error:0.007706	eval-error:0.007907
#
# [3]	train-error:0.007776	eval-error:0.007968
#
# [4]	train-error:0.007337	eval-error:0.007569
#
# [5]	train-error:0.007354	eval-error:0.007574
#
# [6]	train-error:0.007354	eval-error:0.007574
#
# [7]	train-error:0.00735	eval-error:0.007567
#
# [8]	train-error:0.002779	eval-error:0.002775
#
# [9]	train-error:0.006583	eval-error:0.006745
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.15297283974421091, 'max_depth': 3, 'min_child_weight': 0.13829404668278253, 'subsample': 0.9}, logloss: 0.2095
# [0]	train-error:0.005724	eval-error:0.005814
#
# [1]	train-error:0.00254	eval-error:0.00251
#
# [2]	train-error:0.004911	eval-error:0.005036
#
# [3]	train-error:0.00491	eval-error:0.005007
#
# [4]	train-error:0.003172	eval-error:0.00319
#
# [5]	train-error:0.00243	eval-error:0.002402
#
# [6]	train-error:0.003256	eval-error:0.003296
#
# [7]	train-error:0.002553	eval-error:0.002551
#
# [8]	train-error:0.00253	eval-error:0.002544
#
# [9]	train-error:0.002541	eval-error:0.002544
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0017871803480687064, 'max_depth': 4, 'min_child_weight': 0.22927894283383263, 'subsample': 0.9}, logloss: 0.2048
# [0]	train-error:0.000938	eval-error:0.001049
#
# [1]	train-error:0.000489	eval-error:0.000546
#
# [2]	train-error:0.000424	eval-error:0.000485
#
# [3]	train-error:0.000422	eval-error:0.000489
#
# [4]	train-error:0.000424	eval-error:0.000485
#
# [5]	train-error:0.00041	eval-error:0.00048
#
# [6]	train-error:0.00042	eval-error:0.000474
#
# [7]	train-error:0.000417	eval-error:0.000487
#
# [8]	train-error:0.000415	eval-error:0.000483
#
# [9]	train-error:0.000406	eval-error:0.000476
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0004238873783319362, 'max_depth': 9, 'min_child_weight': 1.4517710727707507, 'subsample': 0.8}, logloss: 0.1986
# [0]	train-error:0.001661	eval-error:0.001803
#
# [1]	train-error:0.001417	eval-error:0.001534
#
# [2]	train-error:0.001803	eval-error:0.001921
#
# [3]	train-error:0.001578	eval-error:0.00167
#
# [4]	train-error:0.001223	eval-error:0.001307
#
# [5]	train-error:0.001019	eval-error:0.00109
#
# [6]	train-error:0.001169	eval-error:0.001246
#
# [7]	train-error:0.001037	eval-error:0.001099
#
# [8]	train-error:0.000961	eval-error:0.001042
#
# [9]	train-error:0.001002	eval-error:0.001081
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.467515101449999e-07, 'max_depth': 6, 'min_child_weight': 3.0816427928826893, 'subsample': 0.8}, logloss: 0.2004
# [0]	train-error:0.005758	eval-error:0.005847
#
# [1]	train-error:0.002535	eval-error:0.00251
#
# [2]	train-error:0.004904	eval-error:0.005027
#
# [3]	train-error:0.004915	eval-error:0.005036
#
# [4]	train-error:0.003198	eval-error:0.003247
#
# [5]	train-error:0.003324	eval-error:0.003385
#
# [6]	train-error:0.004558	eval-error:0.004706
#
# [7]	train-error:0.003068	eval-error:0.003124
#
# [8]	train-error:0.002497	eval-error:0.002431
#
# [9]	train-error:0.002624	eval-error:0.002585
#
# params: {'colsample_bytree': 0.65, 'gamma': 7.520220376840852e-07, 'max_depth': 4, 'min_child_weight': 5.594361038690168, 'subsample': 0.9}, logloss: 0.2051
# [0]	train-error:0.001153	eval-error:0.001253
#
# [1]	train-error:0.000851	eval-error:0.000961
#
# [2]	train-error:0.001421	eval-error:0.001547
#
# [3]	train-error:0.000853	eval-error:0.000938
#
# [4]	train-error:0.000756	eval-error:0.000831
#
# [5]	train-error:0.000645	eval-error:0.000707
#
# [6]	train-error:0.000725	eval-error:0.000786
#
# [7]	train-error:0.000617	eval-error:0.000666
#
# [8]	train-error:0.000612	eval-error:0.000671
#
# [9]	train-error:0.000537	eval-error:0.000566
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.01099124850652432, 'max_depth': 8, 'min_child_weight': 2.936687848606885, 'subsample': 0.8}, logloss: 0.1992
# [0]	train-error:0.005757	eval-error:0.00585
#
# [1]	train-error:0.002542	eval-error:0.002515
#
# [2]	train-error:0.005997	eval-error:0.006167
#
# [3]	train-error:0.005999	eval-error:0.006165
#
# [4]	train-error:0.003201	eval-error:0.003258
#
# [5]	train-error:0.003185	eval-error:0.003235
#
# [6]	train-error:0.002683	eval-error:0.00283
#
# [7]	train-error:0.003189	eval-error:0.003194
#
# [8]	train-error:0.003139	eval-error:0.003133
#
# [9]	train-error:0.002625	eval-error:0.002581
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 7.988001227403925e-06, 'max_depth': 4, 'min_child_weight': 0.38913021926630764, 'subsample': 0.65}, logloss: 0.2048
# [0]	train-error:0.002293	eval-error:0.002374
#
# [1]	train-error:0.001994	eval-error:0.002044
#
# [2]	train-error:0.00218	eval-error:0.002159
#
# [3]	train-error:0.002172	eval-error:0.002146
#
# [4]	train-error:0.002176	eval-error:0.002148
#
# [5]	train-error:0.001487	eval-error:0.001545
#
# [6]	train-error:0.001458	eval-error:0.001511
#
# [7]	train-error:0.002176	eval-error:0.00215
#
# [8]	train-error:0.001456	eval-error:0.001513
#
# [9]	train-error:0.002176	eval-error:0.00215
#
# params: {'colsample_bytree': 0.9, 'gamma': 6.851536428840945e-05, 'max_depth': 5, 'min_child_weight': 1.4524362086306866, 'subsample': 0.6000000000000001}, logloss: 0.2016
# [0]	train-error:0.000967	eval-error:0.001078
#
# [1]	train-error:0.000805	eval-error:0.000906
#
# [2]	train-error:0.001381	eval-error:0.001513
#
# [3]	train-error:0.000817	eval-error:0.000888
#
# [4]	train-error:0.000747	eval-error:0.000802
#
# [5]	train-error:0.000639	eval-error:0.000698
#
# [6]	train-error:0.000719	eval-error:0.000775
#
# [7]	train-error:0.000621	eval-error:0.000675
#
# [8]	train-error:0.000612	eval-error:0.000673
#
# [9]	train-error:0.000598	eval-error:0.000655
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.7748357710204208, 'max_depth': 8, 'min_child_weight': 1.5645699549706846, 'subsample': 0.6000000000000001}, logloss: 0.1993
# [0]	train-error:0.000879	eval-error:0.001001
#
# [1]	train-error:0.000473	eval-error:0.000535
#
# [2]	train-error:0.000423	eval-error:0.00048
#
# [3]	train-error:0.000418	eval-error:0.000471
#
# [4]	train-error:0.000432	eval-error:0.000492
#
# [5]	train-error:0.000437	eval-error:0.000496
#
# [6]	train-error:0.000416	eval-error:0.000469
#
# [7]	train-error:0.000414	eval-error:0.000464
#
# [8]	train-error:0.000419	eval-error:0.000467
#
# [9]	train-error:0.000418	eval-error:0.000462
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.03206202372157374, 'max_depth': 9, 'min_child_weight': 0.76398536934159, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.000486	eval-error:0.000546
#
# [1]	train-error:0.000454	eval-error:0.000539
#
# [2]	train-error:0.000455	eval-error:0.000519
#
# [3]	train-error:0.000449	eval-error:0.000512
#
# [4]	train-error:0.000474	eval-error:0.00053
#
# [5]	train-error:0.000464	eval-error:0.000528
#
# [6]	train-error:0.000456	eval-error:0.000512
#
# [7]	train-error:0.000434	eval-error:0.000496
#
# [8]	train-error:0.000418	eval-error:0.000478
#
# [9]	train-error:0.000388	eval-error:0.000455
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.035599052417496425, 'max_depth': 9, 'min_child_weight': 0.8208141984881193, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.000489	eval-error:0.000546
#
# [1]	train-error:0.000454	eval-error:0.000528
#
# [2]	train-error:0.00045	eval-error:0.000507
#
# [3]	train-error:0.000446	eval-error:0.000505
#
# [4]	train-error:0.000469	eval-error:0.000521
#
# [5]	train-error:0.000459	eval-error:0.000521
#
# [6]	train-error:0.000453	eval-error:0.000505
#
# [7]	train-error:0.000433	eval-error:0.000487
#
# [8]	train-error:0.000417	eval-error:0.000471
#
# [9]	train-error:0.000387	eval-error:0.000451
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.038761959275741914, 'max_depth': 9, 'min_child_weight': 0.7228763710248483, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.000831	eval-error:0.000936
#
# [1]	train-error:0.000825	eval-error:0.000927
#
# [2]	train-error:0.000815	eval-error:0.00092
#
# [3]	train-error:0.000815	eval-error:0.000915
#
# [4]	train-error:0.000803	eval-error:0.000904
#
# [5]	train-error:0.0008	eval-error:0.000895
#
# [6]	train-error:0.000794	eval-error:0.000902
#
# [7]	train-error:0.000757	eval-error:0.000854
#
# [8]	train-error:0.000851	eval-error:0.000963
#
# [9]	train-error:0.000812	eval-error:0.000922
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.06381833195974788, 'max_depth': 7, 'min_child_weight': 0.7527031592158453, 'subsample': 0.75}, logloss: 0.1994
# [0]	train-error:0.000816	eval-error:0.000915
#
# [1]	train-error:0.000821	eval-error:0.00092
#
# [2]	train-error:0.000813	eval-error:0.000915
#
# [3]	train-error:0.000813	eval-error:0.000913
#
# [4]	train-error:0.000774	eval-error:0.000879
#
# [5]	train-error:0.000785	eval-error:0.000881
#
# [6]	train-error:0.000773	eval-error:0.000879
#
# [7]	train-error:0.000767	eval-error:0.000872
#
# [8]	train-error:0.000841	eval-error:0.000942
#
# [9]	train-error:0.000731	eval-error:0.000822
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.4176296551781508, 'max_depth': 7, 'min_child_weight': 0.23141157906056029, 'subsample': 0.7000000000000001}, logloss: 0.1994
# [0]	train-error:0.000719	eval-error:0.000818
#
# [1]	train-error:0.000437	eval-error:0.000494
#
# [2]	train-error:0.000448	eval-error:0.00051
#
# [3]	train-error:0.00045	eval-error:0.000512
#
# [4]	train-error:0.000462	eval-error:0.000523
#
# [5]	train-error:0.000463	eval-error:0.00053
#
# [6]	train-error:0.000458	eval-error:0.000526
#
# [7]	train-error:0.00045	eval-error:0.000507
#
# [8]	train-error:0.000428	eval-error:0.000478
#
# [9]	train-error:0.000422	eval-error:0.000474
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.014343031178973236, 'max_depth': 9, 'min_child_weight': 0.26498693301336596, 'subsample': 0.7000000000000001}, logloss: 0.1987
# [0]	train-error:0.000945	eval-error:0.001042
#
# [1]	train-error:0.000875	eval-error:0.000979
#
# [2]	train-error:0.000679	eval-error:0.000764
#
# [3]	train-error:0.000673	eval-error:0.000741
#
# [4]	train-error:0.000668	eval-error:0.000732
#
# [5]	train-error:0.000659	eval-error:0.00072
#
# [6]	train-error:0.000652	eval-error:0.000723
#
# [7]	train-error:0.000652	eval-error:0.000716
#
# [8]	train-error:0.000652	eval-error:0.000718
#
# [9]	train-error:0.000648	eval-error:0.000714
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0001781705357697238, 'max_depth': 8, 'min_child_weight': 0.6299474854788472, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.001421	eval-error:0.001488
#
# [1]	train-error:0.001419	eval-error:0.001484
#
# [2]	train-error:0.001405	eval-error:0.001459
#
# [3]	train-error:0.001143	eval-error:0.001266
#
# [4]	train-error:0.00101	eval-error:0.001128
#
# [5]	train-error:0.001135	eval-error:0.001257
#
# [6]	train-error:0.00114	eval-error:0.001251
#
# [7]	train-error:0.001133	eval-error:0.001255
#
# [8]	train-error:0.001115	eval-error:0.001237
#
# [9]	train-error:0.001127	eval-error:0.001242
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.4011740115970328e-08, 'max_depth': 6, 'min_child_weight': 1.0945372954507293, 'subsample': 0.75}, logloss: 0.2001
# [0]	train-error:0.000856	eval-error:0.000981
#
# [1]	train-error:0.000554	eval-error:0.000623
#
# [2]	train-error:0.000445	eval-error:0.000496
#
# [3]	train-error:0.000442	eval-error:0.000492
#
# [4]	train-error:0.000446	eval-error:0.00051
#
# [5]	train-error:0.000442	eval-error:0.000498
#
# [6]	train-error:0.000447	eval-error:0.000485
#
# [7]	train-error:0.000443	eval-error:0.000492
#
# [8]	train-error:0.000419	eval-error:0.000476
#
# [9]	train-error:0.00042	eval-error:0.000474
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.007104355994460621, 'max_depth': 9, 'min_child_weight': 2.1678020284271025, 'subsample': 0.7000000000000001}, logloss: 0.1988
# [0]	train-error:0.00082	eval-error:0.00092
#
# [1]	train-error:0.00082	eval-error:0.00092
#
# [2]	train-error:0.000812	eval-error:0.000909
#
# [3]	train-error:0.000811	eval-error:0.000913
#
# [4]	train-error:0.000777	eval-error:0.000877
#
# [5]	train-error:0.000788	eval-error:0.000877
#
# [6]	train-error:0.000772	eval-error:0.000865
#
# [7]	train-error:0.000774	eval-error:0.000865
#
# [8]	train-error:0.000746	eval-error:0.000838
#
# [9]	train-error:0.00074	eval-error:0.000834
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.04786906165777829, 'max_depth': 7, 'min_child_weight': 0.12535256654080493, 'subsample': 0.8500000000000001}, logloss: 0.1994
# [0]	train-error:0.000933	eval-error:0.00106
#
# [1]	train-error:0.000487	eval-error:0.000555
#
# [2]	train-error:0.000421	eval-error:0.000492
#
# [3]	train-error:0.000418	eval-error:0.000498
#
# [4]	train-error:0.00042	eval-error:0.000492
#
# [5]	train-error:0.000407	eval-error:0.000485
#
# [6]	train-error:0.000421	eval-error:0.000487
#
# [7]	train-error:0.000424	eval-error:0.000487
#
# [8]	train-error:0.000396	eval-error:0.000467
#
# [9]	train-error:0.000401	eval-error:0.000474
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.9650854656691019, 'max_depth': 9, 'min_child_weight': 0.32556710227007574, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.00077	eval-error:0.000838
#
# [1]	train-error:0.000753	eval-error:0.000845
#
# [2]	train-error:0.00052	eval-error:0.00058
#
# [3]	train-error:0.000676	eval-error:0.000766
#
# [4]	train-error:0.00067	eval-error:0.000752
#
# [5]	train-error:0.000668	eval-error:0.000754
#
# [6]	train-error:0.000662	eval-error:0.000748
#
# [7]	train-error:0.000659	eval-error:0.000748
#
# [8]	train-error:0.000652	eval-error:0.000732
#
# [9]	train-error:0.000646	eval-error:0.00073
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.527654517056279e-05, 'max_depth': 8, 'min_child_weight': 1.0285333760076933, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.001334	eval-error:0.001448
#
# [1]	train-error:0.000981	eval-error:0.001099
#
# [2]	train-error:0.000773	eval-error:0.000877
#
# [3]	train-error:0.000879	eval-error:0.000992
#
# [4]	train-error:0.000864	eval-error:0.000967
#
# [5]	train-error:0.000781	eval-error:0.000879
#
# [6]	train-error:0.000739	eval-error:0.000822
#
# [7]	train-error:0.000743	eval-error:0.000831
#
# [8]	train-error:0.00085	eval-error:0.000954
#
# [9]	train-error:0.000853	eval-error:0.000954
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.11051369108419107, 'max_depth': 7, 'min_child_weight': 0.15830143838616106, 'subsample': 0.7000000000000001}, logloss: 0.1995
# [0]	train-error:0.000489	eval-error:0.000546
#
# [1]	train-error:0.000454	eval-error:0.000528
#
# [2]	train-error:0.00045	eval-error:0.000507
#
# [3]	train-error:0.000445	eval-error:0.000505
#
# [4]	train-error:0.000469	eval-error:0.000521
#
# [5]	train-error:0.000458	eval-error:0.000521
#
# [6]	train-error:0.00046	eval-error:0.000517
#
# [7]	train-error:0.000455	eval-error:0.000512
#
# [8]	train-error:0.000419	eval-error:0.000474
#
# [9]	train-error:0.00042	eval-error:0.000474
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.3928013366014646, 'max_depth': 9, 'min_child_weight': 0.6697948317270562, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.001843	eval-error:0.001951
#
# [1]	train-error:0.00135	eval-error:0.001402
#
# [2]	train-error:0.001079	eval-error:0.001165
#
# [3]	train-error:0.00101	eval-error:0.001124
#
# [4]	train-error:0.000915	eval-error:0.001026
#
# [5]	train-error:0.000993	eval-error:0.001099
#
# [6]	train-error:0.000992	eval-error:0.001097
#
# [7]	train-error:0.000975	eval-error:0.001076
#
# [8]	train-error:0.000979	eval-error:0.001081
#
# [9]	train-error:0.001114	eval-error:0.001223
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0023567722225357993, 'max_depth': 6, 'min_child_weight': 0.5520997941184086, 'subsample': 0.8500000000000001}, logloss: 0.2001
# [0]	train-error:0.001123	eval-error:0.001239
#
# [1]	train-error:0.00089	eval-error:0.00101
#
# [2]	train-error:0.000681	eval-error:0.000782
#
# [3]	train-error:0.000662	eval-error:0.000743
#
# [4]	train-error:0.000668	eval-error:0.000739
#
# [5]	train-error:0.000658	eval-error:0.000725
#
# [6]	train-error:0.000648	eval-error:0.000716
#
# [7]	train-error:0.000649	eval-error:0.000718
#
# [8]	train-error:0.000644	eval-error:0.000718
#
# [9]	train-error:0.000645	eval-error:0.00072
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0300715146696974, 'max_depth': 8, 'min_child_weight': 0.35281164578625773, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.002334	eval-error:0.002445
#
# [1]	train-error:0.002371	eval-error:0.002483
#
# [2]	train-error:0.002381	eval-error:0.002506
#
# [3]	train-error:0.001795	eval-error:0.001948
#
# [4]	train-error:0.002494	eval-error:0.002574
#
# [5]	train-error:0.001817	eval-error:0.001987
#
# [6]	train-error:0.001461	eval-error:0.001568
#
# [7]	train-error:0.001676	eval-error:0.001831
#
# [8]	train-error:0.001541	eval-error:0.001613
#
# [9]	train-error:0.001772	eval-error:0.001887
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.006093972068769563, 'max_depth': 5, 'min_child_weight': 7.41184037447267, 'subsample': 0.65}, logloss: 0.2028
# [0]	train-error:0.001005	eval-error:0.001115
#
# [1]	train-error:0.000808	eval-error:0.000906
#
# [2]	train-error:0.00138	eval-error:0.00152
#
# [3]	train-error:0.000797	eval-error:0.000893
#
# [4]	train-error:0.000741	eval-error:0.000816
#
# [5]	train-error:0.000624	eval-error:0.000677
#
# [6]	train-error:0.000719	eval-error:0.000775
#
# [7]	train-error:0.000622	eval-error:0.00068
#
# [8]	train-error:0.000601	eval-error:0.000657
#
# [9]	train-error:0.00044	eval-error:0.000498
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0008229059536490646, 'max_depth': 8, 'min_child_weight': 0.9305473514419917, 'subsample': 0.7000000000000001}, logloss: 0.1992
# [0]	train-error:0.000863	eval-error:0.000992
#
# [1]	train-error:0.000668	eval-error:0.000754
#
# [2]	train-error:0.000656	eval-error:0.000734
#
# [3]	train-error:0.000481	eval-error:0.000526
#
# [4]	train-error:0.000422	eval-error:0.000458
#
# [5]	train-error:0.000375	eval-error:0.000408
#
# [6]	train-error:0.000404	eval-error:0.000435
#
# [7]	train-error:0.000387	eval-error:0.00043
#
# [8]	train-error:0.000393	eval-error:0.000437
#
# [9]	train-error:0.000363	eval-error:0.000417
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.00015976321127774958, 'max_depth': 9, 'min_child_weight': 0.10402583950927351, 'subsample': 0.9500000000000001}, logloss: 0.1988
# [0]	train-error:0.001296	eval-error:0.001387
#
# [1]	train-error:0.000969	eval-error:0.001083
#
# [2]	train-error:0.000789	eval-error:0.00089
#
# [3]	train-error:0.000782	eval-error:0.000872
#
# [4]	train-error:0.00086	eval-error:0.000967
#
# [5]	train-error:0.000774	eval-error:0.000868
#
# [6]	train-error:0.000849	eval-error:0.000947
#
# [7]	train-error:0.000849	eval-error:0.000949
#
# [8]	train-error:0.000849	eval-error:0.000949
#
# [9]	train-error:0.000812	eval-error:0.000906
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.2304715950892739, 'max_depth': 7, 'min_child_weight': 0.49036672193297737, 'subsample': 0.75}, logloss: 0.1995
# [0]	train-error:0.000966	eval-error:0.001078
#
# [1]	train-error:0.000849	eval-error:0.000929
#
# [2]	train-error:0.000788	eval-error:0.000872
#
# [3]	train-error:0.000685	eval-error:0.000754
#
# [4]	train-error:0.000735	eval-error:0.000843
#
# [5]	train-error:0.000664	eval-error:0.000734
#
# [6]	train-error:0.000754	eval-error:0.000843
#
# [7]	train-error:0.000615	eval-error:0.000684
#
# [8]	train-error:0.000685	eval-error:0.000752
#
# [9]	train-error:0.000659	eval-error:0.000723
#
# params: {'colsample_bytree': 0.65, 'gamma': 2.2881777334546e-05, 'max_depth': 8, 'min_child_weight': 2.3112468499699057, 'subsample': 0.7000000000000001}, logloss: 0.1993
# [0]	train-error:0.000874	eval-error:0.001004
#
# [1]	train-error:0.000477	eval-error:0.000541
#
# [2]	train-error:0.000425	eval-error:0.000489
#
# [3]	train-error:0.000417	eval-error:0.000476
#
# [4]	train-error:0.000425	eval-error:0.000476
#
# [5]	train-error:0.000424	eval-error:0.000474
#
# [6]	train-error:0.000407	eval-error:0.000464
#
# [7]	train-error:0.000411	eval-error:0.000462
#
# [8]	train-error:0.000409	eval-error:0.000464
#
# [9]	train-error:0.000407	eval-error:0.000464
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0012130611384400852, 'max_depth': 9, 'min_child_weight': 0.18288108878666443, 'subsample': 0.8500000000000001}, logloss: 0.1987
# [0]	train-error:0.001845	eval-error:0.001946
#
# [1]	train-error:0.001354	eval-error:0.001405
#
# [2]	train-error:0.00107	eval-error:0.001153
#
# [3]	train-error:0.001021	eval-error:0.001135
#
# [4]	train-error:0.00093	eval-error:0.001056
#
# [5]	train-error:0.001018	eval-error:0.001135
#
# [6]	train-error:0.001004	eval-error:0.001119
#
# [7]	train-error:0.001004	eval-error:0.001121
#
# [8]	train-error:0.001001	eval-error:0.001119
#
# [9]	train-error:0.001128	eval-error:0.001255
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.016922047954358352, 'max_depth': 6, 'min_child_weight': 1.2561854687782281, 'subsample': 0.65}, logloss: 0.2001
# [0]	train-error:0.00102	eval-error:0.001133
#
# [1]	train-error:0.000952	eval-error:0.001058
#
# [2]	train-error:0.000776	eval-error:0.000865
#
# [3]	train-error:0.000831	eval-error:0.000924
#
# [4]	train-error:0.000818	eval-error:0.000918
#
# [5]	train-error:0.00081	eval-error:0.000906
#
# [6]	train-error:0.000806	eval-error:0.000911
#
# [7]	train-error:0.000751	eval-error:0.000845
#
# [8]	train-error:0.000864	eval-error:0.00097
#
# [9]	train-error:0.000828	eval-error:0.000936
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0003879433365074901, 'max_depth': 7, 'min_child_weight': 5.214318785305609, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.007428	eval-error:0.007635
#
# [1]	train-error:0.006257	eval-error:0.006432
#
# [2]	train-error:0.007729	eval-error:0.007925
#
# [3]	train-error:0.007767	eval-error:0.007964
#
# [4]	train-error:0.007149	eval-error:0.007336
#
# [5]	train-error:0.006214	eval-error:0.006371
#
# [6]	train-error:0.007107	eval-error:0.007304
#
# [7]	train-error:0.006203	eval-error:0.006366
#
# [8]	train-error:0.00625	eval-error:0.006416
#
# [9]	train-error:0.006203	eval-error:0.006364
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0055563880184669595, 'max_depth': 3, 'min_child_weight': 0.44383497359835444, 'subsample': 0.8500000000000001}, logloss: 0.2092
# [0]	train-error:0.002296	eval-error:0.002388
#
# [1]	train-error:0.001998	eval-error:0.002055
#
# [2]	train-error:0.002177	eval-error:0.002152
#
# [3]	train-error:0.0022	eval-error:0.002182
#
# [4]	train-error:0.002179	eval-error:0.002152
#
# [5]	train-error:0.001479	eval-error:0.001541
#
# [6]	train-error:0.001526	eval-error:0.001586
#
# [7]	train-error:0.001498	eval-error:0.001556
#
# [8]	train-error:0.001514	eval-error:0.00157
#
# [9]	train-error:0.001485	eval-error:0.001552
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 7.260350118262645e-07, 'max_depth': 5, 'min_child_weight': 0.2806594762788247, 'subsample': 0.9500000000000001}, logloss: 0.2016
# [0]	train-error:0.000881	eval-error:0.001015
#
# [1]	train-error:0.000612	eval-error:0.000693
#
# [2]	train-error:0.00068	eval-error:0.000745
#
# [3]	train-error:0.000577	eval-error:0.000632
#
# [4]	train-error:0.000483	eval-error:0.000532
#
# [5]	train-error:0.000415	eval-error:0.000458
#
# [6]	train-error:0.000431	eval-error:0.000474
#
# [7]	train-error:0.000367	eval-error:0.000424
#
# [8]	train-error:0.000359	eval-error:0.000415
#
# [9]	train-error:0.00035	eval-error:0.000399
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.09590098874695559, 'max_depth': 9, 'min_child_weight': 0.8755443207257929, 'subsample': 0.65}, logloss: 0.1988
# [0]	train-error:0.000777	eval-error:0.000845
#
# [1]	train-error:0.000762	eval-error:0.000854
#
# [2]	train-error:0.000529	eval-error:0.000596
#
# [3]	train-error:0.000678	eval-error:0.00077
#
# [4]	train-error:0.000673	eval-error:0.000759
#
# [5]	train-error:0.000671	eval-error:0.000761
#
# [6]	train-error:0.000665	eval-error:0.00075
#
# [7]	train-error:0.000676	eval-error:0.000773
#
# [8]	train-error:0.000655	eval-error:0.000727
#
# [9]	train-error:0.000653	eval-error:0.000734
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.802486510401773e-05, 'max_depth': 8, 'min_child_weight': 1.7545222157383114, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.001137	eval-error:0.001235
#
# [1]	train-error:0.00078	eval-error:0.000877
#
# [2]	train-error:0.000686	eval-error:0.000777
#
# [3]	train-error:0.000651	eval-error:0.00073
#
# [4]	train-error:0.000692	eval-error:0.000779
#
# [5]	train-error:0.000674	eval-error:0.00075
#
# [6]	train-error:0.000665	eval-error:0.000748
#
# [7]	train-error:0.000668	eval-error:0.000748
#
# [8]	train-error:0.000664	eval-error:0.000734
#
# [9]	train-error:0.000664	eval-error:0.000743
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.9647059090113266, 'max_depth': 8, 'min_child_weight': 2.797733167570924, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000881	eval-error:0.001026
#
# [1]	train-error:0.000784	eval-error:0.00089
#
# [2]	train-error:0.000592	eval-error:0.000657
#
# [3]	train-error:0.000567	eval-error:0.000614
#
# [4]	train-error:0.000597	eval-error:0.000673
#
# [5]	train-error:0.000529	eval-error:0.000582
#
# [6]	train-error:0.000498	eval-error:0.000548
#
# [7]	train-error:0.000509	eval-error:0.000553
#
# [8]	train-error:0.00047	eval-error:0.00051
#
# [9]	train-error:0.000395	eval-error:0.000444
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 6.375034317138765e-06, 'max_depth': 9, 'min_child_weight': 0.576859055906978, 'subsample': 0.7000000000000001}, logloss: 0.1989
# [0]	train-error:0.001359	eval-error:0.001459
#
# [1]	train-error:0.000923	eval-error:0.001035
#
# [2]	train-error:0.00108	eval-error:0.001155
#
# [3]	train-error:0.000964	eval-error:0.001053
#
# [4]	train-error:0.000926	eval-error:0.000981
#
# [5]	train-error:0.000876	eval-error:0.000965
#
# [6]	train-error:0.000799	eval-error:0.00087
#
# [7]	train-error:0.000764	eval-error:0.00085
#
# [8]	train-error:0.00085	eval-error:0.000936
#
# [9]	train-error:0.000833	eval-error:0.000929
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0031229896106545235, 'max_depth': 7, 'min_child_weight': 1.2705113683846683, 'subsample': 0.6000000000000001}, logloss: 0.1998
# [0]	train-error:0.001626	eval-error:0.001765
#
# [1]	train-error:0.001562	eval-error:0.001647
#
# [2]	train-error:0.000976	eval-error:0.001085
#
# [3]	train-error:0.001	eval-error:0.001117
#
# [4]	train-error:0.00101	eval-error:0.001137
#
# [5]	train-error:0.001008	eval-error:0.001121
#
# [6]	train-error:0.001005	eval-error:0.001115
#
# [7]	train-error:0.000997	eval-error:0.001099
#
# [8]	train-error:0.001131	eval-error:0.001251
#
# [9]	train-error:0.001127	eval-error:0.001248
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.24070555301525198, 'max_depth': 6, 'min_child_weight': 0.4116136336808864, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.001085	eval-error:0.001201
#
# [1]	train-error:0.000958	eval-error:0.001058
#
# [2]	train-error:0.000918	eval-error:0.001013
#
# [3]	train-error:0.000754	eval-error:0.000807
#
# [4]	train-error:0.000777	eval-error:0.000865
#
# [5]	train-error:0.000807	eval-error:0.000879
#
# [6]	train-error:0.000727	eval-error:0.00077
#
# [7]	train-error:0.00066	eval-error:0.0007
#
# [8]	train-error:0.000662	eval-error:0.000727
#
# [9]	train-error:0.000591	eval-error:0.00065
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.01994934602471997, 'max_depth': 8, 'min_child_weight': 9.719308698302552, 'subsample': 0.65}, logloss: 0.1995
# [0]	train-error:0.005713	eval-error:0.005777
#
# [1]	train-error:0.005714	eval-error:0.00577
#
# [2]	train-error:0.002677	eval-error:0.002685
#
# [3]	train-error:0.002677	eval-error:0.002682
#
# [4]	train-error:0.002659	eval-error:0.002671
#
# [5]	train-error:0.002635	eval-error:0.002648
#
# [6]	train-error:0.00263	eval-error:0.002648
#
# [7]	train-error:0.002457	eval-error:0.002458
#
# [8]	train-error:0.002457	eval-error:0.002456
#
# [9]	train-error:0.002457	eval-error:0.002456
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0002977830610654581, 'max_depth': 4, 'min_child_weight': 0.20571674799330142, 'subsample': 0.75}, logloss: 0.2046
# [0]	train-error:0.000984	eval-error:0.001115
#
# [1]	train-error:0.000865	eval-error:0.000976
#
# [2]	train-error:0.000603	eval-error:0.000689
#
# [3]	train-error:0.000525	eval-error:0.000573
#
# [4]	train-error:0.000554	eval-error:0.000628
#
# [5]	train-error:0.000495	eval-error:0.000553
#
# [6]	train-error:0.000498	eval-error:0.000544
#
# [7]	train-error:0.000439	eval-error:0.000507
#
# [8]	train-error:0.000433	eval-error:0.000514
#
# [9]	train-error:0.00042	eval-error:0.000494
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.5684817162500934e-08, 'max_depth': 9, 'min_child_weight': 4.042870198893469, 'subsample': 0.8}, logloss: 0.1989
# [0]	train-error:0.0023	eval-error:0.002392
#
# [1]	train-error:0.002	eval-error:0.002059
#
# [2]	train-error:0.002179	eval-error:0.002152
#
# [3]	train-error:0.002208	eval-error:0.002189
#
# [4]	train-error:0.002177	eval-error:0.00215
#
# [5]	train-error:0.001479	eval-error:0.001543
#
# [6]	train-error:0.001528	eval-error:0.00159
#
# [7]	train-error:0.001485	eval-error:0.001552
#
# [8]	train-error:0.001517	eval-error:0.001572
#
# [9]	train-error:0.001487	eval-error:0.001554
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 8.340868991965756e-07, 'max_depth': 5, 'min_child_weight': 0.7904145336284316, 'subsample': 0.7000000000000001}, logloss: 0.2016
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.006221	eval-error:0.006378
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.007415	eval-error:0.007617
#
# [7]	train-error:0.006221	eval-error:0.006378
#
# [8]	train-error:0.006221	eval-error:0.006378
#
# [9]	train-error:0.006221	eval-error:0.006378
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.4910551348630324, 'max_depth': 3, 'min_child_weight': 2.323020645642242, 'subsample': 0.8500000000000001}, logloss: 0.2095
# [0]	train-error:0.000946	eval-error:0.001038
#
# [1]	train-error:0.00073	eval-error:0.000831
#
# [2]	train-error:0.001364	eval-error:0.001488
#
# [3]	train-error:0.000771	eval-error:0.00085
#
# [4]	train-error:0.000705	eval-error:0.00077
#
# [5]	train-error:0.000614	eval-error:0.000668
#
# [6]	train-error:0.0007	eval-error:0.000752
#
# [7]	train-error:0.000606	eval-error:0.000659
#
# [8]	train-error:0.0006	eval-error:0.000662
#
# [9]	train-error:0.000521	eval-error:0.000551
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.05098518633598992, 'max_depth': 8, 'min_child_weight': 1.122970233027086, 'subsample': 0.75}, logloss: 0.1992
# [0]	train-error:0.000831	eval-error:0.000927
#
# [1]	train-error:0.000825	eval-error:0.000918
#
# [2]	train-error:0.000816	eval-error:0.000911
#
# [3]	train-error:0.000816	eval-error:0.000913
#
# [4]	train-error:0.000783	eval-error:0.000881
#
# [5]	train-error:0.000808	eval-error:0.000906
#
# [6]	train-error:0.000776	eval-error:0.000872
#
# [7]	train-error:0.000777	eval-error:0.000875
#
# [8]	train-error:0.000828	eval-error:0.00092
#
# [9]	train-error:0.000813	eval-error:0.000913
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.001483211381483341, 'max_depth': 7, 'min_child_weight': 1.7467758516517993, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.000913	eval-error:0.001067
#
# [1]	train-error:0.000841	eval-error:0.000961
#
# [2]	train-error:0.000817	eval-error:0.000906
#
# [3]	train-error:0.000507	eval-error:0.000573
#
# [4]	train-error:0.000515	eval-error:0.000557
#
# [5]	train-error:0.000431	eval-error:0.000469
#
# [6]	train-error:0.00042	eval-error:0.000467
#
# [7]	train-error:0.000384	eval-error:0.000419
#
# [8]	train-error:0.000384	eval-error:0.000449
#
# [9]	train-error:0.000366	eval-error:0.000426
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.00926146439158095, 'max_depth': 9, 'min_child_weight': 0.31422186628501175, 'subsample': 0.75}, logloss: 0.1989
# [0]	train-error:0.000931	eval-error:0.001035
#
# [1]	train-error:0.000899	eval-error:0.00101
#
# [2]	train-error:0.00068	eval-error:0.00077
#
# [3]	train-error:0.000686	eval-error:0.000768
#
# [4]	train-error:0.000665	eval-error:0.000745
#
# [5]	train-error:0.000675	eval-error:0.00075
#
# [6]	train-error:0.000656	eval-error:0.000734
#
# [7]	train-error:0.000658	eval-error:0.000739
#
# [8]	train-error:0.000643	eval-error:0.000716
#
# [9]	train-error:0.000645	eval-error:0.00072
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.14476602627396912, 'max_depth': 8, 'min_child_weight': 0.686048652990426, 'subsample': 0.65}, logloss: 0.1991
# [0]	train-error:0.000723	eval-error:0.000811
#
# [1]	train-error:0.000435	eval-error:0.000496
#
# [2]	train-error:0.000447	eval-error:0.00051
#
# [3]	train-error:0.000453	eval-error:0.000512
#
# [4]	train-error:0.000463	eval-error:0.000521
#
# [5]	train-error:0.000466	eval-error:0.000526
#
# [6]	train-error:0.000461	eval-error:0.000526
#
# [7]	train-error:0.000452	eval-error:0.000507
#
# [8]	train-error:0.000431	eval-error:0.00048
#
# [9]	train-error:0.000424	eval-error:0.000471
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0036032861741794493, 'max_depth': 9, 'min_child_weight': 0.5076484523415269, 'subsample': 0.7000000000000001}, logloss: 0.1987
# [0]	train-error:0.001883	eval-error:0.001985
#
# [1]	train-error:0.001366	eval-error:0.001427
#
# [2]	train-error:0.001085	eval-error:0.00116
#
# [3]	train-error:0.001033	eval-error:0.001151
#
# [4]	train-error:0.000941	eval-error:0.001063
#
# [5]	train-error:0.001023	eval-error:0.001144
#
# [6]	train-error:0.001013	eval-error:0.001131
#
# [7]	train-error:0.001003	eval-error:0.001126
#
# [8]	train-error:0.00112	eval-error:0.001253
#
# [9]	train-error:0.001119	eval-error:0.001251
#
# params: {'colsample_bytree': 0.9, 'gamma': 9.182793609826434e-08, 'max_depth': 6, 'min_child_weight': 4.986839669588026, 'subsample': 0.6000000000000001}, logloss: 0.2001
# [0]	train-error:0.002516	eval-error:0.002633
#
# [1]	train-error:0.002475	eval-error:0.002617
#
# [2]	train-error:0.00216	eval-error:0.002286
#
# [3]	train-error:0.001734	eval-error:0.001856
#
# [4]	train-error:0.00247	eval-error:0.002535
#
# [5]	train-error:0.001757	eval-error:0.00191
#
# [6]	train-error:0.001436	eval-error:0.001556
#
# [7]	train-error:0.001679	eval-error:0.001837
#
# [8]	train-error:0.001523	eval-error:0.001579
#
# [9]	train-error:0.001676	eval-error:0.001695
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0007355687967145646, 'max_depth': 5, 'min_child_weight': 1.2759634747897646, 'subsample': 0.8}, logloss: 0.2028
# [0]	train-error:0.001295	eval-error:0.001402
#
# [1]	train-error:0.000964	eval-error:0.001085
#
# [2]	train-error:0.000791	eval-error:0.00089
#
# [3]	train-error:0.000776	eval-error:0.00085
#
# [4]	train-error:0.000865	eval-error:0.000954
#
# [5]	train-error:0.000776	eval-error:0.000861
#
# [6]	train-error:0.000751	eval-error:0.000834
#
# [7]	train-error:0.000733	eval-error:0.000811
#
# [8]	train-error:0.000805	eval-error:0.000895
#
# [9]	train-error:0.000841	eval-error:0.000938
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00010796666445976303, 'max_depth': 7, 'min_child_weight': 0.36758693933713066, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.000901	eval-error:0.001015
#
# [1]	train-error:0.000842	eval-error:0.000938
#
# [2]	train-error:0.000853	eval-error:0.000945
#
# [3]	train-error:0.000537	eval-error:0.000582
#
# [4]	train-error:0.000483	eval-error:0.000523
#
# [5]	train-error:0.000458	eval-error:0.00051
#
# [6]	train-error:0.00043	eval-error:0.000492
#
# [7]	train-error:0.000435	eval-error:0.000485
#
# [8]	train-error:0.00039	eval-error:0.000455
#
# [9]	train-error:0.000388	eval-error:0.000453
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.6348542654845469, 'max_depth': 9, 'min_child_weight': 3.0976132988260865, 'subsample': 0.75}, logloss: 0.1989
# [0]	train-error:0.00048	eval-error:0.000519
#
# [1]	train-error:0.00044	eval-error:0.00051
#
# [2]	train-error:0.000445	eval-error:0.000496
#
# [3]	train-error:0.000443	eval-error:0.000501
#
# [4]	train-error:0.00045	eval-error:0.000512
#
# [5]	train-error:0.000438	eval-error:0.000501
#
# [6]	train-error:0.000453	eval-error:0.000501
#
# [7]	train-error:0.000437	eval-error:0.000492
#
# [8]	train-error:0.000419	eval-error:0.00048
#
# [9]	train-error:0.00041	eval-error:0.000469
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.029419589805217895, 'max_depth': 9, 'min_child_weight': 0.7854078480360916, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.000481	eval-error:0.000521
#
# [1]	train-error:0.000442	eval-error:0.00051
#
# [2]	train-error:0.000446	eval-error:0.000501
#
# [3]	train-error:0.000447	eval-error:0.000505
#
# [4]	train-error:0.000446	eval-error:0.000501
#
# [5]	train-error:0.000432	eval-error:0.000487
#
# [6]	train-error:0.000457	eval-error:0.000507
#
# [7]	train-error:0.000439	eval-error:0.000496
#
# [8]	train-error:0.000397	eval-error:0.000455
#
# [9]	train-error:0.000389	eval-error:0.000446
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.06455789067552721, 'max_depth': 9, 'min_child_weight': 1.4818651882154812, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.001134	eval-error:0.001232
#
# [1]	train-error:0.000768	eval-error:0.000865
#
# [2]	train-error:0.000681	eval-error:0.000773
#
# [3]	train-error:0.00064	eval-error:0.000716
#
# [4]	train-error:0.000686	eval-error:0.000779
#
# [5]	train-error:0.000663	eval-error:0.000739
#
# [6]	train-error:0.000656	eval-error:0.000736
#
# [7]	train-error:0.000672	eval-error:0.000748
#
# [8]	train-error:0.000659	eval-error:0.000725
#
# [9]	train-error:0.000661	eval-error:0.000736
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.030211047240946982, 'max_depth': 8, 'min_child_weight': 2.0017607392787653, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000481	eval-error:0.000521
#
# [1]	train-error:0.00043	eval-error:0.000489
#
# [2]	train-error:0.000437	eval-error:0.00048
#
# [3]	train-error:0.00042	eval-error:0.000467
#
# [4]	train-error:0.000417	eval-error:0.000469
#
# [5]	train-error:0.000417	eval-error:0.000467
#
# [6]	train-error:0.000406	eval-error:0.000449
#
# [7]	train-error:0.000395	eval-error:0.000446
#
# [8]	train-error:0.000379	eval-error:0.000437
#
# [9]	train-error:0.000345	eval-error:0.000399
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.27612766914610604, 'max_depth': 9, 'min_child_weight': 0.883790289213797, 'subsample': 0.9500000000000001}, logloss: 0.1985
# [0]	train-error:0.000755	eval-error:0.000836
#
# [1]	train-error:0.000745	eval-error:0.000829
#
# [2]	train-error:0.000749	eval-error:0.000838
#
# [3]	train-error:0.000705	eval-error:0.000791
#
# [4]	train-error:0.000704	eval-error:0.000797
#
# [5]	train-error:0.000674	eval-error:0.000761
#
# [6]	train-error:0.000664	eval-error:0.000754
#
# [7]	train-error:0.000679	eval-error:0.000768
#
# [8]	train-error:0.000673	eval-error:0.000777
#
# [9]	train-error:0.000671	eval-error:0.000768
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.29756939506994873, 'max_depth': 8, 'min_child_weight': 0.9074585257664904, 'subsample': 0.7000000000000001}, logloss: 0.1991
# [0]	train-error:0.000487	eval-error:0.000555
#
# [1]	train-error:0.000456	eval-error:0.000532
#
# [2]	train-error:0.000451	eval-error:0.000514
#
# [3]	train-error:0.000445	eval-error:0.000512
#
# [4]	train-error:0.00047	eval-error:0.000528
#
# [5]	train-error:0.00046	eval-error:0.000523
#
# [6]	train-error:0.000461	eval-error:0.000519
#
# [7]	train-error:0.000453	eval-error:0.000519
#
# [8]	train-error:0.000417	eval-error:0.000478
#
# [9]	train-error:0.000418	eval-error:0.000474
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0700228817512734, 'max_depth': 9, 'min_child_weight': 0.255781660089109, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.000935	eval-error:0.001053
#
# [1]	train-error:0.000484	eval-error:0.000544
#
# [2]	train-error:0.000419	eval-error:0.000487
#
# [3]	train-error:0.000415	eval-error:0.000496
#
# [4]	train-error:0.000419	eval-error:0.000489
#
# [5]	train-error:0.000407	eval-error:0.000485
#
# [6]	train-error:0.000415	eval-error:0.000476
#
# [7]	train-error:0.000414	eval-error:0.000485
#
# [8]	train-error:0.000406	eval-error:0.00048
#
# [9]	train-error:0.000403	eval-error:0.000471
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.11761589144138386, 'max_depth': 9, 'min_child_weight': 0.603639022964531, 'subsample': 0.8}, logloss: 0.1986
# [0]	train-error:0.000968	eval-error:0.001056
#
# [1]	train-error:0.000902	eval-error:0.00101
#
# [2]	train-error:0.000683	eval-error:0.000764
#
# [3]	train-error:0.000682	eval-error:0.000764
#
# [4]	train-error:0.000802	eval-error:0.000893
#
# [5]	train-error:0.000683	eval-error:0.000759
#
# [6]	train-error:0.000659	eval-error:0.000741
#
# [7]	train-error:0.000671	eval-error:0.000754
#
# [8]	train-error:0.000652	eval-error:0.00073
#
# [9]	train-error:0.000652	eval-error:0.00073
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.1847089567007996, 'max_depth': 8, 'min_child_weight': 1.0916522009882075, 'subsample': 0.7000000000000001}, logloss: 0.1991
# [0]	train-error:0.000474	eval-error:0.000519
#
# [1]	train-error:0.000425	eval-error:0.000487
#
# [2]	train-error:0.000433	eval-error:0.00048
#
# [3]	train-error:0.000415	eval-error:0.000469
#
# [4]	train-error:0.000415	eval-error:0.000453
#
# [5]	train-error:0.000413	eval-error:0.000453
#
# [6]	train-error:0.00041	eval-error:0.000453
#
# [7]	train-error:0.000408	eval-error:0.000451
#
# [8]	train-error:0.000387	eval-error:0.000421
#
# [9]	train-error:0.000386	eval-error:0.000421
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.004157175220976503, 'max_depth': 9, 'min_child_weight': 0.4362218806016214, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000769	eval-error:0.00087
#
# [1]	train-error:0.000754	eval-error:0.00085
#
# [2]	train-error:0.000485	eval-error:0.000557
#
# [3]	train-error:0.000667	eval-error:0.000766
#
# [4]	train-error:0.000665	eval-error:0.000761
#
# [5]	train-error:0.000654	eval-error:0.000741
#
# [6]	train-error:0.000659	eval-error:0.00075
#
# [7]	train-error:0.000674	eval-error:0.000775
#
# [8]	train-error:0.000665	eval-error:0.000759
#
# [9]	train-error:0.000767	eval-error:0.000865
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.010128817628803502, 'max_depth': 8, 'min_child_weight': 0.42467430792874933, 'subsample': 0.9500000000000001}, logloss: 0.1990
# [0]	train-error:0.000872	eval-error:0.001004
#
# [1]	train-error:0.000468	eval-error:0.000539
#
# [2]	train-error:0.000424	eval-error:0.000489
#
# [3]	train-error:0.000415	eval-error:0.000476
#
# [4]	train-error:0.000424	eval-error:0.00048
#
# [5]	train-error:0.000427	eval-error:0.000478
#
# [6]	train-error:0.000405	eval-error:0.000458
#
# [7]	train-error:0.000406	eval-error:0.00046
#
# [8]	train-error:0.000397	eval-error:0.000458
#
# [9]	train-error:0.000393	eval-error:0.000449
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.004907197536420019, 'max_depth': 9, 'min_child_weight': 0.12644443166782957, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.000472	eval-error:0.000517
#
# [1]	train-error:0.000424	eval-error:0.000487
#
# [2]	train-error:0.000432	eval-error:0.00048
#
# [3]	train-error:0.000415	eval-error:0.000469
#
# [4]	train-error:0.000413	eval-error:0.000453
#
# [5]	train-error:0.000412	eval-error:0.000453
#
# [6]	train-error:0.000409	eval-error:0.000453
#
# [7]	train-error:0.00041	eval-error:0.000458
#
# [8]	train-error:0.000372	eval-error:0.000415
#
# [9]	train-error:0.000372	eval-error:0.000412
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0010375826929695472, 'max_depth': 9, 'min_child_weight': 0.1766240782383369, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000935	eval-error:0.001038
#
# [1]	train-error:0.000738	eval-error:0.000836
#
# [2]	train-error:0.000668	eval-error:0.000754
#
# [3]	train-error:0.000671	eval-error:0.000761
#
# [4]	train-error:0.000675	eval-error:0.000768
#
# [5]	train-error:0.000674	eval-error:0.000752
#
# [6]	train-error:0.000652	eval-error:0.000716
#
# [7]	train-error:0.000649	eval-error:0.000714
#
# [8]	train-error:0.000642	eval-error:0.000714
#
# [9]	train-error:0.000662	eval-error:0.000741
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.012874094101444451, 'max_depth': 8, 'min_child_weight': 0.10040756349166731, 'subsample': 0.9500000000000001}, logloss: 0.1990
# [0]	train-error:0.00129	eval-error:0.001373
#
# [1]	train-error:0.000963	eval-error:0.001076
#
# [2]	train-error:0.000764	eval-error:0.00085
#
# [3]	train-error:0.000764	eval-error:0.000843
#
# [4]	train-error:0.000862	eval-error:0.000958
#
# [5]	train-error:0.000879	eval-error:0.000974
#
# [6]	train-error:0.000851	eval-error:0.000947
#
# [7]	train-error:0.000864	eval-error:0.000986
#
# [8]	train-error:0.000849	eval-error:0.000947
#
# [9]	train-error:0.000812	eval-error:0.000904
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00048363625980520845, 'max_depth': 7, 'min_child_weight': 0.3101901325116875, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.000479	eval-error:0.000526
#
# [1]	train-error:0.000437	eval-error:0.000507
#
# [2]	train-error:0.000441	eval-error:0.000501
#
# [3]	train-error:0.00044	eval-error:0.000501
#
# [4]	train-error:0.000449	eval-error:0.000512
#
# [5]	train-error:0.000435	eval-error:0.000498
#
# [6]	train-error:0.000452	eval-error:0.000496
#
# [7]	train-error:0.000435	eval-error:0.000489
#
# [8]	train-error:0.000418	eval-error:0.000476
#
# [9]	train-error:0.000409	eval-error:0.000467
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0018533637691978291, 'max_depth': 9, 'min_child_weight': 0.691010069407766, 'subsample': 0.9}, logloss: 0.1987
# [0]	train-error:0.005755	eval-error:0.005841
#
# [1]	train-error:0.002544	eval-error:0.002528
#
# [2]	train-error:0.005974	eval-error:0.006147
#
# [3]	train-error:0.005988	eval-error:0.006153
#
# [4]	train-error:0.003191	eval-error:0.00324
#
# [5]	train-error:0.003316	eval-error:0.003376
#
# [6]	train-error:0.004554	eval-error:0.004697
#
# [7]	train-error:0.002963	eval-error:0.003
#
# [8]	train-error:0.002489	eval-error:0.002422
#
# [9]	train-error:0.002614	eval-error:0.002574
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.0002506945816471419, 'max_depth': 4, 'min_child_weight': 0.5271350539554506, 'subsample': 0.9500000000000001}, logloss: 0.2051
# [0]	train-error:0.000938	eval-error:0.001038
#
# [1]	train-error:0.000745	eval-error:0.000845
#
# [2]	train-error:0.000669	eval-error:0.000757
#
# [3]	train-error:0.000671	eval-error:0.000764
#
# [4]	train-error:0.000694	eval-error:0.000788
#
# [5]	train-error:0.000663	eval-error:0.000752
#
# [6]	train-error:0.000665	eval-error:0.000741
#
# [7]	train-error:0.000666	eval-error:0.000752
#
# [8]	train-error:0.00066	eval-error:0.000739
#
# [9]	train-error:0.000666	eval-error:0.000766
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.8290361494403536e-05, 'max_depth': 8, 'min_child_weight': 0.46822337506850936, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.000831	eval-error:0.000927
#
# [1]	train-error:0.000828	eval-error:0.000918
#
# [2]	train-error:0.000817	eval-error:0.000911
#
# [3]	train-error:0.000817	eval-error:0.000913
#
# [4]	train-error:0.000795	eval-error:0.00089
#
# [5]	train-error:0.000778	eval-error:0.000877
#
# [6]	train-error:0.000788	eval-error:0.00089
#
# [7]	train-error:0.000856	eval-error:0.000954
#
# [8]	train-error:0.000847	eval-error:0.000952
#
# [9]	train-error:0.000813	eval-error:0.000909
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.024029121656100196, 'max_depth': 7, 'min_child_weight': 1.7112516629293923, 'subsample': 0.8500000000000001}, logloss: 0.1994
# [0]	train-error:0.000879	eval-error:0.001001
#
# [1]	train-error:0.00047	eval-error:0.000535
#
# [2]	train-error:0.000426	eval-error:0.000483
#
# [3]	train-error:0.000416	eval-error:0.000471
#
# [4]	train-error:0.000424	eval-error:0.000474
#
# [5]	train-error:0.000427	eval-error:0.00048
#
# [6]	train-error:0.000409	eval-error:0.000462
#
# [7]	train-error:0.00041	eval-error:0.000467
#
# [8]	train-error:0.000398	eval-error:0.00046
#
# [9]	train-error:0.000393	eval-error:0.000451
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.3157964130383484, 'max_depth': 9, 'min_child_weight': 0.9907120833019505, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000853	eval-error:0.000981
#
# [1]	train-error:0.000648	eval-error:0.000709
#
# [2]	train-error:0.000659	eval-error:0.000734
#
# [3]	train-error:0.000483	eval-error:0.000537
#
# [4]	train-error:0.000436	eval-error:0.000485
#
# [5]	train-error:0.000384	eval-error:0.000424
#
# [6]	train-error:0.000393	eval-error:0.00044
#
# [7]	train-error:0.000362	eval-error:0.000412
#
# [8]	train-error:0.000363	eval-error:0.000424
#
# [9]	train-error:0.000357	eval-error:0.000412
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.002303600434247977, 'max_depth': 9, 'min_child_weight': 0.14818119847324013, 'subsample': 0.9}, logloss: 0.1988
# [0]	train-error:0.000939	eval-error:0.00104
#
# [1]	train-error:0.000745	eval-error:0.000843
#
# [2]	train-error:0.000675	eval-error:0.000768
#
# [3]	train-error:0.000671	eval-error:0.000757
#
# [4]	train-error:0.000664	eval-error:0.000732
#
# [5]	train-error:0.000672	eval-error:0.000752
#
# [6]	train-error:0.000645	eval-error:0.000714
#
# [7]	train-error:0.000656	eval-error:0.000723
#
# [8]	train-error:0.000646	eval-error:0.000711
#
# [9]	train-error:0.00064	eval-error:0.000711
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0039324963269132375, 'max_depth': 8, 'min_child_weight': 0.21019339655375513, 'subsample': 0.8500000000000001}, logloss: 0.1990
# [0]	train-error:0.000472	eval-error:0.000517
#
# [1]	train-error:0.000424	eval-error:0.000487
#
# [2]	train-error:0.000433	eval-error:0.00048
#
# [3]	train-error:0.000415	eval-error:0.000469
#
# [4]	train-error:0.000415	eval-error:0.000453
#
# [5]	train-error:0.000412	eval-error:0.000453
#
# [6]	train-error:0.000409	eval-error:0.000453
#
# [7]	train-error:0.00041	eval-error:0.000458
#
# [8]	train-error:0.000372	eval-error:0.000415
#
# [9]	train-error:0.000372	eval-error:0.000412
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.6950182437790454, 'max_depth': 9, 'min_child_weight': 0.24403148894080137, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.001295	eval-error:0.001402
#
# [1]	train-error:0.000964	eval-error:0.001085
#
# [2]	train-error:0.000791	eval-error:0.00089
#
# [3]	train-error:0.000776	eval-error:0.00085
#
# [4]	train-error:0.000865	eval-error:0.000954
#
# [5]	train-error:0.000776	eval-error:0.000861
#
# [6]	train-error:0.000751	eval-error:0.000834
#
# [7]	train-error:0.000733	eval-error:0.000811
#
# [8]	train-error:0.000805	eval-error:0.000895
#
# [9]	train-error:0.000841	eval-error:0.000938
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.04425521123323462, 'max_depth': 7, 'min_child_weight': 0.3445960976857292, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.006221	eval-error:0.006378
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.007415	eval-error:0.007617
#
# [7]	train-error:0.006221	eval-error:0.006378
#
# [8]	train-error:0.006221	eval-error:0.006378
#
# [9]	train-error:0.006221	eval-error:0.006378
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.007376097899839758, 'max_depth': 3, 'min_child_weight': 0.29185020774537934, 'subsample': 0.9}, logloss: 0.2095
# [0]	train-error:0.000783	eval-error:0.000879
#
# [1]	train-error:0.000767	eval-error:0.000856
#
# [2]	train-error:0.00049	eval-error:0.000557
#
# [3]	train-error:0.000671	eval-error:0.000764
#
# [4]	train-error:0.000661	eval-error:0.000743
#
# [5]	train-error:0.000665	eval-error:0.000745
#
# [6]	train-error:0.000656	eval-error:0.000732
#
# [7]	train-error:0.000673	eval-error:0.000761
#
# [8]	train-error:0.000671	eval-error:0.000768
#
# [9]	train-error:0.000785	eval-error:0.000888
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.183967509122184e-05, 'max_depth': 8, 'min_child_weight': 2.6058519666481224, 'subsample': 0.9500000000000001}, logloss: 0.1990
# [0]	train-error:0.001873	eval-error:0.001987
#
# [1]	train-error:0.001199	eval-error:0.001273
#
# [2]	train-error:0.002004	eval-error:0.002105
#
# [3]	train-error:0.001692	eval-error:0.001769
#
# [4]	train-error:0.00136	eval-error:0.001461
#
# [5]	train-error:0.001408	eval-error:0.001502
#
# [6]	train-error:0.001115	eval-error:0.001196
#
# [7]	train-error:0.001189	eval-error:0.001253
#
# [8]	train-error:0.001106	eval-error:0.001167
#
# [9]	train-error:0.001005	eval-error:0.001081
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.017333202433596148, 'max_depth': 6, 'min_child_weight': 1.3753321276005253, 'subsample': 0.8500000000000001}, logloss: 0.2006
# [0]	train-error:0.000951	eval-error:0.001067
#
# [1]	train-error:0.000723	eval-error:0.000829
#
# [2]	train-error:0.000677	eval-error:0.000775
#
# [3]	train-error:0.000632	eval-error:0.000725
#
# [4]	train-error:0.00067	eval-error:0.00077
#
# [5]	train-error:0.000653	eval-error:0.000739
#
# [6]	train-error:0.00065	eval-error:0.000741
#
# [7]	train-error:0.00067	eval-error:0.000764
#
# [8]	train-error:0.000648	eval-error:0.000732
#
# [9]	train-error:0.000644	eval-error:0.000734
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.09760847469814607, 'max_depth': 8, 'min_child_weight': 0.5681142690449981, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000868	eval-error:0.000999
#
# [1]	train-error:0.000599	eval-error:0.000673
#
# [2]	train-error:0.000674	eval-error:0.000732
#
# [3]	train-error:0.000508	eval-error:0.000562
#
# [4]	train-error:0.00045	eval-error:0.000476
#
# [5]	train-error:0.000422	eval-error:0.000458
#
# [6]	train-error:0.000389	eval-error:0.00043
#
# [7]	train-error:0.000406	eval-error:0.000458
#
# [8]	train-error:0.000372	eval-error:0.000426
#
# [9]	train-error:0.000375	eval-error:0.000424
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.6769181328973225e-06, 'max_depth': 9, 'min_child_weight': 0.8925939972753213, 'subsample': 0.6000000000000001}, logloss: 0.1988
# [0]	train-error:0.00571	eval-error:0.005802
#
# [1]	train-error:0.00571	eval-error:0.005807
#
# [2]	train-error:0.002573	eval-error:0.002578
#
# [3]	train-error:0.002673	eval-error:0.002719
#
# [4]	train-error:0.002672	eval-error:0.002716
#
# [5]	train-error:0.002665	eval-error:0.00271
#
# [6]	train-error:0.002567	eval-error:0.002567
#
# [7]	train-error:0.002397	eval-error:0.002377
#
# [8]	train-error:0.002459	eval-error:0.002456
#
# [9]	train-error:0.002449	eval-error:0.002447
#
# params: {'colsample_bytree': 0.9, 'gamma': 6.867394717403086e-05, 'max_depth': 4, 'min_child_weight': 0.3770335971778329, 'subsample': 0.9}, logloss: 0.2046
# [0]	train-error:0.000887	eval-error:0.001006
#
# [1]	train-error:0.000509	eval-error:0.000573
#
# [2]	train-error:0.000428	eval-error:0.000489
#
# [3]	train-error:0.000421	eval-error:0.000476
#
# [4]	train-error:0.000428	eval-error:0.000478
#
# [5]	train-error:0.000428	eval-error:0.000474
#
# [6]	train-error:0.000418	eval-error:0.000467
#
# [7]	train-error:0.000418	eval-error:0.000464
#
# [8]	train-error:0.00041	eval-error:0.000469
#
# [9]	train-error:0.00041	eval-error:0.000467
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0001581992171107137, 'max_depth': 9, 'min_child_weight': 0.7377171279376269, 'subsample': 0.75}, logloss: 0.1987
# [0]	train-error:0.000816	eval-error:0.000915
#
# [1]	train-error:0.000821	eval-error:0.00092
#
# [2]	train-error:0.000813	eval-error:0.000915
#
# [3]	train-error:0.000813	eval-error:0.000913
#
# [4]	train-error:0.000774	eval-error:0.000879
#
# [5]	train-error:0.000785	eval-error:0.000881
#
# [6]	train-error:0.000773	eval-error:0.000879
#
# [7]	train-error:0.000767	eval-error:0.000872
#
# [8]	train-error:0.000841	eval-error:0.000942
#
# [9]	train-error:0.000731	eval-error:0.000822
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 8.279839849193154e-06, 'max_depth': 7, 'min_child_weight': 0.11249528187773888, 'subsample': 0.7000000000000001}, logloss: 0.1994
# [0]	train-error:0.001846	eval-error:0.001946
#
# [1]	train-error:0.001355	eval-error:0.001405
#
# [2]	train-error:0.001084	eval-error:0.001165
#
# [3]	train-error:0.001009	eval-error:0.001119
#
# [4]	train-error:0.000952	eval-error:0.001067
#
# [5]	train-error:0.000999	eval-error:0.001099
#
# [6]	train-error:0.000996	eval-error:0.001101
#
# [7]	train-error:0.000979	eval-error:0.001083
#
# [8]	train-error:0.000978	eval-error:0.001081
#
# [9]	train-error:0.001106	eval-error:0.001217
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.4766013974069655, 'max_depth': 6, 'min_child_weight': 1.1699807881796669, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.000937	eval-error:0.00102
#
# [1]	train-error:0.000753	eval-error:0.000841
#
# [2]	train-error:0.000785	eval-error:0.000854
#
# [3]	train-error:0.000649	eval-error:0.000689
#
# [4]	train-error:0.000771	eval-error:0.000865
#
# [5]	train-error:0.000751	eval-error:0.000827
#
# [6]	train-error:0.000714	eval-error:0.000791
#
# [7]	train-error:0.000633	eval-error:0.000664
#
# [8]	train-error:0.000628	eval-error:0.000675
#
# [9]	train-error:0.000556	eval-error:0.000578
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.9434497514879341, 'max_depth': 8, 'min_child_weight': 3.370121909237509, 'subsample': 0.8500000000000001}, logloss: 0.1993
# [0]	train-error:0.002463	eval-error:0.002485
#
# [1]	train-error:0.002029	eval-error:0.002091
#
# [2]	train-error:0.002241	eval-error:0.002243
#
# [3]	train-error:0.002229	eval-error:0.002209
#
# [4]	train-error:0.00218	eval-error:0.002155
#
# [5]	train-error:0.001485	eval-error:0.00155
#
# [6]	train-error:0.002212	eval-error:0.002193
#
# [7]	train-error:0.002008	eval-error:0.002053
#
# [8]	train-error:0.001473	eval-error:0.001522
#
# [9]	train-error:0.002169	eval-error:0.002143
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0013048795919914156, 'max_depth': 5, 'min_child_weight': 0.6312079983232383, 'subsample': 0.8}, logloss: 0.2016
# [0]	train-error:0.000893	eval-error:0.001004
#
# [1]	train-error:0.000618	eval-error:0.000673
#
# [2]	train-error:0.000482	eval-error:0.000528
#
# [3]	train-error:0.000474	eval-error:0.000519
#
# [4]	train-error:0.000495	eval-error:0.000548
#
# [5]	train-error:0.000477	eval-error:0.000526
#
# [6]	train-error:0.000472	eval-error:0.000532
#
# [7]	train-error:0.000489	eval-error:0.000532
#
# [8]	train-error:0.000478	eval-error:0.000521
#
# [9]	train-error:0.000477	eval-error:0.00053
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0006265189668900339, 'max_depth': 9, 'min_child_weight': 1.9896346067651909, 'subsample': 0.65}, logloss: 0.1987
# 100%|██████████| 100/100 [50:15<00:00, 30.15s/it, best loss: 0.1985380818334912]
# best params:{'colsample_bytree': 0.9500000000000001, 'gamma': 0.27612766914610604, 'max_depth': 9, 'min_child_weight': 0.883790289213797, 'subsample': 0.9500000000000001}, score:0.1985

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.27612766914610604,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 0.883790289213797,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.000461	eval-error:0.000478
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.00046	eval-error:0.000476
# [2]	train-error:0.000459	eval-error:0.000476
# [3]	train-error:0.000445	eval-error:0.000453
# [4]	train-error:0.000443	eval-error:0.000451
# [5]	train-error:0.000429	eval-error:0.000444
# [6]	train-error:0.000403	eval-error:0.000419
# [7]	train-error:0.000376	eval-error:0.000396
# [8]	train-error:0.000355	eval-error:0.000374
# [9]	train-error:0.000355	eval-error:0.000374
# [10]	train-error:0.000353	eval-error:0.000374
# [11]	train-error:0.000331	eval-error:0.000351
# [12]	train-error:0.000323	eval-error:0.000342
# [13]	train-error:0.000284	eval-error:0.000315
# [14]	train-error:0.000279	eval-error:0.000313
# [15]	train-error:0.000276	eval-error:0.000308
# [16]	train-error:0.000208	eval-error:0.000238
# [17]	train-error:0.000237	eval-error:0.000263
# [18]	train-error:0.000237	eval-error:0.000263
# [19]	train-error:0.000207	eval-error:0.000238
# [20]	train-error:0.000175	eval-error:0.000197
# [21]	train-error:0.000171	eval-error:0.000193
# [22]	train-error:0.000168	eval-error:0.000186
# [23]	train-error:0.000158	eval-error:0.000179
# [24]	train-error:0.000157	eval-error:0.000179
# [25]	train-error:0.000138	eval-error:0.000165
# [26]	train-error:0.000138	eval-error:0.000165
# [27]	train-error:0.00012	eval-error:0.000145
# [28]	train-error:0.000106	eval-error:0.000131
# [29]	train-error:0.000105	eval-error:0.000125
# [30]	train-error:8.9e-05	eval-error:0.000102
# [31]	train-error:9.1e-05	eval-error:0.000102
# [32]	train-error:7.2e-05	eval-error:7.9e-05
# [33]	train-error:6.4e-05	eval-error:6.6e-05
# [34]	train-error:6.2e-05	eval-error:6.6e-05
# [35]	train-error:5.7e-05	eval-error:5.7e-05
# [36]	train-error:5.1e-05	eval-error:5e-05
# [37]	train-error:4.2e-05	eval-error:4.3e-05
# [38]	train-error:3.7e-05	eval-error:3.9e-05
# [39]	train-error:3.5e-05	eval-error:3.6e-05
# [40]	train-error:3.3e-05	eval-error:3.4e-05
# [41]	train-error:2.9e-05	eval-error:2.7e-05
# [42]	train-error:2.7e-05	eval-error:2.5e-05
# [43]	train-error:2.3e-05	eval-error:2e-05
# [44]	train-error:2.3e-05	eval-error:2e-05
# [45]	train-error:2.2e-05	eval-error:1.8e-05
# [46]	train-error:2.1e-05	eval-error:1.8e-05
# [47]	train-error:2.1e-05	eval-error:1.8e-05
# [48]	train-error:1.9e-05	eval-error:1.8e-05
# [49]	train-error:1.6e-05	eval-error:1.8e-05
# [50]	train-error:1.5e-05	eval-error:1.8e-05
# [51]	train-error:1.5e-05	eval-error:1.8e-05
# [52]	train-error:1.5e-05	eval-error:1.8e-05
# [53]	train-error:1.4e-05	eval-error:1.8e-05
# [54]	train-error:1.4e-05	eval-error:1.8e-05
# [55]	train-error:1.2e-05	eval-error:1.4e-05
# [56]	train-error:1.2e-05	eval-error:1.4e-05
# [57]	train-error:1.1e-05	eval-error:1.4e-05
# [58]	train-error:1.1e-05	eval-error:1.4e-05
# [59]	train-error:1e-05	eval-error:1.1e-05
# [60]	train-error:4e-06	eval-error:7e-06
# [61]	train-error:4e-06	eval-error:7e-06
# [62]	train-error:4e-06	eval-error:7e-06
# [63]	train-error:4e-06	eval-error:7e-06
# [64]	train-error:3e-06	eval-error:7e-06
# [65]	train-error:3e-06	eval-error:7e-06
# [66]	train-error:3e-06	eval-error:7e-06
# [67]	train-error:3e-06	eval-error:7e-06
# [68]	train-error:3e-06	eval-error:7e-06
# [69]	train-error:3e-06	eval-error:7e-06
# [70]	train-error:3e-06	eval-error:7e-06
# [71]	train-error:3e-06	eval-error:7e-06
# [72]	train-error:3e-06	eval-error:7e-06
# [73]	train-error:3e-06	eval-error:7e-06
# [74]	train-error:3e-06	eval-error:7e-06
# [75]	train-error:3e-06	eval-error:7e-06
# [76]	train-error:3e-06	eval-error:7e-06
# [77]	train-error:3e-06	eval-error:7e-06
# [78]	train-error:3e-06	eval-error:7e-06
# [79]	train-error:3e-06	eval-error:7e-06
# [80]	train-error:3e-06	eval-error:7e-06
# Stopping. Best iteration:
# [60]	train-error:4e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0002

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_27_param_tuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_27_param_tuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.001087
# 1  0.001087
# 2  0.001087
# 3  0.001087
# 4  0.001087

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.001087
# 1   1  0.001087
# 2   2  0.001087
# 3   3  0.001087
# 4   4  0.001087

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_27_param_tuning.csv',index=False)

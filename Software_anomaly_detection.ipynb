# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly','Active connections : (MXBean(com.bea:Name=source09,Type=JDBCConnectionPoolRuntime).ActiveConnectionsCurrentCount)',
'Active connections : (MXBean(com.bea:Name=source09,Type=JDBCDataSourceRuntime).ActiveConnectionsCurrentCount)',
'Connection delay : (MXBean(com.bea:Name=source01,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source02,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source03,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source04,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source05,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source06,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source09,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source10,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'DB connection started : (incld/dx (MXBean(com.bea:Name=source09,Type=JDBCDataSourceRuntime).ConnectionsTotalCount))', 
'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)', 
'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))', 
'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
'Last GC duration : (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).LastGcInfo.duration)',
'Last GC duration : (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).LastGcInfo.duration)', 
'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.used / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))', 
])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
'Active connections : (MXBean(com.bea:Name=source09,Type=JDBCConnectionPoolRuntime).ActiveConnectionsCurrentCount)',
'Active connections : (MXBean(com.bea:Name=source09,Type=JDBCDataSourceRuntime).ActiveConnectionsCurrentCount)',
'Connection delay : (MXBean(com.bea:Name=source01,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source02,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source03,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source04,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source05,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source06,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source09,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'Connection delay : (MXBean(com.bea:Name=source10,Type=JDBCConnectionPoolRuntime).ConnectionDelayTime)',
'DB connection started : (incld/dx (MXBean(com.bea:Name=source09,Type=JDBCDataSourceRuntime).ConnectionsTotalCount))', 
'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)', 
'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))', 
'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
'Last GC duration : (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).LastGcInfo.duration)',
'Last GC duration : (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).LastGcInfo.duration)', 
'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.used / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))', 
'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',                                                                                                                
])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly"],axis=1)
test_x=test_df

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.001424	eval-error:0.001559
#
# [1]	train-error:0.001119	eval-error:0.001189
#
# [2]	train-error:0.001107	eval-error:0.001176
#
# [3]	train-error:0.00119	eval-error:0.001285
#
# [4]	train-error:0.001023	eval-error:0.001097
#
# [5]	train-error:0.00089	eval-error:0.000954
#
# [6]	train-error:0.00083	eval-error:0.000924
#
# [7]	train-error:0.000733	eval-error:0.000807
#
# [8]	train-error:0.000728	eval-error:0.000779
#
# [9]	train-error:0.000839	eval-error:0.000888
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 7.600386536969995e-08, 'max_depth': 9, 'min_child_weight': 2.4764558605815354, 'subsample': 0.9}, logloss: 0.1995
# [0]	train-error:0.014099	eval-error:0.014484
#
# [1]	train-error:0.014118	eval-error:0.014507
#
# [2]	train-error:0.006104	eval-error:0.006235
#
# [3]	train-error:0.00606	eval-error:0.006194
#
# [4]	train-error:0.006038	eval-error:0.006171
#
# [5]	train-error:0.00606	eval-error:0.006187
#
# [6]	train-error:0.006056	eval-error:0.006185
#
# [7]	train-error:0.006116	eval-error:0.006235
#
# [8]	train-error:0.006116	eval-error:0.006235
#
# [9]	train-error:0.006115	eval-error:0.006235
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.688811176107944e-05, 'max_depth': 4, 'min_child_weight': 1.9528741952761615, 'subsample': 0.75}, logloss: 0.2153
# [0]	train-error:0.003192	eval-error:0.003344
#
# [1]	train-error:0.002007	eval-error:0.002121
#
# [2]	train-error:0.002125	eval-error:0.002254
#
# [3]	train-error:0.002141	eval-error:0.002272
#
# [4]	train-error:0.002976	eval-error:0.00317
#
# [5]	train-error:0.002966	eval-error:0.003158
#
# [6]	train-error:0.002149	eval-error:0.002286
#
# [7]	train-error:0.002129	eval-error:0.002281
#
# [8]	train-error:0.00211	eval-error:0.00227
#
# [9]	train-error:0.002081	eval-error:0.00222
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.3625793081282279, 'max_depth': 6, 'min_child_weight': 0.6278550113482062, 'subsample': 0.6000000000000001}, logloss: 0.2030
# [0]	train-error:0.001447	eval-error:0.001575
#
# [1]	train-error:0.001163	eval-error:0.001217
#
# [2]	train-error:0.001146	eval-error:0.001198
#
# [3]	train-error:0.001214	eval-error:0.001285
#
# [4]	train-error:0.000995	eval-error:0.001058
#
# [5]	train-error:0.000973	eval-error:0.001006
#
# [6]	train-error:0.000888	eval-error:0.00092
#
# [7]	train-error:0.00083	eval-error:0.00082
#
# [8]	train-error:0.000797	eval-error:0.000804
#
# [9]	train-error:0.000777	eval-error:0.000802
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.011240806012372938, 'max_depth': 9, 'min_child_weight': 0.16367388536507074, 'subsample': 0.6000000000000001}, logloss: 0.1995
# [0]	train-error:0.006057	eval-error:0.006185
#
# [1]	train-error:0.005962	eval-error:0.006113
#
# [2]	train-error:0.00606	eval-error:0.006187
#
# [3]	train-error:0.006058	eval-error:0.006185
#
# [4]	train-error:0.006057	eval-error:0.006185
#
# [5]	train-error:0.006055	eval-error:0.006185
#
# [6]	train-error:0.006056	eval-error:0.006185
#
# [7]	train-error:0.006054	eval-error:0.006183
#
# [8]	train-error:0.006055	eval-error:0.006185
#
# [9]	train-error:0.006056	eval-error:0.006185
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.9586849893455975e-06, 'max_depth': 5, 'min_child_weight': 0.3569264342381845, 'subsample': 0.7000000000000001}, logloss: 0.2077
# [0]	train-error:0.006673	eval-error:0.006862
#
# [1]	train-error:0.006316	eval-error:0.006493
#
# [2]	train-error:0.00631	eval-error:0.006471
#
# [3]	train-error:0.006304	eval-error:0.006466
#
# [4]	train-error:0.014172	eval-error:0.01457
#
# [5]	train-error:0.014161	eval-error:0.014554
#
# [6]	train-error:0.006107	eval-error:0.006237
#
# [7]	train-error:0.006199	eval-error:0.006319
#
# [8]	train-error:0.006195	eval-error:0.006326
#
# [9]	train-error:0.008345	eval-error:0.00855
#
# params: {'colsample_bytree': 0.65, 'gamma': 2.5446537767532497e-08, 'max_depth': 4, 'min_child_weight': 9.685149300708812, 'subsample': 0.65}, logloss: 0.2155
# [0]	train-error:0.006068	eval-error:0.006208
#
# [1]	train-error:0.005977	eval-error:0.006133
#
# [2]	train-error:0.006078	eval-error:0.006219
#
# [3]	train-error:0.006071	eval-error:0.006199
#
# [4]	train-error:0.00607	eval-error:0.006201
#
# [5]	train-error:0.006069	eval-error:0.006201
#
# [6]	train-error:0.006069	eval-error:0.006201
#
# [7]	train-error:0.006069	eval-error:0.006201
#
# [8]	train-error:0.006067	eval-error:0.006201
#
# [9]	train-error:0.00607	eval-error:0.006194
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.3961538472361732, 'max_depth': 5, 'min_child_weight': 5.697110966418202, 'subsample': 0.75}, logloss: 0.2080
# [0]	train-error:0.014112	eval-error:0.014502
#
# [1]	train-error:0.014113	eval-error:0.0145
#
# [2]	train-error:0.006118	eval-error:0.006255
#
# [3]	train-error:0.006074	eval-error:0.006205
#
# [4]	train-error:0.006052	eval-error:0.006192
#
# [5]	train-error:0.014113	eval-error:0.014502
#
# [6]	train-error:0.00607	eval-error:0.006205
#
# [7]	train-error:0.006114	eval-error:0.006244
#
# [8]	train-error:0.006128	eval-error:0.006262
#
# [9]	train-error:0.006114	eval-error:0.006244
#
# params: {'colsample_bytree': 0.9, 'gamma': 8.218662557117017e-08, 'max_depth': 4, 'min_child_weight': 5.337998732921596, 'subsample': 0.8500000000000001}, logloss: 0.2153
# [0]	train-error:0.014161	eval-error:0.01455
#
# [1]	train-error:0.014166	eval-error:0.014554
#
# [2]	train-error:0.014165	eval-error:0.014559
#
# [3]	train-error:0.014165	eval-error:0.014552
#
# [4]	train-error:0.014165	eval-error:0.014552
#
# [5]	train-error:0.014165	eval-error:0.014552
#
# [6]	train-error:0.014161	eval-error:0.014547
#
# [7]	train-error:0.014161	eval-error:0.014545
#
# [8]	train-error:0.014155	eval-error:0.014545
#
# [9]	train-error:0.014161	eval-error:0.014545
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.0614444716399703e-07, 'max_depth': 3, 'min_child_weight': 0.46019256058052493, 'subsample': 0.6000000000000001}, logloss: 0.2231
# [0]	train-error:0.000973	eval-error:0.00102
#
# [1]	train-error:0.000875	eval-error:0.000895
#
# [2]	train-error:0.000905	eval-error:0.00094
#
# [3]	train-error:0.00089	eval-error:0.000931
#
# [4]	train-error:0.000948	eval-error:0.000995
#
# [5]	train-error:0.000801	eval-error:0.000843
#
# [6]	train-error:0.000838	eval-error:0.000877
#
# [7]	train-error:0.000835	eval-error:0.000879
#
# [8]	train-error:0.000824	eval-error:0.000868
#
# [9]	train-error:0.000739	eval-error:0.000784
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.001628451761972185, 'max_depth': 9, 'min_child_weight': 4.720566907390429, 'subsample': 0.7000000000000001}, logloss: 0.1995
# [0]	train-error:0.002889	eval-error:0.002968
#
# [1]	train-error:0.002887	eval-error:0.002972
#
# [2]	train-error:0.002948	eval-error:0.003056
#
# [3]	train-error:0.002943	eval-error:0.003052
#
# [4]	train-error:0.002889	eval-error:0.00302
#
# [5]	train-error:0.002235	eval-error:0.002365
#
# [6]	train-error:0.002241	eval-error:0.002374
#
# [7]	train-error:0.002238	eval-error:0.002363
#
# [8]	train-error:0.00222	eval-error:0.002349
#
# [9]	train-error:0.002201	eval-error:0.002324
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.7456001069216538, 'max_depth': 6, 'min_child_weight': 2.1305770487717703, 'subsample': 0.8500000000000001}, logloss: 0.2032
# [0]	train-error:0.00201	eval-error:0.002164
#
# [1]	train-error:0.001781	eval-error:0.001905
#
# [2]	train-error:0.00191	eval-error:0.002068
#
# [3]	train-error:0.001856	eval-error:0.002003
#
# [4]	train-error:0.001692	eval-error:0.001842
#
# [5]	train-error:0.001564	eval-error:0.001695
#
# [6]	train-error:0.001849	eval-error:0.001998
#
# [7]	train-error:0.001599	eval-error:0.001738
#
# [8]	train-error:0.001609	eval-error:0.001758
#
# [9]	train-error:0.00181	eval-error:0.001946
#
# params: {'colsample_bytree': 0.75, 'gamma': 4.2744153318375095e-05, 'max_depth': 7, 'min_child_weight': 9.738174574987855, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.014197	eval-error:0.014593
#
# [1]	train-error:0.014197	eval-error:0.014593
#
# [2]	train-error:0.014197	eval-error:0.014593
#
# [3]	train-error:0.014186	eval-error:0.014577
#
# [4]	train-error:0.014197	eval-error:0.014593
#
# [5]	train-error:0.014165	eval-error:0.014552
#
# [6]	train-error:0.014181	eval-error:0.014575
#
# [7]	train-error:0.014168	eval-error:0.014554
#
# [8]	train-error:0.014166	eval-error:0.01455
#
# [9]	train-error:0.014164	eval-error:0.014547
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 5.8498303079905845e-08, 'max_depth': 3, 'min_child_weight': 4.549023990766022, 'subsample': 0.75}, logloss: 0.2211
# [0]	train-error:0.014112	eval-error:0.014502
#
# [1]	train-error:0.014131	eval-error:0.014522
#
# [2]	train-error:0.006117	eval-error:0.006255
#
# [3]	train-error:0.006073	eval-error:0.006205
#
# [4]	train-error:0.006052	eval-error:0.006192
#
# [5]	train-error:0.006074	eval-error:0.006208
#
# [6]	train-error:0.00607	eval-error:0.006205
#
# [7]	train-error:0.006128	eval-error:0.006255
#
# [8]	train-error:0.006128	eval-error:0.006255
#
# [9]	train-error:0.006128	eval-error:0.006255
#
# params: {'colsample_bytree': 0.9, 'gamma': 5.847698842691395e-08, 'max_depth': 4, 'min_child_weight': 5.181587018484642, 'subsample': 0.75}, logloss: 0.2153
# [0]	train-error:0.002872	eval-error:0.003013
#
# [1]	train-error:0.002843	eval-error:0.002961
#
# [2]	train-error:0.002924	eval-error:0.003027
#
# [3]	train-error:0.002923	eval-error:0.003025
#
# [4]	train-error:0.002881	eval-error:0.002997
#
# [5]	train-error:0.002884	eval-error:0.003
#
# [6]	train-error:0.002052	eval-error:0.002152
#
# [7]	train-error:0.002069	eval-error:0.002166
#
# [8]	train-error:0.002096	eval-error:0.002198
#
# [9]	train-error:0.002079	eval-error:0.002173
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.1267889144164593e-05, 'max_depth': 6, 'min_child_weight': 6.889664015696112, 'subsample': 0.75}, logloss: 0.2033
# [0]	train-error:0.002969	eval-error:0.003122
#
# [1]	train-error:0.001914	eval-error:0.002019
#
# [2]	train-error:0.002028	eval-error:0.002141
#
# [3]	train-error:0.002056	eval-error:0.002164
#
# [4]	train-error:0.002041	eval-error:0.002152
#
# [5]	train-error:0.002061	eval-error:0.002166
#
# [6]	train-error:0.002125	eval-error:0.002259
#
# [7]	train-error:0.002115	eval-error:0.002259
#
# [8]	train-error:0.002155	eval-error:0.002284
#
# [9]	train-error:0.002179	eval-error:0.0023
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.045739606749326e-06, 'max_depth': 6, 'min_child_weight': 2.883861127584965, 'subsample': 0.7000000000000001}, logloss: 0.2025
# [0]	train-error:0.002007	eval-error:0.002152
#
# [1]	train-error:0.001829	eval-error:0.00196
#
# [2]	train-error:0.001886	eval-error:0.002055
#
# [3]	train-error:0.001837	eval-error:0.001982
#
# [4]	train-error:0.001712	eval-error:0.001862
#
# [5]	train-error:0.001542	eval-error:0.001679
#
# [6]	train-error:0.001907	eval-error:0.002044
#
# [7]	train-error:0.001606	eval-error:0.001738
#
# [8]	train-error:0.001813	eval-error:0.001991
#
# [9]	train-error:0.001593	eval-error:0.001715
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.04333082756578273, 'max_depth': 7, 'min_child_weight': 3.4296845283887847, 'subsample': 0.65}, logloss: 0.2010
# [0]	train-error:0.0065	eval-error:0.006681
#
# [1]	train-error:0.006306	eval-error:0.006466
#
# [2]	train-error:0.006303	eval-error:0.006455
#
# [3]	train-error:0.006307	eval-error:0.006461
#
# [4]	train-error:0.006303	eval-error:0.006455
#
# [5]	train-error:0.006303	eval-error:0.006455
#
# [6]	train-error:0.006295	eval-error:0.006446
#
# [7]	train-error:0.006273	eval-error:0.006418
#
# [8]	train-error:0.00625	eval-error:0.006405
#
# [9]	train-error:0.006227	eval-error:0.006375
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.007735525124952652, 'max_depth': 4, 'min_child_weight': 7.070334594994568, 'subsample': 0.7000000000000001}, logloss: 0.2139
# [0]	train-error:0.000938	eval-error:0.000988
#
# [1]	train-error:0.000684	eval-error:0.000736
#
# [2]	train-error:0.000844	eval-error:0.000886
#
# [3]	train-error:0.0008	eval-error:0.000852
#
# [4]	train-error:0.000936	eval-error:0.000979
#
# [5]	train-error:0.000801	eval-error:0.000852
#
# [6]	train-error:0.000819	eval-error:0.000854
#
# [7]	train-error:0.000822	eval-error:0.000879
#
# [8]	train-error:0.000756	eval-error:0.000816
#
# [9]	train-error:0.000767	eval-error:0.000822
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 8.218390999029176e-06, 'max_depth': 9, 'min_child_weight': 5.345498397014753, 'subsample': 0.9}, logloss: 0.1995
# [0]	train-error:0.001487	eval-error:0.001593
#
# [1]	train-error:0.001254	eval-error:0.001368
#
# [2]	train-error:0.001139	eval-error:0.001226
#
# [3]	train-error:0.001248	eval-error:0.00138
#
# [4]	train-error:0.001355	eval-error:0.001486
#
# [5]	train-error:0.001059	eval-error:0.00114
#
# [6]	train-error:0.001509	eval-error:0.001663
#
# [7]	train-error:0.001262	eval-error:0.001362
#
# [8]	train-error:0.001215	eval-error:0.001348
#
# [9]	train-error:0.000973	eval-error:0.001053
#
# params: {'colsample_bytree': 0.75, 'gamma': 2.0763491793568945e-08, 'max_depth': 8, 'min_child_weight': 5.279945706433671, 'subsample': 0.8}, logloss: 0.2000
# [0]	train-error:0.002127	eval-error:0.002295
#
# [1]	train-error:0.001549	eval-error:0.001706
#
# [2]	train-error:0.001562	eval-error:0.001683
#
# [3]	train-error:0.001461	eval-error:0.001606
#
# [4]	train-error:0.001222	eval-error:0.001332
#
# [5]	train-error:0.00129	eval-error:0.001427
#
# [6]	train-error:0.0011	eval-error:0.001219
#
# [7]	train-error:0.001056	eval-error:0.001165
#
# [8]	train-error:0.000931	eval-error:0.001006
#
# [9]	train-error:0.000892	eval-error:0.000967
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 1.1262863703725135e-06, 'max_depth': 8, 'min_child_weight': 1.297778825812279, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.001805	eval-error:0.001912
#
# [1]	train-error:0.001802	eval-error:0.001914
#
# [2]	train-error:0.001571	eval-error:0.001674
#
# [3]	train-error:0.001568	eval-error:0.001692
#
# [4]	train-error:0.001481	eval-error:0.001606
#
# [5]	train-error:0.001458	eval-error:0.001575
#
# [6]	train-error:0.00145	eval-error:0.001559
#
# [7]	train-error:0.001371	eval-error:0.001486
#
# [8]	train-error:0.001439	eval-error:0.001545
#
# [9]	train-error:0.001447	eval-error:0.001584
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0003897715858143909, 'max_depth': 8, 'min_child_weight': 1.057902752206968, 'subsample': 0.9500000000000001}, logloss: 0.2002
# [0]	train-error:0.001785	eval-error:0.001878
#
# [1]	train-error:0.000815	eval-error:0.000902
#
# [2]	train-error:0.000809	eval-error:0.000856
#
# [3]	train-error:0.000847	eval-error:0.000931
#
# [4]	train-error:0.000827	eval-error:0.000886
#
# [5]	train-error:0.000775	eval-error:0.000811
#
# [6]	train-error:0.000834	eval-error:0.000904
#
# [7]	train-error:0.000706	eval-error:0.000752
#
# [8]	train-error:0.00069	eval-error:0.00073
#
# [9]	train-error:0.00069	eval-error:0.000727
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 4.270730977056317e-06, 'max_depth': 9, 'min_child_weight': 1.6014879098041053, 'subsample': 0.9}, logloss: 0.1995
# [0]	train-error:0.001271	eval-error:0.001398
#
# [1]	train-error:0.001135	eval-error:0.001269
#
# [2]	train-error:0.001081	eval-error:0.001137
#
# [3]	train-error:0.001335	eval-error:0.00147
#
# [4]	train-error:0.001389	eval-error:0.001516
#
# [5]	train-error:0.001171	eval-error:0.001266
#
# [6]	train-error:0.001354	eval-error:0.001479
#
# [7]	train-error:0.00132	eval-error:0.001452
#
# [8]	train-error:0.001165	eval-error:0.001285
#
# [9]	train-error:0.001249	eval-error:0.001371
#
# params: {'colsample_bytree': 0.65, 'gamma': 4.1621367178123407e-07, 'max_depth': 8, 'min_child_weight': 2.931340298999809, 'subsample': 0.9}, logloss: 0.2000
# [0]	train-error:0.001975	eval-error:0.002078
#
# [1]	train-error:0.001985	eval-error:0.002082
#
# [2]	train-error:0.001979	eval-error:0.002084
#
# [3]	train-error:0.001805	eval-error:0.001908
#
# [4]	train-error:0.001748	eval-error:0.001819
#
# [5]	train-error:0.001769	eval-error:0.001874
#
# [6]	train-error:0.001658	eval-error:0.001747
#
# [7]	train-error:0.001613	eval-error:0.001726
#
# [8]	train-error:0.001636	eval-error:0.001724
#
# [9]	train-error:0.001637	eval-error:0.001731
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.00015069992295254248, 'max_depth': 7, 'min_child_weight': 0.6493910044353347, 'subsample': 0.8500000000000001}, logloss: 0.2011
# [0]	train-error:0.001485	eval-error:0.001606
#
# [1]	train-error:0.001195	eval-error:0.001257
#
# [2]	train-error:0.00119	eval-error:0.001251
#
# [3]	train-error:0.001183	eval-error:0.001273
#
# [4]	train-error:0.000958	eval-error:0.001013
#
# [5]	train-error:0.00096	eval-error:0.001017
#
# [6]	train-error:0.000904	eval-error:0.000981
#
# [7]	train-error:0.000781	eval-error:0.000843
#
# [8]	train-error:0.000803	eval-error:0.000847
#
# [9]	train-error:0.000884	eval-error:0.000933
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.0236406587240753e-08, 'max_depth': 9, 'min_child_weight': 9.931405298656832, 'subsample': 0.9500000000000001}, logloss: 0.1996
# [0]	train-error:0.001427	eval-error:0.001538
#
# [1]	train-error:0.001222	eval-error:0.001346
#
# [2]	train-error:0.001053	eval-error:0.001124
#
# [3]	train-error:0.00118	eval-error:0.001285
#
# [4]	train-error:0.001276	eval-error:0.001409
#
# [5]	train-error:0.001011	eval-error:0.001099
#
# [6]	train-error:0.00143	eval-error:0.001556
#
# [7]	train-error:0.001266	eval-error:0.001341
#
# [8]	train-error:0.000979	eval-error:0.00106
#
# [9]	train-error:0.000963	eval-error:0.001033
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 8.50949185209725e-06, 'max_depth': 8, 'min_child_weight': 0.12915273349580775, 'subsample': 0.8}, logloss: 0.2000
# [0]	train-error:0.001425	eval-error:0.001559
#
# [1]	train-error:0.001119	eval-error:0.001189
#
# [2]	train-error:0.001105	eval-error:0.001174
#
# [3]	train-error:0.001199	eval-error:0.001291
#
# [4]	train-error:0.001202	eval-error:0.001298
#
# [5]	train-error:0.000938	eval-error:0.001022
#
# [6]	train-error:0.001007	eval-error:0.001101
#
# [7]	train-error:0.000903	eval-error:0.000992
#
# [8]	train-error:0.000893	eval-error:0.000972
#
# [9]	train-error:0.000859	eval-error:0.000933
#
# params: {'colsample_bytree': 0.8, 'gamma': 2.101220310763147e-07, 'max_depth': 9, 'min_child_weight': 2.3480303220882237, 'subsample': 0.9}, logloss: 0.1995
# [0]	train-error:0.001985	eval-error:0.002084
#
# [1]	train-error:0.001988	eval-error:0.002091
#
# [2]	train-error:0.001994	eval-error:0.002098
#
# [3]	train-error:0.001809	eval-error:0.001912
#
# [4]	train-error:0.001753	eval-error:0.001826
#
# [5]	train-error:0.001778	eval-error:0.00188
#
# [6]	train-error:0.001649	eval-error:0.001738
#
# [7]	train-error:0.001606	eval-error:0.001697
#
# [8]	train-error:0.001633	eval-error:0.001711
#
# [9]	train-error:0.001808	eval-error:0.001901
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.7677021314652652e-05, 'max_depth': 7, 'min_child_weight': 1.616805785609766, 'subsample': 0.8500000000000001}, logloss: 0.2010
# [0]	train-error:0.001071	eval-error:0.001155
#
# [1]	train-error:0.000863	eval-error:0.000904
#
# [2]	train-error:0.00089	eval-error:0.000938
#
# [3]	train-error:0.00084	eval-error:0.000924
#
# [4]	train-error:0.000863	eval-error:0.000936
#
# [5]	train-error:0.000694	eval-error:0.000752
#
# [6]	train-error:0.000795	eval-error:0.000863
#
# [7]	train-error:0.000755	eval-error:0.000818
#
# [8]	train-error:0.000742	eval-error:0.000795
#
# [9]	train-error:0.000717	eval-error:0.000764
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.00017218808641970628, 'max_depth': 9, 'min_child_weight': 0.895064117771771, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.006057	eval-error:0.006185
#
# [1]	train-error:0.005945	eval-error:0.00609
#
# [2]	train-error:0.006059	eval-error:0.006199
#
# [3]	train-error:0.006057	eval-error:0.006192
#
# [4]	train-error:0.006056	eval-error:0.00619
#
# [5]	train-error:0.006054	eval-error:0.00619
#
# [6]	train-error:0.006054	eval-error:0.00619
#
# [7]	train-error:0.006054	eval-error:0.006185
#
# [8]	train-error:0.006055	eval-error:0.006185
#
# [9]	train-error:0.006055	eval-error:0.006185
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0004023731126438107, 'max_depth': 5, 'min_child_weight': 0.24297808745846827, 'subsample': 0.8}, logloss: 0.2080
# [0]	train-error:0.001626	eval-error:0.001711
#
# [1]	train-error:0.001234	eval-error:0.001359
#
# [2]	train-error:0.001039	eval-error:0.001094
#
# [3]	train-error:0.001218	eval-error:0.001328
#
# [4]	train-error:0.001408	eval-error:0.001541
#
# [5]	train-error:0.001193	eval-error:0.001307
#
# [6]	train-error:0.001359	eval-error:0.001495
#
# [7]	train-error:0.001362	eval-error:0.001502
#
# [8]	train-error:0.001177	eval-error:0.00131
#
# [9]	train-error:0.001275	eval-error:0.001409
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.07336483295970518, 'max_depth': 8, 'min_child_weight': 0.7997004345658252, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.001406	eval-error:0.001538
#
# [1]	train-error:0.001118	eval-error:0.001185
#
# [2]	train-error:0.001089	eval-error:0.001167
#
# [3]	train-error:0.001207	eval-error:0.001298
#
# [4]	train-error:0.001205	eval-error:0.001303
#
# [5]	train-error:0.001011	eval-error:0.001076
#
# [6]	train-error:0.001004	eval-error:0.001101
#
# [7]	train-error:0.000967	eval-error:0.001042
#
# [8]	train-error:0.000908	eval-error:0.000981
#
# [9]	train-error:0.000737	eval-error:0.000797
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0013009203811018923, 'max_depth': 9, 'min_child_weight': 0.34633965687658336, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.001979	eval-error:0.002075
#
# [1]	train-error:0.001979	eval-error:0.002073
#
# [2]	train-error:0.001985	eval-error:0.002084
#
# [3]	train-error:0.0018	eval-error:0.001903
#
# [4]	train-error:0.001748	eval-error:0.001817
#
# [5]	train-error:0.001763	eval-error:0.001867
#
# [6]	train-error:0.001647	eval-error:0.001735
#
# [7]	train-error:0.001596	eval-error:0.001701
#
# [8]	train-error:0.001631	eval-error:0.001724
#
# [9]	train-error:0.001636	eval-error:0.001729
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.007226076673263104, 'max_depth': 7, 'min_child_weight': 0.2514246498279767, 'subsample': 0.8500000000000001}, logloss: 0.2011
# [0]	train-error:0.00172	eval-error:0.001785
#
# [1]	train-error:0.000907	eval-error:0.001001
#
# [2]	train-error:0.000802	eval-error:0.000834
#
# [3]	train-error:0.000707	eval-error:0.000795
#
# [4]	train-error:0.000801	eval-error:0.00085
#
# [5]	train-error:0.000687	eval-error:0.000743
#
# [6]	train-error:0.000774	eval-error:0.000838
#
# [7]	train-error:0.000712	eval-error:0.000745
#
# [8]	train-error:0.000702	eval-error:0.000741
#
# [9]	train-error:0.000673	eval-error:0.000709
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0021081976260230338, 'max_depth': 9, 'min_child_weight': 0.3933332652871098, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.001533	eval-error:0.001633
#
# [1]	train-error:0.001227	eval-error:0.001359
#
# [2]	train-error:0.001071	eval-error:0.001133
#
# [3]	train-error:0.001341	eval-error:0.001482
#
# [4]	train-error:0.00118	eval-error:0.00128
#
# [5]	train-error:0.000948	eval-error:0.001006
#
# [6]	train-error:0.001356	eval-error:0.001486
#
# [7]	train-error:0.001203	eval-error:0.001282
#
# [8]	train-error:0.001215	eval-error:0.00131
#
# [9]	train-error:0.000896	eval-error:0.000958
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.06952309876850739, 'max_depth': 8, 'min_child_weight': 0.2238347738060704, 'subsample': 0.8500000000000001}, logloss: 0.2000
# [0]	train-error:0.000914	eval-error:0.001013
#
# [1]	train-error:0.000822	eval-error:0.000886
#
# [2]	train-error:0.000857	eval-error:0.000931
#
# [3]	train-error:0.000937	eval-error:0.00101
#
# [4]	train-error:0.000916	eval-error:0.001001
#
# [5]	train-error:0.00078	eval-error:0.000847
#
# [6]	train-error:0.000841	eval-error:0.000915
#
# [7]	train-error:0.000809	eval-error:0.000865
#
# [8]	train-error:0.000774	eval-error:0.000829
#
# [9]	train-error:0.000737	eval-error:0.000786
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.001462792032464157, 'max_depth': 9, 'min_child_weight': 0.5532369733242276, 'subsample': 0.8}, logloss: 0.1994
# [0]	train-error:0.003228	eval-error:0.003369
#
# [1]	train-error:0.003228	eval-error:0.003367
#
# [2]	train-error:0.003726	eval-error:0.00384
#
# [3]	train-error:0.003842	eval-error:0.003933
#
# [4]	train-error:0.005983	eval-error:0.006144
#
# [5]	train-error:0.00598	eval-error:0.006133
#
# [6]	train-error:0.00596	eval-error:0.006108
#
# [7]	train-error:0.005918	eval-error:0.006074
#
# [8]	train-error:0.006057	eval-error:0.006192
#
# [9]	train-error:0.005998	eval-error:0.006142
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0001224810438667239, 'max_depth': 5, 'min_child_weight': 0.537469874428029, 'subsample': 0.65}, logloss: 0.2071
# [0]	train-error:0.001071	eval-error:0.001155
#
# [1]	train-error:0.000863	eval-error:0.000904
#
# [2]	train-error:0.00089	eval-error:0.000938
#
# [3]	train-error:0.00084	eval-error:0.000924
#
# [4]	train-error:0.000863	eval-error:0.000936
#
# [5]	train-error:0.000694	eval-error:0.000752
#
# [6]	train-error:0.000795	eval-error:0.000863
#
# [7]	train-error:0.000755	eval-error:0.000818
#
# [8]	train-error:0.000742	eval-error:0.000795
#
# [9]	train-error:0.000717	eval-error:0.000764
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.03009985723428629, 'max_depth': 9, 'min_child_weight': 0.8759230373801739, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.001988	eval-error:0.002134
#
# [1]	train-error:0.001762	eval-error:0.001885
#
# [2]	train-error:0.001831	eval-error:0.001989
#
# [3]	train-error:0.001776	eval-error:0.001917
#
# [4]	train-error:0.001822	eval-error:0.001976
#
# [5]	train-error:0.001525	eval-error:0.001665
#
# [6]	train-error:0.00179	eval-error:0.001944
#
# [7]	train-error:0.001581	eval-error:0.00172
#
# [8]	train-error:0.001594	eval-error:0.001733
#
# [9]	train-error:0.001552	eval-error:0.001679
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.16135176786517988, 'max_depth': 7, 'min_child_weight': 0.6771837537301058, 'subsample': 0.75}, logloss: 0.2009
# [0]	train-error:0.001422	eval-error:0.001532
#
# [1]	train-error:0.001223	eval-error:0.001343
#
# [2]	train-error:0.001101	eval-error:0.001192
#
# [3]	train-error:0.001219	eval-error:0.00135
#
# [4]	train-error:0.001322	eval-error:0.001461
#
# [5]	train-error:0.001003	eval-error:0.001115
#
# [6]	train-error:0.001541	eval-error:0.001667
#
# [7]	train-error:0.001291	eval-error:0.00138
#
# [8]	train-error:0.001259	eval-error:0.001355
#
# [9]	train-error:0.000992	eval-error:0.001053
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.018290667367048253, 'max_depth': 8, 'min_child_weight': 0.16132461420179373, 'subsample': 0.75}, logloss: 0.2000
# [0]	train-error:0.001084	eval-error:0.001158
#
# [1]	train-error:0.000869	eval-error:0.000922
#
# [2]	train-error:0.000861	eval-error:0.00089
#
# [3]	train-error:0.000877	eval-error:0.000952
#
# [4]	train-error:0.000875	eval-error:0.000942
#
# [5]	train-error:0.000782	eval-error:0.000827
#
# [6]	train-error:0.000857	eval-error:0.000922
#
# [7]	train-error:0.000824	eval-error:0.000875
#
# [8]	train-error:0.000739	eval-error:0.000791
#
# [9]	train-error:0.00072	eval-error:0.000761
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.9877099227562275, 'max_depth': 9, 'min_child_weight': 1.295651602831969, 'subsample': 0.7000000000000001}, logloss: 0.1995
# [0]	train-error:0.006058	eval-error:0.006192
#
# [1]	train-error:0.005963	eval-error:0.006117
#
# [2]	train-error:0.006058	eval-error:0.006192
#
# [3]	train-error:0.006059	eval-error:0.00619
#
# [4]	train-error:0.006057	eval-error:0.006185
#
# [5]	train-error:0.006056	eval-error:0.006185
#
# [6]	train-error:0.006054	eval-error:0.006183
#
# [7]	train-error:0.006054	eval-error:0.006183
#
# [8]	train-error:0.006054	eval-error:0.006183
#
# [9]	train-error:0.006054	eval-error:0.006183
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.003205796791353408, 'max_depth': 5, 'min_child_weight': 0.30475215345483997, 'subsample': 0.65}, logloss: 0.2075
# [0]	train-error:0.001427	eval-error:0.001538
#
# [1]	train-error:0.001222	eval-error:0.001346
#
# [2]	train-error:0.001053	eval-error:0.001124
#
# [3]	train-error:0.00118	eval-error:0.001285
#
# [4]	train-error:0.001276	eval-error:0.001409
#
# [5]	train-error:0.001011	eval-error:0.001099
#
# [6]	train-error:0.00143	eval-error:0.001556
#
# [7]	train-error:0.001267	eval-error:0.001341
#
# [8]	train-error:0.000979	eval-error:0.00106
#
# [9]	train-error:0.000963	eval-error:0.001033
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.34980368939971723, 'max_depth': 8, 'min_child_weight': 0.1050431448354598, 'subsample': 0.8}, logloss: 0.2000
# [0]	train-error:0.003014	eval-error:0.003165
#
# [1]	train-error:0.001951	eval-error:0.002057
#
# [2]	train-error:0.002069	eval-error:0.002182
#
# [3]	train-error:0.002093	eval-error:0.002204
#
# [4]	train-error:0.002124	eval-error:0.002238
#
# [5]	train-error:0.002146	eval-error:0.002257
#
# [6]	train-error:0.002185	eval-error:0.002322
#
# [7]	train-error:0.002206	eval-error:0.002356
#
# [8]	train-error:0.002244	eval-error:0.00237
#
# [9]	train-error:0.002216	eval-error:0.002343
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.01942786275184518, 'max_depth': 6, 'min_child_weight': 0.5651729098910747, 'subsample': 0.7000000000000001}, logloss: 0.2026
# [0]	train-error:0.014171	eval-error:0.014554
#
# [1]	train-error:0.014184	eval-error:0.014561
#
# [2]	train-error:0.014182	eval-error:0.014559
#
# [3]	train-error:0.014174	eval-error:0.014547
#
# [4]	train-error:0.014183	eval-error:0.014568
#
# [5]	train-error:0.014166	eval-error:0.014541
#
# [6]	train-error:0.014173	eval-error:0.014545
#
# [7]	train-error:0.014165	eval-error:0.014538
#
# [8]	train-error:0.014164	eval-error:0.014536
#
# [9]	train-error:0.014162	eval-error:0.014541
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.0007293095971038096, 'max_depth': 3, 'min_child_weight': 0.47881667356670043, 'subsample': 0.75}, logloss: 0.2213
# [0]	train-error:0.002152	eval-error:0.002281
#
# [1]	train-error:0.001819	eval-error:0.001946
#
# [2]	train-error:0.001826	eval-error:0.001987
#
# [3]	train-error:0.001729	eval-error:0.001887
#
# [4]	train-error:0.001734	eval-error:0.001894
#
# [5]	train-error:0.00176	eval-error:0.001921
#
# [6]	train-error:0.001749	eval-error:0.00188
#
# [7]	train-error:0.001718	eval-error:0.001856
#
# [8]	train-error:0.00185	eval-error:0.001978
#
# [9]	train-error:0.001818	eval-error:0.001967
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.003962857392667278, 'max_depth': 7, 'min_child_weight': 1.8284185021653565, 'subsample': 0.8500000000000001}, logloss: 0.2010
# [0]	train-error:0.000922	eval-error:0.00102
#
# [1]	train-error:0.00091	eval-error:0.000967
#
# [2]	train-error:0.000868	eval-error:0.000931
#
# [3]	train-error:0.000955	eval-error:0.001024
#
# [4]	train-error:0.000959	eval-error:0.001035
#
# [5]	train-error:0.000828	eval-error:0.000884
#
# [6]	train-error:0.000941	eval-error:0.00097
#
# [7]	train-error:0.000888	eval-error:0.00092
#
# [8]	train-error:0.000806	eval-error:0.000822
#
# [9]	train-error:0.000747	eval-error:0.000766
#
# params: {'colsample_bytree': 0.75, 'gamma': 6.164653529306847e-05, 'max_depth': 9, 'min_child_weight': 1.1020149398748111, 'subsample': 0.6000000000000001}, logloss: 0.1995
# [0]	train-error:0.00301	eval-error:0.003172
#
# [1]	train-error:0.001945	eval-error:0.002057
#
# [2]	train-error:0.002075	eval-error:0.002204
#
# [3]	train-error:0.002105	eval-error:0.002232
#
# [4]	train-error:0.002991	eval-error:0.003179
#
# [5]	train-error:0.002991	eval-error:0.003183
#
# [6]	train-error:0.002213	eval-error:0.002347
#
# [7]	train-error:0.002298	eval-error:0.002456
#
# [8]	train-error:0.002268	eval-error:0.002415
#
# [9]	train-error:0.002245	eval-error:0.002379
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.03192429340226949, 'max_depth': 6, 'min_child_weight': 0.17748880686676174, 'subsample': 0.75}, logloss: 0.2027
# [0]	train-error:0.001814	eval-error:0.001919
#
# [1]	train-error:0.001788	eval-error:0.00188
#
# [2]	train-error:0.0016	eval-error:0.00169
#
# [3]	train-error:0.001674	eval-error:0.001763
#
# [4]	train-error:0.00151	eval-error:0.001624
#
# [5]	train-error:0.001594	eval-error:0.001686
#
# [6]	train-error:0.001533	eval-error:0.001629
#
# [7]	train-error:0.001485	eval-error:0.001602
#
# [8]	train-error:0.001453	eval-error:0.001554
#
# [9]	train-error:0.001247	eval-error:0.001332
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.3036757559417148, 'max_depth': 8, 'min_child_weight': 0.7862276018389476, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.00203	eval-error:0.002127
#
# [1]	train-error:0.002002	eval-error:0.002093
#
# [2]	train-error:0.001987	eval-error:0.002087
#
# [3]	train-error:0.001933	eval-error:0.002025
#
# [4]	train-error:0.001899	eval-error:0.001976
#
# [5]	train-error:0.001653	eval-error:0.001738
#
# [6]	train-error:0.001697	eval-error:0.001788
#
# [7]	train-error:0.001616	eval-error:0.001708
#
# [8]	train-error:0.001655	eval-error:0.001745
#
# [9]	train-error:0.001646	eval-error:0.001729
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.14908760505346444, 'max_depth': 7, 'min_child_weight': 0.41956951666689873, 'subsample': 0.7000000000000001}, logloss: 0.2011
# [0]	train-error:0.003214	eval-error:0.003351
#
# [1]	train-error:0.003207	eval-error:0.003346
#
# [2]	train-error:0.003684	eval-error:0.003813
#
# [3]	train-error:0.003938	eval-error:0.004026
#
# [4]	train-error:0.005938	eval-error:0.006119
#
# [5]	train-error:0.006066	eval-error:0.006208
#
# [6]	train-error:0.005952	eval-error:0.006104
#
# [7]	train-error:0.006024	eval-error:0.006162
#
# [8]	train-error:0.005975	eval-error:0.006144
#
# [9]	train-error:0.006029	eval-error:0.006169
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.0008419696242896033, 'max_depth': 5, 'min_child_weight': 0.3057167260673032, 'subsample': 0.8500000000000001}, logloss: 0.2070
# [0]	train-error:0.001422	eval-error:0.001552
#
# [1]	train-error:0.001116	eval-error:0.001158
#
# [2]	train-error:0.001078	eval-error:0.001144
#
# [3]	train-error:0.001191	eval-error:0.001273
#
# [4]	train-error:0.000983	eval-error:0.001015
#
# [5]	train-error:0.000978	eval-error:0.001013
#
# [6]	train-error:0.000927	eval-error:0.000999
#
# [7]	train-error:0.000824	eval-error:0.000861
#
# [8]	train-error:0.000812	eval-error:0.000859
#
# [9]	train-error:0.00082	eval-error:0.000836
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.5637681968048793e-05, 'max_depth': 9, 'min_child_weight': 1.401012175667641, 'subsample': 0.75}, logloss: 0.1995
# [0]	train-error:0.007233	eval-error:0.007259
#
# [1]	train-error:0.006245	eval-error:0.006378
#
# [2]	train-error:0.006283	eval-error:0.006418
#
# [3]	train-error:0.014166	eval-error:0.014543
#
# [4]	train-error:0.006267	eval-error:0.006407
#
# [5]	train-error:0.00626	eval-error:0.006391
#
# [6]	train-error:0.006252	eval-error:0.006387
#
# [7]	train-error:0.006227	eval-error:0.006362
#
# [8]	train-error:0.006233	eval-error:0.006373
#
# [9]	train-error:0.006214	eval-error:0.006357
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.004911615758284411, 'max_depth': 4, 'min_child_weight': 0.19506203085738835, 'subsample': 0.65}, logloss: 0.2141
# [0]	train-error:0.001382	eval-error:0.001507
#
# [1]	train-error:0.001246	eval-error:0.001366
#
# [2]	train-error:0.001116	eval-error:0.001176
#
# [3]	train-error:0.00135	eval-error:0.001473
#
# [4]	train-error:0.001297	eval-error:0.001414
#
# [5]	train-error:0.001028	eval-error:0.001099
#
# [6]	train-error:0.001467	eval-error:0.001604
#
# [7]	train-error:0.00121	eval-error:0.001305
#
# [8]	train-error:0.000936	eval-error:0.001029
#
# [9]	train-error:0.000912	eval-error:0.001006
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0003298253987342199, 'max_depth': 8, 'min_child_weight': 3.941537429921618, 'subsample': 0.9}, logloss: 0.1999
# [0]	train-error:0.000891	eval-error:0.000979
#
# [1]	train-error:0.000686	eval-error:0.000784
#
# [2]	train-error:0.000831	eval-error:0.000895
#
# [3]	train-error:0.000794	eval-error:0.000895
#
# [4]	train-error:0.000939	eval-error:0.001024
#
# [5]	train-error:0.000748	eval-error:0.000786
#
# [6]	train-error:0.00081	eval-error:0.000856
#
# [7]	train-error:0.000783	eval-error:0.000813
#
# [8]	train-error:0.000656	eval-error:0.000691
#
# [9]	train-error:0.000711	eval-error:0.000732
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.7323721092200217, 'max_depth': 9, 'min_child_weight': 1.0227801802896475, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.002013	eval-error:0.002157
#
# [1]	train-error:0.001788	eval-error:0.00191
#
# [2]	train-error:0.001918	eval-error:0.002075
#
# [3]	train-error:0.001871	eval-error:0.002007
#
# [4]	train-error:0.001699	eval-error:0.00184
#
# [5]	train-error:0.001559	eval-error:0.00169
#
# [6]	train-error:0.001851	eval-error:0.001989
#
# [7]	train-error:0.001614	eval-error:0.001745
#
# [8]	train-error:0.00164	eval-error:0.001783
#
# [9]	train-error:0.001536	eval-error:0.001665
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.5395850457516973, 'max_depth': 7, 'min_child_weight': 7.517427778217446, 'subsample': 0.9500000000000001}, logloss: 0.2009
# [0]	train-error:0.002901	eval-error:0.003004
#
# [1]	train-error:0.002841	eval-error:0.002914
#
# [2]	train-error:0.002899	eval-error:0.003002
#
# [3]	train-error:0.002898	eval-error:0.002997
#
# [4]	train-error:0.002871	eval-error:0.002993
#
# [5]	train-error:0.002855	eval-error:0.002975
#
# [6]	train-error:0.00205	eval-error:0.002152
#
# [7]	train-error:0.002047	eval-error:0.002152
#
# [8]	train-error:0.002086	eval-error:0.002202
#
# [9]	train-error:0.002062	eval-error:0.002168
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.01261557448505387, 'max_depth': 6, 'min_child_weight': 2.90171139430512, 'subsample': 0.9500000000000001}, logloss: 0.2033
# [0]	train-error:0.014198	eval-error:0.014595
#
# [1]	train-error:0.014198	eval-error:0.014595
#
# [2]	train-error:0.014195	eval-error:0.014593
#
# [3]	train-error:0.014188	eval-error:0.014586
#
# [4]	train-error:0.014228	eval-error:0.014624
#
# [5]	train-error:0.014165	eval-error:0.014552
#
# [6]	train-error:0.01418	eval-error:0.014575
#
# [7]	train-error:0.014167	eval-error:0.014552
#
# [8]	train-error:0.01416	eval-error:0.014538
#
# [9]	train-error:0.014165	eval-error:0.014552
#
# params: {'colsample_bytree': 0.75, 'gamma': 3.7210033161885836e-06, 'max_depth': 3, 'min_child_weight': 2.030874861279743, 'subsample': 0.6000000000000001}, logloss: 0.2211
# [0]	train-error:0.00181	eval-error:0.001919
#
# [1]	train-error:0.001804	eval-error:0.001917
#
# [2]	train-error:0.001572	eval-error:0.001681
#
# [3]	train-error:0.001621	eval-error:0.00174
#
# [4]	train-error:0.001492	eval-error:0.00162
#
# [5]	train-error:0.001473	eval-error:0.0016
#
# [6]	train-error:0.001531	eval-error:0.001629
#
# [7]	train-error:0.001443	eval-error:0.001556
#
# [8]	train-error:0.001293	eval-error:0.001389
#
# [9]	train-error:0.001256	eval-error:0.001366
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.7223908218903476e-05, 'max_depth': 8, 'min_child_weight': 1.046864797759807, 'subsample': 0.9}, logloss: 0.2001
# [0]	train-error:0.014097	eval-error:0.014486
#
# [1]	train-error:0.014096	eval-error:0.014484
#
# [2]	train-error:0.006098	eval-error:0.006221
#
# [3]	train-error:0.006057	eval-error:0.006185
#
# [4]	train-error:0.006036	eval-error:0.006169
#
# [5]	train-error:0.014097	eval-error:0.014479
#
# [6]	train-error:0.006071	eval-error:0.006205
#
# [7]	train-error:0.006122	eval-error:0.006248
#
# [8]	train-error:0.006098	eval-error:0.006221
#
# [9]	train-error:0.006113	eval-error:0.006239
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.1730200246125145, 'max_depth': 4, 'min_child_weight': 0.1368368400020984, 'subsample': 0.9500000000000001}, logloss: 0.2153
# [0]	train-error:0.001417	eval-error:0.001545
#
# [1]	train-error:0.001115	eval-error:0.001201
#
# [2]	train-error:0.001093	eval-error:0.001167
#
# [3]	train-error:0.001201	eval-error:0.001289
#
# [4]	train-error:0.000982	eval-error:0.001063
#
# [5]	train-error:0.000868	eval-error:0.000933
#
# [6]	train-error:0.000867	eval-error:0.000945
#
# [7]	train-error:0.00072	eval-error:0.00075
#
# [8]	train-error:0.000708	eval-error:0.000736
#
# [9]	train-error:0.000745	eval-error:0.000791
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.8921733665388465, 'max_depth': 9, 'min_child_weight': 1.216450277659466, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.001978	eval-error:0.002087
#
# [1]	train-error:0.00198	eval-error:0.002087
#
# [2]	train-error:0.001992	eval-error:0.002105
#
# [3]	train-error:0.0018	eval-error:0.001912
#
# [4]	train-error:0.001771	eval-error:0.001851
#
# [5]	train-error:0.001662	eval-error:0.001749
#
# [6]	train-error:0.001683	eval-error:0.001765
#
# [7]	train-error:0.001627	eval-error:0.001722
#
# [8]	train-error:0.001649	eval-error:0.001742
#
# [9]	train-error:0.001615	eval-error:0.001713
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0760448398696967, 'max_depth': 7, 'min_child_weight': 2.51927547151001, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.001831	eval-error:0.001933
#
# [1]	train-error:0.001823	eval-error:0.001933
#
# [2]	train-error:0.001589	eval-error:0.001695
#
# [3]	train-error:0.001663	eval-error:0.001778
#
# [4]	train-error:0.001466	eval-error:0.001606
#
# [5]	train-error:0.001499	eval-error:0.001618
#
# [6]	train-error:0.001517	eval-error:0.001618
#
# [7]	train-error:0.001431	eval-error:0.001541
#
# [8]	train-error:0.001241	eval-error:0.001343
#
# [9]	train-error:0.001245	eval-error:0.001346
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.5657992270581577, 'max_depth': 8, 'min_child_weight': 4.054289508096984, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.001417	eval-error:0.001545
#
# [1]	train-error:0.001115	eval-error:0.001201
#
# [2]	train-error:0.001093	eval-error:0.001167
#
# [3]	train-error:0.001201	eval-error:0.001289
#
# [4]	train-error:0.000981	eval-error:0.001063
#
# [5]	train-error:0.000868	eval-error:0.000933
#
# [6]	train-error:0.000867	eval-error:0.000945
#
# [7]	train-error:0.000721	eval-error:0.00075
#
# [8]	train-error:0.000709	eval-error:0.000734
#
# [9]	train-error:0.000745	eval-error:0.000788
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.9392049927380531, 'max_depth': 9, 'min_child_weight': 1.1908966266466687, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.001424	eval-error:0.001556
#
# [1]	train-error:0.001119	eval-error:0.001201
#
# [2]	train-error:0.001094	eval-error:0.001171
#
# [3]	train-error:0.001203	eval-error:0.001296
#
# [4]	train-error:0.000986	eval-error:0.001072
#
# [5]	train-error:0.000871	eval-error:0.000938
#
# [6]	train-error:0.000869	eval-error:0.000947
#
# [7]	train-error:0.000702	eval-error:0.000736
#
# [8]	train-error:0.00071	eval-error:0.000739
#
# [9]	train-error:0.000749	eval-error:0.000793
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.7425174674298086, 'max_depth': 9, 'min_child_weight': 1.684267402291826, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.001406	eval-error:0.001541
#
# [1]	train-error:0.001108	eval-error:0.001187
#
# [2]	train-error:0.001091	eval-error:0.001165
#
# [3]	train-error:0.001176	eval-error:0.001269
#
# [4]	train-error:0.001035	eval-error:0.001117
#
# [5]	train-error:0.000952	eval-error:0.001051
#
# [6]	train-error:0.000838	eval-error:0.000931
#
# [7]	train-error:0.000721	eval-error:0.000779
#
# [8]	train-error:0.000727	eval-error:0.000779
#
# [9]	train-error:0.000713	eval-error:0.000732
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.2611303166467186, 'max_depth': 9, 'min_child_weight': 1.1985523017503368, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001409	eval-error:0.001532
#
# [1]	train-error:0.001109	eval-error:0.001189
#
# [2]	train-error:0.001092	eval-error:0.001167
#
# [3]	train-error:0.001199	eval-error:0.001287
#
# [4]	train-error:0.000982	eval-error:0.001065
#
# [5]	train-error:0.00092	eval-error:0.001022
#
# [6]	train-error:0.000921	eval-error:0.001031
#
# [7]	train-error:0.000702	eval-error:0.000752
#
# [8]	train-error:0.000713	eval-error:0.000754
#
# [9]	train-error:0.000733	eval-error:0.000791
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.22178665069753367, 'max_depth': 9, 'min_child_weight': 1.4649714420099618, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001817	eval-error:0.001919
#
# [1]	train-error:0.001812	eval-error:0.001914
#
# [2]	train-error:0.001581	eval-error:0.001686
#
# [3]	train-error:0.001632	eval-error:0.001754
#
# [4]	train-error:0.001442	eval-error:0.001581
#
# [5]	train-error:0.001554	eval-error:0.001654
#
# [6]	train-error:0.001502	eval-error:0.001597
#
# [7]	train-error:0.00132	eval-error:0.001402
#
# [8]	train-error:0.001319	eval-error:0.0014
#
# [9]	train-error:0.001226	eval-error:0.00131
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.11695584445764878, 'max_depth': 8, 'min_child_weight': 2.4243175028091244, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.001412	eval-error:0.001536
#
# [1]	train-error:0.001115	eval-error:0.001198
#
# [2]	train-error:0.001094	eval-error:0.001176
#
# [3]	train-error:0.001178	eval-error:0.001273
#
# [4]	train-error:0.001041	eval-error:0.001119
#
# [5]	train-error:0.00096	eval-error:0.001058
#
# [6]	train-error:0.000847	eval-error:0.000936
#
# [7]	train-error:0.00073	eval-error:0.000782
#
# [8]	train-error:0.000712	eval-error:0.000761
#
# [9]	train-error:0.000714	eval-error:0.000732
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.2521491267845166, 'max_depth': 9, 'min_child_weight': 1.5074814786096509, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001427	eval-error:0.001556
#
# [1]	train-error:0.001118	eval-error:0.001201
#
# [2]	train-error:0.001108	eval-error:0.001185
#
# [3]	train-error:0.001186	eval-error:0.001291
#
# [4]	train-error:0.000989	eval-error:0.001042
#
# [5]	train-error:0.000919	eval-error:0.000995
#
# [6]	train-error:0.000795	eval-error:0.000856
#
# [7]	train-error:0.000717	eval-error:0.000766
#
# [8]	train-error:0.000719	eval-error:0.000764
#
# [9]	train-error:0.000706	eval-error:0.000736
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00996060310793052, 'max_depth': 9, 'min_child_weight': 3.2739899207188996, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001868	eval-error:0.001957
#
# [1]	train-error:0.001873	eval-error:0.00196
#
# [2]	train-error:0.001638	eval-error:0.001726
#
# [3]	train-error:0.001608	eval-error:0.001724
#
# [4]	train-error:0.00147	eval-error:0.001606
#
# [5]	train-error:0.001496	eval-error:0.001613
#
# [6]	train-error:0.001518	eval-error:0.001613
#
# [7]	train-error:0.001412	eval-error:0.001518
#
# [8]	train-error:0.001414	eval-error:0.001518
#
# [9]	train-error:0.001263	eval-error:0.001373
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.05516871385093954, 'max_depth': 8, 'min_child_weight': 8.566825713733898, 'subsample': 0.9500000000000001}, logloss: 0.2002
# [0]	train-error:0.001426	eval-error:0.001561
#
# [1]	train-error:0.001117	eval-error:0.001205
#
# [2]	train-error:0.001109	eval-error:0.001185
#
# [3]	train-error:0.001189	eval-error:0.001296
#
# [4]	train-error:0.000967	eval-error:0.001015
#
# [5]	train-error:0.000896	eval-error:0.000967
#
# [6]	train-error:0.000844	eval-error:0.000933
#
# [7]	train-error:0.000738	eval-error:0.000809
#
# [8]	train-error:0.000734	eval-error:0.000802
#
# [9]	train-error:0.000853	eval-error:0.000911
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.009043066123630285, 'max_depth': 9, 'min_child_weight': 3.1463739403601854, 'subsample': 0.9500000000000001}, logloss: 0.1995
# [0]	train-error:0.001832	eval-error:0.001937
#
# [1]	train-error:0.001819	eval-error:0.001921
#
# [2]	train-error:0.001588	eval-error:0.00169
#
# [3]	train-error:0.001655	eval-error:0.001769
#
# [4]	train-error:0.001534	eval-error:0.001656
#
# [5]	train-error:0.001508	eval-error:0.001633
#
# [6]	train-error:0.00151	eval-error:0.001606
#
# [7]	train-error:0.001325	eval-error:0.001418
#
# [8]	train-error:0.00127	eval-error:0.001357
#
# [9]	train-error:0.001225	eval-error:0.001287
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.017432669530908468, 'max_depth': 8, 'min_child_weight': 3.713063375573313, 'subsample': 0.9}, logloss: 0.2001
# [0]	train-error:0.001441	eval-error:0.00157
#
# [1]	train-error:0.001131	eval-error:0.001214
#
# [2]	train-error:0.001114	eval-error:0.001189
#
# [3]	train-error:0.001216	eval-error:0.001314
#
# [4]	train-error:0.000998	eval-error:0.001042
#
# [5]	train-error:0.000919	eval-error:0.00099
#
# [6]	train-error:0.000799	eval-error:0.000863
#
# [7]	train-error:0.000772	eval-error:0.000813
#
# [8]	train-error:0.000752	eval-error:0.000782
#
# [9]	train-error:0.000711	eval-error:0.000739
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.08285040082994058, 'max_depth': 9, 'min_child_weight': 4.635766991397877, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001478	eval-error:0.001588
#
# [1]	train-error:0.001161	eval-error:0.001212
#
# [2]	train-error:0.001139	eval-error:0.001196
#
# [3]	train-error:0.001253	eval-error:0.001337
#
# [4]	train-error:0.001245	eval-error:0.001334
#
# [5]	train-error:0.001048	eval-error:0.001099
#
# [6]	train-error:0.00104	eval-error:0.001128
#
# [7]	train-error:0.001032	eval-error:0.001074
#
# [8]	train-error:0.000961	eval-error:0.00101
#
# [9]	train-error:0.00076	eval-error:0.000818
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.037080568923909145, 'max_depth': 9, 'min_child_weight': 6.508069070027436, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.001823	eval-error:0.00193
#
# [1]	train-error:0.001812	eval-error:0.001919
#
# [2]	train-error:0.001578	eval-error:0.001683
#
# [3]	train-error:0.00163	eval-error:0.001747
#
# [4]	train-error:0.001495	eval-error:0.00162
#
# [5]	train-error:0.001479	eval-error:0.001604
#
# [6]	train-error:0.00154	eval-error:0.001633
#
# [7]	train-error:0.001452	eval-error:0.001566
#
# [8]	train-error:0.001298	eval-error:0.001396
#
# [9]	train-error:0.001256	eval-error:0.001362
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.4889404792106761, 'max_depth': 8, 'min_child_weight': 2.14446891265698, 'subsample': 0.9}, logloss: 0.2001
# [0]	train-error:0.001399	eval-error:0.001534
#
# [1]	train-error:0.001104	eval-error:0.001192
#
# [2]	train-error:0.001083	eval-error:0.001167
#
# [3]	train-error:0.001171	eval-error:0.001266
#
# [4]	train-error:0.001032	eval-error:0.001126
#
# [5]	train-error:0.000951	eval-error:0.001056
#
# [6]	train-error:0.000836	eval-error:0.000929
#
# [7]	train-error:0.000723	eval-error:0.00077
#
# [8]	train-error:0.000727	eval-error:0.000773
#
# [9]	train-error:0.00071	eval-error:0.00073
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.002733815333321541, 'max_depth': 9, 'min_child_weight': 0.6867095886745148, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.001971	eval-error:0.00208
#
# [1]	train-error:0.001979	eval-error:0.002084
#
# [2]	train-error:0.001977	eval-error:0.002084
#
# [3]	train-error:0.001802	eval-error:0.001908
#
# [4]	train-error:0.001743	eval-error:0.001819
#
# [5]	train-error:0.001726	eval-error:0.001812
#
# [6]	train-error:0.001728	eval-error:0.001815
#
# [7]	train-error:0.001617	eval-error:0.001722
#
# [8]	train-error:0.001603	eval-error:0.001704
#
# [9]	train-error:0.001598	eval-error:0.001695
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.002237887124427991, 'max_depth': 7, 'min_child_weight': 0.7281999692102558, 'subsample': 0.9}, logloss: 0.2011
# [0]	train-error:0.001809	eval-error:0.00193
#
# [1]	train-error:0.001809	eval-error:0.001933
#
# [2]	train-error:0.001575	eval-error:0.00169
#
# [3]	train-error:0.001639	eval-error:0.001758
#
# [4]	train-error:0.001519	eval-error:0.001652
#
# [5]	train-error:0.001541	eval-error:0.001654
#
# [6]	train-error:0.001483	eval-error:0.001597
#
# [7]	train-error:0.001235	eval-error:0.001339
#
# [8]	train-error:0.001222	eval-error:0.00133
#
# [9]	train-error:0.001205	eval-error:0.001305
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0008089414036723189, 'max_depth': 8, 'min_child_weight': 0.4819406204525138, 'subsample': 0.9500000000000001}, logloss: 0.2000
# [0]	train-error:0.001413	eval-error:0.001547
#
# [1]	train-error:0.001127	eval-error:0.001205
#
# [2]	train-error:0.001096	eval-error:0.001167
#
# [3]	train-error:0.001189	eval-error:0.001273
#
# [4]	train-error:0.001035	eval-error:0.001117
#
# [5]	train-error:0.001026	eval-error:0.001099
#
# [6]	train-error:0.000835	eval-error:0.000931
#
# [7]	train-error:0.000812	eval-error:0.000865
#
# [8]	train-error:0.000746	eval-error:0.000773
#
# [9]	train-error:0.000828	eval-error:0.000856
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00025214855067116004, 'max_depth': 9, 'min_child_weight': 0.8576167177911127, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.00136	eval-error:0.001473
#
# [1]	train-error:0.001214	eval-error:0.001343
#
# [2]	train-error:0.00106	eval-error:0.001171
#
# [3]	train-error:0.001433	eval-error:0.001597
#
# [4]	train-error:0.001302	eval-error:0.00145
#
# [5]	train-error:0.000998	eval-error:0.001065
#
# [6]	train-error:0.001465	eval-error:0.001609
#
# [7]	train-error:0.001356	eval-error:0.001507
#
# [8]	train-error:0.001183	eval-error:0.001312
#
# [9]	train-error:0.000913	eval-error:0.001001
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0047615414532391044, 'max_depth': 8, 'min_child_weight': 0.6177370279263724, 'subsample': 0.9}, logloss: 0.1999
# [0]	train-error:0.002896	eval-error:0.003004
#
# [1]	train-error:0.002889	eval-error:0.002968
#
# [2]	train-error:0.002948	eval-error:0.003047
#
# [3]	train-error:0.002947	eval-error:0.003045
#
# [4]	train-error:0.002918	eval-error:0.003038
#
# [5]	train-error:0.002904	eval-error:0.003018
#
# [6]	train-error:0.002098	eval-error:0.002198
#
# [7]	train-error:0.002098	eval-error:0.002198
#
# [8]	train-error:0.002132	eval-error:0.002238
#
# [9]	train-error:0.002078	eval-error:0.002182
#
# params: {'colsample_bytree': 0.8, 'gamma': 7.5112140659245e-05, 'max_depth': 6, 'min_child_weight': 0.709940632857837, 'subsample': 0.9500000000000001}, logloss: 0.2034
# [0]	train-error:0.001413	eval-error:0.001547
#
# [1]	train-error:0.001127	eval-error:0.001205
#
# [2]	train-error:0.001096	eval-error:0.001167
#
# [3]	train-error:0.001189	eval-error:0.001273
#
# [4]	train-error:0.001035	eval-error:0.001117
#
# [5]	train-error:0.001026	eval-error:0.001099
#
# [6]	train-error:0.000835	eval-error:0.000929
#
# [7]	train-error:0.000812	eval-error:0.000865
#
# [8]	train-error:0.000746	eval-error:0.000773
#
# [9]	train-error:0.00083	eval-error:0.000856
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.0005884331668237244, 'max_depth': 9, 'min_child_weight': 0.93436701532426, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.001973	eval-error:0.002118
#
# [1]	train-error:0.001747	eval-error:0.001883
#
# [2]	train-error:0.001824	eval-error:0.001985
#
# [3]	train-error:0.001766	eval-error:0.001919
#
# [4]	train-error:0.001648	eval-error:0.00179
#
# [5]	train-error:0.001521	eval-error:0.001667
#
# [6]	train-error:0.001787	eval-error:0.001951
#
# [7]	train-error:0.00159	eval-error:0.001733
#
# [8]	train-error:0.001538	eval-error:0.001688
#
# [9]	train-error:0.001547	eval-error:0.00169
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0029402442194968762, 'max_depth': 7, 'min_child_weight': 1.8522100495342722, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.006057	eval-error:0.00619
#
# [1]	train-error:0.005943	eval-error:0.006104
#
# [2]	train-error:0.00606	eval-error:0.006194
#
# [3]	train-error:0.006059	eval-error:0.006187
#
# [4]	train-error:0.006056	eval-error:0.006187
#
# [5]	train-error:0.006055	eval-error:0.006187
#
# [6]	train-error:0.006055	eval-error:0.006185
#
# [7]	train-error:0.006054	eval-error:0.006185
#
# [8]	train-error:0.006057	eval-error:0.006185
#
# [9]	train-error:0.006057	eval-error:0.006185
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.006797643956998457, 'max_depth': 5, 'min_child_weight': 0.32635564809845036, 'subsample': 0.9500000000000001}, logloss: 0.2080
# [0]	train-error:0.0014	eval-error:0.001525
#
# [1]	train-error:0.00126	eval-error:0.001377
#
# [2]	train-error:0.001112	eval-error:0.001223
#
# [3]	train-error:0.00143	eval-error:0.001584
#
# [4]	train-error:0.001337	eval-error:0.001482
#
# [5]	train-error:0.001048	eval-error:0.00114
#
# [6]	train-error:0.001488	eval-error:0.001647
#
# [7]	train-error:0.001384	eval-error:0.001534
#
# [8]	train-error:0.001188	eval-error:0.001325
#
# [9]	train-error:0.000926	eval-error:0.001008
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.00164534433559834, 'max_depth': 8, 'min_child_weight': 5.921934531994201, 'subsample': 0.9}, logloss: 0.1999
# [0]	train-error:0.001397	eval-error:0.001541
#
# [1]	train-error:0.001102	eval-error:0.001189
#
# [2]	train-error:0.001082	eval-error:0.001165
#
# [3]	train-error:0.001109	eval-error:0.001223
#
# [4]	train-error:0.000891	eval-error:0.001001
#
# [5]	train-error:0.000893	eval-error:0.001006
#
# [6]	train-error:0.000912	eval-error:0.001024
#
# [7]	train-error:0.000704	eval-error:0.000748
#
# [8]	train-error:0.000665	eval-error:0.000709
#
# [9]	train-error:0.000699	eval-error:0.000752
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0002208343408724878, 'max_depth': 9, 'min_child_weight': 0.27177174207299815, 'subsample': 0.9500000000000001}, logloss: 0.1994
# [0]	train-error:0.014097	eval-error:0.014493
#
# [1]	train-error:0.014099	eval-error:0.014488
#
# [2]	train-error:0.006101	eval-error:0.006233
#
# [3]	train-error:0.00606	eval-error:0.006196
#
# [4]	train-error:0.006037	eval-error:0.006178
#
# [5]	train-error:0.014097	eval-error:0.014488
#
# [6]	train-error:0.006054	eval-error:0.006192
#
# [7]	train-error:0.006097	eval-error:0.006226
#
# [8]	train-error:0.006112	eval-error:0.006242
#
# [9]	train-error:0.006099	eval-error:0.006221
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 7.80877421357983e-07, 'max_depth': 4, 'min_child_weight': 0.11174298814150703, 'subsample': 0.8500000000000001}, logloss: 0.2153
# [0]	train-error:0.00187	eval-error:0.001957
#
# [1]	train-error:0.001875	eval-error:0.00196
#
# [2]	train-error:0.00164	eval-error:0.001726
#
# [3]	train-error:0.001632	eval-error:0.001742
#
# [4]	train-error:0.001516	eval-error:0.001643
#
# [5]	train-error:0.001535	eval-error:0.001645
#
# [6]	train-error:0.001526	eval-error:0.001624
#
# [7]	train-error:0.001475	eval-error:0.001566
#
# [8]	train-error:0.001277	eval-error:0.001366
#
# [9]	train-error:0.001264	eval-error:0.001355
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 4.687099720217362e-05, 'max_depth': 8, 'min_child_weight': 8.52224200594679, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.00196	eval-error:0.002107
#
# [1]	train-error:0.001741	eval-error:0.001874
#
# [2]	train-error:0.001814	eval-error:0.00198
#
# [3]	train-error:0.001758	eval-error:0.00191
#
# [4]	train-error:0.001641	eval-error:0.001785
#
# [5]	train-error:0.001511	eval-error:0.001654
#
# [6]	train-error:0.001852	eval-error:0.001996
#
# [7]	train-error:0.00159	eval-error:0.00172
#
# [8]	train-error:0.001587	eval-error:0.001733
#
# [9]	train-error:0.001546	eval-error:0.001681
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 5.053752040599402e-06, 'max_depth': 7, 'min_child_weight': 0.26310570662014576, 'subsample': 0.9}, logloss: 0.2010
# [0]	train-error:0.001399	eval-error:0.001543
#
# [1]	train-error:0.001115	eval-error:0.001185
#
# [2]	train-error:0.001088	eval-error:0.001167
#
# [3]	train-error:0.001206	eval-error:0.001298
#
# [4]	train-error:0.001205	eval-error:0.001303
#
# [5]	train-error:0.001009	eval-error:0.001072
#
# [6]	train-error:0.001003	eval-error:0.001101
#
# [7]	train-error:0.000966	eval-error:0.00104
#
# [8]	train-error:0.000905	eval-error:0.000981
#
# [9]	train-error:0.000736	eval-error:0.000795
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.1490275379141403e-07, 'max_depth': 9, 'min_child_weight': 0.1448646088698242, 'subsample': 0.8500000000000001}, logloss: 0.1995
# [0]	train-error:0.003011	eval-error:0.00317
#
# [1]	train-error:0.001947	eval-error:0.002064
#
# [2]	train-error:0.002124	eval-error:0.002261
#
# [3]	train-error:0.002142	eval-error:0.002275
#
# [4]	train-error:0.002127	eval-error:0.002259
#
# [5]	train-error:0.002195	eval-error:0.002336
#
# [6]	train-error:0.002136	eval-error:0.002275
#
# [7]	train-error:0.002206	eval-error:0.002354
#
# [8]	train-error:0.002201	eval-error:0.00232
#
# [9]	train-error:0.002173	eval-error:0.002297
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.00018269133271943462, 'max_depth': 6, 'min_child_weight': 0.40698239327887326, 'subsample': 0.9}, logloss: 0.2026
# [0]	train-error:0.001825	eval-error:0.001928
#
# [1]	train-error:0.001815	eval-error:0.001928
#
# [2]	train-error:0.001584	eval-error:0.001692
#
# [3]	train-error:0.001654	eval-error:0.001776
#
# [4]	train-error:0.001529	eval-error:0.001645
#
# [5]	train-error:0.001557	eval-error:0.001663
#
# [6]	train-error:0.001496	eval-error:0.001597
#
# [7]	train-error:0.001425	eval-error:0.001532
#
# [8]	train-error:0.001227	eval-error:0.00133
#
# [9]	train-error:0.001236	eval-error:0.001334
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.1125195868305194e-06, 'max_depth': 8, 'min_child_weight': 3.315885745801256, 'subsample': 0.9500000000000001}, logloss: 0.2001
# [0]	train-error:0.000859	eval-error:0.000947
#
# [1]	train-error:0.000659	eval-error:0.000741
#
# [2]	train-error:0.000765	eval-error:0.000811
#
# [3]	train-error:0.000793	eval-error:0.000868
#
# [4]	train-error:0.000907	eval-error:0.000965
#
# [5]	train-error:0.000764	eval-error:0.000818
#
# [6]	train-error:0.000836	eval-error:0.000906
#
# [7]	train-error:0.000807	eval-error:0.000865
#
# [8]	train-error:0.000742	eval-error:0.000811
#
# [9]	train-error:0.000754	eval-error:0.000813
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.3450020666658226e-05, 'max_depth': 9, 'min_child_weight': 0.19359006071132195, 'subsample': 0.9}, logloss: 0.1994
# [0]	train-error:0.001986	eval-error:0.002084
#
# [1]	train-error:0.001969	eval-error:0.002082
#
# [2]	train-error:0.001992	eval-error:0.002102
#
# [3]	train-error:0.001806	eval-error:0.00191
#
# [4]	train-error:0.001744	eval-error:0.001826
#
# [5]	train-error:0.001672	eval-error:0.001751
#
# [6]	train-error:0.001682	eval-error:0.001758
#
# [7]	train-error:0.001622	eval-error:0.001713
#
# [8]	train-error:0.00165	eval-error:0.00174
#
# [9]	train-error:0.001603	eval-error:0.001711
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00010095344399164526, 'max_depth': 7, 'min_child_weight': 2.6361105573368473, 'subsample': 0.9500000000000001}, logloss: 0.2010
# [0]	train-error:0.001818	eval-error:0.001923
#
# [1]	train-error:0.00183	eval-error:0.001935
#
# [2]	train-error:0.00158	eval-error:0.001686
#
# [3]	train-error:0.001603	eval-error:0.001715
#
# [4]	train-error:0.001513	eval-error:0.001633
#
# [5]	train-error:0.00156	eval-error:0.001679
#
# [6]	train-error:0.00146	eval-error:0.001561
#
# [7]	train-error:0.001462	eval-error:0.001568
#
# [8]	train-error:0.001463	eval-error:0.001568
#
# [9]	train-error:0.001405	eval-error:0.001543
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.023596764420378762, 'max_depth': 8, 'min_child_weight': 0.6040550594376117, 'subsample': 0.8500000000000001}, logloss: 0.2002
# [0]	train-error:0.000905	eval-error:0.001008
#
# [1]	train-error:0.000882	eval-error:0.000947
#
# [2]	train-error:0.000845	eval-error:0.000927
#
# [3]	train-error:0.000946	eval-error:0.001017
#
# [4]	train-error:0.000952	eval-error:0.001029
#
# [5]	train-error:0.000781	eval-error:0.000836
#
# [6]	train-error:0.000816	eval-error:0.000861
#
# [7]	train-error:0.000821	eval-error:0.000875
#
# [8]	train-error:0.000788	eval-error:0.000822
#
# [9]	train-error:0.000704	eval-error:0.000734
#
# params: {'colsample_bytree': 0.75, 'gamma': 3.2470734003239325e-05, 'max_depth': 9, 'min_child_weight': 0.21930905809296766, 'subsample': 0.7000000000000001}, logloss: 0.1994
# [0]	train-error:0.001458	eval-error:0.001606
#
# [1]	train-error:0.001124	eval-error:0.001194
#
# [2]	train-error:0.001282	eval-error:0.001396
#
# [3]	train-error:0.00139	eval-error:0.001527
#
# [4]	train-error:0.000997	eval-error:0.001076
#
# [5]	train-error:0.000981	eval-error:0.001042
#
# [6]	train-error:0.000819	eval-error:0.000861
#
# [7]	train-error:0.000816	eval-error:0.000836
#
# [8]	train-error:0.000793	eval-error:0.00082
#
# [9]	train-error:0.000778	eval-error:0.000813
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0005564141918959719, 'max_depth': 9, 'min_child_weight': 0.11824712622272587, 'subsample': 0.65}, logloss: 0.1995
# [0]	train-error:0.001978	eval-error:0.002078
#
# [1]	train-error:0.001975	eval-error:0.002078
#
# [2]	train-error:0.001985	eval-error:0.002091
#
# [3]	train-error:0.001792	eval-error:0.001894
#
# [4]	train-error:0.001741	eval-error:0.00181
#
# [5]	train-error:0.001637	eval-error:0.001717
#
# [6]	train-error:0.001659	eval-error:0.001738
#
# [7]	train-error:0.001603	eval-error:0.001697
#
# [8]	train-error:0.001591	eval-error:0.00169
#
# [9]	train-error:0.001633	eval-error:0.001717
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.048171338999934914, 'max_depth': 7, 'min_child_weight': 0.4559058208866212, 'subsample': 0.9500000000000001}, logloss: 0.2010
# 100%|██████████| 100/100 [41:39<00:00, 24.99s/it, best loss: 0.19939078860614193]
# best params:{'colsample_bytree': 0.9, 'gamma': 0.00996060310793052, 'max_depth': 9, 'min_child_weight': 3.2739899207188996, 'subsample': 0.9500000000000001}, score:0.1994

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.00996060310793052,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight':  3.2739899207188996,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.9,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.001444	eval-error:0.001534
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000822	eval-error:0.000841
# [2]	train-error:0.000946	eval-error:0.000958
# [3]	train-error:0.000882	eval-error:0.000913
# [4]	train-error:0.000854	eval-error:0.000879
# [5]	train-error:0.000845	eval-error:0.000879
# [6]	train-error:0.000787	eval-error:0.000818
# [7]	train-error:0.000727	eval-error:0.000732
# [8]	train-error:0.000644	eval-error:0.000659
# [9]	train-error:0.000649	eval-error:0.000652
# [10]	train-error:0.000611	eval-error:0.000619
# [11]	train-error:0.000571	eval-error:0.000573
# [12]	train-error:0.000569	eval-error:0.000566
# [13]	train-error:0.000511	eval-error:0.000514
# [14]	train-error:0.000495	eval-error:0.000498
# [15]	train-error:0.000531	eval-error:0.000521
# [16]	train-error:0.000517	eval-error:0.000498
# [17]	train-error:0.000451	eval-error:0.000464
# [18]	train-error:0.000458	eval-error:0.000474
# [19]	train-error:0.00048	eval-error:0.000494
# [20]	train-error:0.000446	eval-error:0.000478
# [21]	train-error:0.00043	eval-error:0.000451
# [22]	train-error:0.000352	eval-error:0.000372
# [23]	train-error:0.000336	eval-error:0.000358
# [24]	train-error:0.000334	eval-error:0.000358
# [25]	train-error:0.000334	eval-error:0.00036
# [26]	train-error:0.00032	eval-error:0.000344
# [27]	train-error:0.000283	eval-error:0.000297
# [28]	train-error:0.00021	eval-error:0.000238
# [29]	train-error:0.000192	eval-error:0.000213
# [30]	train-error:0.000169	eval-error:0.00019
# [31]	train-error:0.000138	eval-error:0.000159
# [32]	train-error:0.000121	eval-error:0.000129
# [33]	train-error:0.000118	eval-error:0.000125
# [34]	train-error:0.000116	eval-error:0.00012
# [35]	train-error:0.000114	eval-error:0.00012
# [36]	train-error:0.000114	eval-error:0.00012
# [37]	train-error:0.000113	eval-error:0.000118
# [38]	train-error:9.8e-05	eval-error:0.000111
# [39]	train-error:9e-05	eval-error:9.7e-05
# [40]	train-error:9.1e-05	eval-error:0.000106
# [41]	train-error:7.7e-05	eval-error:7.9e-05
# [42]	train-error:7.2e-05	eval-error:7.5e-05
# [43]	train-error:6.9e-05	eval-error:7.2e-05
# [44]	train-error:6.9e-05	eval-error:7.2e-05
# [45]	train-error:6.5e-05	eval-error:6.8e-05
# [46]	train-error:6.5e-05	eval-error:6.8e-05
# [47]	train-error:5.2e-05	eval-error:5e-05
# [48]	train-error:5.2e-05	eval-error:4.8e-05
# [49]	train-error:4.9e-05	eval-error:4.3e-05
# [50]	train-error:4.6e-05	eval-error:4.1e-05
# [51]	train-error:4.6e-05	eval-error:4.1e-05
# [52]	train-error:4.6e-05	eval-error:4.1e-05
# [53]	train-error:4.7e-05	eval-error:3.6e-05
# [54]	train-error:4.8e-05	eval-error:4.1e-05
# [55]	train-error:4.6e-05	eval-error:3.6e-05
# [56]	train-error:4.6e-05	eval-error:3.4e-05
# [57]	train-error:4.3e-05	eval-error:2.9e-05
# [58]	train-error:4.2e-05	eval-error:2.9e-05
# [59]	train-error:3.6e-05	eval-error:2.5e-05
# [60]	train-error:3.5e-05	eval-error:2.5e-05
# [61]	train-error:3.4e-05	eval-error:2.5e-05
# [62]	train-error:3.4e-05	eval-error:2.5e-05
# [63]	train-error:3.4e-05	eval-error:2.5e-05
# [64]	train-error:3.4e-05	eval-error:2.5e-05
# [65]	train-error:3.4e-05	eval-error:2.5e-05
# [66]	train-error:3.4e-05	eval-error:2.5e-05
# [67]	train-error:3.4e-05	eval-error:2.5e-05
# [68]	train-error:3.3e-05	eval-error:2.3e-05
# [69]	train-error:3.3e-05	eval-error:2.3e-05
# [70]	train-error:3.3e-05	eval-error:2.3e-05
# [71]	train-error:3.3e-05	eval-error:2.3e-05
# [72]	train-error:3.3e-05	eval-error:2.3e-05
# [73]	train-error:3.3e-05	eval-error:2.3e-05
# [74]	train-error:3.3e-05	eval-error:2.3e-05
# [75]	train-error:3.2e-05	eval-error:2.3e-05
# [76]	train-error:3e-05	eval-error:2e-05
# [77]	train-error:3e-05	eval-error:2e-05
# [78]	train-error:3e-05	eval-error:2e-05
# [79]	train-error:3e-05	eval-error:2e-05
# [80]	train-error:3e-05	eval-error:2e-05
# [81]	train-error:2.9e-05	eval-error:2e-05
# [82]	train-error:2.9e-05	eval-error:1.8e-05
# [83]	train-error:2.8e-05	eval-error:1.8e-05
# [84]	train-error:2.7e-05	eval-error:1.8e-05
# [85]	train-error:2.5e-05	eval-error:1.6e-05
# [86]	train-error:2.5e-05	eval-error:1.4e-05
# [87]	train-error:2.4e-05	eval-error:1.6e-05
# [88]	train-error:2.3e-05	eval-error:1.4e-05
# [89]	train-error:2.4e-05	eval-error:1.4e-05
# [90]	train-error:2.3e-05	eval-error:1.4e-05
# [91]	train-error:2.1e-05	eval-error:1.4e-05
# [92]	train-error:2e-05	eval-error:1.4e-05
# [93]	train-error:2e-05	eval-error:1.4e-05
# [94]	train-error:2.1e-05	eval-error:1.4e-05
# [95]	train-error:2e-05	eval-error:1.4e-05
# [96]	train-error:2.1e-05	eval-error:1.4e-05
# [97]	train-error:2e-05	eval-error:1.4e-05
# [98]	train-error:1.9e-05	eval-error:1.4e-05
# [99]	train-error:1.9e-05	eval-error:1.4e-05
# [100]	train-error:1.7e-05	eval-error:1.1e-05
# [101]	train-error:1.6e-05	eval-error:9e-06
# [102]	train-error:1.6e-05	eval-error:9e-06
# [103]	train-error:1.5e-05	eval-error:9e-06
# [104]	train-error:1.5e-05	eval-error:9e-06
# [105]	train-error:1.5e-05	eval-error:9e-06
# [106]	train-error:1.5e-05	eval-error:9e-06
# [107]	train-error:1.5e-05	eval-error:9e-06
# [108]	train-error:1.5e-05	eval-error:9e-06
# [109]	train-error:1.5e-05	eval-error:9e-06
# [110]	train-error:1.5e-05	eval-error:9e-06
# [111]	train-error:1.5e-05	eval-error:9e-06
# [112]	train-error:1.4e-05	eval-error:9e-06
# [113]	train-error:1.4e-05	eval-error:9e-06
# [114]	train-error:1.4e-05	eval-error:9e-06
# [115]	train-error:1.4e-05	eval-error:9e-06
# [116]	train-error:1.4e-05	eval-error:9e-06
# [117]	train-error:1.4e-05	eval-error:9e-06
# [118]	train-error:1.4e-05	eval-error:9e-06
# [119]	train-error:1.4e-05	eval-error:9e-06
# [120]	train-error:1.4e-05	eval-error:9e-06
# [121]	train-error:1.4e-05	eval-error:9e-06
# Stopping. Best iteration:
# [101]	train-error:1.6e-05	eval-error:9e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0001

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_xg25_param_tuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_xg25_param_tuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000027
# 1  0.000027
# 2  0.000027
# 3  0.000027
# 4  0.000027

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000027
# 1   1  0.000027
# 2   2  0.000027
# 3   3  0.000027
# 4   4  0.000027

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_xg25_param_tuning.csv',index=False)

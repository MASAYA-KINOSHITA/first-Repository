# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection_score0_872.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly','Successful wait for connection : (incld/dx (MXBean(com.bea:Name=source08,Type=JDBCDataSourceRuntime).WaitingForConnectionSuccessTotal))',
 'Transaction roll back activity : (incld/dx (MXBean(com.bea:Name=JTARuntime,Type=JTARuntime).TransactionRolledBackTotalCount))',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))'])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=['Successful wait for connection : (incld/dx (MXBean(com.bea:Name=source08,Type=JDBCDataSourceRuntime).WaitingForConnectionSuccessTotal))',
 'Transaction roll back activity : (incld/dx (MXBean(com.bea:Name=JTARuntime,Type=JTARuntime).TransactionRolledBackTotalCount))',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))'])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.002257	eval-error:0.002263
#
# [1]	train-error:0.00238	eval-error:0.002354
#
# [2]	train-error:0.004432	eval-error:0.004524
#
# [3]	train-error:0.002476	eval-error:0.002411
#
# [4]	train-error:0.002363	eval-error:0.002318
#
# [5]	train-error:0.001493	eval-error:0.001559
#
# [6]	train-error:0.001855	eval-error:0.001967
#
# [7]	train-error:0.001753	eval-error:0.001869
#
# [8]	train-error:0.001446	eval-error:0.001509
#
# [9]	train-error:0.001427	eval-error:0.001498
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.00027693786506300457, 'max_depth': 5, 'min_child_weight': 0.4954709761539855, 'subsample': 0.8500000000000001}, logloss: 0.2020
# [0]	train-error:0.000966	eval-error:0.001078
#
# [1]	train-error:0.000687	eval-error:0.000795
#
# [2]	train-error:0.000788	eval-error:0.000865
#
# [3]	train-error:0.000732	eval-error:0.000845
#
# [4]	train-error:0.00083	eval-error:0.000933
#
# [5]	train-error:0.000706	eval-error:0.000791
#
# [6]	train-error:0.000757	eval-error:0.00087
#
# [7]	train-error:0.000794	eval-error:0.00089
#
# [8]	train-error:0.000752	eval-error:0.000856
#
# [9]	train-error:0.000684	eval-error:0.000757
#
# params: {'colsample_bytree': 0.8, 'gamma': 0.0018032058346574076, 'max_depth': 8, 'min_child_weight': 1.323080390564793, 'subsample': 0.8}, logloss: 0.1994
# [0]	train-error:0.000995	eval-error:0.001128
#
# [1]	train-error:0.000875	eval-error:0.000976
#
# [2]	train-error:0.00085	eval-error:0.00094
#
# [3]	train-error:0.000857	eval-error:0.000963
#
# [4]	train-error:0.00081	eval-error:0.00092
#
# [5]	train-error:0.00081	eval-error:0.000906
#
# [6]	train-error:0.000804	eval-error:0.000902
#
# [7]	train-error:0.000803	eval-error:0.000897
#
# [8]	train-error:0.00088	eval-error:0.000992
#
# [9]	train-error:0.000803	eval-error:0.000897
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.443074897313168e-07, 'max_depth': 7, 'min_child_weight': 0.16210099700162672, 'subsample': 0.8}, logloss: 0.1995
# [0]	train-error:0.000838	eval-error:0.000933
#
# [1]	train-error:0.000783	eval-error:0.000854
#
# [2]	train-error:0.00078	eval-error:0.000847
#
# [3]	train-error:0.000828	eval-error:0.000924
#
# [4]	train-error:0.000818	eval-error:0.000909
#
# [5]	train-error:0.000816	eval-error:0.000904
#
# [6]	train-error:0.000817	eval-error:0.000906
#
# [7]	train-error:0.000827	eval-error:0.000927
#
# [8]	train-error:0.000885	eval-error:0.000997
#
# [9]	train-error:0.000847	eval-error:0.000947
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.3604364660502743e-06, 'max_depth': 7, 'min_child_weight': 2.8621999568338703, 'subsample': 0.75}, logloss: 0.1995
# [0]	train-error:0.000852	eval-error:0.000974
#
# [1]	train-error:0.000789	eval-error:0.000884
#
# [2]	train-error:0.001063	eval-error:0.00118
#
# [3]	train-error:0.000803	eval-error:0.000906
#
# [4]	train-error:0.000868	eval-error:0.000974
#
# [5]	train-error:0.000893	eval-error:0.000986
#
# [6]	train-error:0.000896	eval-error:0.000983
#
# [7]	train-error:0.000864	eval-error:0.000947
#
# [8]	train-error:0.000801	eval-error:0.000904
#
# [9]	train-error:0.000773	eval-error:0.000875
#
# params: {'colsample_bytree': 0.65, 'gamma': 4.3902807471307575e-08, 'max_depth': 7, 'min_child_weight': 0.13483349295866312, 'subsample': 0.65}, logloss: 0.2003
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006221	eval-error:0.006378
#
# [2]	train-error:0.006221	eval-error:0.006378
#
# [3]	train-error:0.006221	eval-error:0.006378
#
# [4]	train-error:0.007415	eval-error:0.007617
#
# [5]	train-error:0.006221	eval-error:0.006378
#
# [6]	train-error:0.007415	eval-error:0.007617
#
# [7]	train-error:0.007415	eval-error:0.007617
#
# [8]	train-error:0.006221	eval-error:0.006378
#
# [9]	train-error:0.006221	eval-error:0.006378
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.0830932585734486e-07, 'max_depth': 3, 'min_child_weight': 0.712164445091289, 'subsample': 0.8500000000000001}, logloss: 0.2094
# [0]	train-error:0.000391	eval-error:0.000417
#
# [1]	train-error:0.000419	eval-error:0.000449
#
# [2]	train-error:0.000597	eval-error:0.000664
#
# [3]	train-error:0.000504	eval-error:0.000587
#
# [4]	train-error:0.000547	eval-error:0.000612
#
# [5]	train-error:0.000472	eval-error:0.000521
#
# [6]	train-error:0.000486	eval-error:0.000539
#
# [7]	train-error:0.00047	eval-error:0.000537
#
# [8]	train-error:0.00044	eval-error:0.000485
#
# [9]	train-error:0.000413	eval-error:0.000449
#
# params: {'colsample_bytree': 0.75, 'gamma': 3.4267072694617344e-08, 'max_depth': 9, 'min_child_weight': 0.6093218637984802, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.001661	eval-error:0.001806
#
# [1]	train-error:0.001455	eval-error:0.001581
#
# [2]	train-error:0.003556	eval-error:0.003734
#
# [3]	train-error:0.00141	eval-error:0.001484
#
# [4]	train-error:0.001538	eval-error:0.001647
#
# [5]	train-error:0.001306	eval-error:0.001398
#
# [6]	train-error:0.001321	eval-error:0.001396
#
# [7]	train-error:0.001298	eval-error:0.001391
#
# [8]	train-error:0.001113	eval-error:0.001208
#
# [9]	train-error:0.001029	eval-error:0.00111
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.008336552329111993, 'max_depth': 6, 'min_child_weight': 2.457013428674234, 'subsample': 0.8}, logloss: 0.2014
# [0]	train-error:0.000955	eval-error:0.001065
#
# [1]	train-error:0.00058	eval-error:0.000675
#
# [2]	train-error:0.000706	eval-error:0.000793
#
# [3]	train-error:0.000698	eval-error:0.000782
#
# [4]	train-error:0.0007	eval-error:0.000786
#
# [5]	train-error:0.000628	eval-error:0.0007
#
# [6]	train-error:0.000697	eval-error:0.000775
#
# [7]	train-error:0.000705	eval-error:0.000779
#
# [8]	train-error:0.0007	eval-error:0.000782
#
# [9]	train-error:0.00068	eval-error:0.000745
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.009206140567617305, 'max_depth': 8, 'min_child_weight': 1.3563196588206061, 'subsample': 0.8}, logloss: 0.1991
# [0]	train-error:0.005727	eval-error:0.005782
#
# [1]	train-error:0.005961	eval-error:0.006092
#
# [2]	train-error:0.002364	eval-error:0.002336
#
# [3]	train-error:0.002488	eval-error:0.002456
#
# [4]	train-error:0.00263	eval-error:0.002651
#
# [5]	train-error:0.002419	eval-error:0.002397
#
# [6]	train-error:0.002687	eval-error:0.00268
#
# [7]	train-error:0.002685	eval-error:0.002678
#
# [8]	train-error:0.002568	eval-error:0.002585
#
# [9]	train-error:0.00242	eval-error:0.002399
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.497552501978865e-07, 'max_depth': 4, 'min_child_weight': 7.569529317785837, 'subsample': 0.75}, logloss: 0.2050
# 100%|██████████| 10/10 [04:44<00:00, 28.47s/it, best loss: 0.19888082459899623]
# best params:{'colsample_bytree': 0.75, 'gamma': 3.4267072694617344e-08, 'max_depth': 9, 'min_child_weight': 0.6093218637984802, 'subsample': 0.9500000000000001}, score:0.1989

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# ハイパーパラメータの設定
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 3.4267072694617344e-08,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 0.6093218637984802,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.75,
    'random_state': 71,
}
num_round = 100

# %%
# 学習の実行
# バリデーションデータもモデルに渡し、学習の進行とともにスコアがどう変わるかモニタリングする
# watchlistには学習データおよびバリデーションデータをセットする
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist)
# Out:
# [0]	train-error:0.000387	eval-error:0.000396
# [1]	train-error:0.000398	eval-error:0.000412
# [2]	train-error:0.000457	eval-error:0.000455
# [3]	train-error:0.000425	eval-error:0.00044
# [4]	train-error:0.000424	eval-error:0.000433
# [5]	train-error:0.000414	eval-error:0.000437
# [6]	train-error:0.00042	eval-error:0.000449
# [7]	train-error:0.000408	eval-error:0.000442
# [8]	train-error:0.000428	eval-error:0.000455
# [9]	train-error:0.000405	eval-error:0.000433
# [10]	train-error:0.000399	eval-error:0.000437
# [11]	train-error:0.000389	eval-error:0.000428
# [12]	train-error:0.000378	eval-error:0.000419
# [13]	train-error:0.000342	eval-error:0.000372
# [14]	train-error:0.000315	eval-error:0.000347
# [15]	train-error:0.000309	eval-error:0.00034
# [16]	train-error:0.000254	eval-error:0.000295
# [17]	train-error:0.000257	eval-error:0.000297
# [18]	train-error:0.000225	eval-error:0.000242
# [19]	train-error:0.000223	eval-error:0.000236
# [20]	train-error:0.000213	eval-error:0.000227
# [21]	train-error:0.00022	eval-error:0.000231
# [22]	train-error:0.000189	eval-error:0.000202
# [23]	train-error:0.000212	eval-error:0.000227
# [24]	train-error:0.000169	eval-error:0.000181
# [25]	train-error:0.000174	eval-error:0.000193
# [26]	train-error:0.000184	eval-error:0.000197
# [27]	train-error:0.000164	eval-error:0.000177
# [28]	train-error:0.000152	eval-error:0.000165
# [29]	train-error:0.000124	eval-error:0.00014
# [30]	train-error:0.000114	eval-error:0.000129
# [31]	train-error:0.000103	eval-error:0.000118
# [32]	train-error:8.6e-05	eval-error:0.000102
# [33]	train-error:8.3e-05	eval-error:9.7e-05
# [34]	train-error:5.9e-05	eval-error:6.6e-05
# [35]	train-error:5.2e-05	eval-error:5.7e-05
# [36]	train-error:4.9e-05	eval-error:5.2e-05
# [37]	train-error:4.2e-05	eval-error:4.8e-05
# [38]	train-error:3.1e-05	eval-error:2.9e-05
# [39]	train-error:2.5e-05	eval-error:2.9e-05
# [40]	train-error:2.4e-05	eval-error:2.7e-05
# [41]	train-error:2.4e-05	eval-error:2.5e-05
# [42]	train-error:2.3e-05	eval-error:2.3e-05
# [43]	train-error:2e-05	eval-error:2e-05
# [44]	train-error:1.8e-05	eval-error:1.6e-05
# [45]	train-error:1.6e-05	eval-error:1.6e-05
# [46]	train-error:1.2e-05	eval-error:1.6e-05
# [47]	train-error:1.4e-05	eval-error:1.8e-05
# [48]	train-error:1.4e-05	eval-error:1.8e-05
# [49]	train-error:1.2e-05	eval-error:1.6e-05
# [50]	train-error:1.2e-05	eval-error:1.6e-05
# [51]	train-error:1.2e-05	eval-error:1.6e-05
# [52]	train-error:1.1e-05	eval-error:1.6e-05
# [53]	train-error:1.1e-05	eval-error:1.4e-05
# [54]	train-error:9e-06	eval-error:1.4e-05
# [55]	train-error:9e-06	eval-error:1.4e-05
# [56]	train-error:9e-06	eval-error:1.4e-05
# [57]	train-error:9e-06	eval-error:1.4e-05
# [58]	train-error:5e-06	eval-error:9e-06
# [59]	train-error:5e-06	eval-error:9e-06
# [60]	train-error:5e-06	eval-error:9e-06
# [61]	train-error:4e-06	eval-error:9e-06
# [62]	train-error:4e-06	eval-error:9e-06
# [63]	train-error:4e-06	eval-error:9e-06
# [64]	train-error:4e-06	eval-error:9e-06
# [65]	train-error:3e-06	eval-error:9e-06
# [66]	train-error:4e-06	eval-error:9e-06
# [67]	train-error:3e-06	eval-error:9e-06
# [68]	train-error:3e-06	eval-error:9e-06
# [69]	train-error:3e-06	eval-error:9e-06
# [70]	train-error:3e-06	eval-error:9e-06
# [71]	train-error:3e-06	eval-error:9e-06
# [72]	train-error:3e-06	eval-error:9e-06
# [73]	train-error:3e-06	eval-error:9e-06
# [74]	train-error:3e-06	eval-error:9e-06
# [75]	train-error:3e-06	eval-error:9e-06
# [76]	train-error:3e-06	eval-error:7e-06
# [77]	train-error:3e-06	eval-error:7e-06
# [78]	train-error:3e-06	eval-error:7e-06
# [79]	train-error:3e-06	eval-error:7e-06
# [80]	train-error:3e-06	eval-error:7e-06
# [81]	train-error:3e-06	eval-error:7e-06
# [82]	train-error:3e-06	eval-error:7e-06
# [83]	train-error:3e-06	eval-error:7e-06
# [84]	train-error:3e-06	eval-error:7e-06
# [85]	train-error:3e-06	eval-error:7e-06
# [86]	train-error:3e-06	eval-error:7e-06
# [87]	train-error:3e-06	eval-error:7e-06
# [88]	train-error:3e-06	eval-error:7e-06
# [89]	train-error:3e-06	eval-error:7e-06
# [90]	train-error:3e-06	eval-error:7e-06
# [91]	train-error:3e-06	eval-error:7e-06
# [92]	train-error:3e-06	eval-error:7e-06
# [93]	train-error:3e-06	eval-error:7e-06
# [94]	train-error:3e-06	eval-error:7e-06
# [95]	train-error:3e-06	eval-error:7e-06
# [96]	train-error:2e-06	eval-error:7e-06
# [97]	train-error:2e-06	eval-error:7e-06
# [98]	train-error:2e-06	eval-error:7e-06
# [99]	train-error:2e-06	eval-error:7e-06

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 3.4267072694617344e-08,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 0.6093218637984802,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.75,
    'random_state': 71,
}
num_round = 500
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.000387	eval-error:0.000396
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000398	eval-error:0.000412
# [2]	train-error:0.000457	eval-error:0.000455
# [3]	train-error:0.000425	eval-error:0.00044
# [4]	train-error:0.000424	eval-error:0.000433
# [5]	train-error:0.000414	eval-error:0.000437
# [6]	train-error:0.00042	eval-error:0.000449
# [7]	train-error:0.000408	eval-error:0.000442
# [8]	train-error:0.000428	eval-error:0.000455
# [9]	train-error:0.000405	eval-error:0.000433
# [10]	train-error:0.000399	eval-error:0.000437
# [11]	train-error:0.000389	eval-error:0.000428
# [12]	train-error:0.000378	eval-error:0.000419
# [13]	train-error:0.000342	eval-error:0.000372
# [14]	train-error:0.000315	eval-error:0.000347
# [15]	train-error:0.000309	eval-error:0.00034
# [16]	train-error:0.000254	eval-error:0.000295
# [17]	train-error:0.000257	eval-error:0.000297
# [18]	train-error:0.000225	eval-error:0.000242
# [19]	train-error:0.000223	eval-error:0.000236
# [20]	train-error:0.000213	eval-error:0.000227
# [21]	train-error:0.00022	eval-error:0.000231
# [22]	train-error:0.000189	eval-error:0.000202
# [23]	train-error:0.000212	eval-error:0.000227
# [24]	train-error:0.000169	eval-error:0.000181
# [25]	train-error:0.000174	eval-error:0.000193
# [26]	train-error:0.000184	eval-error:0.000197
# [27]	train-error:0.000164	eval-error:0.000177
# [28]	train-error:0.000152	eval-error:0.000165
# [29]	train-error:0.000124	eval-error:0.00014
# [30]	train-error:0.000114	eval-error:0.000129
# [31]	train-error:0.000103	eval-error:0.000118
# [32]	train-error:8.6e-05	eval-error:0.000102
# [33]	train-error:8.3e-05	eval-error:9.7e-05
# [34]	train-error:5.9e-05	eval-error:6.6e-05
# [35]	train-error:5.2e-05	eval-error:5.7e-05
# [36]	train-error:4.9e-05	eval-error:5.2e-05
# [37]	train-error:4.2e-05	eval-error:4.8e-05
# [38]	train-error:3.1e-05	eval-error:2.9e-05
# [39]	train-error:2.5e-05	eval-error:2.9e-05
# [40]	train-error:2.4e-05	eval-error:2.7e-05
# [41]	train-error:2.4e-05	eval-error:2.5e-05
# [42]	train-error:2.3e-05	eval-error:2.3e-05
# [43]	train-error:2e-05	eval-error:2e-05
# [44]	train-error:1.8e-05	eval-error:1.6e-05
# [45]	train-error:1.6e-05	eval-error:1.6e-05
# [46]	train-error:1.2e-05	eval-error:1.6e-05
# [47]	train-error:1.4e-05	eval-error:1.8e-05
# [48]	train-error:1.4e-05	eval-error:1.8e-05
# [49]	train-error:1.2e-05	eval-error:1.6e-05
# [50]	train-error:1.2e-05	eval-error:1.6e-05
# [51]	train-error:1.2e-05	eval-error:1.6e-05
# [52]	train-error:1.1e-05	eval-error:1.6e-05
# [53]	train-error:1.1e-05	eval-error:1.4e-05
# [54]	train-error:9e-06	eval-error:1.4e-05
# [55]	train-error:9e-06	eval-error:1.4e-05
# [56]	train-error:9e-06	eval-error:1.4e-05
# [57]	train-error:9e-06	eval-error:1.4e-05
# [58]	train-error:5e-06	eval-error:9e-06
# [59]	train-error:5e-06	eval-error:9e-06
# [60]	train-error:5e-06	eval-error:9e-06
# [61]	train-error:4e-06	eval-error:9e-06
# [62]	train-error:4e-06	eval-error:9e-06
# [63]	train-error:4e-06	eval-error:9e-06
# [64]	train-error:4e-06	eval-error:9e-06
# [65]	train-error:3e-06	eval-error:9e-06
# [66]	train-error:4e-06	eval-error:9e-06
# [67]	train-error:3e-06	eval-error:9e-06
# [68]	train-error:3e-06	eval-error:9e-06
# [69]	train-error:3e-06	eval-error:9e-06
# [70]	train-error:3e-06	eval-error:9e-06
# [71]	train-error:3e-06	eval-error:9e-06
# [72]	train-error:3e-06	eval-error:9e-06
# [73]	train-error:3e-06	eval-error:9e-06
# [74]	train-error:3e-06	eval-error:9e-06
# [75]	train-error:3e-06	eval-error:9e-06
# [76]	train-error:3e-06	eval-error:7e-06
# [77]	train-error:3e-06	eval-error:7e-06
# [78]	train-error:3e-06	eval-error:7e-06
# [79]	train-error:3e-06	eval-error:7e-06
# [80]	train-error:3e-06	eval-error:7e-06
# [81]	train-error:3e-06	eval-error:7e-06
# [82]	train-error:3e-06	eval-error:7e-06
# [83]	train-error:3e-06	eval-error:7e-06
# [84]	train-error:3e-06	eval-error:7e-06
# [85]	train-error:3e-06	eval-error:7e-06
# [86]	train-error:3e-06	eval-error:7e-06
# [87]	train-error:3e-06	eval-error:7e-06
# [88]	train-error:3e-06	eval-error:7e-06
# [89]	train-error:3e-06	eval-error:7e-06
# [90]	train-error:3e-06	eval-error:7e-06
# [91]	train-error:3e-06	eval-error:7e-06
# [92]	train-error:3e-06	eval-error:7e-06
# [93]	train-error:3e-06	eval-error:7e-06
# [94]	train-error:3e-06	eval-error:7e-06
# [95]	train-error:3e-06	eval-error:7e-06
# [96]	train-error:2e-06	eval-error:7e-06
# Stopping. Best iteration:
# [76]	train-error:3e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0001

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_27_pram_tuning2.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_27_pram_tuning2.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000031
# 1  0.000031
# 2  0.000031
# 3  0.000031
# 4  0.000031

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000031
# 1   1  0.000031
# 2   2  0.000031
# 3   3  0.000031
# 4   4  0.000031

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_27_pram_tuning2.csv',index=False)

# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection_%E7%9B%B8%E9%96%A2%E4%BF%82%E6%95%B025_2_param_notuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.0,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 1,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'random_state': 71,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss


def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.4f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
    'subsample': hp.quniform('subsample', 0.6, 0.95, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 0.95, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    # 'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    # 'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.4f}')
# Out:
# [0]	train-error:0.002114	eval-error:0.002157
#
# [1]	train-error:0.001205	eval-error:0.001341
#
# [2]	train-error:0.001741	eval-error:0.001921
#
# [3]	train-error:0.001091	eval-error:0.001219
#
# [4]	train-error:0.001158	eval-error:0.001276
#
# [5]	train-error:0.001094	eval-error:0.001219
#
# [6]	train-error:0.000949	eval-error:0.001017
#
# [7]	train-error:0.000921	eval-error:0.001017
#
# [8]	train-error:0.00104	eval-error:0.00116
#
# [9]	train-error:0.001035	eval-error:0.001146
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.0723684627939308e-06, 'max_depth': 6, 'min_child_weight': 5.109357411753681, 'subsample': 0.9}, logloss: 0.2014
# [0]	train-error:0.001945	eval-error:0.002112
#
# [1]	train-error:0.001164	eval-error:0.001266
#
# [2]	train-error:0.001569	eval-error:0.001738
#
# [3]	train-error:0.001135	eval-error:0.001266
#
# [4]	train-error:0.001168	eval-error:0.001298
#
# [5]	train-error:0.001101	eval-error:0.001214
#
# [6]	train-error:0.000973	eval-error:0.001101
#
# [7]	train-error:0.001084	eval-error:0.001208
#
# [8]	train-error:0.00107	eval-error:0.001192
#
# [9]	train-error:0.001072	eval-error:0.00118
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.2702089259186731, 'max_depth': 6, 'min_child_weight': 1.0248215138527301, 'subsample': 0.7000000000000001}, logloss: 0.2009
# [0]	train-error:0.005761	eval-error:0.00587
#
# [1]	train-error:0.002716	eval-error:0.002778
#
# [2]	train-error:0.005704	eval-error:0.005904
#
# [3]	train-error:0.002505	eval-error:0.002635
#
# [4]	train-error:0.002411	eval-error:0.00244
#
# [5]	train-error:0.001979	eval-error:0.002141
#
# [6]	train-error:0.002248	eval-error:0.002381
#
# [7]	train-error:0.002256	eval-error:0.00232
#
# [8]	train-error:0.002217	eval-error:0.002304
#
# [9]	train-error:0.002198	eval-error:0.002279
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.0004961171165105902, 'max_depth': 4, 'min_child_weight': 2.4120419909422, 'subsample': 0.8500000000000001}, logloss: 0.2056
# [0]	train-error:0.002467	eval-error:0.002537
#
# [1]	train-error:0.00122	eval-error:0.001387
#
# [2]	train-error:0.001317	eval-error:0.001452
#
# [3]	train-error:0.000957	eval-error:0.001101
#
# [4]	train-error:0.000955	eval-error:0.001101
#
# [5]	train-error:0.000866	eval-error:0.001001
#
# [6]	train-error:0.000836	eval-error:0.000933
#
# [7]	train-error:0.000816	eval-error:0.000922
#
# [8]	train-error:0.000759	eval-error:0.000854
#
# [9]	train-error:0.000801	eval-error:0.000897
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 8.434089634902163e-05, 'max_depth': 7, 'min_child_weight': 1.8975562233622196, 'subsample': 0.65}, logloss: 0.2005
# [0]	train-error:0.001936	eval-error:0.002107
#
# [1]	train-error:0.001156	eval-error:0.001255
#
# [2]	train-error:0.001748	eval-error:0.001914
#
# [3]	train-error:0.001182	eval-error:0.001291
#
# [4]	train-error:0.001188	eval-error:0.001291
#
# [5]	train-error:0.001165	eval-error:0.001257
#
# [6]	train-error:0.00119	eval-error:0.001285
#
# [7]	train-error:0.001145	eval-error:0.001237
#
# [8]	train-error:0.001109	eval-error:0.001226
#
# [9]	train-error:0.001087	eval-error:0.001192
#
# params: {'colsample_bytree': 0.75, 'gamma': 4.579389684251614e-08, 'max_depth': 6, 'min_child_weight': 0.19771206876956054, 'subsample': 0.8}, logloss: 0.2011
# [0]	train-error:0.000757	eval-error:0.000847
#
# [1]	train-error:0.00072	eval-error:0.000786
#
# [2]	train-error:0.000909	eval-error:0.000983
#
# [3]	train-error:0.00072	eval-error:0.000784
#
# [4]	train-error:0.00066	eval-error:0.000736
#
# [5]	train-error:0.000647	eval-error:0.000711
#
# [6]	train-error:0.000625	eval-error:0.000682
#
# [7]	train-error:0.000643	eval-error:0.000711
#
# [8]	train-error:0.000593	eval-error:0.000655
#
# [9]	train-error:0.000519	eval-error:0.000575
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.6044401066602461e-07, 'max_depth': 8, 'min_child_weight': 0.43463681505469504, 'subsample': 0.65}, logloss: 0.1992
# [0]	train-error:0.001867	eval-error:0.00196
#
# [1]	train-error:0.000985	eval-error:0.001108
#
# [2]	train-error:0.000951	eval-error:0.00104
#
# [3]	train-error:0.000829	eval-error:0.000909
#
# [4]	train-error:0.000757	eval-error:0.000838
#
# [5]	train-error:0.000779	eval-error:0.00085
#
# [6]	train-error:0.000707	eval-error:0.000788
#
# [7]	train-error:0.000618	eval-error:0.00072
#
# [8]	train-error:0.000591	eval-error:0.000691
#
# [9]	train-error:0.000512	eval-error:0.000596
#
# params: {'colsample_bytree': 0.65, 'gamma': 1.7244344171095665e-05, 'max_depth': 8, 'min_child_weight': 0.2811664863585612, 'subsample': 0.9500000000000001}, logloss: 0.1993
# [0]	train-error:0.000776	eval-error:0.000845
#
# [1]	train-error:0.000788	eval-error:0.00087
#
# [2]	train-error:0.000705	eval-error:0.0008
#
# [3]	train-error:0.000718	eval-error:0.00082
#
# [4]	train-error:0.000804	eval-error:0.000906
#
# [5]	train-error:0.000689	eval-error:0.000775
#
# [6]	train-error:0.000745	eval-error:0.000834
#
# [7]	train-error:0.000795	eval-error:0.000893
#
# [8]	train-error:0.00073	eval-error:0.000809
#
# [9]	train-error:0.000652	eval-error:0.000727
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.098717428935628e-06, 'max_depth': 8, 'min_child_weight': 1.7272907897484242, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.002058	eval-error:0.002173
#
# [1]	train-error:0.001871	eval-error:0.002001
#
# [2]	train-error:0.003467	eval-error:0.003722
#
# [3]	train-error:0.001211	eval-error:0.001321
#
# [4]	train-error:0.001018	eval-error:0.001153
#
# [5]	train-error:0.000991	eval-error:0.001092
#
# [6]	train-error:0.000876	eval-error:0.000988
#
# [7]	train-error:0.001091	eval-error:0.001208
#
# [8]	train-error:0.001091	eval-error:0.001192
#
# [9]	train-error:0.000885	eval-error:0.000974
#
# params: {'colsample_bytree': 0.8, 'gamma': 2.0774230251042185e-05, 'max_depth': 6, 'min_child_weight': 4.874040646969098, 'subsample': 0.65}, logloss: 0.2008
# [0]	train-error:0.000804	eval-error:0.000856
#
# [1]	train-error:0.00069	eval-error:0.000797
#
# [2]	train-error:0.000925	eval-error:0.000992
#
# [3]	train-error:0.000716	eval-error:0.000809
#
# [4]	train-error:0.000689	eval-error:0.000773
#
# [5]	train-error:0.000629	eval-error:0.000711
#
# [6]	train-error:0.00068	eval-error:0.000766
#
# [7]	train-error:0.000652	eval-error:0.000718
#
# [8]	train-error:0.000479	eval-error:0.000553
#
# [9]	train-error:0.000475	eval-error:0.00053
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 9.62724374628406e-07, 'max_depth': 8, 'min_child_weight': 0.3666841049791335, 'subsample': 0.7000000000000001}, logloss: 0.1992
# [0]	train-error:0.001014	eval-error:0.001108
#
# [1]	train-error:0.000838	eval-error:0.000884
#
# [2]	train-error:0.000931	eval-error:0.00101
#
# [3]	train-error:0.000788	eval-error:0.000872
#
# [4]	train-error:0.000773	eval-error:0.000856
#
# [5]	train-error:0.000733	eval-error:0.000791
#
# [6]	train-error:0.000748	eval-error:0.000831
#
# [7]	train-error:0.000713	eval-error:0.000784
#
# [8]	train-error:0.000706	eval-error:0.000768
#
# [9]	train-error:0.000674	eval-error:0.000745
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.006786478437998676, 'max_depth': 7, 'min_child_weight': 0.11443209525520882, 'subsample': 0.9}, logloss: 0.1997
# [0]	train-error:0.000881	eval-error:0.000945
#
# [1]	train-error:0.000742	eval-error:0.000816
#
# [2]	train-error:0.00158	eval-error:0.001704
#
# [3]	train-error:0.000754	eval-error:0.000825
#
# [4]	train-error:0.000727	eval-error:0.000791
#
# [5]	train-error:0.000701	eval-error:0.000782
#
# [6]	train-error:0.000736	eval-error:0.000822
#
# [7]	train-error:0.000739	eval-error:0.000822
#
# [8]	train-error:0.000739	eval-error:0.00082
#
# [9]	train-error:0.000803	eval-error:0.000877
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.2467604649180642e-05, 'max_depth': 7, 'min_child_weight': 0.38005261357465064, 'subsample': 0.6000000000000001}, logloss: 0.1997
# [0]	train-error:0.002186	eval-error:0.002272
#
# [1]	train-error:0.001328	eval-error:0.001441
#
# [2]	train-error:0.001026	eval-error:0.001137
#
# [3]	train-error:0.000857	eval-error:0.000954
#
# [4]	train-error:0.000831	eval-error:0.000904
#
# [5]	train-error:0.000702	eval-error:0.000759
#
# [6]	train-error:0.000758	eval-error:0.000836
#
# [7]	train-error:0.000683	eval-error:0.000766
#
# [8]	train-error:0.000727	eval-error:0.00085
#
# [9]	train-error:0.000649	eval-error:0.000723
#
# params: {'colsample_bytree': 0.65, 'gamma': 2.2026343599204256e-07, 'max_depth': 7, 'min_child_weight': 2.3614513738641385, 'subsample': 0.9}, logloss: 0.2001
# [0]	train-error:0.002523	eval-error:0.002642
#
# [1]	train-error:0.001293	eval-error:0.001377
#
# [2]	train-error:0.001751	eval-error:0.001933
#
# [3]	train-error:0.000946	eval-error:0.001065
#
# [4]	train-error:0.001046	eval-error:0.00114
#
# [5]	train-error:0.000915	eval-error:0.001001
#
# [6]	train-error:0.001043	eval-error:0.001142
#
# [7]	train-error:0.000918	eval-error:0.001026
#
# [8]	train-error:0.000918	eval-error:0.001042
#
# [9]	train-error:0.000899	eval-error:0.000986
#
# params: {'colsample_bytree': 0.65, 'gamma': 0.23758691008593058, 'max_depth': 6, 'min_child_weight': 0.16819460777950598, 'subsample': 0.7000000000000001}, logloss: 0.2016
# [0]	train-error:0.005712	eval-error:0.005775
#
# [1]	train-error:0.002528	eval-error:0.002472
#
# [2]	train-error:0.005964	eval-error:0.006137
#
# [3]	train-error:0.002321	eval-error:0.002408
#
# [4]	train-error:0.002217	eval-error:0.002257
#
# [5]	train-error:0.00249	eval-error:0.002479
#
# [6]	train-error:0.002583	eval-error:0.002614
#
# [7]	train-error:0.002459	eval-error:0.002456
#
# [8]	train-error:0.002437	eval-error:0.002442
#
# [9]	train-error:0.002435	eval-error:0.002442
#
# params: {'colsample_bytree': 0.8, 'gamma': 7.035305605197186e-05, 'max_depth': 4, 'min_child_weight': 0.15211012771451118, 'subsample': 0.8}, logloss: 0.2050
# [0]	train-error:0.001041	eval-error:0.001128
#
# [1]	train-error:0.000867	eval-error:0.000915
#
# [2]	train-error:0.000933	eval-error:0.001006
#
# [3]	train-error:0.000811	eval-error:0.000886
#
# [4]	train-error:0.000806	eval-error:0.000897
#
# [5]	train-error:0.000772	eval-error:0.000841
#
# [6]	train-error:0.000767	eval-error:0.000865
#
# [7]	train-error:0.00072	eval-error:0.000793
#
# [8]	train-error:0.000717	eval-error:0.000777
#
# [9]	train-error:0.000708	eval-error:0.000757
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.008023229282863711, 'max_depth': 7, 'min_child_weight': 5.17961942421295, 'subsample': 0.75}, logloss: 0.1997
# [0]	train-error:0.002464	eval-error:0.002485
#
# [1]	train-error:0.002103	eval-error:0.002102
#
# [2]	train-error:0.004233	eval-error:0.004402
#
# [3]	train-error:0.00135	eval-error:0.001479
#
# [4]	train-error:0.001383	eval-error:0.0015
#
# [5]	train-error:0.001331	eval-error:0.001441
#
# [6]	train-error:0.001358	eval-error:0.001461
#
# [7]	train-error:0.001265	eval-error:0.001346
#
# [8]	train-error:0.001198	eval-error:0.001316
#
# [9]	train-error:0.001437	eval-error:0.001504
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.0023650020325680153, 'max_depth': 5, 'min_child_weight': 2.4123056887922494, 'subsample': 0.8}, logloss: 0.2024
# [0]	train-error:0.00225	eval-error:0.002241
#
# [1]	train-error:0.002368	eval-error:0.00234
#
# [2]	train-error:0.004268	eval-error:0.004398
#
# [3]	train-error:0.001705	eval-error:0.001865
#
# [4]	train-error:0.001279	eval-error:0.001423
#
# [5]	train-error:0.001329	eval-error:0.00143
#
# [6]	train-error:0.001313	eval-error:0.001441
#
# [7]	train-error:0.001319	eval-error:0.001448
#
# [8]	train-error:0.001516	eval-error:0.00159
#
# [9]	train-error:0.001544	eval-error:0.001595
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 4.4726195774979587e-05, 'max_depth': 5, 'min_child_weight': 0.6403430979940217, 'subsample': 0.65}, logloss: 0.2022
# [0]	train-error:0.000993	eval-error:0.001094
#
# [1]	train-error:0.00072	eval-error:0.000831
#
# [2]	train-error:0.000816	eval-error:0.00092
#
# [3]	train-error:0.000744	eval-error:0.000852
#
# [4]	train-error:0.000717	eval-error:0.000831
#
# [5]	train-error:0.000712	eval-error:0.000793
#
# [6]	train-error:0.000718	eval-error:0.00082
#
# [7]	train-error:0.000684	eval-error:0.000782
#
# [8]	train-error:0.000714	eval-error:0.000779
#
# [9]	train-error:0.000637	eval-error:0.00072
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 7.634594106769651e-08, 'max_depth': 7, 'min_child_weight': 0.16267591710506507, 'subsample': 0.7000000000000001}, logloss: 0.1999
# [0]	train-error:0.005713	eval-error:0.005777
#
# [1]	train-error:0.002543	eval-error:0.002492
#
# [2]	train-error:0.005545	eval-error:0.005721
#
# [3]	train-error:0.002317	eval-error:0.002404
#
# [4]	train-error:0.002298	eval-error:0.002304
#
# [5]	train-error:0.002288	eval-error:0.002302
#
# [6]	train-error:0.002065	eval-error:0.002139
#
# [7]	train-error:0.002034	eval-error:0.002112
#
# [8]	train-error:0.002663	eval-error:0.002664
#
# [9]	train-error:0.002649	eval-error:0.002651
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.02543153272542293, 'max_depth': 4, 'min_child_weight': 0.24863547869209432, 'subsample': 0.7000000000000001}, logloss: 0.2055
# [0]	train-error:0.000489	eval-error:0.000541
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000438	eval-error:0.000507
#
# [3]	train-error:0.000402	eval-error:0.000458
#
# [4]	train-error:0.000423	eval-error:0.000492
#
# [5]	train-error:0.000418	eval-error:0.000483
#
# [6]	train-error:0.000414	eval-error:0.000487
#
# [7]	train-error:0.000409	eval-error:0.000474
#
# [8]	train-error:0.000402	eval-error:0.000476
#
# [9]	train-error:0.000384	eval-error:0.000444
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0157280377402228e-08, 'max_depth': 9, 'min_child_weight': 0.934856680043736, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.00049	eval-error:0.000541
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000401	eval-error:0.000453
#
# [3]	train-error:0.000402	eval-error:0.000455
#
# [4]	train-error:0.000388	eval-error:0.00044
#
# [5]	train-error:0.000427	eval-error:0.000485
#
# [6]	train-error:0.000386	eval-error:0.000442
#
# [7]	train-error:0.000403	eval-error:0.000458
#
# [8]	train-error:0.000364	eval-error:0.000403
#
# [9]	train-error:0.000365	eval-error:0.000419
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.7377027746792613e-06, 'max_depth': 9, 'min_child_weight': 1.1689204370685218, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.00049	eval-error:0.000541
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000401	eval-error:0.000453
#
# [3]	train-error:0.000402	eval-error:0.000455
#
# [4]	train-error:0.000388	eval-error:0.00044
#
# [5]	train-error:0.000427	eval-error:0.000485
#
# [6]	train-error:0.000386	eval-error:0.000442
#
# [7]	train-error:0.000401	eval-error:0.000458
#
# [8]	train-error:0.000386	eval-error:0.00043
#
# [9]	train-error:0.000393	eval-error:0.000453
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.271399751893654e-08, 'max_depth': 9, 'min_child_weight': 1.0022707584942978, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.000484	eval-error:0.000523
#
# [1]	train-error:0.000433	eval-error:0.000489
#
# [2]	train-error:0.000424	eval-error:0.000487
#
# [3]	train-error:0.000403	eval-error:0.000455
#
# [4]	train-error:0.000397	eval-error:0.000453
#
# [5]	train-error:0.000424	eval-error:0.000476
#
# [6]	train-error:0.000411	eval-error:0.000474
#
# [7]	train-error:0.000378	eval-error:0.000433
#
# [8]	train-error:0.000366	eval-error:0.000417
#
# [9]	train-error:0.000362	eval-error:0.000412
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.75833086622005e-08, 'max_depth': 9, 'min_child_weight': 1.1564014903882334, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000479	eval-error:0.000521
#
# [1]	train-error:0.000428	eval-error:0.000485
#
# [2]	train-error:0.00042	eval-error:0.000485
#
# [3]	train-error:0.000397	eval-error:0.000451
#
# [4]	train-error:0.000393	eval-error:0.000446
#
# [5]	train-error:0.000423	eval-error:0.000474
#
# [6]	train-error:0.000409	eval-error:0.000474
#
# [7]	train-error:0.000372	eval-error:0.000417
#
# [8]	train-error:0.000363	eval-error:0.000412
#
# [9]	train-error:0.000362	eval-error:0.000412
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.899790478029309e-06, 'max_depth': 9, 'min_child_weight': 0.6752187382188584, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000533	eval-error:0.000569
#
# [1]	train-error:0.000456	eval-error:0.000512
#
# [2]	train-error:0.000441	eval-error:0.000503
#
# [3]	train-error:0.000433	eval-error:0.000494
#
# [4]	train-error:0.000444	eval-error:0.000514
#
# [5]	train-error:0.000436	eval-error:0.000496
#
# [6]	train-error:0.000429	eval-error:0.000494
#
# [7]	train-error:0.000391	eval-error:0.000451
#
# [8]	train-error:0.000377	eval-error:0.00044
#
# [9]	train-error:0.000369	eval-error:0.000417
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.3048251030475917e-08, 'max_depth': 9, 'min_child_weight': 8.36361858880527, 'subsample': 0.8500000000000001}, logloss: 0.1986
# [0]	train-error:0.000771	eval-error:0.000868
#
# [1]	train-error:0.00077	eval-error:0.00087
#
# [2]	train-error:0.000686	eval-error:0.000775
#
# [3]	train-error:0.000676	eval-error:0.000759
#
# [4]	train-error:0.000807	eval-error:0.000911
#
# [5]	train-error:0.000673	eval-error:0.000745
#
# [6]	train-error:0.000686	eval-error:0.000775
#
# [7]	train-error:0.000754	eval-error:0.000845
#
# [8]	train-error:0.00065	eval-error:0.000736
#
# [9]	train-error:0.000657	eval-error:0.000734
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0004621083382970862, 'max_depth': 8, 'min_child_weight': 0.5537880769160572, 'subsample': 0.8500000000000001}, logloss: 0.1990
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006245	eval-error:0.006418
#
# [2]	train-error:0.007735	eval-error:0.00793
#
# [3]	train-error:0.006609	eval-error:0.006826
#
# [4]	train-error:0.007214	eval-error:0.007456
#
# [5]	train-error:0.006013	eval-error:0.00623
#
# [6]	train-error:0.005998	eval-error:0.006199
#
# [7]	train-error:0.006052	eval-error:0.006246
#
# [8]	train-error:0.006051	eval-error:0.006251
#
# [9]	train-error:0.006158	eval-error:0.006332
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.7205847877178397e-07, 'max_depth': 3, 'min_child_weight': 0.6164462174868485, 'subsample': 0.9500000000000001}, logloss: 0.2098
# [0]	train-error:0.000484	eval-error:0.000523
#
# [1]	train-error:0.000432	eval-error:0.000489
#
# [2]	train-error:0.000421	eval-error:0.000478
#
# [3]	train-error:0.00041	eval-error:0.000462
#
# [4]	train-error:0.000407	eval-error:0.000467
#
# [5]	train-error:0.000407	eval-error:0.000467
#
# [6]	train-error:0.000407	eval-error:0.000483
#
# [7]	train-error:0.000378	eval-error:0.000446
#
# [8]	train-error:0.000375	eval-error:0.000444
#
# [9]	train-error:0.000365	eval-error:0.000428
#
# params: {'colsample_bytree': 0.9, 'gamma': 7.4955938858791325e-06, 'max_depth': 9, 'min_child_weight': 1.4107851258561168, 'subsample': 0.9}, logloss: 0.1985
# [0]	train-error:0.000501	eval-error:0.000535
#
# [1]	train-error:0.000438	eval-error:0.000496
#
# [2]	train-error:0.000429	eval-error:0.000489
#
# [3]	train-error:0.000429	eval-error:0.000483
#
# [4]	train-error:0.000413	eval-error:0.000464
#
# [5]	train-error:0.000443	eval-error:0.000489
#
# [6]	train-error:0.00042	eval-error:0.00048
#
# [7]	train-error:0.00039	eval-error:0.00044
#
# [8]	train-error:0.000382	eval-error:0.000435
#
# [9]	train-error:0.000377	eval-error:0.000426
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.905066027488156e-07, 'max_depth': 9, 'min_child_weight': 4.144148512367074, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000773	eval-error:0.000868
#
# [1]	train-error:0.000757	eval-error:0.000809
#
# [2]	train-error:0.000656	eval-error:0.00073
#
# [3]	train-error:0.000661	eval-error:0.000743
#
# [4]	train-error:0.000738	eval-error:0.000825
#
# [5]	train-error:0.000643	eval-error:0.000732
#
# [6]	train-error:0.000643	eval-error:0.000725
#
# [7]	train-error:0.000749	eval-error:0.000834
#
# [8]	train-error:0.000643	eval-error:0.000727
#
# [9]	train-error:0.000634	eval-error:0.000718
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0005049797537214336, 'max_depth': 8, 'min_child_weight': 0.7791048377434087, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.002254	eval-error:0.002252
#
# [1]	train-error:0.002366	eval-error:0.002338
#
# [2]	train-error:0.004439	eval-error:0.004599
#
# [3]	train-error:0.002607	eval-error:0.002644
#
# [4]	train-error:0.001948	eval-error:0.002005
#
# [5]	train-error:0.001291	eval-error:0.001414
#
# [6]	train-error:0.001909	eval-error:0.002068
#
# [7]	train-error:0.001226	eval-error:0.001357
#
# [8]	train-error:0.00146	eval-error:0.001541
#
# [9]	train-error:0.002115	eval-error:0.002107
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 7.102287097040292e-08, 'max_depth': 5, 'min_child_weight': 1.2987436563538375, 'subsample': 0.9}, logloss: 0.2022
# [0]	train-error:0.000498	eval-error:0.000532
#
# [1]	train-error:0.000437	eval-error:0.000494
#
# [2]	train-error:0.000427	eval-error:0.000489
#
# [3]	train-error:0.000427	eval-error:0.000485
#
# [4]	train-error:0.000415	eval-error:0.000464
#
# [5]	train-error:0.000443	eval-error:0.000489
#
# [6]	train-error:0.000421	eval-error:0.00048
#
# [7]	train-error:0.000395	eval-error:0.000446
#
# [8]	train-error:0.00038	eval-error:0.000428
#
# [9]	train-error:0.000376	eval-error:0.000419
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 4.455476359733367e-06, 'max_depth': 9, 'min_child_weight': 3.3546905879896864, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.007427	eval-error:0.007631
#
# [1]	train-error:0.006232	eval-error:0.006389
#
# [2]	train-error:0.007427	eval-error:0.007631
#
# [3]	train-error:0.007427	eval-error:0.007628
#
# [4]	train-error:0.007427	eval-error:0.007628
#
# [5]	train-error:0.006232	eval-error:0.006389
#
# [6]	train-error:0.006278	eval-error:0.006491
#
# [7]	train-error:0.006232	eval-error:0.006389
#
# [8]	train-error:0.00623	eval-error:0.006387
#
# [9]	train-error:0.00619	eval-error:0.006357
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.7341017527493168e-08, 'max_depth': 3, 'min_child_weight': 9.02841229581539, 'subsample': 0.8}, logloss: 0.2094
# [0]	train-error:0.002072	eval-error:0.002238
#
# [1]	train-error:0.001015	eval-error:0.001174
#
# [2]	train-error:0.000989	eval-error:0.001081
#
# [3]	train-error:0.000813	eval-error:0.000909
#
# [4]	train-error:0.000809	eval-error:0.000952
#
# [5]	train-error:0.00072	eval-error:0.00085
#
# [6]	train-error:0.00068	eval-error:0.000797
#
# [7]	train-error:0.000682	eval-error:0.000802
#
# [8]	train-error:0.000637	eval-error:0.000748
#
# [9]	train-error:0.000597	eval-error:0.000714
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.00030011287091066233, 'max_depth': 8, 'min_child_weight': 1.6679358912063988, 'subsample': 0.8500000000000001}, logloss: 0.1998
# [0]	train-error:0.000949	eval-error:0.001072
#
# [1]	train-error:0.00072	eval-error:0.000831
#
# [2]	train-error:0.000696	eval-error:0.000797
#
# [3]	train-error:0.000705	eval-error:0.00082
#
# [4]	train-error:0.000786	eval-error:0.000888
#
# [5]	train-error:0.000671	eval-error:0.00075
#
# [6]	train-error:0.000741	eval-error:0.000825
#
# [7]	train-error:0.000768	eval-error:0.000854
#
# [8]	train-error:0.000721	eval-error:0.000791
#
# [9]	train-error:0.000662	eval-error:0.000741
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00017698190434827345, 'max_depth': 8, 'min_child_weight': 0.4618748331670358, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000481	eval-error:0.000519
#
# [1]	train-error:0.000501	eval-error:0.000557
#
# [2]	train-error:0.000646	eval-error:0.000684
#
# [3]	train-error:0.000424	eval-error:0.000455
#
# [4]	train-error:0.000421	eval-error:0.000451
#
# [5]	train-error:0.000415	eval-error:0.000451
#
# [6]	train-error:0.000421	eval-error:0.00046
#
# [7]	train-error:0.00039	eval-error:0.000412
#
# [8]	train-error:0.000351	eval-error:0.000403
#
# [9]	train-error:0.000329	eval-error:0.000383
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.7254028287112565, 'max_depth': 9, 'min_child_weight': 0.755529304333477, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000769	eval-error:0.000865
#
# [1]	train-error:0.000776	eval-error:0.000879
#
# [2]	train-error:0.00069	eval-error:0.000777
#
# [3]	train-error:0.000683	eval-error:0.000777
#
# [4]	train-error:0.000682	eval-error:0.000777
#
# [5]	train-error:0.000674	eval-error:0.000766
#
# [6]	train-error:0.000675	eval-error:0.000759
#
# [7]	train-error:0.000749	eval-error:0.000836
#
# [8]	train-error:0.000646	eval-error:0.000727
#
# [9]	train-error:0.000621	eval-error:0.000705
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.0827937048348656e-07, 'max_depth': 8, 'min_child_weight': 0.26874790214943156, 'subsample': 0.9}, logloss: 0.1989
# [0]	train-error:0.001347	eval-error:0.001445
#
# [1]	train-error:0.001439	eval-error:0.001511
#
# [2]	train-error:0.001179	eval-error:0.001296
#
# [3]	train-error:0.001133	eval-error:0.001253
#
# [4]	train-error:0.001176	eval-error:0.001289
#
# [5]	train-error:0.001149	eval-error:0.001271
#
# [6]	train-error:0.001166	eval-error:0.00128
#
# [7]	train-error:0.001143	eval-error:0.001255
#
# [8]	train-error:0.001149	eval-error:0.001255
#
# [9]	train-error:0.001139	eval-error:0.001253
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.1220317695272585e-06, 'max_depth': 6, 'min_child_weight': 3.176574561103231, 'subsample': 0.8}, logloss: 0.2001
# [0]	train-error:0.000887	eval-error:0.000947
#
# [1]	train-error:0.000726	eval-error:0.000779
#
# [2]	train-error:0.001379	eval-error:0.001488
#
# [3]	train-error:0.00072	eval-error:0.000761
#
# [4]	train-error:0.00077	eval-error:0.000825
#
# [5]	train-error:0.000711	eval-error:0.000768
#
# [6]	train-error:0.000856	eval-error:0.000942
#
# [7]	train-error:0.000827	eval-error:0.000915
#
# [8]	train-error:0.000829	eval-error:0.000918
#
# [9]	train-error:0.000808	eval-error:0.000895
#
# params: {'colsample_bytree': 0.8, 'gamma': 3.671599939518886e-07, 'max_depth': 7, 'min_child_weight': 0.10089281463535828, 'subsample': 0.9500000000000001}, logloss: 0.1997
# [0]	train-error:0.000514	eval-error:0.000544
#
# [1]	train-error:0.000517	eval-error:0.000575
#
# [2]	train-error:0.000692	eval-error:0.000716
#
# [3]	train-error:0.00045	eval-error:0.000494
#
# [4]	train-error:0.000451	eval-error:0.000496
#
# [5]	train-error:0.000439	eval-error:0.000446
#
# [6]	train-error:0.000432	eval-error:0.000489
#
# [7]	train-error:0.000422	eval-error:0.000444
#
# [8]	train-error:0.000381	eval-error:0.000426
#
# [9]	train-error:0.00034	eval-error:0.000401
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.0976947874343255e-05, 'max_depth': 9, 'min_child_weight': 6.9693768763523, 'subsample': 0.9}, logloss: 0.1986
# [0]	train-error:0.000769	eval-error:0.000865
#
# [1]	train-error:0.000754	eval-error:0.000807
#
# [2]	train-error:0.000652	eval-error:0.000723
#
# [3]	train-error:0.000657	eval-error:0.000739
#
# [4]	train-error:0.000735	eval-error:0.000818
#
# [5]	train-error:0.000642	eval-error:0.00073
#
# [6]	train-error:0.000643	eval-error:0.000723
#
# [7]	train-error:0.000748	eval-error:0.000834
#
# [8]	train-error:0.000643	eval-error:0.000723
#
# [9]	train-error:0.000631	eval-error:0.000714
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0015371863581078934, 'max_depth': 8, 'min_child_weight': 0.33090480443147735, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.005715	eval-error:0.005768
#
# [1]	train-error:0.005707	eval-error:0.005764
#
# [2]	train-error:0.002659	eval-error:0.002671
#
# [3]	train-error:0.002657	eval-error:0.002669
#
# [4]	train-error:0.002658	eval-error:0.002669
#
# [5]	train-error:0.002658	eval-error:0.002669
#
# [6]	train-error:0.002658	eval-error:0.002669
#
# [7]	train-error:0.002626	eval-error:0.002644
#
# [8]	train-error:0.00242	eval-error:0.002417
#
# [9]	train-error:0.002419	eval-error:0.002417
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.0183280722139156e-06, 'max_depth': 4, 'min_child_weight': 2.046144709373219, 'subsample': 0.8500000000000001}, logloss: 0.2047
# [0]	train-error:0.000994	eval-error:0.001103
#
# [1]	train-error:0.000828	eval-error:0.000913
#
# [2]	train-error:0.001532	eval-error:0.001645
#
# [3]	train-error:0.000753	eval-error:0.000818
#
# [4]	train-error:0.000718	eval-error:0.000791
#
# [5]	train-error:0.000692	eval-error:0.000757
#
# [6]	train-error:0.000738	eval-error:0.000825
#
# [7]	train-error:0.000724	eval-error:0.000788
#
# [8]	train-error:0.000731	eval-error:0.000795
#
# [9]	train-error:0.000736	eval-error:0.000807
#
# params: {'colsample_bytree': 0.8, 'gamma': 6.197479167110729e-06, 'max_depth': 7, 'min_child_weight': 0.45182390390826405, 'subsample': 0.8}, logloss: 0.1997
# [0]	train-error:0.002155	eval-error:0.002349
#
# [1]	train-error:0.001014	eval-error:0.001176
#
# [2]	train-error:0.001007	eval-error:0.00111
#
# [3]	train-error:0.000801	eval-error:0.000942
#
# [4]	train-error:0.000813	eval-error:0.000938
#
# [5]	train-error:0.000748	eval-error:0.000899
#
# [6]	train-error:0.000704	eval-error:0.000822
#
# [7]	train-error:0.000656	eval-error:0.000775
#
# [8]	train-error:0.000657	eval-error:0.000777
#
# [9]	train-error:0.000619	eval-error:0.000739
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 3.7266892247912605e-08, 'max_depth': 8, 'min_child_weight': 0.8615744317259246, 'subsample': 0.6000000000000001}, logloss: 0.1998
# [0]	train-error:0.002255	eval-error:0.002254
#
# [1]	train-error:0.002367	eval-error:0.002338
#
# [2]	train-error:0.004439	eval-error:0.004599
#
# [3]	train-error:0.002608	eval-error:0.002642
#
# [4]	train-error:0.001952	eval-error:0.002005
#
# [5]	train-error:0.001291	eval-error:0.001414
#
# [6]	train-error:0.00191	eval-error:0.002073
#
# [7]	train-error:0.001226	eval-error:0.001362
#
# [8]	train-error:0.00146	eval-error:0.001545
#
# [9]	train-error:0.002115	eval-error:0.002112
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.06978002819012792, 'max_depth': 5, 'min_child_weight': 1.555191424678886, 'subsample': 0.9}, logloss: 0.2022
# [0]	train-error:0.002103	eval-error:0.002146
#
# [1]	train-error:0.001187	eval-error:0.001321
#
# [2]	train-error:0.001729	eval-error:0.001919
#
# [3]	train-error:0.001084	eval-error:0.001214
#
# [4]	train-error:0.001154	eval-error:0.001276
#
# [5]	train-error:0.001079	eval-error:0.001208
#
# [6]	train-error:0.000943	eval-error:0.001031
#
# [7]	train-error:0.000905	eval-error:0.000999
#
# [8]	train-error:0.001035	eval-error:0.001153
#
# [9]	train-error:0.001033	eval-error:0.001142
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.00011239837010846441, 'max_depth': 6, 'min_child_weight': 0.2032192643988869, 'subsample': 0.9}, logloss: 0.2014
# [0]	train-error:0.000998	eval-error:0.001117
#
# [1]	train-error:0.000963	eval-error:0.001087
#
# [2]	train-error:0.000822	eval-error:0.000924
#
# [3]	train-error:0.00094	eval-error:0.001058
#
# [4]	train-error:0.00086	eval-error:0.000981
#
# [5]	train-error:0.000889	eval-error:0.000992
#
# [6]	train-error:0.000844	eval-error:0.000954
#
# [7]	train-error:0.000888	eval-error:0.000992
#
# [8]	train-error:0.000847	eval-error:0.000942
#
# [9]	train-error:0.000844	eval-error:0.000933
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.1657430970010127e-07, 'max_depth': 7, 'min_child_weight': 1.136302795156434, 'subsample': 0.8}, logloss: 0.1993
# [0]	train-error:0.000492	eval-error:0.000528
#
# [1]	train-error:0.000464	eval-error:0.000544
#
# [2]	train-error:0.000672	eval-error:0.000718
#
# [3]	train-error:0.000379	eval-error:0.000424
#
# [4]	train-error:0.000371	eval-error:0.00043
#
# [5]	train-error:0.000379	eval-error:0.000437
#
# [6]	train-error:0.000386	eval-error:0.000451
#
# [7]	train-error:0.000347	eval-error:0.000387
#
# [8]	train-error:0.000342	eval-error:0.000387
#
# [9]	train-error:0.000328	eval-error:0.000367
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.613233460881199e-05, 'max_depth': 9, 'min_child_weight': 3.0475919300567202, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000779	eval-error:0.000845
#
# [1]	train-error:0.000794	eval-error:0.000877
#
# [2]	train-error:0.000713	eval-error:0.000811
#
# [3]	train-error:0.000716	eval-error:0.000818
#
# [4]	train-error:0.000745	eval-error:0.000827
#
# [5]	train-error:0.000682	eval-error:0.000775
#
# [6]	train-error:0.000686	eval-error:0.000782
#
# [7]	train-error:0.000681	eval-error:0.00077
#
# [8]	train-error:0.000665	eval-error:0.000759
#
# [9]	train-error:0.000651	eval-error:0.000734
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.00161196567699374, 'max_depth': 8, 'min_child_weight': 2.0157876782341595, 'subsample': 0.75}, logloss: 0.1990
# [0]	train-error:0.002103	eval-error:0.002146
#
# [1]	train-error:0.001189	eval-error:0.001323
#
# [2]	train-error:0.001729	eval-error:0.001921
#
# [3]	train-error:0.001087	eval-error:0.001214
#
# [4]	train-error:0.001153	eval-error:0.001282
#
# [5]	train-error:0.001055	eval-error:0.001167
#
# [6]	train-error:0.000893	eval-error:0.001017
#
# [7]	train-error:0.000917	eval-error:0.001015
#
# [8]	train-error:0.001038	eval-error:0.001146
#
# [9]	train-error:0.00103	eval-error:0.001135
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 1.5690034843593382e-08, 'max_depth': 6, 'min_child_weight': 0.1348231978968475, 'subsample': 0.9500000000000001}, logloss: 0.2014
# [0]	train-error:0.00216	eval-error:0.002279
#
# [1]	train-error:0.001256	eval-error:0.001421
#
# [2]	train-error:0.001028	eval-error:0.001119
#
# [3]	train-error:0.000919	eval-error:0.001051
#
# [4]	train-error:0.000797	eval-error:0.000909
#
# [5]	train-error:0.000735	eval-error:0.000804
#
# [6]	train-error:0.000757	eval-error:0.00085
#
# [7]	train-error:0.000699	eval-error:0.000779
#
# [8]	train-error:0.000689	eval-error:0.000793
#
# [9]	train-error:0.000645	eval-error:0.000709
#
# params: {'colsample_bytree': 0.65, 'gamma': 6.239779713338497e-07, 'max_depth': 7, 'min_child_weight': 0.34141487554054517, 'subsample': 0.7000000000000001}, logloss: 0.2001
# [0]	train-error:0.000479	eval-error:0.000521
#
# [1]	train-error:0.000427	eval-error:0.000485
#
# [2]	train-error:0.000418	eval-error:0.000474
#
# [3]	train-error:0.000406	eval-error:0.000458
#
# [4]	train-error:0.000404	eval-error:0.000462
#
# [5]	train-error:0.000405	eval-error:0.000462
#
# [6]	train-error:0.000405	eval-error:0.000478
#
# [7]	train-error:0.000375	eval-error:0.000442
#
# [8]	train-error:0.000372	eval-error:0.00044
#
# [9]	train-error:0.000361	eval-error:0.000426
#
# params: {'colsample_bytree': 0.9, 'gamma': 4.7043661340830206e-05, 'max_depth': 9, 'min_child_weight': 0.5159716461829418, 'subsample': 0.9}, logloss: 0.1985
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006244	eval-error:0.006416
#
# [2]	train-error:0.007718	eval-error:0.007916
#
# [3]	train-error:0.00659	eval-error:0.006815
#
# [4]	train-error:0.007207	eval-error:0.007447
#
# [5]	train-error:0.006008	eval-error:0.006226
#
# [6]	train-error:0.005989	eval-error:0.00619
#
# [7]	train-error:0.006051	eval-error:0.006251
#
# [8]	train-error:0.00605	eval-error:0.006253
#
# [9]	train-error:0.006162	eval-error:0.006337
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.5264527002600753e-06, 'max_depth': 3, 'min_child_weight': 0.705660636749987, 'subsample': 0.8}, logloss: 0.2098
# [0]	train-error:0.001016	eval-error:0.00111
#
# [1]	train-error:0.000844	eval-error:0.000893
#
# [2]	train-error:0.000908	eval-error:0.00099
#
# [3]	train-error:0.000797	eval-error:0.000881
#
# [4]	train-error:0.000782	eval-error:0.000856
#
# [5]	train-error:0.000754	eval-error:0.000818
#
# [6]	train-error:0.00076	eval-error:0.000845
#
# [7]	train-error:0.000714	eval-error:0.000782
#
# [8]	train-error:0.000714	eval-error:0.000766
#
# [9]	train-error:0.000674	eval-error:0.000736
#
# params: {'colsample_bytree': 0.75, 'gamma': 1.3707795653064947e-07, 'max_depth': 7, 'min_child_weight': 0.22309558110975625, 'subsample': 0.75}, logloss: 0.1997
# [0]	train-error:0.001654	eval-error:0.001788
#
# [1]	train-error:0.000966	eval-error:0.001108
#
# [2]	train-error:0.000612	eval-error:0.000686
#
# [3]	train-error:0.000512	eval-error:0.000566
#
# [4]	train-error:0.000471	eval-error:0.000532
#
# [5]	train-error:0.00044	eval-error:0.000478
#
# [6]	train-error:0.000457	eval-error:0.000471
#
# [7]	train-error:0.000308	eval-error:0.000394
#
# [8]	train-error:0.000292	eval-error:0.000369
#
# [9]	train-error:0.000285	eval-error:0.000362
#
# params: {'colsample_bytree': 0.65, 'gamma': 6.215098916209328e-08, 'max_depth': 9, 'min_child_weight': 2.436317588610229, 'subsample': 0.8500000000000001}, logloss: 0.1988
# [0]	train-error:0.005755	eval-error:0.005804
#
# [1]	train-error:0.005755	eval-error:0.005804
#
# [2]	train-error:0.002701	eval-error:0.002707
#
# [3]	train-error:0.002662	eval-error:0.00268
#
# [4]	train-error:0.002661	eval-error:0.00268
#
# [5]	train-error:0.002659	eval-error:0.002673
#
# [6]	train-error:0.002656	eval-error:0.002671
#
# [7]	train-error:0.002623	eval-error:0.002646
#
# [8]	train-error:0.002421	eval-error:0.00242
#
# [9]	train-error:0.002421	eval-error:0.00242
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.010082069029941774, 'max_depth': 4, 'min_child_weight': 5.4951350544781485, 'subsample': 0.65}, logloss: 0.2047
# [0]	train-error:0.000776	eval-error:0.00087
#
# [1]	train-error:0.00076	eval-error:0.000813
#
# [2]	train-error:0.000656	eval-error:0.00073
#
# [3]	train-error:0.00066	eval-error:0.000743
#
# [4]	train-error:0.000738	eval-error:0.000827
#
# [5]	train-error:0.000643	eval-error:0.000732
#
# [6]	train-error:0.000643	eval-error:0.000727
#
# [7]	train-error:0.000748	eval-error:0.000834
#
# [8]	train-error:0.000643	eval-error:0.000727
#
# [9]	train-error:0.000634	eval-error:0.000718
#
# params: {'colsample_bytree': 0.9, 'gamma': 1.3155421834592007e-06, 'max_depth': 8, 'min_child_weight': 1.1238690992605773, 'subsample': 0.9500000000000001}, logloss: 0.1989
# [0]	train-error:0.002254	eval-error:0.002261
#
# [1]	train-error:0.002367	eval-error:0.002343
#
# [2]	train-error:0.004265	eval-error:0.004436
#
# [3]	train-error:0.001779	eval-error:0.001948
#
# [4]	train-error:0.001259	eval-error:0.001416
#
# [5]	train-error:0.001199	eval-error:0.001323
#
# [6]	train-error:0.001229	eval-error:0.00135
#
# [7]	train-error:0.001249	eval-error:0.001387
#
# [8]	train-error:0.001487	eval-error:0.001572
#
# [9]	train-error:0.001472	eval-error:0.001525
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 1.2194223115946912e-05, 'max_depth': 5, 'min_child_weight': 0.31366313385836914, 'subsample': 0.75}, logloss: 0.2021
# [0]	train-error:0.000823	eval-error:0.000936
#
# [1]	train-error:0.000687	eval-error:0.000777
#
# [2]	train-error:0.000844	eval-error:0.000924
#
# [3]	train-error:0.000643	eval-error:0.000709
#
# [4]	train-error:0.000608	eval-error:0.000689
#
# [5]	train-error:0.000592	eval-error:0.000666
#
# [6]	train-error:0.000643	eval-error:0.000734
#
# [7]	train-error:0.000674	eval-error:0.000754
#
# [8]	train-error:0.000594	eval-error:0.000664
#
# [9]	train-error:0.000586	eval-error:0.000641
#
# params: {'colsample_bytree': 0.8, 'gamma': 5.359770284028757e-07, 'max_depth': 8, 'min_child_weight': 0.3948823928607584, 'subsample': 0.8}, logloss: 0.1992
# [0]	train-error:0.001417	eval-error:0.001484
#
# [1]	train-error:0.001418	eval-error:0.0015
#
# [2]	train-error:0.001168	eval-error:0.001282
#
# [3]	train-error:0.001128	eval-error:0.001244
#
# [4]	train-error:0.001143	eval-error:0.001251
#
# [5]	train-error:0.001119	eval-error:0.001228
#
# [6]	train-error:0.001135	eval-error:0.001242
#
# [7]	train-error:0.001133	eval-error:0.001242
#
# [8]	train-error:0.001134	eval-error:0.001253
#
# [9]	train-error:0.001115	eval-error:0.001226
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.1249367426366541e-08, 'max_depth': 6, 'min_child_weight': 0.6120971172981141, 'subsample': 0.9}, logloss: 0.2001
# [0]	train-error:0.000484	eval-error:0.000523
#
# [1]	train-error:0.000432	eval-error:0.000489
#
# [2]	train-error:0.000422	eval-error:0.000487
#
# [3]	train-error:0.00041	eval-error:0.000464
#
# [4]	train-error:0.000404	eval-error:0.000469
#
# [5]	train-error:0.0004	eval-error:0.000467
#
# [6]	train-error:0.000406	eval-error:0.000485
#
# [7]	train-error:0.000366	eval-error:0.000444
#
# [8]	train-error:0.000363	eval-error:0.000426
#
# [9]	train-error:0.000362	eval-error:0.000426
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.06131205289438824, 'max_depth': 9, 'min_child_weight': 1.3297191135868855, 'subsample': 0.8500000000000001}, logloss: 0.1986
# [0]	train-error:0.000998	eval-error:0.001094
#
# [1]	train-error:0.000737	eval-error:0.000838
#
# [2]	train-error:0.000828	eval-error:0.000936
#
# [3]	train-error:0.000744	eval-error:0.000838
#
# [4]	train-error:0.000711	eval-error:0.000802
#
# [5]	train-error:0.000716	eval-error:0.0008
#
# [6]	train-error:0.000711	eval-error:0.000788
#
# [7]	train-error:0.000676	eval-error:0.000766
#
# [8]	train-error:0.000699	eval-error:0.00077
#
# [9]	train-error:0.00061	eval-error:0.000696
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 0.003293779428794091, 'max_depth': 7, 'min_child_weight': 4.132526928797244, 'subsample': 0.8500000000000001}, logloss: 0.1999
# [0]	train-error:0.000759	eval-error:0.000841
#
# [1]	train-error:0.00077	eval-error:0.000863
#
# [2]	train-error:0.000748	eval-error:0.000829
#
# [3]	train-error:0.000737	eval-error:0.00082
#
# [4]	train-error:0.00079	eval-error:0.000888
#
# [5]	train-error:0.000673	eval-error:0.000752
#
# [6]	train-error:0.000683	eval-error:0.000784
#
# [7]	train-error:0.000786	eval-error:0.000886
#
# [8]	train-error:0.00068	eval-error:0.000761
#
# [9]	train-error:0.000649	eval-error:0.000745
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 9.214327269931716e-06, 'max_depth': 8, 'min_child_weight': 0.851753866934497, 'subsample': 0.7000000000000001}, logloss: 0.1990
# [0]	train-error:0.000487	eval-error:0.000526
#
# [1]	train-error:0.000486	eval-error:0.000535
#
# [2]	train-error:0.000622	eval-error:0.000634
#
# [3]	train-error:0.000411	eval-error:0.000424
#
# [4]	train-error:0.000425	eval-error:0.000453
#
# [5]	train-error:0.000404	eval-error:0.000408
#
# [6]	train-error:0.000427	eval-error:0.000455
#
# [7]	train-error:0.000401	eval-error:0.000421
#
# [8]	train-error:0.000379	eval-error:0.000424
#
# [9]	train-error:0.000358	eval-error:0.000406
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 3.892208468834771e-06, 'max_depth': 9, 'min_child_weight': 2.6790480458334134, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000494	eval-error:0.000544
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000406	eval-error:0.00046
#
# [3]	train-error:0.000403	eval-error:0.000455
#
# [4]	train-error:0.000388	eval-error:0.000437
#
# [5]	train-error:0.00043	eval-error:0.000487
#
# [6]	train-error:0.000391	eval-error:0.000442
#
# [7]	train-error:0.000409	eval-error:0.00046
#
# [8]	train-error:0.000368	eval-error:0.000406
#
# [9]	train-error:0.000367	eval-error:0.000419
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.147328829862678e-05, 'max_depth': 9, 'min_child_weight': 1.8039326485282612, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.00049	eval-error:0.000541
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000401	eval-error:0.000453
#
# [3]	train-error:0.000402	eval-error:0.000455
#
# [4]	train-error:0.000388	eval-error:0.00044
#
# [5]	train-error:0.000427	eval-error:0.000485
#
# [6]	train-error:0.000386	eval-error:0.000442
#
# [7]	train-error:0.000401	eval-error:0.000458
#
# [8]	train-error:0.000386	eval-error:0.00043
#
# [9]	train-error:0.000393	eval-error:0.000453
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 9.836664428071936e-05, 'max_depth': 9, 'min_child_weight': 1.050654183572227, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.000731	eval-error:0.000811
#
# [1]	train-error:0.000433	eval-error:0.000487
#
# [2]	train-error:0.000482	eval-error:0.000514
#
# [3]	train-error:0.00067	eval-error:0.000745
#
# [4]	train-error:0.000648	eval-error:0.00073
#
# [5]	train-error:0.000658	eval-error:0.000736
#
# [6]	train-error:0.00062	eval-error:0.0007
#
# [7]	train-error:0.000465	eval-error:0.000507
#
# [8]	train-error:0.000422	eval-error:0.000458
#
# [9]	train-error:0.000419	eval-error:0.000462
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0006796763546790868, 'max_depth': 9, 'min_child_weight': 1.8390180751082559, 'subsample': 0.7000000000000001}, logloss: 0.1987
# [0]	train-error:0.000957	eval-error:0.001065
#
# [1]	train-error:0.000722	eval-error:0.000827
#
# [2]	train-error:0.000705	eval-error:0.000795
#
# [3]	train-error:0.000715	eval-error:0.000818
#
# [4]	train-error:0.000797	eval-error:0.000906
#
# [5]	train-error:0.00069	eval-error:0.000788
#
# [6]	train-error:0.000785	eval-error:0.000879
#
# [7]	train-error:0.000782	eval-error:0.000877
#
# [8]	train-error:0.000771	eval-error:0.000865
#
# [9]	train-error:0.000603	eval-error:0.000677
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.0002047891982645688, 'max_depth': 8, 'min_child_weight': 1.4640896211232204, 'subsample': 0.8}, logloss: 0.1989
# [0]	train-error:0.000508	eval-error:0.000555
#
# [1]	train-error:0.00045	eval-error:0.000503
#
# [2]	train-error:0.00046	eval-error:0.000512
#
# [3]	train-error:0.000438	eval-error:0.000485
#
# [4]	train-error:0.000449	eval-error:0.000505
#
# [5]	train-error:0.000458	eval-error:0.000505
#
# [6]	train-error:0.000443	eval-error:0.000521
#
# [7]	train-error:0.000455	eval-error:0.000512
#
# [8]	train-error:0.000428	eval-error:0.000494
#
# [9]	train-error:0.000418	eval-error:0.000485
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.3030915494067875e-05, 'max_depth': 9, 'min_child_weight': 3.847454246903396, 'subsample': 0.65}, logloss: 0.1987
# [0]	train-error:0.000486	eval-error:0.000535
#
# [1]	train-error:0.00044	eval-error:0.000498
#
# [2]	train-error:0.000397	eval-error:0.000451
#
# [3]	train-error:0.000396	eval-error:0.000451
#
# [4]	train-error:0.000381	eval-error:0.000435
#
# [5]	train-error:0.000422	eval-error:0.000483
#
# [6]	train-error:0.000381	eval-error:0.000437
#
# [7]	train-error:0.000398	eval-error:0.000458
#
# [8]	train-error:0.000381	eval-error:0.000424
#
# [9]	train-error:0.00039	eval-error:0.000449
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 3.70617196060936e-05, 'max_depth': 9, 'min_child_weight': 0.5359937825005604, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.000957	eval-error:0.001065
#
# [1]	train-error:0.000733	eval-error:0.000847
#
# [2]	train-error:0.000711	eval-error:0.000802
#
# [3]	train-error:0.000715	eval-error:0.000818
#
# [4]	train-error:0.000791	eval-error:0.000886
#
# [5]	train-error:0.000682	eval-error:0.000773
#
# [6]	train-error:0.000686	eval-error:0.000777
#
# [7]	train-error:0.000773	eval-error:0.000856
#
# [8]	train-error:0.000669	eval-error:0.000745
#
# [9]	train-error:0.000668	eval-error:0.000752
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 6.186708090723761e-05, 'max_depth': 8, 'min_child_weight': 2.2386708153583137, 'subsample': 0.8}, logloss: 0.1990
# [0]	train-error:0.000481	eval-error:0.000521
#
# [1]	train-error:0.000432	eval-error:0.000487
#
# [2]	train-error:0.000421	eval-error:0.000483
#
# [3]	train-error:0.000408	eval-error:0.000462
#
# [4]	train-error:0.000403	eval-error:0.000464
#
# [5]	train-error:0.0004	eval-error:0.000462
#
# [6]	train-error:0.000406	eval-error:0.000478
#
# [7]	train-error:0.000367	eval-error:0.000442
#
# [8]	train-error:0.000364	eval-error:0.000421
#
# [9]	train-error:0.00036	eval-error:0.000417
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.431741331005986e-07, 'max_depth': 9, 'min_child_weight': 0.9174339464387951, 'subsample': 0.8500000000000001}, logloss: 0.1985
# [0]	train-error:0.000758	eval-error:0.000841
#
# [1]	train-error:0.000771	eval-error:0.000865
#
# [2]	train-error:0.000748	eval-error:0.000831
#
# [3]	train-error:0.000738	eval-error:0.00082
#
# [4]	train-error:0.000797	eval-error:0.000902
#
# [5]	train-error:0.000676	eval-error:0.000757
#
# [6]	train-error:0.000685	eval-error:0.000784
#
# [7]	train-error:0.000787	eval-error:0.000886
#
# [8]	train-error:0.000682	eval-error:0.000764
#
# [9]	train-error:0.000652	eval-error:0.000748
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.6401634470944019e-06, 'max_depth': 8, 'min_child_weight': 1.2498764920890553, 'subsample': 0.7000000000000001}, logloss: 0.1990
# [0]	train-error:0.000732	eval-error:0.000813
#
# [1]	train-error:0.000435	eval-error:0.000494
#
# [2]	train-error:0.000502	eval-error:0.000548
#
# [3]	train-error:0.000678	eval-error:0.000759
#
# [4]	train-error:0.000653	eval-error:0.000732
#
# [5]	train-error:0.000472	eval-error:0.000528
#
# [6]	train-error:0.000646	eval-error:0.000727
#
# [7]	train-error:0.000462	eval-error:0.00051
#
# [8]	train-error:0.000485	eval-error:0.000523
#
# [9]	train-error:0.000433	eval-error:0.000489
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.4323004017530583e-06, 'max_depth': 9, 'min_child_weight': 1.7367845082371292, 'subsample': 0.65}, logloss: 0.1987
# [0]	train-error:0.000806	eval-error:0.00087
#
# [1]	train-error:0.000699	eval-error:0.000773
#
# [2]	train-error:0.001054	eval-error:0.001131
#
# [3]	train-error:0.000715	eval-error:0.000791
#
# [4]	train-error:0.000649	eval-error:0.000739
#
# [5]	train-error:0.000643	eval-error:0.000732
#
# [6]	train-error:0.000646	eval-error:0.000727
#
# [7]	train-error:0.000631	eval-error:0.000718
#
# [8]	train-error:0.000628	eval-error:0.000698
#
# [9]	train-error:0.000526	eval-error:0.00058
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 7.2423118243760375e-06, 'max_depth': 8, 'min_child_weight': 5.798396560833715, 'subsample': 0.75}, logloss: 0.1992
# [0]	train-error:0.000732	eval-error:0.0008
#
# [1]	train-error:0.000468	eval-error:0.000519
#
# [2]	train-error:0.00044	eval-error:0.000492
#
# [3]	train-error:0.000411	eval-error:0.000471
#
# [4]	train-error:0.000436	eval-error:0.000487
#
# [5]	train-error:0.000429	eval-error:0.000485
#
# [6]	train-error:0.00042	eval-error:0.000471
#
# [7]	train-error:0.000413	eval-error:0.00046
#
# [8]	train-error:0.000388	eval-error:0.000437
#
# [9]	train-error:0.000372	eval-error:0.000424
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0002879001018519732, 'max_depth': 9, 'min_child_weight': 0.7389736968637893, 'subsample': 0.8}, logloss: 0.1985
# [0]	train-error:0.000784	eval-error:0.000879
#
# [1]	train-error:0.00079	eval-error:0.000893
#
# [2]	train-error:0.000704	eval-error:0.000793
#
# [3]	train-error:0.000703	eval-error:0.000791
#
# [4]	train-error:0.00076	eval-error:0.000841
#
# [5]	train-error:0.000693	eval-error:0.000782
#
# [6]	train-error:0.000693	eval-error:0.000779
#
# [7]	train-error:0.000764	eval-error:0.000852
#
# [8]	train-error:0.000662	eval-error:0.000741
#
# [9]	train-error:0.000606	eval-error:0.00068
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.004224415376745295, 'max_depth': 8, 'min_child_weight': 2.84730434736368, 'subsample': 0.8500000000000001}, logloss: 0.1989
# [0]	train-error:0.000834	eval-error:0.000924
#
# [1]	train-error:0.00085	eval-error:0.000954
#
# [2]	train-error:0.000828	eval-error:0.000924
#
# [3]	train-error:0.000826	eval-error:0.000918
#
# [4]	train-error:0.000815	eval-error:0.000904
#
# [5]	train-error:0.000818	eval-error:0.000915
#
# [6]	train-error:0.000909	eval-error:0.001017
#
# [7]	train-error:0.000893	eval-error:0.000999
#
# [8]	train-error:0.000859	eval-error:0.000963
#
# [9]	train-error:0.000844	eval-error:0.000952
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 0.0007464888165870678, 'max_depth': 7, 'min_child_weight': 3.5719281953483004, 'subsample': 0.9}, logloss: 0.1993
# [0]	train-error:0.000744	eval-error:0.000811
#
# [1]	train-error:0.000686	eval-error:0.000752
#
# [2]	train-error:0.000662	eval-error:0.000693
#
# [3]	train-error:0.000511	eval-error:0.00056
#
# [4]	train-error:0.00049	eval-error:0.000553
#
# [5]	train-error:0.000453	eval-error:0.00051
#
# [6]	train-error:0.000467	eval-error:0.000528
#
# [7]	train-error:0.000423	eval-error:0.000471
#
# [8]	train-error:0.000368	eval-error:0.000417
#
# [9]	train-error:0.000365	eval-error:0.000433
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 2.199313215501341e-07, 'max_depth': 9, 'min_child_weight': 0.9722613791302026, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.000723	eval-error:0.000782
#
# [1]	train-error:0.000612	eval-error:0.000652
#
# [2]	train-error:0.000805	eval-error:0.000863
#
# [3]	train-error:0.000599	eval-error:0.000675
#
# [4]	train-error:0.000659	eval-error:0.000734
#
# [5]	train-error:0.000619	eval-error:0.000691
#
# [6]	train-error:0.00066	eval-error:0.000752
#
# [7]	train-error:0.000655	eval-error:0.000718
#
# [8]	train-error:0.000598	eval-error:0.000655
#
# [9]	train-error:0.000468	eval-error:0.000512
#
# params: {'colsample_bytree': 0.75, 'gamma': 4.069144709845961e-08, 'max_depth': 8, 'min_child_weight': 0.6485998747741765, 'subsample': 0.75}, logloss: 0.1991
# [0]	train-error:0.006456	eval-error:0.006679
#
# [1]	train-error:0.003405	eval-error:0.003475
#
# [2]	train-error:0.005862	eval-error:0.006076
#
# [3]	train-error:0.002722	eval-error:0.002864
#
# [4]	train-error:0.002695	eval-error:0.002726
#
# [5]	train-error:0.002035	eval-error:0.002193
#
# [6]	train-error:0.002353	eval-error:0.002533
#
# [7]	train-error:0.00267	eval-error:0.00273
#
# [8]	train-error:0.002209	eval-error:0.002254
#
# [9]	train-error:0.002188	eval-error:0.002229
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 0.015016972949217075, 'max_depth': 4, 'min_child_weight': 1.6087287401935644, 'subsample': 0.9}, logloss: 0.2063
# [0]	train-error:0.000529	eval-error:0.000566
#
# [1]	train-error:0.000537	eval-error:0.000646
#
# [2]	train-error:0.000615	eval-error:0.000652
#
# [3]	train-error:0.000472	eval-error:0.000546
#
# [4]	train-error:0.000452	eval-error:0.000532
#
# [5]	train-error:0.00045	eval-error:0.000528
#
# [6]	train-error:0.000449	eval-error:0.000526
#
# [7]	train-error:0.00043	eval-error:0.000507
#
# [8]	train-error:0.000408	eval-error:0.000469
#
# [9]	train-error:0.000403	eval-error:0.000476
#
# params: {'colsample_bytree': 0.8, 'gamma': 9.808963587576482e-07, 'max_depth': 9, 'min_child_weight': 4.79570741869623, 'subsample': 0.6000000000000001}, logloss: 0.1989
# [0]	train-error:0.000822	eval-error:0.000915
#
# [1]	train-error:0.000845	eval-error:0.000952
#
# [2]	train-error:0.00082	eval-error:0.000918
#
# [3]	train-error:0.000819	eval-error:0.00092
#
# [4]	train-error:0.000853	eval-error:0.000961
#
# [5]	train-error:0.000792	eval-error:0.000872
#
# [6]	train-error:0.000847	eval-error:0.000949
#
# [7]	train-error:0.000884	eval-error:0.000988
#
# [8]	train-error:0.000847	eval-error:0.000945
#
# [9]	train-error:0.000841	eval-error:0.000931
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00012652209337927936, 'max_depth': 7, 'min_child_weight': 0.4799296116475535, 'subsample': 0.8500000000000001}, logloss: 0.1993
# [0]	train-error:0.002461	eval-error:0.002492
#
# [1]	train-error:0.002025	eval-error:0.002093
#
# [2]	train-error:0.002281	eval-error:0.0023
#
# [3]	train-error:0.002246	eval-error:0.002259
#
# [4]	train-error:0.002275	eval-error:0.002288
#
# [5]	train-error:0.002023	eval-error:0.002091
#
# [6]	train-error:0.00205	eval-error:0.002123
#
# [7]	train-error:0.001973	eval-error:0.002028
#
# [8]	train-error:0.001463	eval-error:0.001538
#
# [9]	train-error:0.002212	eval-error:0.002189
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.0466504314946006e-07, 'max_depth': 5, 'min_child_weight': 0.3913380020165867, 'subsample': 0.8}, logloss: 0.2016
# [0]	train-error:0.000731	eval-error:0.000811
#
# [1]	train-error:0.000433	eval-error:0.000487
#
# [2]	train-error:0.000501	eval-error:0.000541
#
# [3]	train-error:0.000652	eval-error:0.000752
#
# [4]	train-error:0.000637	eval-error:0.000723
#
# [5]	train-error:0.000639	eval-error:0.000725
#
# [6]	train-error:0.000628	eval-error:0.000709
#
# [7]	train-error:0.00044	eval-error:0.000487
#
# [8]	train-error:0.000443	eval-error:0.000501
#
# [9]	train-error:0.000415	eval-error:0.000476
#
# params: {'colsample_bytree': 0.9, 'gamma': 2.5976743754321703e-08, 'max_depth': 9, 'min_child_weight': 2.1285290415697924, 'subsample': 0.7000000000000001}, logloss: 0.1987
# [0]	train-error:0.000773	eval-error:0.000868
#
# [1]	train-error:0.000773	eval-error:0.000872
#
# [2]	train-error:0.000689	eval-error:0.000777
#
# [3]	train-error:0.000678	eval-error:0.000761
#
# [4]	train-error:0.000808	eval-error:0.000913
#
# [5]	train-error:0.000674	eval-error:0.000748
#
# [6]	train-error:0.000689	eval-error:0.000775
#
# [7]	train-error:0.000757	eval-error:0.000847
#
# [8]	train-error:0.000654	eval-error:0.000739
#
# [9]	train-error:0.000658	eval-error:0.000739
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.0427030687819012e-05, 'max_depth': 8, 'min_child_weight': 0.8091201311805424, 'subsample': 0.8500000000000001}, logloss: 0.1990
# [0]	train-error:0.000501	eval-error:0.000548
#
# [1]	train-error:0.000446	eval-error:0.000503
#
# [2]	train-error:0.000452	eval-error:0.000519
#
# [3]	train-error:0.000418	eval-error:0.000469
#
# [4]	train-error:0.00044	eval-error:0.000496
#
# [5]	train-error:0.000419	eval-error:0.000471
#
# [6]	train-error:0.000428	eval-error:0.000496
#
# [7]	train-error:0.000421	eval-error:0.000483
#
# [8]	train-error:0.000413	eval-error:0.00048
#
# [9]	train-error:0.000394	eval-error:0.000458
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.001026433916242314, 'max_depth': 9, 'min_child_weight': 2.5001868568477215, 'subsample': 0.75}, logloss: 0.1986
# [0]	train-error:0.007415	eval-error:0.007619
#
# [1]	train-error:0.006245	eval-error:0.006418
#
# [2]	train-error:0.007735	eval-error:0.00793
#
# [3]	train-error:0.006609	eval-error:0.006826
#
# [4]	train-error:0.007214	eval-error:0.007456
#
# [5]	train-error:0.006013	eval-error:0.00623
#
# [6]	train-error:0.005996	eval-error:0.006199
#
# [7]	train-error:0.006052	eval-error:0.006246
#
# [8]	train-error:0.006051	eval-error:0.006251
#
# [9]	train-error:0.006158	eval-error:0.006332
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 6.593920763941722e-05, 'max_depth': 3, 'min_child_weight': 0.2749017243248617, 'subsample': 0.9500000000000001}, logloss: 0.2098
# [0]	train-error:0.000758	eval-error:0.000847
#
# [1]	train-error:0.000662	eval-error:0.000727
#
# [2]	train-error:0.000895	eval-error:0.000956
#
# [3]	train-error:0.000646	eval-error:0.000682
#
# [4]	train-error:0.0006	eval-error:0.000652
#
# [5]	train-error:0.000601	eval-error:0.000659
#
# [6]	train-error:0.000603	eval-error:0.000657
#
# [7]	train-error:0.000567	eval-error:0.000625
#
# [8]	train-error:0.000568	eval-error:0.000609
#
# [9]	train-error:0.000563	eval-error:0.000607
#
# params: {'colsample_bytree': 0.8, 'gamma': 1.907923159884452e-08, 'max_depth': 8, 'min_child_weight': 0.5764123127849347, 'subsample': 0.9}, logloss: 0.1990
# [0]	train-error:0.001029	eval-error:0.001144
#
# [1]	train-error:0.000978	eval-error:0.001103
#
# [2]	train-error:0.00083	eval-error:0.000933
#
# [3]	train-error:0.000817	eval-error:0.000911
#
# [4]	train-error:0.000875	eval-error:0.001006
#
# [5]	train-error:0.000813	eval-error:0.000909
#
# [6]	train-error:0.000905	eval-error:0.001031
#
# [7]	train-error:0.000847	eval-error:0.000954
#
# [8]	train-error:0.000855	eval-error:0.000965
#
# [9]	train-error:0.000847	eval-error:0.000961
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 5.232196458333775e-06, 'max_depth': 7, 'min_child_weight': 6.562226112855557, 'subsample': 0.8}, logloss: 0.1994
# [0]	train-error:0.000719	eval-error:0.000791
#
# [1]	train-error:0.000449	eval-error:0.000521
#
# [2]	train-error:0.00061	eval-error:0.000652
#
# [3]	train-error:0.000418	eval-error:0.000483
#
# [4]	train-error:0.000424	eval-error:0.000505
#
# [5]	train-error:0.000359	eval-error:0.00041
#
# [6]	train-error:0.000378	eval-error:0.00044
#
# [7]	train-error:0.000369	eval-error:0.000399
#
# [8]	train-error:0.000344	eval-error:0.000381
#
# [9]	train-error:0.000334	eval-error:0.000381
#
# params: {'colsample_bytree': 0.75, 'gamma': 0.3851442158700292, 'max_depth': 9, 'min_child_weight': 1.4569509902411941, 'subsample': 0.8}, logloss: 0.1987
# [0]	train-error:0.000828	eval-error:0.000922
#
# [1]	train-error:0.00085	eval-error:0.000956
#
# [2]	train-error:0.000825	eval-error:0.000924
#
# [3]	train-error:0.000813	eval-error:0.000899
#
# [4]	train-error:0.000813	eval-error:0.000904
#
# [5]	train-error:0.000811	eval-error:0.000897
#
# [6]	train-error:0.000908	eval-error:0.001015
#
# [7]	train-error:0.000891	eval-error:0.000999
#
# [8]	train-error:0.000858	eval-error:0.000963
#
# [9]	train-error:0.000843	eval-error:0.000952
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 1.465764888920269e-05, 'max_depth': 7, 'min_child_weight': 1.8670562722778894, 'subsample': 0.9}, logloss: 0.1993
# [0]	train-error:0.001414	eval-error:0.001482
#
# [1]	train-error:0.001418	eval-error:0.001502
#
# [2]	train-error:0.001165	eval-error:0.001278
#
# [3]	train-error:0.001118	eval-error:0.001237
#
# [4]	train-error:0.001147	eval-error:0.001255
#
# [5]	train-error:0.001123	eval-error:0.001242
#
# [6]	train-error:0.001135	eval-error:0.001255
#
# [7]	train-error:0.001119	eval-error:0.00123
#
# [8]	train-error:0.001124	eval-error:0.001246
#
# [9]	train-error:0.001114	eval-error:0.001235
#
# params: {'colsample_bytree': 0.9, 'gamma': 3.9580844910092936e-07, 'max_depth': 6, 'min_child_weight': 0.18235597394493838, 'subsample': 0.8500000000000001}, logloss: 0.2001
# [0]	train-error:0.000771	eval-error:0.000865
#
# [1]	train-error:0.000801	eval-error:0.000879
#
# [2]	train-error:0.000889	eval-error:0.000947
#
# [3]	train-error:0.000649	eval-error:0.0007
#
# [4]	train-error:0.000619	eval-error:0.000689
#
# [5]	train-error:0.000613	eval-error:0.00068
#
# [6]	train-error:0.000613	eval-error:0.000668
#
# [7]	train-error:0.00058	eval-error:0.000634
#
# [8]	train-error:0.000566	eval-error:0.000619
#
# [9]	train-error:0.000557	eval-error:0.000605
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 0.00038152219606915193, 'max_depth': 8, 'min_child_weight': 0.6871115569560902, 'subsample': 0.8500000000000001}, logloss: 0.1991
# [0]	train-error:0.00049	eval-error:0.000541
#
# [1]	train-error:0.000443	eval-error:0.000503
#
# [2]	train-error:0.000401	eval-error:0.000453
#
# [3]	train-error:0.000402	eval-error:0.000455
#
# [4]	train-error:0.000388	eval-error:0.00044
#
# [5]	train-error:0.000427	eval-error:0.000485
#
# [6]	train-error:0.000387	eval-error:0.000442
#
# [7]	train-error:0.000406	eval-error:0.000458
#
# [8]	train-error:0.000366	eval-error:0.000403
#
# [9]	train-error:0.000365	eval-error:0.000419
#
# params: {'colsample_bytree': 0.9500000000000001, 'gamma': 2.9338897104488368e-05, 'max_depth': 9, 'min_child_weight': 1.2220955314896877, 'subsample': 0.75}, logloss: 0.1985
# [0]	train-error:0.002056	eval-error:0.002198
#
# [1]	train-error:0.001094	eval-error:0.001276
#
# [2]	train-error:0.000984	eval-error:0.00111
#
# [3]	train-error:0.000739	eval-error:0.00082
#
# [4]	train-error:0.000809	eval-error:0.000913
#
# [5]	train-error:0.000648	eval-error:0.00075
#
# [6]	train-error:0.00066	eval-error:0.00075
#
# [7]	train-error:0.000648	eval-error:0.000743
#
# [8]	train-error:0.000622	eval-error:0.00073
#
# [9]	train-error:0.000582	eval-error:0.000691
#
# params: {'colsample_bytree': 0.6000000000000001, 'gamma': 1.0213683843299487e-05, 'max_depth': 8, 'min_child_weight': 1.0594843423627112, 'subsample': 0.7000000000000001}, logloss: 0.1998
# [0]	train-error:0.002582	eval-error:0.002578
#
# [1]	train-error:0.001498	eval-error:0.001613
#
# [2]	train-error:0.003747	eval-error:0.003963
#
# [3]	train-error:0.001397	eval-error:0.001527
#
# [4]	train-error:0.001513	eval-error:0.001604
#
# [5]	train-error:0.001557	eval-error:0.001645
#
# [6]	train-error:0.001418	eval-error:0.001543
#
# [7]	train-error:0.001358	eval-error:0.001484
#
# [8]	train-error:0.001374	eval-error:0.001495
#
# [9]	train-error:0.001481	eval-error:0.001541
#
# params: {'colsample_bytree': 0.7000000000000001, 'gamma': 7.089448948283158e-07, 'max_depth': 5, 'min_child_weight': 0.29734695658833565, 'subsample': 0.8500000000000001}, logloss: 0.2027
# [0]	train-error:0.000477	eval-error:0.000517
#
# [1]	train-error:0.000463	eval-error:0.000507
#
# [2]	train-error:0.000586	eval-error:0.000607
#
# [3]	train-error:0.00039	eval-error:0.000415
#
# [4]	train-error:0.000421	eval-error:0.000446
#
# [5]	train-error:0.000383	eval-error:0.000392
#
# [6]	train-error:0.0004	eval-error:0.000444
#
# [7]	train-error:0.000392	eval-error:0.000419
#
# [8]	train-error:0.00037	eval-error:0.000417
#
# [9]	train-error:0.000353	eval-error:0.000408
#
# params: {'colsample_bytree': 0.8500000000000001, 'gamma': 6.021377271615493e-08, 'max_depth': 9, 'min_child_weight': 0.41677815138428903, 'subsample': 0.9500000000000001}, logloss: 0.1986
# [0]	train-error:0.000993	eval-error:0.001121
#
# [1]	train-error:0.000961	eval-error:0.001094
#
# [2]	train-error:0.000819	eval-error:0.000924
#
# [3]	train-error:0.000936	eval-error:0.001056
#
# [4]	train-error:0.000856	eval-error:0.000981
#
# [5]	train-error:0.000884	eval-error:0.000988
#
# [6]	train-error:0.000839	eval-error:0.000952
#
# [7]	train-error:0.000884	eval-error:0.000992
#
# [8]	train-error:0.000843	eval-error:0.00094
#
# [9]	train-error:0.000842	eval-error:0.000938
#
# params: {'colsample_bytree': 0.9, 'gamma': 0.00016767760781633567, 'max_depth': 7, 'min_child_weight': 0.235775134170374, 'subsample': 0.8}, logloss: 0.1993
# 100%|██████████| 100/100 [49:44<00:00, 29.85s/it, best loss: 0.19848636944695378]
# best params:{'colsample_bytree': 0.9500000000000001, 'gamma': 3.899790478029309e-06, 'max_depth': 9, 'min_child_weight': 0.6752187382188584, 'subsample': 0.8500000000000001}, score:0.1985

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    #'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 3.899790478029309e-06,
    'alpha': 0.0,
    'lambda': 1.0,
    'min_child_weight': 0.6752187382188584,
    'max_depth': 9,
    'subsample': 0.85,
    'colsample_bytree': 0.95,
    'silent':1,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=20)
# Out:
# [0]	train-error:0.000476	eval-error:0.000503
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.000473	eval-error:0.000496
# [2]	train-error:0.000462	eval-error:0.000487
# [3]	train-error:0.000423	eval-error:0.000444
# [4]	train-error:0.000446	eval-error:0.000471
# [5]	train-error:0.000401	eval-error:0.000415
# [6]	train-error:0.000423	eval-error:0.000437
# [7]	train-error:0.000387	eval-error:0.000424
# [8]	train-error:0.000366	eval-error:0.000387
# [9]	train-error:0.000382	eval-error:0.000406
# [10]	train-error:0.000353	eval-error:0.000392
# [11]	train-error:0.000348	eval-error:0.000369
# [12]	train-error:0.000331	eval-error:0.000353
# [13]	train-error:0.000325	eval-error:0.000358
# [14]	train-error:0.000323	eval-error:0.000353
# [15]	train-error:0.000307	eval-error:0.000322
# [16]	train-error:0.000298	eval-error:0.000313
# [17]	train-error:0.00026	eval-error:0.000285
# [18]	train-error:0.000163	eval-error:0.000188
# [19]	train-error:0.000161	eval-error:0.000188
# [20]	train-error:0.000161	eval-error:0.000188
# [21]	train-error:0.000162	eval-error:0.000188
# [22]	train-error:0.000151	eval-error:0.000179
# [23]	train-error:0.000142	eval-error:0.000168
# [24]	train-error:0.000125	eval-error:0.00015
# [25]	train-error:0.000121	eval-error:0.000143
# [26]	train-error:0.000119	eval-error:0.000143
# [27]	train-error:0.000118	eval-error:0.000143
# [28]	train-error:0.000114	eval-error:0.00014
# [29]	train-error:0.00011	eval-error:0.000138
# [30]	train-error:0.000105	eval-error:0.000134
# [31]	train-error:9.9e-05	eval-error:0.00012
# [32]	train-error:9.7e-05	eval-error:0.000118
# [33]	train-error:9.6e-05	eval-error:0.000116
# [34]	train-error:8.6e-05	eval-error:9.5e-05
# [35]	train-error:6.9e-05	eval-error:7.2e-05
# [36]	train-error:6.1e-05	eval-error:6.1e-05
# [37]	train-error:5.4e-05	eval-error:5.4e-05
# [38]	train-error:4.8e-05	eval-error:5e-05
# [39]	train-error:4.5e-05	eval-error:4.5e-05
# [40]	train-error:3.7e-05	eval-error:3.9e-05
# [41]	train-error:3e-05	eval-error:2.9e-05
# [42]	train-error:2.9e-05	eval-error:2.9e-05
# [43]	train-error:2.8e-05	eval-error:2.7e-05
# [44]	train-error:2.4e-05	eval-error:2e-05
# [45]	train-error:2.3e-05	eval-error:2e-05
# [46]	train-error:2.1e-05	eval-error:2e-05
# [47]	train-error:2e-05	eval-error:2e-05
# [48]	train-error:1.8e-05	eval-error:2e-05
# [49]	train-error:1.6e-05	eval-error:2e-05
# [50]	train-error:1.5e-05	eval-error:2e-05
# [51]	train-error:1.4e-05	eval-error:1.8e-05
# [52]	train-error:1.4e-05	eval-error:1.8e-05
# [53]	train-error:1.3e-05	eval-error:1.8e-05
# [54]	train-error:1.4e-05	eval-error:2e-05
# [55]	train-error:1.3e-05	eval-error:1.8e-05
# [56]	train-error:1.2e-05	eval-error:1.8e-05
# [57]	train-error:1.2e-05	eval-error:1.8e-05
# [58]	train-error:1.2e-05	eval-error:1.8e-05
# [59]	train-error:1.2e-05	eval-error:1.8e-05
# [60]	train-error:1.2e-05	eval-error:1.8e-05
# [61]	train-error:1.2e-05	eval-error:1.8e-05
# [62]	train-error:1.2e-05	eval-error:1.8e-05
# [63]	train-error:1.1e-05	eval-error:1.6e-05
# [64]	train-error:1.1e-05	eval-error:1.6e-05
# [65]	train-error:1.1e-05	eval-error:1.6e-05
# [66]	train-error:6e-06	eval-error:1.1e-05
# [67]	train-error:6e-06	eval-error:1.1e-05
# [68]	train-error:6e-06	eval-error:1.1e-05
# [69]	train-error:5e-06	eval-error:9e-06
# [70]	train-error:5e-06	eval-error:9e-06
# [71]	train-error:5e-06	eval-error:9e-06
# [72]	train-error:5e-06	eval-error:9e-06
# [73]	train-error:5e-06	eval-error:9e-06
# [74]	train-error:5e-06	eval-error:9e-06
# [75]	train-error:5e-06	eval-error:9e-06
# [76]	train-error:5e-06	eval-error:9e-06
# [77]	train-error:5e-06	eval-error:9e-06
# [78]	train-error:4e-06	eval-error:7e-06
# [79]	train-error:4e-06	eval-error:7e-06
# [80]	train-error:4e-06	eval-error:7e-06
# [81]	train-error:4e-06	eval-error:7e-06
# [82]	train-error:4e-06	eval-error:7e-06
# [83]	train-error:4e-06	eval-error:7e-06
# [84]	train-error:4e-06	eval-error:7e-06
# [85]	train-error:4e-06	eval-error:7e-06
# [86]	train-error:4e-06	eval-error:7e-06
# [87]	train-error:4e-06	eval-error:7e-06
# [88]	train-error:4e-06	eval-error:7e-06
# [89]	train-error:3e-06	eval-error:7e-06
# [90]	train-error:4e-06	eval-error:7e-06
# [91]	train-error:3e-06	eval-error:7e-06
# [92]	train-error:3e-06	eval-error:7e-06
# [93]	train-error:3e-06	eval-error:7e-06
# [94]	train-error:3e-06	eval-error:7e-06
# [95]	train-error:3e-06	eval-error:7e-06
# [96]	train-error:3e-06	eval-error:7e-06
# [97]	train-error:3e-06	eval-error:7e-06
# [98]	train-error:3e-06	eval-error:7e-06
# Stopping. Best iteration:
# [78]	train-error:4e-06	eval-error:7e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.4f}')
# Out:
# logloss: 0.0001

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_25-2_param_notuning.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_25-2_param_notuning.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.000182
# 1  0.000182
# 2  0.000182
# 3  0.000182
# 4  0.000182

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.000182
# 1   1  0.000182
# 2   2  0.000182
# 3   3  0.000182
# 4   4  0.000182

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_25-2_param_notuning.csv',index=False)

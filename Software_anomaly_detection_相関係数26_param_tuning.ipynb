# %% [markdown]
# <a href="https://colab.research.google.com/github/MASAYA-KINOSHITA/first-Repository/blob/main/Software_anomaly_detection_%E7%9B%B8%E9%96%A2%E4%BF%82%E6%95%B026_param_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np

# %%
# data_train csvファイルの読み込み
train_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/train.zip (Unzipped Files)/train.csv',usecols=['Anomaly',
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
# data_test csvファイルの読み込み
test_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/test.zip (Unzipped Files)/test.csv',usecols=[
 'GC activity : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionCount))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS Scavenge,type=GarbageCollector).CollectionTime))',
 'Rel. swap usage : ((MXBean(java.lang:type=OperatingSystem).FreeSwapSpaceSize / MXBean(java.lang:type=OperatingSystem).TotalSwapSpaceSize))',
 'Stuck threads : (MXBean(com.bea:Name=ThreadPoolRuntime,Type=ThreadPoolRuntime).StuckThreadCount)',
 'Stuck threads : (MXBean(com.bea:ApplicationRuntime=sys01,Name=default,Type=WorkManagerRuntime).StuckThreadCount)',
 'Process CPU : (MXBean(java.lang:type=OperatingSystem).ProcessCpuLoad)',
 'Rel. heap committed : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.committed / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'System CPU : (MXBean(java.lang:type=OperatingSystem).SystemCpuLoad)',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Process CPU : (\\Process(java)\\CPU)',
 'Rel. heap usage : ((MXBean(java.lang:type=Memory).HeapMemoryUsage.used / MXBean(java.lang:type=Memory).HeapMemoryUsage.max))',
 'Rel. open file descriptors : ((MXBean(java.lang:type=OperatingSystem).OpenFileDescriptorCount / MXBean(java.lang:type=OperatingSystem).MaxFileDescriptorCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.committed / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Eden Space,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source04,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.committed / MXBean(java.lang:name=Code Cache,type=MemoryPool).Usage.max))',
 'Prepared statement cache hit rate : ((MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheHitCount / MXBean(com.bea:Name=source02,Type=JDBCDataSourceRuntime).PrepStmtCacheMissCount))',
 'Memory space usage : ((MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Perm Gen,type=MemoryPool).Usage.max))',
 'Memory space usage : ((MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.used / MXBean(java.lang:name=PS Old Gen,type=MemoryPool).Usage.max))',
 'Daemon thread count : (MXBean(java.lang:type=Threading).DaemonThreadCount)',
 'host',
 'Total thread count : (MXBean(java.lang:type=Threading).ThreadCount)',
 'Rel. nonHeap usage : ((MXBean(java.lang:type=Memory).NonHeapMemoryUsage.used / MXBean(java.lang:type=Memory).NonHeapMemoryUsage.max))',
 'Rel. physical mem usage : ((MXBean(java.lang:type=OperatingSystem).FreePhysicalMemorySize / MXBean(java.lang:type=OperatingSystem).TotalPhysicalMemorySize))',
 'GC time : (incld/dx (MXBean(java.lang:name=PS MarkSweep,type=GarbageCollector).CollectionTime))',
 'Rel. Swap Usage : ((\\Swap\\used / \\Swap\\total))' 
 ])

# %%
#異常フラグのみのリストを作成
train_y=train_df["Anomaly"]

# %%
#異常フラグ、カテゴリを除いたリストを作成
train_x=train_df.drop(["Anomaly","host"],axis=1)
test_x=test_df.drop(["host"],axis=1)

# %%
train_x = pd.DataFrame(train_x)
test_x = pd.DataFrame(test_x)

# %%
train_y = pd.Series(train_y)

# %%
# ラベルエンコーディング（OrdinalEncoder）
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder


oe = preprocessing.OrdinalEncoder()
train_encoded = oe.fit_transform(train_df[['host']].values)
train_decoded = oe.inverse_transform(train_encoded)
test_encoded = oe.fit_transform(test_df[['host']].values)
test_decoded = oe.inverse_transform(test_encoded)

print('エンコード結果: ', [train_encoded,test_encoded])
print('元に戻す: ', [train_decoded,test_decoded])
# Out:
# エンコード結果:  [array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [9.],
#        [9.],
#        [9.]])]
# 元に戻す:  [array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object), array([['lphost06'],
#        ['lphost06'],
#        ['lphost06'],
#        ...,
#        ['lphost18'],
#        ['lphost18'],
#        ['lphost18']], dtype=object)]

# %%
train_encoded_df = pd.DataFrame(train_encoded)
train_encoded_df.columns=['host']
test_encoded_df = pd.DataFrame(test_encoded)
test_encoded_df.columns=['host']

# %%
#エンコードしたカテゴリデータとカテゴリを除いた訓練データを結合
train_x=pd.concat([train_x, train_encoded_df],axis=1)
test_x=pd.concat([test_x, test_encoded_df],axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
#ハイパーパラメータのチューニング
# xgboostによる学習・予測を行うクラス
import xgboost as xgb



class Model:

    def __init__(self, params=None):
        self.model = None
        if params is None:
            self.params = {}
        else:
            self.params = params

    def fit(self, tr_x, tr_y, va_x, va_y):
        params ={
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.00014307741815837628,
    'alpha': 0.0002857624279734903,
    'lambda': 0.00010908892137476965,
    'min_child_weight': 1.4034295969588149,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
        params.update(self.params)
        num_round = 100
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, dtrain, num_round, evals=watchlist)

    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred


# -----------------------------------
# 探索するパラメータの空間の指定
# -----------------------------------
# hp.choiceでは、複数の選択肢から選ぶ
# hp.uniformでは、下限・上限を指定した一様分布から抽出する。引数は下限・上限
# hp.quniformでは、下限・上限を指定した一様分布のうち一定の間隔ごとの点から抽出する。引数は下限・上限・間隔
# hp.loguniformでは、下限・上限を指定した対数が一様分布に従う分布から抽出する。引数は下限・上限の対数をとった値

from hyperopt import hp

space = {
    'activation': hp.choice('activation', ['prelu', 'relu']),
    'dropout': hp.uniform('dropout', 0, 0.2),
    'units': hp.quniform('units', 32, 256, 32),
    'learning_rate': hp.loguniform('learning_rate', np.log(0.00001), np.log(0.01)),
}

# -----------------------------------
# hyperoptを使ったパラメータ探索
# -----------------------------------
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.metrics import log_loss
def score(params):
    # パラメータを与えたときに最小化する評価指標を指定する
    # 具体的には、モデルにパラメータを指定して学習・予測させた場合のスコアを返すようにする

    # max_depthの型を整数型に修正する
    params['max_depth'] = int(params['max_depth'])

    # Modelクラスを定義しているものとする
    # Modelクラスは、fitで学習し、predictで予測値の確率を出力する
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss: {score:.8f}')

    # 情報を記録しておく
    history.append((params, score))

    return {'loss': score, 'status': STATUS_OK}


# 探索するパラメータの空間を指定する
space = {
    'min_child_weight': hp.loguniform('min_child_weight', np.log(0.1), np.log(10)),
    'max_depth': hp.quniform('max_depth', 3, 10, 1),
    'subsample': hp.quniform('subsample', 0.6, 1.00, 0.05),
    'colsample_bytree': hp.quniform('colsample_bytree', 0.6, 1.00, 0.05),
    'gamma': hp.loguniform('gamma', np.log(1e-8), np.log(1.0)),
    # 余裕があればalpha, lambdaも調整する
    'alpha' : hp.loguniform('alpha', np.log(1e-8), np.log(1.0)),
    'lambda' : hp.loguniform('lambda', np.log(1e-6), np.log(10.0)),
     
}

# hyperoptによるパラメータ探索の実行
max_evals = 100
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals=max_evals)

# 記録した情報からパラメータとスコアを出力する
# （trialsからも情報が取得できるが、パラメータの取得がやや行いづらいため）
history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params:{best[0]}, score:{best[1]:.8f}')
# Out:
# [0]	train-error:0.000906	eval-error:0.001037
#
# [1]	train-error:0.000596	eval-error:0.000739
#
# [2]	train-error:0.000653	eval-error:0.00077
#
# [3]	train-error:0.000484	eval-error:0.000561
#
# [4]	train-error:0.000522	eval-error:0.000606
#
# [5]	train-error:0.000428	eval-error:0.000501
#
# [6]	train-error:0.000447	eval-error:0.00051
#
# [7]	train-error:0.000429	eval-error:0.000496
#
# [8]	train-error:0.000409	eval-error:0.000484
#
# [9]	train-error:0.000344	eval-error:0.000391
#
# [10]	train-error:0.000337	eval-error:0.000382
#
# [11]	train-error:0.000338	eval-error:0.000388
#
# [12]	train-error:0.000326	eval-error:0.000362
#
# [13]	train-error:0.000261	eval-error:0.000306
#
# [14]	train-error:0.000275	eval-error:0.000312
#
# [15]	train-error:0.000239	eval-error:0.000289
#
# [16]	train-error:0.000238	eval-error:0.00028
#
# [17]	train-error:0.000222	eval-error:0.000266
#
# [18]	train-error:0.000212	eval-error:0.000263
#
# [19]	train-error:0.000212	eval-error:0.000261
#
# [20]	train-error:0.000193	eval-error:0.000244
#
# [21]	train-error:0.000162	eval-error:0.00021
#
# [22]	train-error:0.000155	eval-error:0.00021
#
# [23]	train-error:0.000155	eval-error:0.000215
#
# [24]	train-error:0.000118	eval-error:0.000176
#
# [25]	train-error:0.00013	eval-error:0.000176
#
# [26]	train-error:0.000123	eval-error:0.00017
#
# [27]	train-error:0.000109	eval-error:0.000159
#
# [28]	train-error:9.6e-05	eval-error:0.000142
#
# [29]	train-error:7.2e-05	eval-error:0.000116
#
# [30]	train-error:6.5e-05	eval-error:0.000105
#
# [31]	train-error:5.9e-05	eval-error:0.000105
#
# [32]	train-error:5.5e-05	eval-error:9.9e-05
#
# [33]	train-error:3.9e-05	eval-error:8.5e-05
#
# [34]	train-error:3.6e-05	eval-error:8.2e-05
#
# [35]	train-error:3.3e-05	eval-error:6.8e-05
#
# [36]	train-error:2.8e-05	eval-error:5.1e-05
#
# [37]	train-error:2.7e-05	eval-error:4.2e-05
#
# [38]	train-error:2.6e-05	eval-error:3.7e-05
#
# [39]	train-error:2.5e-05	eval-error:3.7e-05
#
# [40]	train-error:2.1e-05	eval-error:3.1e-05
#
# [41]	train-error:1.6e-05	eval-error:3.4e-05
#
# [42]	train-error:1.4e-05	eval-error:3.1e-05
#
# [43]	train-error:1.3e-05	eval-error:3.1e-05
#
# [44]	train-error:1.3e-05	eval-error:3.1e-05
#
# [45]	train-error:1.2e-05	eval-error:2.8e-05
#
# [46]	train-error:1.1e-05	eval-error:2.5e-05
#
# [47]	train-error:1.1e-05	eval-error:2.5e-05
#
# [48]	train-error:1.1e-05	eval-error:2.5e-05
#
# [49]	train-error:1e-05	eval-error:2.5e-05
#
# [50]	train-error:1e-05	eval-error:2.8e-05
#
# [51]	train-error:9e-06	eval-error:2.8e-05
#
# [52]	train-error:5e-06	eval-error:2e-05
#
# [53]	train-error:5e-06	eval-error:2e-05
#
# [54]	train-error:5e-06	eval-error:2e-05
#
# [55]	train-error:4e-06	eval-error:2e-05
#
# [56]	train-error:4e-06	eval-error:2e-05
#
# [57]	train-error:3e-06	eval-error:1.7e-05
#
# [58]	train-error:3e-06	eval-error:1.7e-05
#
# [59]	train-error:3e-06	eval-error:1.7e-05
#
# [60]	train-error:3e-06	eval-error:1.7e-05
#
# [61]	train-error:3e-06	eval-error:1.7e-05
#
# [62]	train-error:3e-06	eval-error:1.7e-05
#
# [63]	train-error:3e-06	eval-error:1.4e-05
#
# [64]	train-error:3e-06	eval-error:1.7e-05
#
# [65]	train-error:3e-06	eval-error:1.7e-05
#
# [66]	train-error:4e-06	eval-error:1.7e-05
#
# [67]	train-error:4e-06	eval-error:1.7e-05
#
# [68]	train-error:4e-06	eval-error:1.7e-05
#
# [69]	train-error:4e-06	eval-error:2e-05
#
# [70]	train-error:4e-06	eval-error:2e-05
#
# [71]	train-error:3e-06	eval-error:2e-05
#
# [72]	train-error:3e-06	eval-error:2e-05
#
# [73]	train-error:3e-06	eval-error:2e-05
#
# [74]	train-error:3e-06	eval-error:2e-05
#
# [75]	train-error:3e-06	eval-error:2e-05
#
# [76]	train-error:3e-06	eval-error:2e-05
#
# [77]	train-error:3e-06	eval-error:2e-05
#
# [78]	train-error:3e-06	eval-error:2e-05
#
# [79]	train-error:3e-06	eval-error:2e-05
#
# [80]	train-error:3e-06	eval-error:2e-05
#
# [81]	train-error:3e-06	eval-error:2e-05
#
# [82]	train-error:3e-06	eval-error:2e-05
#
# [83]	train-error:3e-06	eval-error:2e-05
#
# [84]	train-error:3e-06	eval-error:2e-05
#
# [85]	train-error:3e-06	eval-error:2e-05
#
# [86]	train-error:2e-06	eval-error:2e-05
#
# [87]	train-error:2e-06	eval-error:1.7e-05
#
# [88]	train-error:2e-06	eval-error:1.7e-05
#
# [89]	train-error:1e-06	eval-error:1.7e-05
#
# [90]	train-error:1e-06	eval-error:1.7e-05
#
# [91]	train-error:1e-06	eval-error:1.4e-05
#
# [92]	train-error:1e-06	eval-error:1.4e-05
#
# [93]	train-error:1e-06	eval-error:1.4e-05
#
# [94]	train-error:1e-06	eval-error:1.4e-05
#
# [95]	train-error:1e-06	eval-error:1.4e-05
#
# [96]	train-error:1e-06	eval-error:1.4e-05
#
# [97]	train-error:1e-06	eval-error:1.4e-05
#
# [98]	train-error:1e-06	eval-error:1.4e-05
#
# [99]	train-error:1e-06	eval-error:1.4e-05
#
# params: {'alpha': 0.21253368664755193, 'colsample_bytree': 0.6000000000000001, 'gamma': 9.86055425429988e-07, 'lambda': 0.00013041441471258808, 'max_depth': 9, 'min_child_weight': 0.43345440266117186, 'subsample': 0.8}, logloss: 0.00010455
# [0]	train-error:0.000947	eval-error:0.001025
#
# [1]	train-error:0.00073	eval-error:0.000813
#
# [2]	train-error:0.000683	eval-error:0.000765
#
# [3]	train-error:0.000423	eval-error:0.00051
#
# [4]	train-error:0.000493	eval-error:0.000564
#
# [5]	train-error:0.000387	eval-error:0.00047
#
# [6]	train-error:0.000419	eval-error:0.000493
#
# [7]	train-error:0.000505	eval-error:0.000598
#
# [8]	train-error:0.000385	eval-error:0.00047
#
# [9]	train-error:0.000376	eval-error:0.000462
#
# [10]	train-error:0.000362	eval-error:0.000445
#
# [11]	train-error:0.000358	eval-error:0.000445
#
# [12]	train-error:0.000355	eval-error:0.000445
#
# [13]	train-error:0.000336	eval-error:0.000433
#
# [14]	train-error:0.000335	eval-error:0.000402
#
# [15]	train-error:0.000312	eval-error:0.000413
#
# [16]	train-error:0.000302	eval-error:0.000382
#
# [17]	train-error:0.000253	eval-error:0.00034
#
# [18]	train-error:0.000247	eval-error:0.000331
#
# [19]	train-error:0.000248	eval-error:0.000331
#
# [20]	train-error:0.000219	eval-error:0.000278
#
# [21]	train-error:0.000135	eval-error:0.000201
#
# [22]	train-error:0.000154	eval-error:0.000201
#
# [23]	train-error:0.000113	eval-error:0.00017
#
# [24]	train-error:0.000112	eval-error:0.000164
#
# [25]	train-error:0.000102	eval-error:0.000159
#
# [26]	train-error:0.000101	eval-error:0.00015
#
# [27]	train-error:8.6e-05	eval-error:0.00013
#
# [28]	train-error:8.2e-05	eval-error:0.000127
#
# [29]	train-error:7.4e-05	eval-error:0.000119
#
# [30]	train-error:7e-05	eval-error:0.000113
#
# [31]	train-error:7e-05	eval-error:0.000113
#
# [32]	train-error:6.2e-05	eval-error:9.9e-05
#
# [33]	train-error:5.8e-05	eval-error:9.3e-05
#
# [34]	train-error:5.5e-05	eval-error:9.3e-05
#
# [35]	train-error:4.7e-05	eval-error:7.6e-05
#
# [36]	train-error:4.5e-05	eval-error:7.6e-05
#
# [37]	train-error:4.3e-05	eval-error:7.1e-05
#
# [38]	train-error:3.8e-05	eval-error:5.4e-05
#
# [39]	train-error:3.7e-05	eval-error:5.1e-05
#
# [40]	train-error:3.5e-05	eval-error:5.1e-05
#
# [41]	train-error:2.9e-05	eval-error:4.8e-05
#
# [42]	train-error:2.8e-05	eval-error:4.5e-05
#
# [43]	train-error:2.1e-05	eval-error:4.5e-05
#
# [44]	train-error:1.8e-05	eval-error:4.2e-05
#
# [45]	train-error:1.6e-05	eval-error:4e-05
#
# [46]	train-error:1e-05	eval-error:3.4e-05
#
# [47]	train-error:8e-06	eval-error:3.1e-05
#
# [48]	train-error:6e-06	eval-error:2.8e-05
#
# [49]	train-error:7e-06	eval-error:2.8e-05
#
# [50]	train-error:6e-06	eval-error:2.8e-05
#
# [51]	train-error:6e-06	eval-error:2.8e-05
#
# [52]	train-error:6e-06	eval-error:2.5e-05
#
# [53]	train-error:6e-06	eval-error:2.8e-05
#
# [54]	train-error:6e-06	eval-error:2.8e-05
#
# [55]	train-error:6e-06	eval-error:2.5e-05
#
# [56]	train-error:5e-06	eval-error:2.5e-05
#
# [57]	train-error:4e-06	eval-error:2.5e-05
#
# [58]	train-error:4e-06	eval-error:2.5e-05
#
# [59]	train-error:4e-06	eval-error:2.5e-05
#
# [60]	train-error:4e-06	eval-error:2.5e-05
#
# [61]	train-error:4e-06	eval-error:2.5e-05
#
# [62]	train-error:4e-06	eval-error:2.3e-05
#
# [63]	train-error:4e-06	eval-error:2.3e-05
#
# [64]	train-error:4e-06	eval-error:2.3e-05
#
# [65]	train-error:4e-06	eval-error:2e-05
#
# [66]	train-error:4e-06	eval-error:2e-05
#
# [67]	train-error:4e-06	eval-error:1.7e-05
#
# [68]	train-error:4e-06	eval-error:2e-05
#
# [69]	train-error:4e-06	eval-error:2e-05
#
# [70]	train-error:4e-06	eval-error:1.7e-05
#
# [71]	train-error:4e-06	eval-error:2e-05
#
# [72]	train-error:4e-06	eval-error:2e-05
#
# [73]	train-error:4e-06	eval-error:1.7e-05
#
# [74]	train-error:3e-06	eval-error:1.7e-05
#
# [75]	train-error:4e-06	eval-error:1.7e-05
#
# [76]	train-error:4e-06	eval-error:1.7e-05
#
# [77]	train-error:3e-06	eval-error:1.7e-05
#
# [78]	train-error:3e-06	eval-error:2e-05
#
# [79]	train-error:4e-06	eval-error:2e-05
#
# [80]	train-error:3e-06	eval-error:2e-05
#
# [81]	train-error:3e-06	eval-error:2e-05
#
# [82]	train-error:3e-06	eval-error:2e-05
#
# [83]	train-error:3e-06	eval-error:1.7e-05
#
# [84]	train-error:3e-06	eval-error:2e-05
#
# [85]	train-error:3e-06	eval-error:2e-05
#
# [86]	train-error:3e-06	eval-error:2e-05
#
# [87]	train-error:3e-06	eval-error:2e-05
#
# [88]	train-error:3e-06	eval-error:2e-05
#
# [89]	train-error:3e-06	eval-error:2e-05
#
# [90]	train-error:3e-06	eval-error:2e-05
#
# [91]	train-error:3e-06	eval-error:2e-05
#
# [92]	train-error:2e-06	eval-error:2e-05
#
# [93]	train-error:2e-06	eval-error:1.7e-05
#
# [94]	train-error:2e-06	eval-error:1.7e-05
#
# [95]	train-error:2e-06	eval-error:1.7e-05
#
# [96]	train-error:2e-06	eval-error:1.7e-05
#
# [97]	train-error:2e-06	eval-error:1.7e-05
#
# [98]	train-error:2e-06	eval-error:1.7e-05
#
# [99]	train-error:2e-06	eval-error:1.7e-05
#
# params: {'alpha': 0.04113452703553128, 'colsample_bytree': 0.9, 'gamma': 0.0011498638863690488, 'lambda': 0.007562336784951362, 'max_depth': 9, 'min_child_weight': 0.6997154003571642, 'subsample': 0.7000000000000001}, logloss: 0.00011115
# [0]	train-error:0.000854	eval-error:0.000943
#
# [1]	train-error:0.000411	eval-error:0.000501
#
# [2]	train-error:0.000512	eval-error:0.000589
#
# [3]	train-error:0.000461	eval-error:0.000518
#
# [4]	train-error:0.000452	eval-error:0.000524
#
# [5]	train-error:0.000428	eval-error:0.000487
#
# [6]	train-error:0.000399	eval-error:0.00047
#
# [7]	train-error:0.000375	eval-error:0.000447
#
# [8]	train-error:0.000378	eval-error:0.00045
#
# [9]	train-error:0.000408	eval-error:0.000464
#
# [10]	train-error:0.000392	eval-error:0.000453
#
# [11]	train-error:0.000373	eval-error:0.000445
#
# [12]	train-error:0.000345	eval-error:0.000416
#
# [13]	train-error:0.000346	eval-error:0.000422
#
# [14]	train-error:0.000278	eval-error:0.000371
#
# [15]	train-error:0.000276	eval-error:0.000354
#
# [16]	train-error:0.000253	eval-error:0.00032
#
# [17]	train-error:0.000221	eval-error:0.00028
#
# [18]	train-error:0.000193	eval-error:0.000249
#
# [19]	train-error:0.000149	eval-error:0.000212
#
# [20]	train-error:0.00011	eval-error:0.000173
#
# [21]	train-error:0.000122	eval-error:0.000164
#
# [22]	train-error:0.000115	eval-error:0.000156
#
# [23]	train-error:9.3e-05	eval-error:0.00013
#
# [24]	train-error:9.6e-05	eval-error:0.000142
#
# [25]	train-error:9.1e-05	eval-error:0.00013
#
# [26]	train-error:8.8e-05	eval-error:0.000127
#
# [27]	train-error:8.6e-05	eval-error:0.000127
#
# [28]	train-error:7.9e-05	eval-error:0.00011
#
# [29]	train-error:8.3e-05	eval-error:0.000122
#
# [30]	train-error:6.3e-05	eval-error:9.6e-05
#
# [31]	train-error:6.4e-05	eval-error:0.000105
#
# [32]	train-error:5.2e-05	eval-error:8.5e-05
#
# [33]	train-error:5.5e-05	eval-error:8.2e-05
#
# [34]	train-error:5e-05	eval-error:8.2e-05
#
# [35]	train-error:4.7e-05	eval-error:7.9e-05
#
# [36]	train-error:4.6e-05	eval-error:7.9e-05
#
# [37]	train-error:3.9e-05	eval-error:7.1e-05
#
# [38]	train-error:3.6e-05	eval-error:6.5e-05
#
# [39]	train-error:3e-05	eval-error:5.4e-05
#
# [40]	train-error:2.8e-05	eval-error:4.8e-05
#
# [41]	train-error:2.5e-05	eval-error:4.2e-05
#
# [42]	train-error:2.1e-05	eval-error:3.4e-05
#
# [43]	train-error:1.8e-05	eval-error:3.7e-05
#
# [44]	train-error:1.7e-05	eval-error:3.4e-05
#
# [45]	train-error:1.6e-05	eval-error:3.4e-05
#
# [46]	train-error:1.5e-05	eval-error:2.8e-05
#
# [47]	train-error:1.3e-05	eval-error:2.5e-05
#
# [48]	train-error:1.3e-05	eval-error:2.5e-05
#
# [49]	train-error:7e-06	eval-error:2.3e-05
#
# [50]	train-error:1e-05	eval-error:2.3e-05
#
# [51]	train-error:6e-06	eval-error:2.3e-05
#
# [52]	train-error:6e-06	eval-error:2e-05
#
# [53]	train-error:5e-06	eval-error:1.7e-05
#
# [54]	train-error:5e-06	eval-error:2e-05
#
# [55]	train-error:6e-06	eval-error:1.7e-05
#
# [56]	train-error:6e-06	eval-error:1.7e-05
#
# [57]	train-error:4e-06	eval-error:1.4e-05
#
# [58]	train-error:4e-06	eval-error:1.7e-05
#
# [59]	train-error:5e-06	eval-error:1.4e-05
#
# [60]	train-error:5e-06	eval-error:1.7e-05
#
# [61]	train-error:5e-06	eval-error:1.7e-05
#
# [62]	train-error:4e-06	eval-error:1.7e-05
#
# [63]	train-error:5e-06	eval-error:1.7e-05
#
# [64]	train-error:4e-06	eval-error:1.7e-05
#
# [65]	train-error:4e-06	eval-error:1.7e-05
#
# [66]	train-error:4e-06	eval-error:1.7e-05
#
# [67]	train-error:4e-06	eval-error:1.7e-05
#
# [68]	train-error:4e-06	eval-error:1.7e-05
#
# [69]	train-error:4e-06	eval-error:1.7e-05
#
# [70]	train-error:4e-06	eval-error:1.7e-05
#
# [71]	train-error:4e-06	eval-error:1.4e-05
#
# [72]	train-error:4e-06	eval-error:1.4e-05
#
# [73]	train-error:3e-06	eval-error:1.4e-05
#
# [74]	train-error:3e-06	eval-error:1.4e-05
#
# [75]	train-error:3e-06	eval-error:1.4e-05
#
# [76]	train-error:4e-06	eval-error:1.4e-05
#
# [77]	train-error:3e-06	eval-error:1.4e-05
#
# [78]	train-error:3e-06	eval-error:1.4e-05
#
# [79]	train-error:3e-06	eval-error:1.4e-05
#
# [80]	train-error:3e-06	eval-error:1.4e-05
#
# [81]	train-error:3e-06	eval-error:1.4e-05
#
# [82]	train-error:3e-06	eval-error:1.4e-05
#
# [83]	train-error:3e-06	eval-error:1.4e-05
#
# [84]	train-error:2e-06	eval-error:1.4e-05
#
# [85]	train-error:2e-06	eval-error:1.4e-05
#
# [86]	train-error:2e-06	eval-error:1.4e-05
#
# [87]	train-error:2e-06	eval-error:1.4e-05
#
# [88]	train-error:2e-06	eval-error:1.4e-05
#
# [89]	train-error:2e-06	eval-error:1.4e-05
#
# [90]	train-error:2e-06	eval-error:1.4e-05
#
# [91]	train-error:2e-06	eval-error:1.4e-05
#
# [92]	train-error:2e-06	eval-error:1.4e-05
#
# [93]	train-error:1e-06	eval-error:1.4e-05
#
# [94]	train-error:1e-06	eval-error:1.4e-05
#
# [95]	train-error:1e-06	eval-error:1.4e-05
#
# [96]	train-error:1e-06	eval-error:1.4e-05
#
# [97]	train-error:2e-06	eval-error:1.4e-05
#
# [98]	train-error:2e-06	eval-error:1.4e-05
#
# [99]	train-error:2e-06	eval-error:1.4e-05
#
# params: {'alpha': 0.0014374773279725724, 'colsample_bytree': 0.75, 'gamma': 2.671126779906625e-05, 'lambda': 0.08301841986531037, 'max_depth': 9, 'min_child_weight': 0.43005174746146035, 'subsample': 0.6000000000000001}, logloss: 0.00010624
# [0]	train-error:0.001744	eval-error:0.001815
#
# [1]	train-error:0.001056	eval-error:0.001119
#
# [2]	train-error:0.001268	eval-error:0.001317
#
# [3]	train-error:0.001226	eval-error:0.001198
#
# [4]	train-error:0.001111	eval-error:0.001121
#
# [5]	train-error:0.000981	eval-error:0.001039
#
# [6]	train-error:0.000974	eval-error:0.001039
#
# [7]	train-error:0.000947	eval-error:0.001034
#
# [8]	train-error:0.000963	eval-error:0.001037
#
# [9]	train-error:0.00091	eval-error:0.000994
#
# [10]	train-error:0.000869	eval-error:0.00094
#
# [11]	train-error:0.000882	eval-error:0.000949
#
# [12]	train-error:0.000886	eval-error:0.000949
#
# [13]	train-error:0.000876	eval-error:0.000943
#
# [14]	train-error:0.000863	eval-error:0.000935
#
# [15]	train-error:0.000857	eval-error:0.00094
#
# [16]	train-error:0.000864	eval-error:0.000929
#
# [17]	train-error:0.00085	eval-error:0.00092
#
# [18]	train-error:0.000791	eval-error:0.000867
#
# [19]	train-error:0.000753	eval-error:0.000801
#
# [20]	train-error:0.000706	eval-error:0.000765
#
# [21]	train-error:0.000754	eval-error:0.000838
#
# [22]	train-error:0.000718	eval-error:0.000796
#
# [23]	train-error:0.000681	eval-error:0.000748
#
# [24]	train-error:0.000653	eval-error:0.000731
#
# [25]	train-error:0.000612	eval-error:0.000671
#
# [26]	train-error:0.000586	eval-error:0.000651
#
# [27]	train-error:0.000621	eval-error:0.000705
#
# [28]	train-error:0.000523	eval-error:0.0006
#
# [29]	train-error:0.000541	eval-error:0.00062
#
# [30]	train-error:0.000456	eval-error:0.000535
#
# [31]	train-error:0.00044	eval-error:0.000513
#
# [32]	train-error:0.000406	eval-error:0.000504
#
# [33]	train-error:0.000387	eval-error:0.000473
#
# [34]	train-error:0.000403	eval-error:0.000493
#
# [35]	train-error:0.000365	eval-error:0.000459
#
# [36]	train-error:0.000364	eval-error:0.000456
#
# [37]	train-error:0.000355	eval-error:0.000453
#
# [38]	train-error:0.000303	eval-error:0.000385
#
# [39]	train-error:0.00029	eval-error:0.000382
#
# [40]	train-error:0.00028	eval-error:0.000374
#
# [41]	train-error:0.000262	eval-error:0.000348
#
# [42]	train-error:0.00024	eval-error:0.000334
#
# [43]	train-error:0.000229	eval-error:0.000317
#
# [44]	train-error:0.000205	eval-error:0.000283
#
# [45]	train-error:0.000188	eval-error:0.000255
#
# [46]	train-error:0.000175	eval-error:0.000246
#
# [47]	train-error:0.000171	eval-error:0.000246
#
# [48]	train-error:0.000139	eval-error:0.000201
#
# [49]	train-error:0.000122	eval-error:0.00019
#
# [50]	train-error:0.000115	eval-error:0.000178
#
# [51]	train-error:8.7e-05	eval-error:0.000144
#
# [52]	train-error:8.4e-05	eval-error:0.000144
#
# [53]	train-error:8.1e-05	eval-error:0.000136
#
# [54]	train-error:7.2e-05	eval-error:0.000119
#
# [55]	train-error:6.9e-05	eval-error:0.000119
#
# [56]	train-error:6.8e-05	eval-error:0.000116
#
# [57]	train-error:6.5e-05	eval-error:0.000105
#
# [58]	train-error:5.5e-05	eval-error:9.6e-05
#
# [59]	train-error:5.5e-05	eval-error:0.000102
#
# [60]	train-error:5.5e-05	eval-error:9.3e-05
#
# [61]	train-error:4.8e-05	eval-error:8.8e-05
#
# [62]	train-error:4.5e-05	eval-error:6.8e-05
#
# [63]	train-error:4.5e-05	eval-error:6.8e-05
#
# [64]	train-error:3.7e-05	eval-error:6.2e-05
#
# [65]	train-error:3.6e-05	eval-error:5.7e-05
#
# [66]	train-error:3.5e-05	eval-error:5.7e-05
#
# [67]	train-error:3.5e-05	eval-error:5.4e-05
#
# [68]	train-error:3.5e-05	eval-error:5.1e-05
#
# [69]	train-error:3.4e-05	eval-error:4.8e-05
#
# [70]	train-error:3.4e-05	eval-error:4.8e-05
#
# [71]	train-error:3.3e-05	eval-error:4.5e-05
#
# [72]	train-error:3.2e-05	eval-error:4.5e-05
#
# [73]	train-error:3.2e-05	eval-error:4.8e-05
#
# [74]	train-error:3.2e-05	eval-error:4.8e-05
#
# [75]	train-error:3.2e-05	eval-error:4.2e-05
#
# [76]	train-error:3e-05	eval-error:4.8e-05
#
# [77]	train-error:2.9e-05	eval-error:4.5e-05
#
# [78]	train-error:2.8e-05	eval-error:4.5e-05
#
# [79]	train-error:2.7e-05	eval-error:4.2e-05
#
# [80]	train-error:2.2e-05	eval-error:3.4e-05
#
# [81]	train-error:2.1e-05	eval-error:3.1e-05
#
# [82]	train-error:1.7e-05	eval-error:2.8e-05
#
# [83]	train-error:1.5e-05	eval-error:2.5e-05
#
# [84]	train-error:1.5e-05	eval-error:2.8e-05
#
# [85]	train-error:1.6e-05	eval-error:2.8e-05
#
# [86]	train-error:1.3e-05	eval-error:2.8e-05
#
# [87]	train-error:1.2e-05	eval-error:2.8e-05
#
# [88]	train-error:1.1e-05	eval-error:2.8e-05
#
# [89]	train-error:1.1e-05	eval-error:2.8e-05
#
# [90]	train-error:1.1e-05	eval-error:2.8e-05
#
# [91]	train-error:1.1e-05	eval-error:2.8e-05
#
# [92]	train-error:1.1e-05	eval-error:2.8e-05
#
# [93]	train-error:8e-06	eval-error:2.5e-05
#
# [94]	train-error:6e-06	eval-error:2.3e-05
#
# [95]	train-error:4e-06	eval-error:2.3e-05
#
# [96]	train-error:4e-06	eval-error:2e-05
#
# [97]	train-error:4e-06	eval-error:2e-05
#
# [98]	train-error:4e-06	eval-error:2e-05
#
# [99]	train-error:4e-06	eval-error:2e-05
#
# params: {'alpha': 2.0924601976008386e-07, 'colsample_bytree': 0.65, 'gamma': 7.506895113690553e-08, 'lambda': 0.08753053397287429, 'max_depth': 6, 'min_child_weight': 0.25613504266358367, 'subsample': 0.7000000000000001}, logloss: 0.00023958
# [0]	train-error:0.005843	eval-error:0.005882
#
# [1]	train-error:0.003505	eval-error:0.003512
#
# [2]	train-error:0.002384	eval-error:0.002368
#
# [3]	train-error:0.003324	eval-error:0.003336
#
# [4]	train-error:0.003272	eval-error:0.003367
#
# [5]	train-error:0.002952	eval-error:0.002962
#
# [6]	train-error:0.002818	eval-error:0.002843
#
# [7]	train-error:0.002478	eval-error:0.002461
#
# [8]	train-error:0.002484	eval-error:0.002467
#
# [9]	train-error:0.002624	eval-error:0.002634
#
# [10]	train-error:0.002271	eval-error:0.002305
#
# [11]	train-error:0.001746	eval-error:0.001863
#
# [12]	train-error:0.00174	eval-error:0.001861
#
# [13]	train-error:0.001929	eval-error:0.002011
#
# [14]	train-error:0.001788	eval-error:0.001827
#
# [15]	train-error:0.001926	eval-error:0.001991
#
# [16]	train-error:0.001924	eval-error:0.002008
#
# [17]	train-error:0.001766	eval-error:0.001821
#
# [18]	train-error:0.001748	eval-error:0.001795
#
# [19]	train-error:0.001892	eval-error:0.001957
#
# [20]	train-error:0.001763	eval-error:0.001798
#
# [21]	train-error:0.001744	eval-error:0.001787
#
# [22]	train-error:0.001857	eval-error:0.001934
#
# [23]	train-error:0.001863	eval-error:0.001948
#
# [24]	train-error:0.001723	eval-error:0.001793
#
# [25]	train-error:0.001857	eval-error:0.001943
#
# [26]	train-error:0.001748	eval-error:0.001861
#
# [27]	train-error:0.001384	eval-error:0.001526
#
# [28]	train-error:0.001357	eval-error:0.001501
#
# [29]	train-error:0.001565	eval-error:0.001643
#
# [30]	train-error:0.001342	eval-error:0.001478
#
# [31]	train-error:0.001559	eval-error:0.001634
#
# [32]	train-error:0.001336	eval-error:0.001464
#
# [33]	train-error:0.001442	eval-error:0.001555
#
# [34]	train-error:0.001318	eval-error:0.001439
#
# [35]	train-error:0.001302	eval-error:0.00143
#
# [36]	train-error:0.001309	eval-error:0.001374
#
# [37]	train-error:0.001234	eval-error:0.00134
#
# [38]	train-error:0.001173	eval-error:0.001274
#
# [39]	train-error:0.001174	eval-error:0.001269
#
# [40]	train-error:0.001162	eval-error:0.001274
#
# [41]	train-error:0.001007	eval-error:0.001104
#
# [42]	train-error:0.000998	eval-error:0.001102
#
# [43]	train-error:0.001007	eval-error:0.001113
#
# [44]	train-error:0.001003	eval-error:0.001119
#
# [45]	train-error:0.000992	eval-error:0.001104
#
# [46]	train-error:0.000989	eval-error:0.001104
#
# [47]	train-error:0.000989	eval-error:0.001104
#
# [48]	train-error:0.000988	eval-error:0.001099
#
# [49]	train-error:0.000988	eval-error:0.001102
#
# [50]	train-error:0.001105	eval-error:0.001198
#
# [51]	train-error:0.001102	eval-error:0.001195
#
# [52]	train-error:0.001092	eval-error:0.001195
#
# [53]	train-error:0.000973	eval-error:0.00109
#
# [54]	train-error:0.000997	eval-error:0.001116
#
# [55]	train-error:0.000987	eval-error:0.001113
#
# [56]	train-error:0.000947	eval-error:0.001082
#
# [57]	train-error:0.000949	eval-error:0.001073
#
# [58]	train-error:0.001043	eval-error:0.001158
#
# [59]	train-error:0.001058	eval-error:0.001167
#
# [60]	train-error:0.001032	eval-error:0.001138
#
# [61]	train-error:0.000917	eval-error:0.001042
#
# [62]	train-error:0.000835	eval-error:0.000943
#
# [63]	train-error:0.000835	eval-error:0.000943
#
# [64]	train-error:0.000896	eval-error:0.000994
#
# [65]	train-error:0.000886	eval-error:0.000994
#
# [66]	train-error:0.000845	eval-error:0.000966
#
# [67]	train-error:0.000795	eval-error:0.000903
#
# [68]	train-error:0.000741	eval-error:0.000869
#
# [69]	train-error:0.000688	eval-error:0.000824
#
# [70]	train-error:0.000664	eval-error:0.000762
#
# [71]	train-error:0.000629	eval-error:0.000716
#
# [72]	train-error:0.000618	eval-error:0.000708
#
# [73]	train-error:0.000592	eval-error:0.000697
#
# [74]	train-error:0.000578	eval-error:0.000677
#
# [75]	train-error:0.000488	eval-error:0.000592
#
# [76]	train-error:0.000482	eval-error:0.000592
#
# [77]	train-error:0.000467	eval-error:0.000558
#
# [78]	train-error:0.000467	eval-error:0.000555
#
# [79]	train-error:0.000468	eval-error:0.000564
#
# [80]	train-error:0.000413	eval-error:0.000476
#
# [81]	train-error:0.000392	eval-error:0.000479
#
# [82]	train-error:0.0004	eval-error:0.000479
#
# [83]	train-error:0.000372	eval-error:0.000442
#
# [84]	train-error:0.000341	eval-error:0.000402
#
# [85]	train-error:0.000335	eval-error:0.000399
#
# [86]	train-error:0.000327	eval-error:0.000388
#
# [87]	train-error:0.00033	eval-error:0.000391
#
# [88]	train-error:0.000316	eval-error:0.000379
#
# [89]	train-error:0.000308	eval-error:0.000377
#
# [90]	train-error:0.000302	eval-error:0.000362
#
# [91]	train-error:0.000293	eval-error:0.00036
#
# [92]	train-error:0.00029	eval-error:0.00036
#
# [93]	train-error:0.000288	eval-error:0.00036
#
# [94]	train-error:0.000275	eval-error:0.000331
#
# [95]	train-error:0.000269	eval-error:0.000329
#
# [96]	train-error:0.000254	eval-error:0.00032
#
# [97]	train-error:0.000237	eval-error:0.000306
#
# [98]	train-error:0.000233	eval-error:0.000297
#
# [99]	train-error:0.000213	eval-error:0.000278
#
# params: {'alpha': 6.435998711876909e-05, 'colsample_bytree': 0.65, 'gamma': 3.58601817934257e-08, 'lambda': 0.70829217957189, 'max_depth': 4, 'min_child_weight': 5.560469418670792, 'subsample': 0.7000000000000001}, logloss: 0.00164775
# [0]	train-error:0.001555	eval-error:0.001691
#
# [1]	train-error:0.001059	eval-error:0.001136
#
# [2]	train-error:0.00134	eval-error:0.001402
#
# [3]	train-error:0.001109	eval-error:0.001113
#
# [4]	train-error:0.000838	eval-error:0.000895
#
# [5]	train-error:0.000813	eval-error:0.000884
#
# [6]	train-error:0.000733	eval-error:0.000793
#
# [7]	train-error:0.000789	eval-error:0.000872
#
# [8]	train-error:0.000857	eval-error:0.000937
#
# [9]	train-error:0.000841	eval-error:0.00092
#
# [10]	train-error:0.000736	eval-error:0.000824
#
# [11]	train-error:0.000809	eval-error:0.000901
#
# [12]	train-error:0.000707	eval-error:0.000818
#
# [13]	train-error:0.000728	eval-error:0.000841
#
# [14]	train-error:0.000644	eval-error:0.00075
#
# [15]	train-error:0.000586	eval-error:0.000674
#
# [16]	train-error:0.00055	eval-error:0.000612
#
# [17]	train-error:0.000507	eval-error:0.000572
#
# [18]	train-error:0.000451	eval-error:0.000524
#
# [19]	train-error:0.000442	eval-error:0.000513
#
# [20]	train-error:0.000423	eval-error:0.00051
#
# [21]	train-error:0.000399	eval-error:0.000484
#
# [22]	train-error:0.000379	eval-error:0.00047
#
# [23]	train-error:0.000367	eval-error:0.000456
#
# [24]	train-error:0.000353	eval-error:0.000442
#
# [25]	train-error:0.000351	eval-error:0.000433
#
# [26]	train-error:0.000337	eval-error:0.000428
#
# [27]	train-error:0.000334	eval-error:0.000425
#
# [28]	train-error:0.000328	eval-error:0.000419
#
# [29]	train-error:0.00029	eval-error:0.000394
#
# [30]	train-error:0.000275	eval-error:0.000371
#
# [31]	train-error:0.000251	eval-error:0.000334
#
# [32]	train-error:0.00021	eval-error:0.000275
#
# [33]	train-error:0.000209	eval-error:0.000275
#
# [34]	train-error:0.000185	eval-error:0.000255
#
# [35]	train-error:0.000174	eval-error:0.000246
#
# [36]	train-error:0.000171	eval-error:0.000241
#
# [37]	train-error:0.000155	eval-error:0.000215
#
# [38]	train-error:0.000136	eval-error:0.000198
#
# [39]	train-error:0.000142	eval-error:0.000218
#
# [40]	train-error:0.000101	eval-error:0.000187
#
# [41]	train-error:7.6e-05	eval-error:0.000156
#
# [42]	train-error:7.5e-05	eval-error:0.000147
#
# [43]	train-error:6.9e-05	eval-error:0.000127
#
# [44]	train-error:7.1e-05	eval-error:0.000127
#
# [45]	train-error:6.7e-05	eval-error:0.000122
#
# [46]	train-error:6.6e-05	eval-error:0.000113
#
# [47]	train-error:6.4e-05	eval-error:0.000102
#
# [48]	train-error:5.9e-05	eval-error:9.1e-05
#
# [49]	train-error:5.3e-05	eval-error:7.9e-05
#
# [50]	train-error:4.9e-05	eval-error:6.8e-05
#
# [51]	train-error:3.4e-05	eval-error:4.8e-05
#
# [52]	train-error:2.8e-05	eval-error:4e-05
#
# [53]	train-error:2.3e-05	eval-error:4e-05
#
# [54]	train-error:2.6e-05	eval-error:4e-05
#
# [55]	train-error:2.1e-05	eval-error:3.4e-05
#
# [56]	train-error:2.1e-05	eval-error:3.4e-05
#
# [57]	train-error:1.8e-05	eval-error:3.4e-05
#
# [58]	train-error:1.7e-05	eval-error:3.4e-05
#
# [59]	train-error:1.6e-05	eval-error:3.1e-05
#
# [60]	train-error:1.4e-05	eval-error:3.1e-05
#
# [61]	train-error:1.4e-05	eval-error:2.8e-05
#
# [62]	train-error:1.4e-05	eval-error:2.8e-05
#
# [63]	train-error:1.3e-05	eval-error:2.8e-05
#
# [64]	train-error:1.3e-05	eval-error:2.5e-05
#
# [65]	train-error:1.1e-05	eval-error:2.5e-05
#
# [66]	train-error:1.1e-05	eval-error:2.5e-05
#
# [67]	train-error:1.1e-05	eval-error:2.3e-05
#
# [68]	train-error:1.1e-05	eval-error:1.7e-05
#
# [69]	train-error:1.1e-05	eval-error:1.7e-05
#
# [70]	train-error:8e-06	eval-error:1.7e-05
#
# [71]	train-error:8e-06	eval-error:1.7e-05
#
# [72]	train-error:8e-06	eval-error:1.7e-05
#
# [73]	train-error:8e-06	eval-error:1.7e-05
#
# [74]	train-error:6e-06	eval-error:1.7e-05
#
# [75]	train-error:6e-06	eval-error:1.7e-05
#
# [76]	train-error:6e-06	eval-error:2e-05
#
# [77]	train-error:6e-06	eval-error:2e-05
#
# [78]	train-error:6e-06	eval-error:1.7e-05
#
# [79]	train-error:5e-06	eval-error:2e-05
#
# [80]	train-error:4e-06	eval-error:2e-05
#
# [81]	train-error:4e-06	eval-error:2e-05
#
# [82]	train-error:4e-06	eval-error:2e-05
#
# [83]	train-error:4e-06	eval-error:2e-05
#
# [84]	train-error:4e-06	eval-error:2.3e-05
#
# [85]	train-error:4e-06	eval-error:2.3e-05
#
# [86]	train-error:4e-06	eval-error:2.3e-05
#
# [87]	train-error:4e-06	eval-error:2.3e-05
#
# [88]	train-error:4e-06	eval-error:2.3e-05
#
# [89]	train-error:4e-06	eval-error:2.3e-05
#
# [90]	train-error:4e-06	eval-error:2.3e-05
#
# [91]	train-error:4e-06	eval-error:2e-05
#
# [92]	train-error:4e-06	eval-error:2.3e-05
#
# [93]	train-error:4e-06	eval-error:2.3e-05
#
# [94]	train-error:4e-06	eval-error:2.3e-05
#
# [95]	train-error:4e-06	eval-error:2.3e-05
#
# [96]	train-error:4e-06	eval-error:2.3e-05
#
# [97]	train-error:4e-06	eval-error:2.3e-05
#
# [98]	train-error:4e-06	eval-error:2.3e-05
#
# [99]	train-error:4e-06	eval-error:2.3e-05
#
# params: {'alpha': 0.05667593989711418, 'colsample_bytree': 0.65, 'gamma': 6.710873853314071e-07, 'lambda': 0.006985685942953635, 'max_depth': 7, 'min_child_weight': 0.7715297834212568, 'subsample': 0.75}, logloss: 0.00014276
# [0]	train-error:0.001711	eval-error:0.001747
#
# [1]	train-error:0.00098	eval-error:0.00096
#
# [2]	train-error:0.001657	eval-error:0.001623
#
# [3]	train-error:0.001085	eval-error:0.001042
#
# [4]	train-error:0.001088	eval-error:0.001051
#
# [5]	train-error:0.001097	eval-error:0.001119
#
# [6]	train-error:0.000873	eval-error:0.000918
#
# [7]	train-error:0.001009	eval-error:0.001096
#
# [8]	train-error:0.001047	eval-error:0.001124
#
# [9]	train-error:0.001008	eval-error:0.00107
#
# [10]	train-error:0.000878	eval-error:0.000935
#
# [11]	train-error:0.000888	eval-error:0.000969
#
# [12]	train-error:0.000898	eval-error:0.000971
#
# [13]	train-error:0.000899	eval-error:0.000988
#
# [14]	train-error:0.000891	eval-error:0.000971
#
# [15]	train-error:0.000891	eval-error:0.000971
#
# [16]	train-error:0.000767	eval-error:0.000847
#
# [17]	train-error:0.000742	eval-error:0.000833
#
# [18]	train-error:0.00071	eval-error:0.000779
#
# [19]	train-error:0.000685	eval-error:0.000745
#
# [20]	train-error:0.000665	eval-error:0.000719
#
# [21]	train-error:0.000651	eval-error:0.000716
#
# [22]	train-error:0.000621	eval-error:0.000697
#
# [23]	train-error:0.000675	eval-error:0.000736
#
# [24]	train-error:0.000598	eval-error:0.000671
#
# [25]	train-error:0.000561	eval-error:0.00064
#
# [26]	train-error:0.000542	eval-error:0.000623
#
# [27]	train-error:0.000593	eval-error:0.000674
#
# [28]	train-error:0.000518	eval-error:0.000612
#
# [29]	train-error:0.000521	eval-error:0.000603
#
# [30]	train-error:0.000489	eval-error:0.000589
#
# [31]	train-error:0.000459	eval-error:0.000549
#
# [32]	train-error:0.000469	eval-error:0.000575
#
# [33]	train-error:0.000454	eval-error:0.000558
#
# [34]	train-error:0.00043	eval-error:0.000524
#
# [35]	train-error:0.000402	eval-error:0.000501
#
# [36]	train-error:0.000409	eval-error:0.000507
#
# [37]	train-error:0.000401	eval-error:0.000501
#
# [38]	train-error:0.00039	eval-error:0.00049
#
# [39]	train-error:0.000388	eval-error:0.000487
#
# [40]	train-error:0.000384	eval-error:0.000484
#
# [41]	train-error:0.000335	eval-error:0.000428
#
# [42]	train-error:0.000329	eval-error:0.000425
#
# [43]	train-error:0.000321	eval-error:0.000408
#
# [44]	train-error:0.00027	eval-error:0.000365
#
# [45]	train-error:0.00025	eval-error:0.000331
#
# [46]	train-error:0.000199	eval-error:0.000292
#
# [47]	train-error:0.000193	eval-error:0.000278
#
# [48]	train-error:0.00019	eval-error:0.000275
#
# [49]	train-error:0.000177	eval-error:0.000269
#
# [50]	train-error:0.000162	eval-error:0.000246
#
# [51]	train-error:0.000152	eval-error:0.000227
#
# [52]	train-error:0.00014	eval-error:0.000207
#
# [53]	train-error:0.000127	eval-error:0.000193
#
# [54]	train-error:0.000124	eval-error:0.00019
#
# [55]	train-error:0.000121	eval-error:0.000193
#
# [56]	train-error:0.000109	eval-error:0.000187
#
# [57]	train-error:0.000107	eval-error:0.000181
#
# [58]	train-error:0.0001	eval-error:0.000161
#
# [59]	train-error:9.3e-05	eval-error:0.000156
#
# [60]	train-error:7.6e-05	eval-error:0.000136
#
# [61]	train-error:7.2e-05	eval-error:0.000125
#
# [62]	train-error:7.3e-05	eval-error:0.000119
#
# [63]	train-error:6.9e-05	eval-error:0.000116
#
# [64]	train-error:6.5e-05	eval-error:0.000116
#
# [65]	train-error:5.5e-05	eval-error:9.6e-05
#
# [66]	train-error:5e-05	eval-error:9.6e-05
#
# [67]	train-error:5.1e-05	eval-error:9.1e-05
#
# [68]	train-error:5e-05	eval-error:7.9e-05
#
# [69]	train-error:4.7e-05	eval-error:7.9e-05
#
# [70]	train-error:4.7e-05	eval-error:7.1e-05
#
# [71]	train-error:4.7e-05	eval-error:7.4e-05
#
# [72]	train-error:4.7e-05	eval-error:7.1e-05
#
# [73]	train-error:4.7e-05	eval-error:7.4e-05
#
# [74]	train-error:4.5e-05	eval-error:7.4e-05
#
# [75]	train-error:4.5e-05	eval-error:7.1e-05
#
# [76]	train-error:4.3e-05	eval-error:6.8e-05
#
# [77]	train-error:4.2e-05	eval-error:6.5e-05
#
# [78]	train-error:4.2e-05	eval-error:6.8e-05
#
# [79]	train-error:4.2e-05	eval-error:6.8e-05
#
# [80]	train-error:4.2e-05	eval-error:6.5e-05
#
# [81]	train-error:4.2e-05	eval-error:6.5e-05
#
# [82]	train-error:4.2e-05	eval-error:6.5e-05
#
# [83]	train-error:4.2e-05	eval-error:6.5e-05
#
# [84]	train-error:4.2e-05	eval-error:6.5e-05
#
# [85]	train-error:4.2e-05	eval-error:6.8e-05
#
# [86]	train-error:4.1e-05	eval-error:6.2e-05
#
# [87]	train-error:3.8e-05	eval-error:5.9e-05
#
# [88]	train-error:4e-05	eval-error:6.2e-05
#
# [89]	train-error:3.5e-05	eval-error:5.9e-05
#
# [90]	train-error:3.5e-05	eval-error:5.9e-05
#
# [91]	train-error:3.6e-05	eval-error:6.2e-05
#
# [92]	train-error:3.4e-05	eval-error:5.9e-05
#
# [93]	train-error:3.3e-05	eval-error:5.9e-05
#
# [94]	train-error:3.3e-05	eval-error:5.9e-05
#
# [95]	train-error:2.9e-05	eval-error:4.8e-05
#
# [96]	train-error:2.4e-05	eval-error:4.2e-05
#
# [97]	train-error:2.3e-05	eval-error:4.2e-05
#
# [98]	train-error:2.2e-05	eval-error:4.2e-05
#
# [99]	train-error:2.2e-05	eval-error:4.2e-05
#
# params: {'alpha': 0.006524164675350762, 'colsample_bytree': 0.65, 'gamma': 0.00043889627733847974, 'lambda': 0.012554147088968449, 'max_depth': 6, 'min_child_weight': 9.900403418945483, 'subsample': 0.9}, logloss: 0.00040725
# [0]	train-error:0.000866	eval-error:0.000966
#
# [1]	train-error:0.000391	eval-error:0.000476
#
# [2]	train-error:0.000501	eval-error:0.000589
#
# [3]	train-error:0.000429	eval-error:0.00049
#
# [4]	train-error:0.000497	eval-error:0.000578
#
# [5]	train-error:0.000442	eval-error:0.000515
#
# [6]	train-error:0.000382	eval-error:0.000464
#
# [7]	train-error:0.000357	eval-error:0.000439
#
# [8]	train-error:0.000367	eval-error:0.000442
#
# [9]	train-error:0.000366	eval-error:0.000447
#
# [10]	train-error:0.000338	eval-error:0.000413
#
# [11]	train-error:0.000341	eval-error:0.000433
#
# [12]	train-error:0.000314	eval-error:0.000396
#
# [13]	train-error:0.000301	eval-error:0.000399
#
# [14]	train-error:0.000268	eval-error:0.000368
#
# [15]	train-error:0.000236	eval-error:0.00034
#
# [16]	train-error:0.000244	eval-error:0.000337
#
# [17]	train-error:0.000218	eval-error:0.000309
#
# [18]	train-error:0.000109	eval-error:0.000161
#
# [19]	train-error:0.000142	eval-error:0.000195
#
# [20]	train-error:9.2e-05	eval-error:0.000144
#
# [21]	train-error:0.000101	eval-error:0.000153
#
# [22]	train-error:9.1e-05	eval-error:0.000139
#
# [23]	train-error:8.7e-05	eval-error:0.000136
#
# [24]	train-error:6.9e-05	eval-error:0.00011
#
# [25]	train-error:7.4e-05	eval-error:0.000122
#
# [26]	train-error:7.1e-05	eval-error:0.000116
#
# [27]	train-error:6.2e-05	eval-error:0.000105
#
# [28]	train-error:5.6e-05	eval-error:8.8e-05
#
# [29]	train-error:5e-05	eval-error:8.5e-05
#
# [30]	train-error:4.5e-05	eval-error:7.6e-05
#
# [31]	train-error:4.3e-05	eval-error:7.9e-05
#
# [32]	train-error:4.2e-05	eval-error:7.9e-05
#
# [33]	train-error:4e-05	eval-error:7.9e-05
#
# [34]	train-error:3.9e-05	eval-error:7.6e-05
#
# [35]	train-error:3.6e-05	eval-error:7.1e-05
#
# [36]	train-error:3.3e-05	eval-error:6.2e-05
#
# [37]	train-error:3e-05	eval-error:6.2e-05
#
# [38]	train-error:2.5e-05	eval-error:5.1e-05
#
# [39]	train-error:1.5e-05	eval-error:3.7e-05
#
# [40]	train-error:1.4e-05	eval-error:3.7e-05
#
# [41]	train-error:1e-05	eval-error:3.1e-05
#
# [42]	train-error:6e-06	eval-error:2e-05
#
# [43]	train-error:5e-06	eval-error:1.7e-05
#
# [44]	train-error:4e-06	eval-error:1.7e-05
#
# [45]	train-error:4e-06	eval-error:1.7e-05
#
# [46]	train-error:3e-06	eval-error:1.7e-05
#
# [47]	train-error:3e-06	eval-error:1.7e-05
#
# [48]	train-error:3e-06	eval-error:1.7e-05
#
# [49]	train-error:2e-06	eval-error:1.7e-05
#
# [50]	train-error:2e-06	eval-error:1.7e-05
#
# [51]	train-error:2e-06	eval-error:1.7e-05
#
# [52]	train-error:2e-06	eval-error:1.7e-05
#
# [53]	train-error:2e-06	eval-error:1.7e-05
#
# [54]	train-error:1e-06	eval-error:1.7e-05
#
# [55]	train-error:1e-06	eval-error:1.4e-05
#
# [56]	train-error:1e-06	eval-error:1.4e-05
#
# [57]	train-error:1e-06	eval-error:1.4e-05
#
# [58]	train-error:1e-06	eval-error:1.4e-05
#
# [59]	train-error:1e-06	eval-error:1.4e-05
#
# [60]	train-error:1e-06	eval-error:1.4e-05
#
# [61]	train-error:1e-06	eval-error:1.4e-05
#
# [62]	train-error:1e-06	eval-error:1.4e-05
#
# [63]	train-error:1e-06	eval-error:1.4e-05
#
# [64]	train-error:1e-06	eval-error:1.4e-05
#
# [65]	train-error:1e-06	eval-error:1.4e-05
#
# [66]	train-error:1e-06	eval-error:1.4e-05
#
# [67]	train-error:1e-06	eval-error:1.4e-05
#
# [68]	train-error:1e-06	eval-error:1.4e-05
#
# [69]	train-error:1e-06	eval-error:1.4e-05
#
# [70]	train-error:1e-06	eval-error:1.4e-05
#
# [71]	train-error:1e-06	eval-error:1.4e-05
#
# [72]	train-error:1e-06	eval-error:1.4e-05
#
# [73]	train-error:1e-06	eval-error:1.7e-05
#
# [74]	train-error:1e-06	eval-error:1.7e-05
#
# [75]	train-error:1e-06	eval-error:1.7e-05
#
# [76]	train-error:1e-06	eval-error:1.7e-05
#
# [77]	train-error:1e-06	eval-error:1.7e-05
#
# [78]	train-error:1e-06	eval-error:1.4e-05
#
# [79]	train-error:1e-06	eval-error:1.7e-05
#
# [80]	train-error:1e-06	eval-error:1.4e-05
#
# [81]	train-error:0	eval-error:1.7e-05
#
# [82]	train-error:0	eval-error:1.7e-05
#
# [83]	train-error:0	eval-error:1.7e-05
#
# [84]	train-error:0	eval-error:1.7e-05
#
# [85]	train-error:0	eval-error:1.7e-05
#
# [86]	train-error:0	eval-error:1.7e-05
#
# [87]	train-error:0	eval-error:1.7e-05
#
# [88]	train-error:0	eval-error:1.7e-05
#
# [89]	train-error:0	eval-error:1.7e-05
#
# [90]	train-error:0	eval-error:1.7e-05
#
# [91]	train-error:0	eval-error:1.7e-05
#
# [92]	train-error:0	eval-error:1.7e-05
#
# [93]	train-error:0	eval-error:1.7e-05
#
# [94]	train-error:0	eval-error:1.7e-05
#
# [95]	train-error:0	eval-error:1.7e-05
#
# [96]	train-error:0	eval-error:1.7e-05
#
# [97]	train-error:0	eval-error:1.4e-05
#
# [98]	train-error:0	eval-error:1.7e-05
#
# [99]	train-error:0	eval-error:1.7e-05
#
# params: {'alpha': 9.261471297063876e-05, 'colsample_bytree': 0.8, 'gamma': 0.0014509460572582741, 'lambda': 0.029418447964715818, 'max_depth': 9, 'min_child_weight': 0.13979497730324253, 'subsample': 0.9}, logloss: 0.00010281
# [0]	train-error:0.001446	eval-error:0.001478
#
# [1]	train-error:0.001412	eval-error:0.001458
#
# [2]	train-error:0.00142	eval-error:0.001458
#
# [3]	train-error:0.001139	eval-error:0.00126
#
# [4]	train-error:0.001157	eval-error:0.001266
#
# [5]	train-error:0.001136	eval-error:0.001255
#
# [6]	train-error:0.001144	eval-error:0.00126
#
# [7]	train-error:0.001133	eval-error:0.001249
#
# [8]	train-error:0.001139	eval-error:0.001255
#
# [9]	train-error:0.001141	eval-error:0.001257
#
# [10]	train-error:0.001126	eval-error:0.001243
#
# [11]	train-error:0.001138	eval-error:0.001257
#
# [12]	train-error:0.001136	eval-error:0.001255
#
# [13]	train-error:0.001134	eval-error:0.001252
#
# [14]	train-error:0.001141	eval-error:0.001252
#
# [15]	train-error:0.001137	eval-error:0.001255
#
# [16]	train-error:0.001136	eval-error:0.001249
#
# [17]	train-error:0.001024	eval-error:0.00115
#
# [18]	train-error:0.00085	eval-error:0.000991
#
# [19]	train-error:0.001006	eval-error:0.001119
#
# [20]	train-error:0.000999	eval-error:0.001119
#
# [21]	train-error:0.00099	eval-error:0.001113
#
# [22]	train-error:0.000969	eval-error:0.00109
#
# [23]	train-error:0.000917	eval-error:0.001028
#
# [24]	train-error:0.000911	eval-error:0.001022
#
# [25]	train-error:0.000858	eval-error:0.000966
#
# [26]	train-error:0.000849	eval-error:0.000963
#
# [27]	train-error:0.000728	eval-error:0.000838
#
# [28]	train-error:0.000633	eval-error:0.000753
#
# [29]	train-error:0.000659	eval-error:0.000773
#
# [30]	train-error:0.000605	eval-error:0.000697
#
# [31]	train-error:0.000563	eval-error:0.000657
#
# [32]	train-error:0.000559	eval-error:0.000654
#
# [33]	train-error:0.000529	eval-error:0.00062
#
# [34]	train-error:0.000482	eval-error:0.000578
#
# [35]	train-error:0.000398	eval-error:0.000496
#
# [36]	train-error:0.000384	eval-error:0.000481
#
# [37]	train-error:0.000319	eval-error:0.000408
#
# [38]	train-error:0.000312	eval-error:0.000394
#
# [39]	train-error:0.000304	eval-error:0.000382
#
# [40]	train-error:0.000254	eval-error:0.000331
#
# [41]	train-error:0.000218	eval-error:0.000309
#
# [42]	train-error:0.000214	eval-error:0.000309
#
# [43]	train-error:0.000186	eval-error:0.000283
#
# [44]	train-error:0.000183	eval-error:0.000278
#
# [45]	train-error:0.000183	eval-error:0.000278
#
# [46]	train-error:0.000154	eval-error:0.000258
#
# [47]	train-error:0.000152	eval-error:0.000249
#
# [48]	train-error:0.000151	eval-error:0.000246
#
# [49]	train-error:0.000151	eval-error:0.000246
#
# [50]	train-error:0.000149	eval-error:0.000241
#
# [51]	train-error:0.000131	eval-error:0.000204
#
# [52]	train-error:0.00013	eval-error:0.000204
#
# [53]	train-error:0.000113	eval-error:0.000181
#
# [54]	train-error:0.000113	eval-error:0.000187
#
# [55]	train-error:9.3e-05	eval-error:0.000136
#
# [56]	train-error:9e-05	eval-error:0.000136
#
# [57]	train-error:8.7e-05	eval-error:0.000122
#
# [58]	train-error:8.6e-05	eval-error:0.000119
#
# [59]	train-error:8.4e-05	eval-error:0.000122
#
# [60]	train-error:8.1e-05	eval-error:0.00011
#
# [61]	train-error:7.9e-05	eval-error:0.000108
#
# [62]	train-error:7.8e-05	eval-error:0.000105
#
# [63]	train-error:7.7e-05	eval-error:0.000105
#
# [64]	train-error:6.4e-05	eval-error:9.1e-05
#
# [65]	train-error:6.2e-05	eval-error:8.8e-05
#
# [66]	train-error:5.4e-05	eval-error:8.2e-05
#
# [67]	train-error:5.3e-05	eval-error:8.2e-05
#
# [68]	train-error:4.8e-05	eval-error:7.9e-05
#
# [69]	train-error:4.9e-05	eval-error:7.9e-05
#
# [70]	train-error:4.5e-05	eval-error:7.6e-05
#
# [71]	train-error:4.2e-05	eval-error:7.1e-05
#
# [72]	train-error:4.1e-05	eval-error:6.8e-05
#
# [73]	train-error:4.2e-05	eval-error:6.5e-05
#
# [74]	train-error:3.9e-05	eval-error:5.7e-05
#
# [75]	train-error:3.9e-05	eval-error:5.4e-05
#
# [76]	train-error:3.7e-05	eval-error:5.4e-05
#
# [77]	train-error:3.7e-05	eval-error:5.4e-05
#
# [78]	train-error:3.6e-05	eval-error:5.4e-05
#
# [79]	train-error:3.2e-05	eval-error:4.2e-05
#
# [80]	train-error:3.3e-05	eval-error:4.2e-05
#
# [81]	train-error:3.2e-05	eval-error:4.2e-05
#
# [82]	train-error:2.7e-05	eval-error:4.2e-05
#
# [83]	train-error:2.6e-05	eval-error:4e-05
#
# [84]	train-error:2.6e-05	eval-error:4e-05
#
# [85]	train-error:2.6e-05	eval-error:4e-05
#
# [86]	train-error:2.5e-05	eval-error:4e-05
#
# [87]	train-error:2.5e-05	eval-error:4e-05
#
# [88]	train-error:2.4e-05	eval-error:4e-05
#
# [89]	train-error:2.4e-05	eval-error:4e-05
#
# [90]	train-error:2.2e-05	eval-error:4e-05
#
# [91]	train-error:2.2e-05	eval-error:4e-05
#
# [92]	train-error:1.9e-05	eval-error:4e-05
#
# [93]	train-error:2e-05	eval-error:4e-05
#
# [94]	train-error:2.1e-05	eval-error:4e-05
#
# [95]	train-error:2.1e-05	eval-error:4e-05
#
# [96]	train-error:1.9e-05	eval-error:4e-05
#
# [97]	train-error:1.9e-05	eval-error:4e-05
#
# [98]	train-error:1.8e-05	eval-error:3.7e-05
#
# [99]	train-error:1.8e-05	eval-error:3.7e-05
#
# params: {'alpha': 1.3255436785623851e-08, 'colsample_bytree': 1.0, 'gamma': 1.884578440922508e-05, 'lambda': 0.12051183556646677, 'max_depth': 6, 'min_child_weight': 4.763005435793687, 'subsample': 0.75}, logloss: 0.00033789
# [0]	train-error:0.002316	eval-error:0.002438
#
# [1]	train-error:0.002005	eval-error:0.002056
#
# [2]	train-error:0.002245	eval-error:0.002209
#
# [3]	train-error:0.002239	eval-error:0.002331
#
# [4]	train-error:0.002095	eval-error:0.002079
#
# [5]	train-error:0.00208	eval-error:0.002048
#
# [6]	train-error:0.00219	eval-error:0.002274
#
# [7]	train-error:0.002046	eval-error:0.002019
#
# [8]	train-error:0.00203	eval-error:0.002008
#
# [9]	train-error:0.002169	eval-error:0.002135
#
# [10]	train-error:0.001427	eval-error:0.00145
#
# [11]	train-error:0.001306	eval-error:0.001337
#
# [12]	train-error:0.001301	eval-error:0.001325
#
# [13]	train-error:0.001357	eval-error:0.001379
#
# [14]	train-error:0.001201	eval-error:0.00124
#
# [15]	train-error:0.001423	eval-error:0.001447
#
# [16]	train-error:0.001405	eval-error:0.001441
#
# [17]	train-error:0.001396	eval-error:0.001436
#
# [18]	train-error:0.001391	eval-error:0.00143
#
# [19]	train-error:0.001374	eval-error:0.00141
#
# [20]	train-error:0.001354	eval-error:0.001393
#
# [21]	train-error:0.001358	eval-error:0.001402
#
# [22]	train-error:0.001354	eval-error:0.001379
#
# [23]	train-error:0.001201	eval-error:0.001246
#
# [24]	train-error:0.001189	eval-error:0.001232
#
# [25]	train-error:0.001182	eval-error:0.001209
#
# [26]	train-error:0.001108	eval-error:0.001164
#
# [27]	train-error:0.001107	eval-error:0.001164
#
# [28]	train-error:0.001023	eval-error:0.001087
#
# [29]	train-error:0.001012	eval-error:0.001079
#
# [30]	train-error:0.001012	eval-error:0.001076
#
# [31]	train-error:0.001006	eval-error:0.001087
#
# [32]	train-error:0.001007	eval-error:0.00109
#
# [33]	train-error:0.000926	eval-error:0.001042
#
# [34]	train-error:0.000886	eval-error:0.000991
#
# [35]	train-error:0.000887	eval-error:0.000983
#
# [36]	train-error:0.000806	eval-error:0.000901
#
# [37]	train-error:0.0008	eval-error:0.000895
#
# [38]	train-error:0.000821	eval-error:0.000909
#
# [39]	train-error:0.000743	eval-error:0.000833
#
# [40]	train-error:0.000722	eval-error:0.00083
#
# [41]	train-error:0.000692	eval-error:0.000793
#
# [42]	train-error:0.000566	eval-error:0.000666
#
# [43]	train-error:0.000511	eval-error:0.000615
#
# [44]	train-error:0.000558	eval-error:0.000671
#
# [45]	train-error:0.000535	eval-error:0.000654
#
# [46]	train-error:0.000513	eval-error:0.000637
#
# [47]	train-error:0.000413	eval-error:0.000527
#
# [48]	train-error:0.000391	eval-error:0.000507
#
# [49]	train-error:0.000375	eval-error:0.000487
#
# [50]	train-error:0.00036	eval-error:0.00047
#
# [51]	train-error:0.000351	eval-error:0.000464
#
# [52]	train-error:0.000337	eval-error:0.000442
#
# [53]	train-error:0.000335	eval-error:0.000436
#
# [54]	train-error:0.000296	eval-error:0.000382
#
# [55]	train-error:0.000319	eval-error:0.000422
#
# [56]	train-error:0.000269	eval-error:0.000346
#
# [57]	train-error:0.000271	eval-error:0.00036
#
# [58]	train-error:0.000253	eval-error:0.000329
#
# [59]	train-error:0.000219	eval-error:0.000306
#
# [60]	train-error:0.00021	eval-error:0.000295
#
# [61]	train-error:0.000213	eval-error:0.0003
#
# [62]	train-error:0.000207	eval-error:0.000297
#
# [63]	train-error:0.0002	eval-error:0.0003
#
# [64]	train-error:0.000189	eval-error:0.000283
#
# [65]	train-error:0.000171	eval-error:0.000269
#
# [66]	train-error:0.00016	eval-error:0.000249
#
# [67]	train-error:0.000153	eval-error:0.000235
#
# [68]	train-error:0.000149	eval-error:0.000227
#
# [69]	train-error:0.000141	eval-error:0.00021
#
# [70]	train-error:0.000138	eval-error:0.000215
#
# [71]	train-error:0.000134	eval-error:0.000204
#
# [72]	train-error:0.000133	eval-error:0.000204
#
# [73]	train-error:0.000127	eval-error:0.000201
#
# [74]	train-error:0.00012	eval-error:0.000187
#
# [75]	train-error:0.000119	eval-error:0.000187
#
# [76]	train-error:0.000106	eval-error:0.000161
#
# [77]	train-error:0.000106	eval-error:0.000159
#
# [78]	train-error:0.0001	eval-error:0.000147
#
# [79]	train-error:9.8e-05	eval-error:0.000144
#
# [80]	train-error:9.7e-05	eval-error:0.000139
#
# [81]	train-error:9.6e-05	eval-error:0.000136
#
# [82]	train-error:9.6e-05	eval-error:0.000136
#
# [83]	train-error:9.6e-05	eval-error:0.000136
#
# [84]	train-error:9.5e-05	eval-error:0.000136
#
# [85]	train-error:9.1e-05	eval-error:0.000136
#
# [86]	train-error:8.5e-05	eval-error:0.00013
#
# [87]	train-error:8.6e-05	eval-error:0.00013
#
# [88]	train-error:7.4e-05	eval-error:0.000122
#
# [89]	train-error:7.4e-05	eval-error:0.000122
#
# [90]	train-error:6.9e-05	eval-error:0.000116
#
# [91]	train-error:6.4e-05	eval-error:0.000113
#
# [92]	train-error:6.4e-05	eval-error:0.000113
#
# [93]	train-error:6.3e-05	eval-error:0.000105
#
# [94]	train-error:6e-05	eval-error:9.6e-05
#
# [95]	train-error:5.5e-05	eval-error:9.1e-05
#
# [96]	train-error:4.9e-05	eval-error:8.5e-05
#
# [97]	train-error:4.5e-05	eval-error:7.9e-05
#
# [98]	train-error:4.3e-05	eval-error:7.6e-05
#
# [99]	train-error:4.2e-05	eval-error:7.4e-05
#
# params: {'alpha': 7.339696489363736e-07, 'colsample_bytree': 0.9, 'gamma': 1.598052890203162e-06, 'lambda': 0.0007001903616475526, 'max_depth': 5, 'min_child_weight': 2.3289795255989634, 'subsample': 0.65}, logloss: 0.00055974
# [0]	train-error:0.001557	eval-error:0.001696
#
# [1]	train-error:0.001046	eval-error:0.001093
#
# [2]	train-error:0.000966	eval-error:0.000969
#
# [3]	train-error:0.000861	eval-error:0.000892
#
# [4]	train-error:0.000801	eval-error:0.000838
#
# [5]	train-error:0.00078	eval-error:0.000869
#
# [6]	train-error:0.000843	eval-error:0.000886
#
# [7]	train-error:0.000769	eval-error:0.000858
#
# [8]	train-error:0.000679	eval-error:0.000742
#
# [9]	train-error:0.000845	eval-error:0.000898
#
# [10]	train-error:0.000843	eval-error:0.000884
#
# [11]	train-error:0.000756	eval-error:0.000804
#
# [12]	train-error:0.00076	eval-error:0.000844
#
# ...
# [0]	train-error:0.002326	eval-error:0.002447
#
# [1]	train-error:0.002311	eval-error:0.002441
#
# [2]	train-error:0.002502	eval-error:0.002472
#
# [3]	train-error:0.002333	eval-error:0.002277
#
# [4]	train-error:0.002113	eval-error:0.002082
#
# [5]	train-error:0.002032	eval-error:0.002002
#
# [6]	train-error:0.002037	eval-error:0.002019
#
# [7]	train-error:0.002031	eval-error:0.002016
#
# [8]	train-error:0.00202	eval-error:0.001994
#
# [9]	train-error:0.001361	eval-error:0.001399
#
# [10]	train-error:0.001245	eval-error:0.001308
#
# [11]	train-error:0.001326	eval-error:0.001385
#
# [12]	train-error:0.001296	eval-error:0.001334
#
# [13]	train-error:0.001241	eval-error:0.001311
#
# [14]	train-error:0.001242	eval-error:0.001308
#
# [15]	train-error:0.001255	eval-error:0.001314
#
# [16]	train-error:0.001288	eval-error:0.00132
#
# [17]	train-error:0.001258	eval-error:0.001303
#
# [18]	train-error:0.001245	eval-error:0.001297
#
# [19]	train-error:0.001197	eval-error:0.001269
#
# [20]	train-error:0.001158	eval-error:0.001238
#
# [21]	train-error:0.001148	eval-error:0.001221
#
# [22]	train-error:0.001133	eval-error:0.001201
#
# [23]	train-error:0.001129	eval-error:0.001192
#
# [24]	train-error:0.001022	eval-error:0.001099
#
# [25]	train-error:0.001095	eval-error:0.001175
#
# [26]	train-error:0.000968	eval-error:0.001068
#
# [27]	train-error:0.000961	eval-error:0.001053
#
# [28]	train-error:0.000956	eval-error:0.001045
#
# [29]	train-error:0.000882	eval-error:0.000988
#
# [30]	train-error:0.000827	eval-error:0.000918
#
# [31]	train-error:0.000818	eval-error:0.000918
#
# [32]	train-error:0.000804	eval-error:0.000892
#
# [33]	train-error:0.000781	eval-error:0.000886
#
# [34]	train-error:0.000772	eval-error:0.000858
#
# [35]	train-error:0.000763	eval-error:0.00085
#
# [36]	train-error:0.000702	eval-error:0.000782
#
# [37]	train-error:0.000711	eval-error:0.00079
#
# [38]	train-error:0.000717	eval-error:0.000804
#
# [39]	train-error:0.000673	eval-error:0.000739
#
# [40]	train-error:0.000637	eval-error:0.000691
#
# [41]	train-error:0.000638	eval-error:0.0007
#
# [42]	train-error:0.000503	eval-error:0.000589
#
# [43]	train-error:0.000434	eval-error:0.000535
#
# [44]	train-error:0.00042	eval-error:0.000527
#
# [45]	train-error:0.000406	eval-error:0.000513
#
# [46]	train-error:0.000411	eval-error:0.000513
#
# [47]	train-error:0.0004	eval-error:0.000504
#
# [48]	train-error:0.000384	eval-error:0.000484
#
# [49]	train-error:0.000343	eval-error:0.000456
#
# [50]	train-error:0.00033	eval-error:0.00043
#
# [51]	train-error:0.000314	eval-error:0.00043
#
# [52]	train-error:0.00029	eval-error:0.000399
#
# [53]	train-error:0.000285	eval-error:0.000396
#
# [54]	train-error:0.000277	eval-error:0.000385
#
# [55]	train-error:0.000255	eval-error:0.000357
#
# [56]	train-error:0.000232	eval-error:0.000337
#
# [57]	train-error:0.000229	eval-error:0.000337
#
# [58]	train-error:0.000176	eval-error:0.000272
#
# [59]	train-error:0.000174	eval-error:0.000261
#
# [60]	train-error:0.000173	eval-error:0.000261
#
# [61]	train-error:0.000169	eval-error:0.000255
#
# [62]	train-error:0.000164	eval-error:0.000252
#
# [63]	train-error:0.000142	eval-error:0.000229
#
# [64]	train-error:0.000133	eval-error:0.000227
#
# [65]	train-error:0.00013	eval-error:0.000221
#
# [66]	train-error:0.000127	eval-error:0.000218
#
# [67]	train-error:0.00011	eval-error:0.000201
#
# [68]	train-error:0.000108	eval-error:0.000184
#
# [69]	train-error:0.0001	eval-error:0.000173
#
# [70]	train-error:9.6e-05	eval-error:0.000164
#
# [71]	train-error:9.6e-05	eval-error:0.000161
#
# [72]	train-error:9.1e-05	eval-error:0.000147
#
# [73]	train-error:9.1e-05	eval-error:0.000147
#
# [74]	train-error:8.9e-05	eval-error:0.000144
#
# [75]	train-error:7.6e-05	eval-error:0.000113
#
# [76]	train-error:7.6e-05	eval-error:0.000116
#
# [77]	train-error:7.6e-05	eval-error:0.00011
#
# [78]	train-error:7.5e-05	eval-error:0.000105
#
# [79]	train-error:7.3e-05	eval-error:0.000105
#
# [80]	train-error:7.3e-05	eval-error:0.000105
#
# [81]	train-error:7.2e-05	eval-error:0.000102
#
# [82]	train-error:7.2e-05	eval-error:0.000105
#
# [83]	train-error:7.6e-05	eval-error:0.000113
#
# [84]	train-error:7.2e-05	eval-error:9.9e-05
#
# [85]	train-error:7.2e-05	eval-error:9.9e-05
#
# [86]	train-error:6.1e-05	eval-error:8.5e-05
#
# [87]	train-error:6.2e-05	eval-error:8.5e-05
#
# [88]	train-error:5.8e-05	eval-error:8.5e-05
#
# [89]	train-error:5.8e-05	eval-error:8.5e-05
#
# [90]	train-error:5.9e-05	eval-error:8.5e-05
#
# [91]	train-error:5.5e-05	eval-error:7.9e-05
#
# [92]	train-error:5.6e-05	eval-error:7.4e-05
#
# [93]	train-error:5e-05	eval-error:5.9e-05
#
# [94]	train-error:4.9e-05	eval-error:5.9e-05
#
# [95]	train-error:4.9e-05	eval-error:5.9e-05
#
# [96]	train-error:4.5e-05	eval-error:5.9e-05
#
# [97]	train-error:4.4e-05	eval-error:5.7e-05
#
# [98]	train-error:4.1e-05	eval-error:5.7e-05
#
# [99]	train-error:4e-05	eval-error:5.4e-05
#
# params: {'alpha': 0.004592569964142404, 'colsample_bytree': 0.75, 'gamma': 5.8252769637837384e-08, 'lambda': 0.02696701082348362, 'max_depth': 5, 'min_child_weight': 1.472817368068891, 'subsample': 0.75}, logloss: 0.00052832
# [0]	train-error:0.0017	eval-error:0.001736
#
# [1]	train-error:0.000954	eval-error:0.00096
#
# [2]	train-error:0.001623	eval-error:0.001577
#
# [3]	train-error:0.001053	eval-error:0.000997
#
# [4]	train-error:0.001078	eval-error:0.001079
#
# [5]	train-error:0.00109	eval-error:0.001124
#
# [6]	train-error:0.000895	eval-error:0.000937
#
# [7]	train-error:0.001012	eval-error:0.001099
#
# [8]	train-error:0.001	eval-error:0.001079
#
# [9]	train-error:0.000972	eval-error:0.001039
#
# [10]	train-error:0.000831	eval-error:0.000906
#
# [11]	train-error:0.000828	eval-error:0.000875
#
# [12]	train-error:0.000883	eval-error:0.00094
#
# [13]	train-error:0.00085	eval-error:0.00092
#
# [14]	train-error:0.00084	eval-error:0.00092
#
# [15]	train-error:0.000835	eval-error:0.000935
#
# [16]	train-error:0.000816	eval-error:0.000901
#
# [17]	train-error:0.000723	eval-error:0.000801
#
# [18]	train-error:0.000731	eval-error:0.000816
#
# [19]	train-error:0.000636	eval-error:0.000725
#
# [20]	train-error:0.000586	eval-error:0.000674
#
# [21]	train-error:0.000619	eval-error:0.0007
#
# [22]	train-error:0.000641	eval-error:0.000711
#
# [23]	train-error:0.000632	eval-error:0.000691
#
# [24]	train-error:0.000593	eval-error:0.000663
#
# [25]	train-error:0.000541	eval-error:0.000612
#
# [26]	train-error:0.000547	eval-error:0.000623
#
# [27]	train-error:0.00053	eval-error:0.000615
#
# [28]	train-error:0.00048	eval-error:0.000572
#
# [29]	train-error:0.000474	eval-error:0.000575
#
# [30]	train-error:0.000435	eval-error:0.000532
#
# [31]	train-error:0.000404	eval-error:0.000498
#
# [32]	train-error:0.000394	eval-error:0.000481
#
# [33]	train-error:0.000375	eval-error:0.00047
#
# [34]	train-error:0.00037	eval-error:0.000464
#
# [35]	train-error:0.000331	eval-error:0.000442
#
# [36]	train-error:0.000341	eval-error:0.000439
#
# [37]	train-error:0.00031	eval-error:0.000419
#
# [38]	train-error:0.00026	eval-error:0.000346
#
# [39]	train-error:0.000255	eval-error:0.000329
#
# [40]	train-error:0.000249	eval-error:0.000323
#
# [41]	train-error:0.000241	eval-error:0.000306
#
# [42]	train-error:0.000217	eval-error:0.000303
#
# [43]	train-error:0.00021	eval-error:0.000283
#
# [44]	train-error:0.000199	eval-error:0.00028
#
# [45]	train-error:0.000164	eval-error:0.000246
#
# [46]	train-error:0.000154	eval-error:0.000221
#
# [47]	train-error:0.000148	eval-error:0.000212
#
# [48]	train-error:0.000116	eval-error:0.00019
#
# [49]	train-error:0.000115	eval-error:0.000167
#
# [50]	train-error:9.9e-05	eval-error:0.000164
#
# [51]	train-error:8.1e-05	eval-error:0.00015
#
# [52]	train-error:8.1e-05	eval-error:0.00015
#
# [53]	train-error:8e-05	eval-error:0.00015
#
# [54]	train-error:7.5e-05	eval-error:0.000136
#
# [55]	train-error:7e-05	eval-error:0.000133
#
# [56]	train-error:6.9e-05	eval-error:0.00013
#
# [57]	train-error:6.2e-05	eval-error:0.00011
#
# [58]	train-error:5.3e-05	eval-error:0.000102
#
# [59]	train-error:5e-05	eval-error:9.3e-05
#
# [60]	train-error:4.9e-05	eval-error:9.6e-05
#
# [61]	train-error:4.7e-05	eval-error:9.9e-05
#
# [62]	train-error:4.8e-05	eval-error:9.3e-05
#
# [63]	train-error:4.8e-05	eval-error:9.3e-05
#
# [64]	train-error:4.4e-05	eval-error:7.9e-05
#
# [65]	train-error:4e-05	eval-error:7.6e-05
#
# [66]	train-error:4e-05	eval-error:7.4e-05
#
# [67]	train-error:3.9e-05	eval-error:7.4e-05
#
# [68]	train-error:3.9e-05	eval-error:7.1e-05
#
# [69]	train-error:3.5e-05	eval-error:5.7e-05
#
# [70]	train-error:3.3e-05	eval-error:5.1e-05
#
# [71]	train-error:3e-05	eval-error:4.5e-05
#
# [72]	train-error:2.9e-05	eval-error:4.2e-05
#
# [73]	train-error:2.6e-05	eval-error:4.2e-05
#
# [74]	train-error:2.6e-05	eval-error:4.2e-05
#
# [75]	train-error:2.7e-05	eval-error:4e-05
#
# [76]	train-error:2.6e-05	eval-error:3.7e-05
#
# [77]	train-error:2.1e-05	eval-error:3.4e-05
#
# [78]	train-error:2.2e-05	eval-error:3.1e-05
#
# [79]	train-error:1.9e-05	eval-error:2.8e-05
#
# [80]	train-error:1.8e-05	eval-error:2.8e-05
#
# [81]	train-error:1.8e-05	eval-error:3.1e-05
#
# [82]	train-error:1.8e-05	eval-error:2.8e-05
#
# [83]	train-error:1.8e-05	eval-error:2.5e-05
#
# [84]	train-error:1.7e-05	eval-error:2.5e-05
#
# [85]	train-error:1.7e-05	eval-error:2.8e-05
#
# [86]	train-error:1.7e-05	eval-error:2.3e-05
#
# [87]	train-error:1.6e-05	eval-error:2e-05
#
# [88]	train-error:1.3e-05	eval-error:2e-05
#
# [89]	train-error:1.3e-05	eval-error:2e-05
#
# [90]	train-error:1.3e-05	eval-error:2.3e-05
#
# [91]	train-error:1.2e-05	eval-error:2.3e-05
#
# [92]	train-error:1.1e-05	eval-error:2.3e-05
#
# [93]	train-error:1.1e-05	eval-error:2.3e-05
#
# [94]	train-error:1e-05	eval-error:2.3e-05
#
# [95]	train-error:9e-06	eval-error:2.3e-05
#
# [96]	train-error:9e-06	eval-error:2e-05
#
# [97]	train-error:8e-06	eval-error:2e-05
#
# [98]	train-error:8e-06	eval-error:2e-05
#
# [99]	train-error:8e-06	eval-error:2.3e-05
#
# params: {'alpha': 0.0029599725179655003, 'colsample_bytree': 0.65, 'gamma': 0.0015573377456512636, 'lambda': 0.03180886780980767, 'max_depth': 6, 'min_child_weight': 0.7673088712034022, 'subsample': 0.9500000000000001}, logloss: 0.00025613
# [0]	train-error:0.001749	eval-error:0.001815
#
# [1]	train-error:0.001454	eval-error:0.00158
#
# [2]	train-error:0.001942	eval-error:0.001985
#
# [3]	train-error:0.001044	eval-error:0.001065
#
# [4]	train-error:0.000963	eval-error:0.000963
#
# [5]	train-error:0.001068	eval-error:0.001093
#
# [6]	train-error:0.000808	eval-error:0.000872
#
# [7]	train-error:0.00105	eval-error:0.001127
#
# [8]	train-error:0.000806	eval-error:0.000869
#
# [9]	train-error:0.001005	eval-error:0.001059
#
# [10]	train-error:0.000978	eval-error:0.001042
#
# [11]	train-error:0.000965	eval-error:0.001039
#
# [12]	train-error:0.000809	eval-error:0.000895
#
# [13]	train-error:0.000919	eval-error:0.001005
#
# [14]	train-error:0.00076	eval-error:0.000833
#
# [15]	train-error:0.000754	eval-error:0.00083
#
# [16]	train-error:0.000767	eval-error:0.000847
#
# [17]	train-error:0.000722	eval-error:0.00081
#
# [18]	train-error:0.000639	eval-error:0.000731
#
# [19]	train-error:0.000629	eval-error:0.000719
#
# [20]	train-error:0.000627	eval-error:0.000714
#
# [21]	train-error:0.000661	eval-error:0.000748
#
# [22]	train-error:0.000661	eval-error:0.000748
#
# [23]	train-error:0.00059	eval-error:0.000683
#
# [24]	train-error:0.000589	eval-error:0.00068
#
# [25]	train-error:0.000586	eval-error:0.000677
#
# [26]	train-error:0.000575	eval-error:0.000674
#
# [27]	train-error:0.000568	eval-error:0.000663
#
# [28]	train-error:0.000554	eval-error:0.000646
#
# [29]	train-error:0.000547	eval-error:0.000637
#
# [30]	train-error:0.00054	eval-error:0.000632
#
# [31]	train-error:0.000528	eval-error:0.000617
#
# [32]	train-error:0.000474	eval-error:0.000572
#
# [33]	train-error:0.000454	eval-error:0.000549
#
# [34]	train-error:0.00043	eval-error:0.000524
#
# [35]	train-error:0.000406	eval-error:0.000496
#
# [36]	train-error:0.000404	eval-error:0.00049
#
# [37]	train-error:0.000398	eval-error:0.000484
#
# [38]	train-error:0.000365	eval-error:0.00045
#
# [39]	train-error:0.000389	eval-error:0.000476
#
# [40]	train-error:0.000388	eval-error:0.000479
#
# [41]	train-error:0.000338	eval-error:0.000422
#
# [42]	train-error:0.000293	eval-error:0.000377
#
# [43]	train-error:0.000289	eval-error:0.000371
#
# [44]	train-error:0.000257	eval-error:0.00034
#
# [45]	train-error:0.000225	eval-error:0.000306
#
# [46]	train-error:0.000223	eval-error:0.000306
#
# [47]	train-error:0.000217	eval-error:0.000303
#
# [48]	train-error:0.00021	eval-error:0.0003
#
# [49]	train-error:0.000196	eval-error:0.00028
#
# [50]	train-error:0.000171	eval-error:0.000263
#
# [51]	train-error:0.000164	eval-error:0.000241
#
# [52]	train-error:0.000155	eval-error:0.000229
#
# [53]	train-error:0.000161	eval-error:0.000232
#
# [54]	train-error:0.000147	eval-error:0.000218
#
# [55]	train-error:0.000122	eval-error:0.000181
#
# [56]	train-error:0.000117	eval-error:0.00017
#
# [57]	train-error:0.000112	eval-error:0.000159
#
# [58]	train-error:0.00011	eval-error:0.000147
#
# [59]	train-error:0.000103	eval-error:0.000144
#
# [60]	train-error:9.3e-05	eval-error:0.00013
#
# [61]	train-error:8.6e-05	eval-error:0.000125
#
# [62]	train-error:7.4e-05	eval-error:0.000102
#
# [63]	train-error:7.3e-05	eval-error:9.9e-05
#
# [64]	train-error:7.2e-05	eval-error:9.9e-05
#
# [65]	train-error:6.9e-05	eval-error:9.3e-05
#
# [66]	train-error:6.7e-05	eval-error:8.8e-05
#
# [67]	train-error:7e-05	eval-error:9.6e-05
#
# [68]	train-error:6.7e-05	eval-error:8.8e-05
#
# [69]	train-error:6.2e-05	eval-error:8.2e-05
#
# [70]	train-error:5e-05	eval-error:6.8e-05
#
# [71]	train-error:4.5e-05	eval-error:6.2e-05
#
# [72]	train-error:4.3e-05	eval-error:6.2e-05
#
# [73]	train-error:4.3e-05	eval-error:6.2e-05
#
# [74]	train-error:4.3e-05	eval-error:6.2e-05
#
# [75]	train-error:4.2e-05	eval-error:6.2e-05
#
# [76]	train-error:4.2e-05	eval-error:6.2e-05
#
# [77]	train-error:4e-05	eval-error:6.2e-05
#
# [78]	train-error:3.9e-05	eval-error:5.9e-05
#
# [79]	train-error:3.7e-05	eval-error:5.4e-05
#
# [80]	train-error:3.6e-05	eval-error:5.4e-05
#
# [81]	train-error:3.5e-05	eval-error:5.4e-05
#
# [82]	train-error:3.4e-05	eval-error:5.1e-05
#
# [83]	train-error:3.3e-05	eval-error:5.1e-05
#
# [84]	train-error:3.2e-05	eval-error:5.1e-05
#
# [85]	train-error:3.3e-05	eval-error:4.8e-05
#
# [86]	train-error:3.1e-05	eval-error:4.5e-05
#
# [87]	train-error:3e-05	eval-error:4.2e-05
#
# [88]	train-error:2.5e-05	eval-error:4.2e-05
#
# [89]	train-error:2.4e-05	eval-error:4.2e-05
#
# [90]	train-error:2.4e-05	eval-error:4e-05
#
# [91]	train-error:2.3e-05	eval-error:3.7e-05
#
# [92]	train-error:2.3e-05	eval-error:3.7e-05
#
# [93]	train-error:2.3e-05	eval-error:3.7e-05
#
# [94]	train-error:2.2e-05	eval-error:3.7e-05
#
# [95]	train-error:2.2e-05	eval-error:3.7e-05
#
# [96]	train-error:2.1e-05	eval-error:3.7e-05
#
# [97]	train-error:2.1e-05	eval-error:3.7e-05
#
# [98]	train-error:2e-05	eval-error:3.7e-05
#
# [99]	train-error:2e-05	eval-error:3.7e-05
#
# params: {'alpha': 0.0006611233674120149, 'colsample_bytree': 0.8, 'gamma': 0.0011748123256970988, 'lambda': 4.2545664097550535, 'max_depth': 6, 'min_child_weight': 1.2873252046402242, 'subsample': 0.75}, logloss: 0.00033666
# [0]	train-error:0.000878	eval-error:0.00096
#
# [1]	train-error:0.000562	eval-error:0.000654
#
# [2]	train-error:0.000673	eval-error:0.000782
#
# [3]	train-error:0.000597	eval-error:0.000674
#
# [4]	train-error:0.000522	eval-error:0.000612
#
# [5]	train-error:0.00046	eval-error:0.000535
#
# [6]	train-error:0.000432	eval-error:0.00051
#
# [7]	train-error:0.000417	eval-error:0.000493
#
# [8]	train-error:0.000408	eval-error:0.00047
#
# [9]	train-error:0.0004	eval-error:0.000479
#
# [10]	train-error:0.00037	eval-error:0.000439
#
# [11]	train-error:0.000362	eval-error:0.000422
#
# [12]	train-error:0.000364	eval-error:0.000419
#
# [13]	train-error:0.000349	eval-error:0.000413
#
# [14]	train-error:0.000302	eval-error:0.000368
#
# [15]	train-error:0.000278	eval-error:0.000357
#
# [16]	train-error:0.000259	eval-error:0.00032
#
# [17]	train-error:0.00024	eval-error:0.000297
#
# [18]	train-error:0.000118	eval-error:0.000178
#
# [19]	train-error:0.000158	eval-error:0.000201
#
# [20]	train-error:0.000118	eval-error:0.000173
#
# [21]	train-error:0.000115	eval-error:0.000161
#
# [22]	train-error:0.000105	eval-error:0.00015
#
# [23]	train-error:0.000101	eval-error:0.000144
#
# [24]	train-error:9.6e-05	eval-error:0.000139
#
# [25]	train-error:8.5e-05	eval-error:0.000119
#
# [26]	train-error:8.5e-05	eval-error:0.000119
#
# [27]	train-error:8.4e-05	eval-error:0.000119
#
# [28]	train-error:7.7e-05	eval-error:0.000116
#
# [29]	train-error:7.2e-05	eval-error:0.000108
#
# [30]	train-error:7e-05	eval-error:0.00011
#
# [31]	train-error:7e-05	eval-error:0.000108
#
#  14%|█▍        | 14/100 [1:03:05<5:46:31, 241.76s/it, best loss: 0.00010280597985864335]

# %%
# xgboostの実装
# -----------------------------------
import xgboost as xgb
from sklearn.metrics import log_loss

# 特徴量と目的変数をxgboostのデータ構造に変換する
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(va_x,label=va_y)
dtest = xgb.DMatrix(test_x)

# %%
# 学習データとバリデーションデータのスコアのモニタリング
# -----------------------------------
# モニタリングをloglossで行い、アーリーストッピングの観察するroundを20とする
params = {
    'booster': 'gbtree',
    'objective': 'binary:logistic',
    'eta': 0.1,
    'gamma': 0.00014307741815837628,
    'alpha':  0.0002857624279734903,
    'lambda': 0.00010908892137476965,
    'min_child_weight': 1.4034295969588149,
    'max_depth': 9,
    'subsample': 0.95,
    'colsample_bytree': 0.95,
    'random_state': 71,
    #上記で取得したパラメータ
}
num_round = 5000
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
model = xgb.train(params, dtrain, num_round, evals=watchlist,
                  early_stopping_rounds=50)
# Out:
# [0]	train-error:0.000903	eval-error:0.000957
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 50 rounds.
# [1]	train-error:0.000436	eval-error:0.000447
# [2]	train-error:0.000462	eval-error:0.000487
# [3]	train-error:0.000434	eval-error:0.000462
# [4]	train-error:0.000432	eval-error:0.000453
# [5]	train-error:0.00043	eval-error:0.00045
# [6]	train-error:0.000399	eval-error:0.000425
# [7]	train-error:0.000387	eval-error:0.000411
# [8]	train-error:0.00039	eval-error:0.000419
# [9]	train-error:0.000368	eval-error:0.000399
# [10]	train-error:0.000359	eval-error:0.000391
# [11]	train-error:0.000349	eval-error:0.000377
# [12]	train-error:0.00033	eval-error:0.000368
# [13]	train-error:0.000292	eval-error:0.000323
# [14]	train-error:0.000219	eval-error:0.000249
# [15]	train-error:0.000169	eval-error:0.00021
# [16]	train-error:0.000134	eval-error:0.000161
# [17]	train-error:0.000141	eval-error:0.000176
# [18]	train-error:0.00013	eval-error:0.000156
# [19]	train-error:0.000117	eval-error:0.000147
# [20]	train-error:0.000113	eval-error:0.000147
# [21]	train-error:0.000103	eval-error:0.000133
# [22]	train-error:9.4e-05	eval-error:0.000119
# [23]	train-error:9.3e-05	eval-error:0.000125
# [24]	train-error:8.6e-05	eval-error:0.000122
# [25]	train-error:8.4e-05	eval-error:0.000119
# [26]	train-error:7.9e-05	eval-error:0.000108
# [27]	train-error:7.9e-05	eval-error:0.000105
# [28]	train-error:6.9e-05	eval-error:8.8e-05
# [29]	train-error:6.7e-05	eval-error:8.8e-05
# [30]	train-error:6e-05	eval-error:7.1e-05
# [31]	train-error:5.9e-05	eval-error:7.1e-05
# [32]	train-error:4.6e-05	eval-error:5.1e-05
# [33]	train-error:4.3e-05	eval-error:5.1e-05
# [34]	train-error:4e-05	eval-error:4.8e-05
# [35]	train-error:3.5e-05	eval-error:4.5e-05
# [36]	train-error:2.9e-05	eval-error:3.4e-05
# [37]	train-error:2.4e-05	eval-error:1.7e-05
# [38]	train-error:2.3e-05	eval-error:1.4e-05
# [39]	train-error:2.3e-05	eval-error:1.4e-05
# [40]	train-error:2.2e-05	eval-error:1.4e-05
# [41]	train-error:2.1e-05	eval-error:1.1e-05
# [42]	train-error:1.8e-05	eval-error:1.1e-05
# [43]	train-error:1.7e-05	eval-error:8e-06
# [44]	train-error:1.6e-05	eval-error:8e-06
# [45]	train-error:1.2e-05	eval-error:8e-06
# [46]	train-error:1e-05	eval-error:8e-06
# [47]	train-error:1e-05	eval-error:8e-06
# [48]	train-error:9e-06	eval-error:6e-06
# [49]	train-error:8e-06	eval-error:6e-06
# [50]	train-error:6e-06	eval-error:6e-06
# [51]	train-error:6e-06	eval-error:6e-06
# [52]	train-error:5e-06	eval-error:6e-06
# [53]	train-error:5e-06	eval-error:6e-06
# [54]	train-error:4e-06	eval-error:3e-06
# [55]	train-error:4e-06	eval-error:3e-06
# [56]	train-error:4e-06	eval-error:3e-06
# [57]	train-error:4e-06	eval-error:3e-06
# [58]	train-error:4e-06	eval-error:3e-06
# [59]	train-error:4e-06	eval-error:3e-06
# [60]	train-error:4e-06	eval-error:3e-06
# [61]	train-error:4e-06	eval-error:3e-06
# [62]	train-error:4e-06	eval-error:3e-06
# [63]	train-error:4e-06	eval-error:3e-06
# [64]	train-error:4e-06	eval-error:3e-06
# [65]	train-error:4e-06	eval-error:3e-06
# [66]	train-error:4e-06	eval-error:3e-06
# [67]	train-error:4e-06	eval-error:3e-06
# [68]	train-error:4e-06	eval-error:3e-06
# [69]	train-error:4e-06	eval-error:3e-06
# [70]	train-error:4e-06	eval-error:3e-06
# [71]	train-error:4e-06	eval-error:3e-06
# [72]	train-error:4e-06	eval-error:3e-06
# [73]	train-error:4e-06	eval-error:3e-06
# [74]	train-error:3e-06	eval-error:3e-06
# [75]	train-error:3e-06	eval-error:3e-06
# [76]	train-error:3e-06	eval-error:3e-06
# [77]	train-error:3e-06	eval-error:3e-06
# [78]	train-error:3e-06	eval-error:3e-06
# [79]	train-error:3e-06	eval-error:3e-06
# [80]	train-error:3e-06	eval-error:3e-06
# [81]	train-error:3e-06	eval-error:3e-06
# [82]	train-error:3e-06	eval-error:3e-06
# [83]	train-error:3e-06	eval-error:3e-06
# [84]	train-error:3e-06	eval-error:3e-06
# [85]	train-error:3e-06	eval-error:3e-06
# [86]	train-error:3e-06	eval-error:3e-06
# [87]	train-error:3e-06	eval-error:3e-06
# [88]	train-error:3e-06	eval-error:3e-06
# [89]	train-error:3e-06	eval-error:3e-06
# [90]	train-error:2e-06	eval-error:3e-06
# [91]	train-error:2e-06	eval-error:3e-06
# [92]	train-error:2e-06	eval-error:3e-06
# [93]	train-error:2e-06	eval-error:3e-06
# [94]	train-error:3e-06	eval-error:3e-06
# [95]	train-error:2e-06	eval-error:3e-06
# [96]	train-error:2e-06	eval-error:3e-06
# [97]	train-error:2e-06	eval-error:3e-06
# [98]	train-error:2e-06	eval-error:3e-06
# [99]	train-error:2e-06	eval-error:3e-06
# [100]	train-error:2e-06	eval-error:3e-06
# [101]	train-error:2e-06	eval-error:3e-06
# [102]	train-error:2e-06	eval-error:3e-06
# [103]	train-error:2e-06	eval-error:3e-06
# [104]	train-error:2e-06	eval-error:3e-06
# Stopping. Best iteration:
# [54]	train-error:4e-06	eval-error:3e-06

# %%
# バリデーションデータでのスコアの確認
va_pred = model.predict(dvalid)
score = log_loss(va_y, va_pred)
print(f'logloss: {score:.8f}')
# Out:
# logloss: 0.00003853

# %%
# 構築したモデルの保存
import pickle
file = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_26_param_tuning6.pkl'
pickle.dump(model, open(file, 'wb'))

# 学習済みモデルを削除
del model

# %%
#from モジュール名 import クラス名（もしくは関数名や変数名）
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlibをinlineで表示するためのおまじない (plt.show()しなくていい)
# %matplotlib inline

# %%
# 構築したモデルの読み込み
import pickle
filename = '/content/drive/MyDrive/Nishika ソフトウェアの異常検知/モデル/xgboost_trained_model_26_param_tuning6.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# submission csvファイルの読み込み
submission_df = pd.read_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/data.zip (Unzipped Files)/sample_submission.csv')

# %%
id_df=submission_df.iloc[:,0]
id_df.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: id, dtype: int64

# %%
pred=loaded_model.predict(dtest,ntree_limit=loaded_model.best_ntree_limit)

# %%
pred_df = pd.DataFrame(pred)
pred_df.head()
# Out:
#           0
# 0  0.001972
# 1  0.001972
# 2  0.001972
# 3  0.001972
# 4  0.001972

# %%
output_df=pd.concat([id_df, pred_df],axis=1)
output_df.columns=['id','Anomaly']
output_df.head()
# Out:
#    id   Anomaly
# 0   0  0.001972
# 1   1  0.001972
# 2   2  0.001972
# 3   3  0.001972
# 4   4  0.001972

# %%
output_df.to_csv('/content/drive/MyDrive/Nishika ソフトウェアの異常検知/提出用ファイル/model_26_param_tuning6.csv',index=False)
